# %%
############################ 0. PREPARATION ############################

#-------------------------- import packages --------------------------
import random
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from itertools import combinations
import seaborn as sns
import copy
import itertools

import tensorflow as tf
import tensorflow_lattice as tfl
import tf_keras as keras # need keras 2 to fit Lattice model
from tf_keras.models import Sequential, Model
from tf_keras.layers import Dense, Input, Multiply, Add, Embedding, Reshape, Concatenate, Dropout, BatchNormalization, Lambda, Layer, CategoryEncoding, Activation
from tf_keras.constraints import Constraint
from tf_keras.callbacks import EarlyStopping
from tf_keras.initializers import Zeros, Constant
from tf_keras.optimizers import Adam, Nadam, RMSprop
from tf_keras.models import clone_model
import keras_tuner as kt
from tf_keras import backend as K
from tf_keras import regularizers
from tf_keras.utils import plot_model
from tf_keras.losses import Poisson, Loss
from tf_keras.metrics import MeanAbsoluteError, RootMeanSquaredError
from scipy.stats import gamma


from pygam import LinearGAM, GAM, s, f, l
from sklearn.linear_model import ElasticNet
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error as mae
from sklearn.tree import DecisionTreeRegressor
from interpret.glassbox import ExplainableBoostingClassifier

# %%
#-------------------------- for reproducibility --------------------------
seed_value = 28
keras.utils.set_random_seed(seed_value)

# %%
#-------------------------- import data --------------------------
data = pd.read_csv("synthetic_high_var.csv")

# %%
#-------------------------- remove outliers --------------------------
log_claim = np.log(data['Y'])
IQR = log_claim.quantile(0.75) - log_claim.quantile(0.25) # inter-quartile range
lower_whisker = log_claim.quantile(0.25)- 1.5*IQR
upper_whisker = log_claim.quantile(0.75) + 1.5*IQR

# remove outliers: filter rows where the log of 'Y' is within the whiskers
dt_cleaned = data[(log_claim >= lower_whisker) & (log_claim <= upper_whisker)]
dt_cleaned
# Out:
#              X1        X2        X3        X4        X5        X6        X7  \
# 0      0.097627 -0.215654 -0.261487  0.855910 -0.977807  0.070514  0.247397
# 1      0.430379 -0.917687 -0.577348  0.805874 -0.996460  0.808088 -0.727145
# 2      0.205527  0.846601 -0.046190 -0.144766 -0.689890  0.004793  0.787168
# 3      0.089766 -0.187530 -0.835531  0.021611 -0.366478 -0.798260 -0.363850
# 4     -0.152690  0.888564 -0.524681  0.166400  0.303690  0.055164  0.158018
# ...         ...       ...       ...       ...       ...       ...       ...
# 19995  0.496349  0.336766  0.766494 -0.723110  0.451842 -0.547824  0.165682
# 19996 -0.403467  0.989823 -0.239838  0.690306  0.015041  0.168038 -0.808643
# 19997 -0.107088  0.176448 -0.661992  0.568246  0.620266  0.669292 -0.267906
# 19998 -0.279747 -0.150770 -0.472139  0.238510  0.102065 -0.832383  0.539168
# 19999  0.251773  0.803265 -0.397666 -0.684942 -0.548488 -0.791774 -0.620137
#
#              X8        X9       X10             Y
# 0     -0.844805 -0.633014  0.932805   5807.221783
# 1      0.592222  0.416902  0.949203    123.051416
# 2     -0.029304 -0.254262 -0.739165   4631.966402
# 3      0.669637 -0.150974  0.020263     98.022434
# 4      0.046901 -0.468522 -0.772319   1040.200506
# ...         ...       ...       ...           ...
# 19995 -0.515032  0.372611 -0.262674    230.804310
# 19996 -0.903895 -0.433667 -0.389854    286.076124
# 19997  0.006409  0.871063 -0.570751   8394.179570
# 19998  0.073274  0.110462 -0.408447      0.003924
# 19999  0.197031 -0.409905  0.685008  17280.039276
#
# [19159 rows x 11 columns]

# %%
#-------------------------- distribution of log(response) --------------------------
plt.figure(figsize = (10, 6)) # set the size of the figure
sns.set_style("darkgrid")
sns.histplot(np.log(dt_cleaned['Y']), bins = 30, kde = True) # draw the chart
plt.title('Distribution of log(Y)')
plt.xlabel('Log(Y)')
plt.ylabel('Frequency')
plt.tick_params(axis = 'x')
plt.tick_params(axis = 'y')
plt.grid(True)
plt.show()

# %%
#-------------------------- column lists --------------------------
target_var = "Y" # target feature
all_vars = list(dt_cleaned.columns)
all_vars.remove(target_var) # store all input features
cat_vars = [] # categorical features

# %%
############################ 1. MODEL FITTING ############################

#-------------------------- train-test split --------------------------
X_main, X_test, y_main, y_test = train_test_split(
    dt_cleaned[all_vars], dt_cleaned[["Y"]], test_size = 0.2, random_state = 1)
X_train, X_val, y_train, y_val  = train_test_split(
    X_main, y_main, test_size = 0.25, random_state = 1)

# %%
# -------------------------- function to create a subnetwork --------------------------
# subnet for numerical variables
def create_subnet(num_layers, units_per_layer, activation, model_name, dropout_rate = 0, trainable = True, seed = 1):
    model = Sequential(name = model_name)
    for _ in range(num_layers):
        model.add(Dense(units_per_layer, activation = activation, trainable = trainable))
        model.add(Dropout(dropout_rate, seed = seed))
    model.add(Dense(1, trainable = trainable))
    model.add(BatchNormalization(scale = False)) # for identifiability
    return model

# layer to add all subnets' outputs and a bias term
@keras.saving.register_keras_serializable()
class AddSubnetOutput(Layer):
    def __init__(self, activation = None, **kwargs):
        super().__init__(**kwargs)
        self.activation = keras.activations.get(activation)
        self.bias = self.add_weight(
            shape = (1,), initializer = 'zeros', trainable = True, name = 'bias'
        )   
    def call(self, inputs):
        subnet_sum = K.sum(inputs, axis = -1, keepdims = True)
        output = subnet_sum + self.bias
        if self.activation is not None:
            output = self.activation(output)
        return output

# %%
# -------------------------- define model architecture --------------------------
inputs = []  # input layers
sub_outputs_main = []  # main effect subnet output
num_neurons_main = 10
num_layers_main = 2
activation = 'leaky_relu'
keypoints = 10
monotonicity_list = {"X3" : "decreasing"} # either "increasing", "decreasing", or "none"

# main effect
for name in all_vars:
    input_layer = Input(shape = (1,), name = name)
    inputs.append(input_layer)

    # subnetworks for main effects
    if name in cat_vars: # categorical variables
        # categorical variables will be one-hot encoded
        embed_layer = Embedding(input_dim = X_train[name].nunique(), 
                                output_dim = 1, 
                                name = f"{name}_embed")(input_layer)
        embed_layer_reshape = Reshape(target_shape = (1,), name = f"{name}_reshape")(embed_layer)
        mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(embed_layer_reshape)
        sub_outputs_main.append(mean_layer)
    elif name in monotonicity_list: # variables with monotonicity constraint
        calibrator_layer = tfl.layers.PWLCalibration(
            input_keypoints =  np.linspace(X_train[name].min(), X_train[name].max(), num = keypoints), # keypoints
            monotonicity = monotonicity_list[name], # monotonicity constraint
            name = f"{name}_pwlcalibrator"
        )(input_layer)
        mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(calibrator_layer)
        sub_outputs_main.append(mean_layer)
    else: # numeric variables
        subnet = create_subnet(num_layers_main, num_neurons_main, activation, f"{name}_subnetwork")
        sub_output = subnet(input_layer)
        sub_outputs_main.append(sub_output)

# combine subnets' outputs
main_subnets = Concatenate(name = "main_subnet")(sub_outputs_main)
final_output = AddSubnetOutput(activation = 'exponential',
                     name = "main_output")(main_subnets)

# final model
model_main_effect = Model(inputs = inputs, outputs = final_output)

# %%
plot_model(model_main_effect)

# %%
# -------------------------- define loss function --------------------------
# we will use a Gamma loss function
def gamma_nll(y_true, y_pred):
    y_pred = K.clip(y_pred, 1e-7, 1e30)
    return K.mean(y_true/y_pred - K.log(y_true/y_pred))

# create training & validation data consistent with the model architecture
X_train_split = []
X_val_split = []
X_test_split = []
for i in range(len(X_train.columns)):
    X_train_split.append(X_train.iloc[:, i])
    X_val_split.append(X_val.iloc[:, i])
    X_test_split.append(X_test.iloc[:, i])

# compile and fit
model_main_effect.compile(optimizer = "rmsprop", loss = gamma_nll, metrics = [RootMeanSquaredError()])
es = EarlyStopping(restore_best_weights = True, patience = 10)
# %time hist_main = model_main_effect.fit(X_train_split, y_train, epochs = 5_000, \
    callbacks = [es], batch_size = 1_000, validation_data = (X_val_split, y_val))
# Out:
# Epoch 1/5000
# 12/12 [==============================] - 2s 24ms/step - loss: 20016.1680 - root_mean_squared_error: 4451.6030 - val_loss: 1015.5277 - val_root_mean_squared_error: 4317.9731
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 11615.3301 - root_mean_squared_error: 4410.9956 - val_loss: 935.5793 - val_root_mean_squared_error: 4317.9517
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 8536.3721 - root_mean_squared_error: 4362.1426 - val_loss: 883.9492 - val_root_mean_squared_error: 4317.9351
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 5647.2993 - root_mean_squared_error: 4372.9248 - val_loss: 804.6866 - val_root_mean_squared_error: 4317.9082
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4076.0942 - root_mean_squared_error: 4355.7461 - val_loss: 756.8617 - val_root_mean_squared_error: 4317.8916
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2822.8594 - root_mean_squared_error: 4326.3584 - val_loss: 676.6306 - val_root_mean_squared_error: 4317.8608
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2080.0627 - root_mean_squared_error: 4318.6055 - val_loss: 622.0577 - val_root_mean_squared_error: 4317.8350
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 1495.9125 - root_mean_squared_error: 4315.8281 - val_loss: 535.9839 - val_root_mean_squared_error: 4317.7900
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 1094.3062 - root_mean_squared_error: 4315.2476 - val_loss: 449.4955 - val_root_mean_squared_error: 4317.7231
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 745.3427 - root_mean_squared_error: 4315.4629 - val_loss: 368.7750 - val_root_mean_squared_error: 4317.6372
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 474.4004 - root_mean_squared_error: 4315.8579 - val_loss: 325.6722 - val_root_mean_squared_error: 4317.5674
# Epoch 12/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 357.4342 - root_mean_squared_error: 4316.4087 - val_loss: 311.3347 - val_root_mean_squared_error: 4317.5386
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 287.7744 - root_mean_squared_error: 4316.3140 - val_loss: 289.2103 - val_root_mean_squared_error: 4317.4883
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 241.4318 - root_mean_squared_error: 4316.2710 - val_loss: 259.7490 - val_root_mean_squared_error: 4317.4087
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 201.8937 - root_mean_squared_error: 4316.0044 - val_loss: 226.1449 - val_root_mean_squared_error: 4317.2915
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 162.7896 - root_mean_squared_error: 4315.9888 - val_loss: 204.9458 - val_root_mean_squared_error: 4317.1982
# Epoch 17/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 138.8146 - root_mean_squared_error: 4315.6733 - val_loss: 175.6371 - val_root_mean_squared_error: 4317.0312
# Epoch 18/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 117.0770 - root_mean_squared_error: 4315.2358 - val_loss: 131.4475 - val_root_mean_squared_error: 4316.6367
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 102.0208 - root_mean_squared_error: 4314.8579 - val_loss: 117.0321 - val_root_mean_squared_error: 4316.4458
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 89.3624 - root_mean_squared_error: 4314.4399 - val_loss: 111.6725 - val_root_mean_squared_error: 4316.3564
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 80.4265 - root_mean_squared_error: 4313.4902 - val_loss: 89.8492 - val_root_mean_squared_error: 4315.9023
# Epoch 22/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 69.1584 - root_mean_squared_error: 4312.5981 - val_loss: 87.1135 - val_root_mean_squared_error: 4315.8306
# Epoch 23/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 61.4415 - root_mean_squared_error: 4312.0703 - val_loss: 73.2459 - val_root_mean_squared_error: 4315.3730
# Epoch 24/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 54.2499 - root_mean_squared_error: 4311.2583 - val_loss: 65.1361 - val_root_mean_squared_error: 4315.0093
# Epoch 25/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 48.3812 - root_mean_squared_error: 4309.7173 - val_loss: 46.2851 - val_root_mean_squared_error: 4313.6851
# Epoch 26/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 42.1921 - root_mean_squared_error: 4309.1167 - val_loss: 52.3354 - val_root_mean_squared_error: 4314.1899
# Epoch 27/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 38.6456 - root_mean_squared_error: 4307.5308 - val_loss: 47.6140 - val_root_mean_squared_error: 4313.7974
# Epoch 28/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 33.7481 - root_mean_squared_error: 4306.7065 - val_loss: 40.9298 - val_root_mean_squared_error: 4312.9980
# Epoch 29/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 30.4059 - root_mean_squared_error: 4304.0786 - val_loss: 37.5540 - val_root_mean_squared_error: 4312.5454
# Epoch 30/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 26.8657 - root_mean_squared_error: 4303.1387 - val_loss: 29.3764 - val_root_mean_squared_error: 4310.8853
# Epoch 31/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 23.9302 - root_mean_squared_error: 4300.5933 - val_loss: 26.9700 - val_root_mean_squared_error: 4310.1177
# Epoch 32/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 21.3434 - root_mean_squared_error: 4298.3984 - val_loss: 24.2685 - val_root_mean_squared_error: 4309.1943
# Epoch 33/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 19.0618 - root_mean_squared_error: 4296.2690 - val_loss: 26.3240 - val_root_mean_squared_error: 4309.7651
# Epoch 34/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 17.1095 - root_mean_squared_error: 4292.0283 - val_loss: 23.3880 - val_root_mean_squared_error: 4308.6479
# Epoch 35/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 15.6149 - root_mean_squared_error: 4290.3955 - val_loss: 21.9110 - val_root_mean_squared_error: 4307.9849
# Epoch 36/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 13.9081 - root_mean_squared_error: 4286.1587 - val_loss: 23.6780 - val_root_mean_squared_error: 4308.7031
# Epoch 37/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 12.6947 - root_mean_squared_error: 4283.7461 - val_loss: 23.2146 - val_root_mean_squared_error: 4308.3799
# Epoch 38/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 11.7287 - root_mean_squared_error: 4278.7500 - val_loss: 14.3239 - val_root_mean_squared_error: 4301.3467
# Epoch 39/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 10.4613 - root_mean_squared_error: 4273.8389 - val_loss: 17.1381 - val_root_mean_squared_error: 4304.0942
# Epoch 40/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 9.5180 - root_mean_squared_error: 4267.2407 - val_loss: 18.8047 - val_root_mean_squared_error: 4305.3535
# Epoch 41/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 8.7966 - root_mean_squared_error: 4262.9165 - val_loss: 19.4606 - val_root_mean_squared_error: 4305.7427
# Epoch 42/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 8.1478 - root_mean_squared_error: 4255.6704 - val_loss: 20.4043 - val_root_mean_squared_error: 4306.4087
# Epoch 43/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 7.5175 - root_mean_squared_error: 4250.8354 - val_loss: 22.4605 - val_root_mean_squared_error: 4307.3672
# Epoch 44/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 7.1099 - root_mean_squared_error: 4245.6440 - val_loss: 21.1415 - val_root_mean_squared_error: 4306.0303
# Epoch 45/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 6.5766 - root_mean_squared_error: 4238.0894 - val_loss: 13.7284 - val_root_mean_squared_error: 4298.5430
# Epoch 46/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 6.2585 - root_mean_squared_error: 4225.1367 - val_loss: 12.3406 - val_root_mean_squared_error: 4296.0220
# Epoch 47/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 5.9211 - root_mean_squared_error: 4219.9897 - val_loss: 6.6834 - val_root_mean_squared_error: 4263.7041
# Epoch 48/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 5.7207 - root_mean_squared_error: 4217.8848 - val_loss: 10.3890 - val_root_mean_squared_error: 4288.2188
# Epoch 49/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 5.5023 - root_mean_squared_error: 4211.4521 - val_loss: 6.1003 - val_root_mean_squared_error: 4252.2319
# Epoch 50/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 5.2674 - root_mean_squared_error: 4201.7573 - val_loss: 8.4849 - val_root_mean_squared_error: 4279.3965
# Epoch 51/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 5.1312 - root_mean_squared_error: 4198.9482 - val_loss: 6.6652 - val_root_mean_squared_error: 4253.7407
# Epoch 52/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 5.0610 - root_mean_squared_error: 4201.0527 - val_loss: 6.0843 - val_root_mean_squared_error: 4247.7544
# Epoch 53/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.9088 - root_mean_squared_error: 4201.5576 - val_loss: 4.9425 - val_root_mean_squared_error: 4195.5850
# Epoch 54/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.8540 - root_mean_squared_error: 4198.1860 - val_loss: 5.0187 - val_root_mean_squared_error: 4200.8271
# Epoch 55/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8144 - root_mean_squared_error: 4199.9771 - val_loss: 4.8197 - val_root_mean_squared_error: 4179.5820
# Epoch 56/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7634 - root_mean_squared_error: 4214.5449 - val_loss: 4.7659 - val_root_mean_squared_error: 4165.6616
# Epoch 57/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7524 - root_mean_squared_error: 4227.9399 - val_loss: 4.8433 - val_root_mean_squared_error: 4301.6255
# Epoch 58/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7158 - root_mean_squared_error: 4281.0103 - val_loss: 5.7387 - val_root_mean_squared_error: 8674.4785
# Epoch 59/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7181 - root_mean_squared_error: 4294.2041 - val_loss: 5.5842 - val_root_mean_squared_error: 6579.2485
# Epoch 60/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7073 - root_mean_squared_error: 4271.9487 - val_loss: 5.3184 - val_root_mean_squared_error: 5616.5425
# Epoch 61/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7203 - root_mean_squared_error: 4291.2607 - val_loss: 5.2607 - val_root_mean_squared_error: 5496.6089
# Epoch 62/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7113 - root_mean_squared_error: 4287.8843 - val_loss: 4.9865 - val_root_mean_squared_error: 4894.5420
# Epoch 63/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7074 - root_mean_squared_error: 4321.4102 - val_loss: 5.4800 - val_root_mean_squared_error: 7479.8125
# Epoch 64/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7151 - root_mean_squared_error: 4319.3301 - val_loss: 5.5842 - val_root_mean_squared_error: 8185.6992
# Epoch 65/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.6971 - root_mean_squared_error: 4351.2798 - val_loss: 5.7267 - val_root_mean_squared_error: 10199.7275
# Epoch 66/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7206 - root_mean_squared_error: 4393.9438 - val_loss: 5.5473 - val_root_mean_squared_error: 8082.9370
# CPU times: user 6.3 s, sys: 641 ms, total: 6.94 s
# Wall time: 5.58 s

# %%
# -------------------------- get validation loss --------------------------
main_val_loss, main_rmse = model_main_effect.evaluate(X_val_split, y_val, verbose = False) # get the validation loss and RMSE
print(f"Validation loss for main effect: {main_val_loss}")
print(f"Validation RMSE for main effect: {main_rmse}")
# Out:
# Validation loss for main effect: 4.765851974487305
# Validation RMSE for main effect: 4165.662109375

# %%
# -------------------------- quantify variable importance --------------------------
main_output_layer = model_main_effect.get_layer("main_subnet")  # Get the subnet output layer
main_model = Model(inputs = model_main_effect.inputs, outputs = main_output_layer.output)
main_output_values = main_model.predict(X_train_split)
# subnet_weights = model_main_effect.get_layer("main_output").get_weights()[0]


# Get the variance of each subnetwork across all data points
subnet_variance = []
for i in range(main_output_values.shape[1]):
    subnet_variance.append(np.var(main_output_values[:, i]))

# Define covariates
covariates = [name for name in all_vars]

# -------------------------- plot the variable importance --------------------------
# Create DataFrame for variable importance
var_importance = pd.DataFrame({"Covariates": covariates, "Subnet Variance": subnet_variance})

# Sort the DataFrame by subnet variance in decreasing order
varimp_sorted = var_importance.sort_values(by = "Subnet Variance", ascending = False)

# Create a bar plot using Seaborn
plt.figure(figsize = (10, 6))
sns.barplot(x = "Covariates", y = "Subnet Variance", data = varimp_sorted)
plt.title("Subnet Variance by Covariates")
plt.xlabel("Covariates")
plt.ylabel("Subnet Variance")
plt.show()
# Out:
# 360/360 [==============================] - 0s 687us/step

# %%
#-------------------------- view the shape function --------------------------
# create the plot
var_name = "X3"
var_index = all_vars.index(var_name)
plt.figure(figsize = (12, 6))
sns.lineplot(x = X_train_split[var_index], 
             y = main_output_values[:,var_index].flatten())
plt.xlabel(f"{var_name}")
plt.ylabel('Subnetwork Output')
plt.title(f"Shape function for {var_name}")
plt.grid(True)
plt.show()

# %%
############################   preparation for interaction selection   ############################
global_layers = ["main_subnet", "main_output", "interaction_output", "final_output"] # these layers are always trainable
interaction_loss = {} # this stores the validation loss when fitting each pair of interaction effect
imp_vars = [f"X{i}" for i in range(1,7)] # important variables
interactions = combinations(imp_vars, 2)
num_layers_interaction = 3 # number of layers for each interaction effect
num_neurons_interaction = 30 # number of neurons per dense layer for each interaction effect
keypoints = 20
lattice_sizes_pairwise = {}
for var in imp_vars:
    if var in cat_vars:
        lattice_sizes_pairwise[var] = X_train[var].nunique()
    else:
        lattice_sizes_pairwise[var] = 8

# %%
# -------------------------- create calibrator for lattice layer --------------------------
def add_calibrate_layer(var, data, monotonicity_list, lattice_sizes, keypoints, cat_vars, lattice_smooth_reg = [0,0]):
    if var in cat_vars:
        calibrator_layer = tfl.layers.CategoricalCalibration(
            num_buckets = data[var].nunique(),
            output_min = 0,
            output_max = lattice_sizes[var] - 1,
            name = f"{var}_calibrator_pairwise"
        )
    else:
        calibrator_layer = tfl.layers.PWLCalibration(
            input_keypoints =  np.linspace(data[var].min(), data[var].max(), num = keypoints), # keypoints
            kernel_regularizer = ('hessian', lattice_smooth_reg[0], lattice_smooth_reg[1]), # for smoothness
            monotonicity = monotonicity_list[var] if var in monotonicity_list else "none", # monotonicity constraint
            output_min = 0,
            output_max = lattice_sizes[var] - 1,
            name = f"{var}_calibrator_pairwise"
            )
    return calibrator_layer

# %%
############################   select interaction effect   ############################

# add pairwise effect and evaluate validation loss
for var1, var2 in interactions:

    # -------------------------- initialize a cloned model --------------------------
    model_main_cloned = clone_model(model_main_effect) # clone the main effect model
    model_main_cloned.build(model_main_effect.input_shape)
    model_main_cloned.set_weights(model_main_effect.get_weights()) # copy the weights


    # -------------------------- build a subnet for pairwise interaction effect --------------------------
    var1_input = model_main_cloned.inputs[all_vars.index(var1)]
    var2_input = model_main_cloned.inputs[all_vars.index(var2)]

    # Lattice model if the pair contains a monotonic variable
    if any(var in monotonicity_list for var in [var1, var2]):
        lattice_inputs = []

        # create calibrator_layer
        calibrator_var1 = add_calibrate_layer(var1, X_train, monotonicity_list, lattice_sizes_pairwise, keypoints, cat_vars)
        calibrator_var2 = add_calibrate_layer(var2, X_train, monotonicity_list, lattice_sizes_pairwise, keypoints, cat_vars)
        calibrator_layer_var1 = calibrator_var1(var1_input)
        calibrator_layer_var2 = calibrator_var2(var2_input)
        
        # lattice
        lattice_inputs.append(calibrator_layer_var1)
        lattice_inputs.append(calibrator_layer_var2)
        lattice_layer = tfl.layers.Lattice(lattice_sizes = [lattice_sizes_pairwise[var1],lattice_sizes_pairwise[var2]], 
                             monotonicities = ["increasing" if var1 in monotonicity_list else 'none',
                                                "increasing" if var2 in monotonicity_list else 'none'],
                             name = f"{var1}_{var2}_lattice")(lattice_inputs)
        pairwise_output = BatchNormalization(scale = False, name = f"{var1}_{var2}_mean")(lattice_layer)
    else:
        # Subnetwork if the pair contains no monotonic variables
        pairwise_input_layer = Concatenate(name = f"{var1}_{var2}_concat")([var1_input, var2_input])
        pairwise_subnet = create_subnet(num_layers_interaction, 
                                        num_neurons_interaction, 
                                        activation, 
                                        f"{var1}_{var2}_subnetwork")
        pairwise_output = pairwise_subnet(pairwise_input_layer)

    # final output
    interaction_subnet_output = Activation('exponential',
                        name = "interaction_output")(pairwise_output)
    main_subnet_output = model_main_cloned.output
    final_output = Multiply(name = "final_output")([main_subnet_output, interaction_subnet_output])
    model_pairwise = Model(inputs = model_main_cloned.inputs, outputs = final_output)


    # -------------------------- switch on/off layers --------------------------
    for layer in model_pairwise.layers:
        if layer.name not in global_layers and var1 not in layer.name and var2 not in layer.name:
            layer.trainable = False


    #-------------------------- custom loss function with marginal clarity constraint --------------------------
    # add marginal clarity constraint
    main_effects_output = model_pairwise.get_layer("main_subnet").output
    main_output_var1 = main_effects_output[all_vars.index(var1)]
    main_output_var2 = main_effects_output[all_vars.index(var2)]
    interaction_output = pairwise_output
    lambd = 5
    penalty = lambd * (
        K.abs(K.mean(main_output_var1 * interaction_output)) +
        K.abs(K.mean(main_output_var2 * interaction_output))
    )

    # Add the penalty to the model's total loss
    model_pairwise.add_loss(penalty)

    # -------------------------- compile and train the model --------------------------
    model_pairwise.compile(optimizer = 'rmsprop', 
                           loss = gamma_nll, 
                           metrics = [gamma_nll, RootMeanSquaredError()])
    es = EarlyStopping(monitor = 'val_gamma_nll', patience = 10, restore_best_weights = True)
    model_pairwise.fit(X_train_split, y_train, epochs = 5_000, \
                            callbacks = [es], batch_size = 1_000, validation_data = (X_val_split, y_val))
    _, gamma_log_metric, _ = model_pairwise.evaluate(X_val_split, y_val, batch_size = X_val_split[0].shape[0])
    interaction_loss[f"{var1}_{var2}"] = gamma_log_metric # add to the val loss list
# Out:
# Epoch 1/5000
# 12/12 [==============================] - 1s 27ms/step - loss: 4.9487 - gamma_nll: 4.9385 - root_mean_squared_error: 4285.7500 - val_loss: 5.9212 - val_gamma_nll: 4.9157 - val_root_mean_squared_error: 4180.3369
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7671 - gamma_nll: 4.7678 - root_mean_squared_error: 4174.0078 - val_loss: 5.9179 - val_gamma_nll: 4.9668 - val_root_mean_squared_error: 4180.7588
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7522 - gamma_nll: 4.7483 - root_mean_squared_error: 4161.1709 - val_loss: 6.4365 - val_gamma_nll: 5.5677 - val_root_mean_squared_error: 4244.3452
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7556 - gamma_nll: 4.7438 - root_mean_squared_error: 4167.6240 - val_loss: 6.0161 - val_gamma_nll: 5.1392 - val_root_mean_squared_error: 4213.8550
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7400 - gamma_nll: 4.7348 - root_mean_squared_error: 4159.4336 - val_loss: 5.8790 - val_gamma_nll: 4.9539 - val_root_mean_squared_error: 4195.2148
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7357 - gamma_nll: 4.7434 - root_mean_squared_error: 4153.7495 - val_loss: 6.0242 - val_gamma_nll: 5.1409 - val_root_mean_squared_error: 4305.3496
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7318 - gamma_nll: 4.7315 - root_mean_squared_error: 4146.2622 - val_loss: 5.7619 - val_gamma_nll: 4.9042 - val_root_mean_squared_error: 4192.6665
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7316 - gamma_nll: 4.7244 - root_mean_squared_error: 4156.1509 - val_loss: 5.6367 - val_gamma_nll: 4.8837 - val_root_mean_squared_error: 4185.3984
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7339 - gamma_nll: 4.7400 - root_mean_squared_error: 4147.9116 - val_loss: 5.4219 - val_gamma_nll: 4.7941 - val_root_mean_squared_error: 4168.5117
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7273 - gamma_nll: 4.7245 - root_mean_squared_error: 4156.3657 - val_loss: 5.5214 - val_gamma_nll: 4.8417 - val_root_mean_squared_error: 4189.7539
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7271 - gamma_nll: 4.7120 - root_mean_squared_error: 4153.5215 - val_loss: 5.6324 - val_gamma_nll: 4.9221 - val_root_mean_squared_error: 4181.3818
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7227 - gamma_nll: 4.7288 - root_mean_squared_error: 4147.0259 - val_loss: 5.4874 - val_gamma_nll: 4.8971 - val_root_mean_squared_error: 4176.2451
# Epoch 13/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7150 - gamma_nll: 4.7096 - root_mean_squared_error: 4147.4561 - val_loss: 5.3945 - val_gamma_nll: 4.8053 - val_root_mean_squared_error: 4169.6577
# Epoch 14/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7168 - gamma_nll: 4.7114 - root_mean_squared_error: 4141.0645 - val_loss: 5.3694 - val_gamma_nll: 4.8854 - val_root_mean_squared_error: 4226.5732
# Epoch 15/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7108 - gamma_nll: 4.7132 - root_mean_squared_error: 4144.2461 - val_loss: 5.5023 - val_gamma_nll: 4.8094 - val_root_mean_squared_error: 4256.9863
# Epoch 16/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7143 - gamma_nll: 4.6995 - root_mean_squared_error: 4138.9365 - val_loss: 5.2464 - val_gamma_nll: 4.7935 - val_root_mean_squared_error: 4287.5854
# Epoch 17/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7035 - gamma_nll: 4.6861 - root_mean_squared_error: 4136.8687 - val_loss: 5.2623 - val_gamma_nll: 4.7962 - val_root_mean_squared_error: 4278.2471
# Epoch 18/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7090 - gamma_nll: 4.7166 - root_mean_squared_error: 4149.6748 - val_loss: 5.0304 - val_gamma_nll: 4.7390 - val_root_mean_squared_error: 4246.2529
# Epoch 19/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7018 - gamma_nll: 4.7052 - root_mean_squared_error: 4146.2607 - val_loss: 5.0370 - val_gamma_nll: 4.7822 - val_root_mean_squared_error: 4251.4863
# Epoch 20/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7065 - gamma_nll: 4.6993 - root_mean_squared_error: 4141.9756 - val_loss: 5.0180 - val_gamma_nll: 4.7214 - val_root_mean_squared_error: 4210.6211
# Epoch 21/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7059 - gamma_nll: 4.6947 - root_mean_squared_error: 4142.9053 - val_loss: 5.0974 - val_gamma_nll: 4.7374 - val_root_mean_squared_error: 4284.6113
# Epoch 22/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6967 - gamma_nll: 4.6965 - root_mean_squared_error: 4136.9404 - val_loss: 4.9068 - val_gamma_nll: 4.7219 - val_root_mean_squared_error: 4218.3169
# Epoch 23/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7049 - gamma_nll: 4.6914 - root_mean_squared_error: 4143.4604 - val_loss: 4.8335 - val_gamma_nll: 4.7014 - val_root_mean_squared_error: 4219.2583
# Epoch 24/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6965 - gamma_nll: 4.7003 - root_mean_squared_error: 4143.0059 - val_loss: 4.8998 - val_gamma_nll: 4.7995 - val_root_mean_squared_error: 4457.3931
# Epoch 25/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7062 - gamma_nll: 4.6980 - root_mean_squared_error: 4130.3174 - val_loss: 4.8143 - val_gamma_nll: 4.7051 - val_root_mean_squared_error: 4191.0933
# Epoch 26/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6978 - gamma_nll: 4.6865 - root_mean_squared_error: 4145.3564 - val_loss: 4.9576 - val_gamma_nll: 4.7470 - val_root_mean_squared_error: 4318.8730
# Epoch 27/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7024 - gamma_nll: 4.6978 - root_mean_squared_error: 4142.2261 - val_loss: 4.9080 - val_gamma_nll: 4.7523 - val_root_mean_squared_error: 4251.7681
# Epoch 28/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6972 - gamma_nll: 4.6884 - root_mean_squared_error: 4135.3711 - val_loss: 4.8349 - val_gamma_nll: 4.7582 - val_root_mean_squared_error: 4228.5449
# Epoch 29/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7012 - gamma_nll: 4.6989 - root_mean_squared_error: 4139.7739 - val_loss: 4.9953 - val_gamma_nll: 4.6858 - val_root_mean_squared_error: 4194.6006
# Epoch 30/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6953 - gamma_nll: 4.6831 - root_mean_squared_error: 4143.1597 - val_loss: 4.8909 - val_gamma_nll: 4.7072 - val_root_mean_squared_error: 4224.8213
# Epoch 31/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6893 - gamma_nll: 4.6866 - root_mean_squared_error: 4146.4219 - val_loss: 4.8545 - val_gamma_nll: 4.7007 - val_root_mean_squared_error: 4193.5273
# Epoch 32/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6988 - gamma_nll: 4.6911 - root_mean_squared_error: 4147.7637 - val_loss: 4.7618 - val_gamma_nll: 4.6688 - val_root_mean_squared_error: 4158.4297
# Epoch 33/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6889 - gamma_nll: 4.6927 - root_mean_squared_error: 4139.0835 - val_loss: 4.8002 - val_gamma_nll: 4.7020 - val_root_mean_squared_error: 4162.5903
# Epoch 34/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6878 - gamma_nll: 4.6932 - root_mean_squared_error: 4140.6821 - val_loss: 5.0880 - val_gamma_nll: 4.7097 - val_root_mean_squared_error: 4183.8848
# Epoch 35/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6920 - gamma_nll: 4.6956 - root_mean_squared_error: 4137.0850 - val_loss: 4.8760 - val_gamma_nll: 4.6706 - val_root_mean_squared_error: 4169.1924
# Epoch 36/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6863 - gamma_nll: 4.6708 - root_mean_squared_error: 4138.4336 - val_loss: 5.0399 - val_gamma_nll: 4.7046 - val_root_mean_squared_error: 4209.3027
# Epoch 37/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6898 - gamma_nll: 4.6844 - root_mean_squared_error: 4139.0859 - val_loss: 4.9931 - val_gamma_nll: 4.7095 - val_root_mean_squared_error: 4196.3438
# Epoch 38/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6938 - gamma_nll: 4.6949 - root_mean_squared_error: 4143.6328 - val_loss: 5.0441 - val_gamma_nll: 4.7176 - val_root_mean_squared_error: 4286.9160
# Epoch 39/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6861 - gamma_nll: 4.6827 - root_mean_squared_error: 4141.4609 - val_loss: 4.8984 - val_gamma_nll: 4.7472 - val_root_mean_squared_error: 4304.1211
# Epoch 40/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6819 - gamma_nll: 4.6845 - root_mean_squared_error: 4138.0024 - val_loss: 4.9475 - val_gamma_nll: 4.6931 - val_root_mean_squared_error: 4158.7661
# Epoch 41/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6901 - gamma_nll: 4.6900 - root_mean_squared_error: 4140.0991 - val_loss: 4.7721 - val_gamma_nll: 4.6745 - val_root_mean_squared_error: 4158.2100
# Epoch 42/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6882 - gamma_nll: 4.6853 - root_mean_squared_error: 4142.7446 - val_loss: 5.0244 - val_gamma_nll: 4.6989 - val_root_mean_squared_error: 4176.8921
# 1/1 [==============================] - 0s 17ms/step - loss: 4.7312 - gamma_nll: 4.6777 - root_mean_squared_error: 4158.4292
# Epoch 1/5000
# 12/12 [==============================] - 2s 29ms/step - loss: 5.0305 - gamma_nll: 5.0196 - root_mean_squared_error: 5553.6660 - val_loss: 8.8373 - val_gamma_nll: 5.5959 - val_root_mean_squared_error: 5920.9106
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8132 - gamma_nll: 4.8089 - root_mean_squared_error: 4387.6963 - val_loss: 8.5248 - val_gamma_nll: 5.5325 - val_root_mean_squared_error: 5539.6558
# Epoch 3/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7902 - gamma_nll: 4.7815 - root_mean_squared_error: 4329.2690 - val_loss: 7.9730 - val_gamma_nll: 5.2937 - val_root_mean_squared_error: 4840.0483
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7853 - gamma_nll: 4.7743 - root_mean_squared_error: 4333.9238 - val_loss: 7.6578 - val_gamma_nll: 5.2168 - val_root_mean_squared_error: 4667.3687
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7796 - gamma_nll: 4.7785 - root_mean_squared_error: 4324.4526 - val_loss: 7.2188 - val_gamma_nll: 5.0378 - val_root_mean_squared_error: 4345.5186
# Epoch 6/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7721 - gamma_nll: 4.7752 - root_mean_squared_error: 4310.0894 - val_loss: 6.9134 - val_gamma_nll: 4.9376 - val_root_mean_squared_error: 4256.0591
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7747 - gamma_nll: 4.7708 - root_mean_squared_error: 4313.9961 - val_loss: 6.6888 - val_gamma_nll: 4.8859 - val_root_mean_squared_error: 4211.6992
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7679 - gamma_nll: 4.7603 - root_mean_squared_error: 4319.3013 - val_loss: 6.6071 - val_gamma_nll: 4.9306 - val_root_mean_squared_error: 4264.3335
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7597 - gamma_nll: 4.7636 - root_mean_squared_error: 4283.8125 - val_loss: 6.3117 - val_gamma_nll: 4.8396 - val_root_mean_squared_error: 4245.7549
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7614 - gamma_nll: 4.7596 - root_mean_squared_error: 4326.4751 - val_loss: 6.1063 - val_gamma_nll: 4.7704 - val_root_mean_squared_error: 4175.5913
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7546 - gamma_nll: 4.7455 - root_mean_squared_error: 4323.4507 - val_loss: 5.8479 - val_gamma_nll: 4.6792 - val_root_mean_squared_error: 4141.2012
# Epoch 12/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7559 - gamma_nll: 4.7630 - root_mean_squared_error: 4322.4175 - val_loss: 5.7542 - val_gamma_nll: 4.7283 - val_root_mean_squared_error: 4158.8071
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7506 - gamma_nll: 4.7481 - root_mean_squared_error: 4311.0698 - val_loss: 5.6557 - val_gamma_nll: 4.6698 - val_root_mean_squared_error: 4140.4409
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7505 - gamma_nll: 4.7412 - root_mean_squared_error: 4322.2300 - val_loss: 5.5494 - val_gamma_nll: 4.6771 - val_root_mean_squared_error: 4138.7969
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7445 - gamma_nll: 4.7458 - root_mean_squared_error: 4330.1074 - val_loss: 5.5346 - val_gamma_nll: 4.7272 - val_root_mean_squared_error: 4164.7021
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7543 - gamma_nll: 4.7363 - root_mean_squared_error: 4367.6860 - val_loss: 5.4626 - val_gamma_nll: 4.7310 - val_root_mean_squared_error: 4185.7065
# Epoch 17/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7368 - gamma_nll: 4.7159 - root_mean_squared_error: 4311.0234 - val_loss: 5.5177 - val_gamma_nll: 4.8113 - val_root_mean_squared_error: 4281.2607
# Epoch 18/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7411 - gamma_nll: 4.7477 - root_mean_squared_error: 4327.4443 - val_loss: 5.3914 - val_gamma_nll: 4.7896 - val_root_mean_squared_error: 4321.1411
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7419 - gamma_nll: 4.7451 - root_mean_squared_error: 4357.0391 - val_loss: 5.3213 - val_gamma_nll: 4.7957 - val_root_mean_squared_error: 4288.1494
# Epoch 20/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7444 - gamma_nll: 4.7357 - root_mean_squared_error: 4339.4741 - val_loss: 5.2582 - val_gamma_nll: 4.8138 - val_root_mean_squared_error: 4343.6885
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7354 - gamma_nll: 4.7301 - root_mean_squared_error: 4339.0781 - val_loss: 5.0668 - val_gamma_nll: 4.7345 - val_root_mean_squared_error: 4283.3989
# Epoch 22/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7299 - gamma_nll: 4.7322 - root_mean_squared_error: 4349.8604 - val_loss: 4.9680 - val_gamma_nll: 4.7084 - val_root_mean_squared_error: 4236.3994
# Epoch 23/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7401 - gamma_nll: 4.7263 - root_mean_squared_error: 4366.2910 - val_loss: 4.8904 - val_gamma_nll: 4.6830 - val_root_mean_squared_error: 4203.9160
# 1/1 [==============================] - 0s 18ms/step - loss: 5.6429 - gamma_nll: 4.6785 - root_mean_squared_error: 4140.4404
# Epoch 1/5000
# 12/12 [==============================] - 1s 26ms/step - loss: 4.8159 - gamma_nll: 4.8095 - root_mean_squared_error: 4180.6367 - val_loss: 5.1018 - val_gamma_nll: 5.0220 - val_root_mean_squared_error: 5302.4224
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7502 - gamma_nll: 4.7495 - root_mean_squared_error: 4162.3848 - val_loss: 5.1655 - val_gamma_nll: 5.1131 - val_root_mean_squared_error: 5716.2783
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7278 - gamma_nll: 4.7237 - root_mean_squared_error: 4156.6230 - val_loss: 5.2435 - val_gamma_nll: 5.1441 - val_root_mean_squared_error: 4939.1309
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7314 - gamma_nll: 4.7209 - root_mean_squared_error: 4157.6997 - val_loss: 5.1691 - val_gamma_nll: 5.1208 - val_root_mean_squared_error: 5909.7104
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7216 - gamma_nll: 4.7153 - root_mean_squared_error: 4151.7104 - val_loss: 5.5191 - val_gamma_nll: 5.3277 - val_root_mean_squared_error: 5702.0435
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7186 - gamma_nll: 4.7248 - root_mean_squared_error: 4154.9058 - val_loss: 5.3167 - val_gamma_nll: 5.2007 - val_root_mean_squared_error: 5255.4858
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7182 - gamma_nll: 4.7148 - root_mean_squared_error: 4143.8262 - val_loss: 5.3301 - val_gamma_nll: 5.2578 - val_root_mean_squared_error: 5167.3560
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7154 - gamma_nll: 4.7098 - root_mean_squared_error: 4147.1138 - val_loss: 5.1686 - val_gamma_nll: 5.1023 - val_root_mean_squared_error: 5108.2593
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7134 - gamma_nll: 4.7205 - root_mean_squared_error: 4141.6484 - val_loss: 5.5299 - val_gamma_nll: 5.4481 - val_root_mean_squared_error: 5435.6953
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7131 - gamma_nll: 4.7129 - root_mean_squared_error: 4144.4448 - val_loss: 5.3190 - val_gamma_nll: 5.2581 - val_root_mean_squared_error: 5690.4355
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7128 - gamma_nll: 4.6980 - root_mean_squared_error: 4151.5015 - val_loss: 5.5443 - val_gamma_nll: 5.4800 - val_root_mean_squared_error: 5184.0962
# 1/1 [==============================] - 0s 19ms/step - loss: 5.0978 - gamma_nll: 5.0291 - root_mean_squared_error: 5302.4229
# Epoch 1/5000
# 12/12 [==============================] - 1s 27ms/step - loss: 4.9408 - gamma_nll: 4.9283 - root_mean_squared_error: 4368.3369 - val_loss: 4.9850 - val_gamma_nll: 4.8295 - val_root_mean_squared_error: 4239.3506
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7373 - gamma_nll: 4.7342 - root_mean_squared_error: 4175.0596 - val_loss: 4.9639 - val_gamma_nll: 4.8560 - val_root_mean_squared_error: 4251.6875
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7281 - gamma_nll: 4.7237 - root_mean_squared_error: 4170.8955 - val_loss: 5.0761 - val_gamma_nll: 4.9925 - val_root_mean_squared_error: 4488.7456
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7288 - gamma_nll: 4.7183 - root_mean_squared_error: 4169.2393 - val_loss: 5.0076 - val_gamma_nll: 4.9831 - val_root_mean_squared_error: 4413.4453
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7251 - gamma_nll: 4.7212 - root_mean_squared_error: 4175.6660 - val_loss: 5.0191 - val_gamma_nll: 4.9892 - val_root_mean_squared_error: 4617.6172
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7160 - gamma_nll: 4.7257 - root_mean_squared_error: 4163.8267 - val_loss: 5.0750 - val_gamma_nll: 5.0234 - val_root_mean_squared_error: 4818.9077
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7165 - gamma_nll: 4.7128 - root_mean_squared_error: 4155.5649 - val_loss: 5.0263 - val_gamma_nll: 4.9984 - val_root_mean_squared_error: 4706.1909
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7198 - gamma_nll: 4.7137 - root_mean_squared_error: 4166.8984 - val_loss: 4.9847 - val_gamma_nll: 4.9218 - val_root_mean_squared_error: 4414.8604
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7066 - gamma_nll: 4.7119 - root_mean_squared_error: 4149.5513 - val_loss: 4.9340 - val_gamma_nll: 4.8868 - val_root_mean_squared_error: 4376.9043
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7197 - gamma_nll: 4.7181 - root_mean_squared_error: 4167.5688 - val_loss: 5.0495 - val_gamma_nll: 4.9783 - val_root_mean_squared_error: 4635.6387
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7077 - gamma_nll: 4.6910 - root_mean_squared_error: 4162.1558 - val_loss: 4.9008 - val_gamma_nll: 4.8314 - val_root_mean_squared_error: 4212.7056
# 1/1 [==============================] - 0s 16ms/step - loss: 4.9934 - gamma_nll: 4.8392 - root_mean_squared_error: 4239.3506
# Epoch 1/5000
# 12/12 [==============================] - 1s 26ms/step - loss: 4.7995 - gamma_nll: 4.7924 - root_mean_squared_error: 4258.7939 - val_loss: 5.1733 - val_gamma_nll: 5.0898 - val_root_mean_squared_error: 6036.6807
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7463 - gamma_nll: 4.7433 - root_mean_squared_error: 4157.6992 - val_loss: 5.1765 - val_gamma_nll: 5.1075 - val_root_mean_squared_error: 6752.1079
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7206 - gamma_nll: 4.7166 - root_mean_squared_error: 4146.8232 - val_loss: 5.1126 - val_gamma_nll: 5.0974 - val_root_mean_squared_error: 6144.5161
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7263 - gamma_nll: 4.7153 - root_mean_squared_error: 4161.5078 - val_loss: 5.1215 - val_gamma_nll: 5.0305 - val_root_mean_squared_error: 5860.2974
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7177 - gamma_nll: 4.7160 - root_mean_squared_error: 4152.5610 - val_loss: 4.9937 - val_gamma_nll: 4.9749 - val_root_mean_squared_error: 5250.2798
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7269 - gamma_nll: 4.7352 - root_mean_squared_error: 4157.3960 - val_loss: 5.1555 - val_gamma_nll: 5.0707 - val_root_mean_squared_error: 6229.3433
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7227 - gamma_nll: 4.7193 - root_mean_squared_error: 4145.8306 - val_loss: 5.0313 - val_gamma_nll: 5.0009 - val_root_mean_squared_error: 5609.8862
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7189 - gamma_nll: 4.7121 - root_mean_squared_error: 4150.5796 - val_loss: 5.0774 - val_gamma_nll: 4.8964 - val_root_mean_squared_error: 4754.4531
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7058 - gamma_nll: 4.7132 - root_mean_squared_error: 4142.2134 - val_loss: 5.0883 - val_gamma_nll: 5.0533 - val_root_mean_squared_error: 4921.4175
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7095 - gamma_nll: 4.7084 - root_mean_squared_error: 4146.9395 - val_loss: 5.1960 - val_gamma_nll: 4.8780 - val_root_mean_squared_error: 4269.3804
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7122 - gamma_nll: 4.6980 - root_mean_squared_error: 4149.6826 - val_loss: 5.0716 - val_gamma_nll: 4.9181 - val_root_mean_squared_error: 4619.4272
# Epoch 12/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7140 - gamma_nll: 4.7213 - root_mean_squared_error: 4145.1245 - val_loss: 5.0285 - val_gamma_nll: 4.8290 - val_root_mean_squared_error: 4271.0786
# Epoch 13/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7029 - gamma_nll: 4.6971 - root_mean_squared_error: 4142.5186 - val_loss: 5.0198 - val_gamma_nll: 4.9076 - val_root_mean_squared_error: 4307.8438
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7093 - gamma_nll: 4.7012 - root_mean_squared_error: 4139.0171 - val_loss: 5.0014 - val_gamma_nll: 4.8285 - val_root_mean_squared_error: 4313.2119
# Epoch 15/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6996 - gamma_nll: 4.7009 - root_mean_squared_error: 4142.3477 - val_loss: 5.0632 - val_gamma_nll: 4.9303 - val_root_mean_squared_error: 4336.8857
# Epoch 16/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7055 - gamma_nll: 4.6902 - root_mean_squared_error: 4141.2549 - val_loss: 5.0124 - val_gamma_nll: 4.8353 - val_root_mean_squared_error: 4319.6880
# Epoch 17/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7034 - gamma_nll: 4.6852 - root_mean_squared_error: 4133.6792 - val_loss: 5.1121 - val_gamma_nll: 4.8066 - val_root_mean_squared_error: 4286.6226
# Epoch 18/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7037 - gamma_nll: 4.7108 - root_mean_squared_error: 4145.7896 - val_loss: 5.2412 - val_gamma_nll: 5.0029 - val_root_mean_squared_error: 5182.0195
# Epoch 19/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6935 - gamma_nll: 4.6960 - root_mean_squared_error: 4133.9492 - val_loss: 5.1194 - val_gamma_nll: 4.8824 - val_root_mean_squared_error: 4192.5547
# Epoch 20/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7060 - gamma_nll: 4.6998 - root_mean_squared_error: 4145.5981 - val_loss: 5.0512 - val_gamma_nll: 4.9208 - val_root_mean_squared_error: 4153.0850
# Epoch 21/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6894 - gamma_nll: 4.6779 - root_mean_squared_error: 4142.1953 - val_loss: 5.5547 - val_gamma_nll: 4.9661 - val_root_mean_squared_error: 4526.0947
# Epoch 22/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6950 - gamma_nll: 4.6967 - root_mean_squared_error: 4133.5098 - val_loss: 5.3018 - val_gamma_nll: 4.9115 - val_root_mean_squared_error: 4212.7407
# Epoch 23/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7025 - gamma_nll: 4.6903 - root_mean_squared_error: 4143.0088 - val_loss: 5.5393 - val_gamma_nll: 5.0160 - val_root_mean_squared_error: 4283.9185
# Epoch 24/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6964 - gamma_nll: 4.7018 - root_mean_squared_error: 4145.1406 - val_loss: 5.1562 - val_gamma_nll: 4.9112 - val_root_mean_squared_error: 4192.1465
# Epoch 25/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6962 - gamma_nll: 4.6884 - root_mean_squared_error: 4136.9453 - val_loss: 5.6154 - val_gamma_nll: 5.1894 - val_root_mean_squared_error: 4181.6475
# Epoch 26/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6894 - gamma_nll: 4.6834 - root_mean_squared_error: 4141.6436 - val_loss: 5.3917 - val_gamma_nll: 5.3361 - val_root_mean_squared_error: 4174.7163
# Epoch 27/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7012 - gamma_nll: 4.6944 - root_mean_squared_error: 4152.7944 - val_loss: 5.3141 - val_gamma_nll: 5.1818 - val_root_mean_squared_error: 4171.2915
# 1/1 [==============================] - 0s 16ms/step - loss: 5.1108 - gamma_nll: 4.8114 - root_mean_squared_error: 4286.6235
# Epoch 1/5000
# 12/12 [==============================] - 1s 28ms/step - loss: 5.0447 - gamma_nll: 5.0364 - root_mean_squared_error: 6463.4502 - val_loss: 8.9927 - val_gamma_nll: 5.7528 - val_root_mean_squared_error: 6748.3306
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.8689 - gamma_nll: 4.8673 - root_mean_squared_error: 4651.7642 - val_loss: 8.5893 - val_gamma_nll: 5.6000 - val_root_mean_squared_error: 5845.5239
# Epoch 3/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8491 - gamma_nll: 4.8399 - root_mean_squared_error: 4544.7720 - val_loss: 8.1010 - val_gamma_nll: 5.3984 - val_root_mean_squared_error: 5208.3877
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.8339 - gamma_nll: 4.8227 - root_mean_squared_error: 4551.1475 - val_loss: 8.1408 - val_gamma_nll: 5.5460 - val_root_mean_squared_error: 5754.8335
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.8295 - gamma_nll: 4.8274 - root_mean_squared_error: 4516.3228 - val_loss: 7.7536 - val_gamma_nll: 5.4175 - val_root_mean_squared_error: 5202.1582
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.8153 - gamma_nll: 4.8173 - root_mean_squared_error: 4499.2593 - val_loss: 7.4058 - val_gamma_nll: 5.2671 - val_root_mean_squared_error: 4805.8350
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.8104 - gamma_nll: 4.8094 - root_mean_squared_error: 4480.0693 - val_loss: 7.1904 - val_gamma_nll: 5.2109 - val_root_mean_squared_error: 4661.7388
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.8010 - gamma_nll: 4.7926 - root_mean_squared_error: 4456.8149 - val_loss: 6.9168 - val_gamma_nll: 5.1292 - val_root_mean_squared_error: 4561.3364
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7980 - gamma_nll: 4.8031 - root_mean_squared_error: 4449.6216 - val_loss: 6.6507 - val_gamma_nll: 5.0073 - val_root_mean_squared_error: 4408.2852
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7890 - gamma_nll: 4.7866 - root_mean_squared_error: 4439.5566 - val_loss: 6.4060 - val_gamma_nll: 4.9265 - val_root_mean_squared_error: 4286.8179
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7823 - gamma_nll: 4.7727 - root_mean_squared_error: 4420.2930 - val_loss: 6.1992 - val_gamma_nll: 4.8590 - val_root_mean_squared_error: 4240.8511
# Epoch 12/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7803 - gamma_nll: 4.7884 - root_mean_squared_error: 4417.8164 - val_loss: 5.9648 - val_gamma_nll: 4.7523 - val_root_mean_squared_error: 4197.8730
# Epoch 13/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7775 - gamma_nll: 4.7735 - root_mean_squared_error: 4407.1460 - val_loss: 5.9265 - val_gamma_nll: 4.8101 - val_root_mean_squared_error: 4218.4673
# Epoch 14/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7759 - gamma_nll: 4.7680 - root_mean_squared_error: 4394.8159 - val_loss: 5.7710 - val_gamma_nll: 4.7708 - val_root_mean_squared_error: 4192.1670
# Epoch 15/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7669 - gamma_nll: 4.7692 - root_mean_squared_error: 4390.5645 - val_loss: 5.6877 - val_gamma_nll: 4.7825 - val_root_mean_squared_error: 4191.7402
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7677 - gamma_nll: 4.7521 - root_mean_squared_error: 4369.2788 - val_loss: 5.5044 - val_gamma_nll: 4.6877 - val_root_mean_squared_error: 4166.5532
# Epoch 17/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7666 - gamma_nll: 4.7480 - root_mean_squared_error: 4379.9814 - val_loss: 5.3940 - val_gamma_nll: 4.6675 - val_root_mean_squared_error: 4154.1899
# Epoch 18/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7688 - gamma_nll: 4.7764 - root_mean_squared_error: 4374.0259 - val_loss: 5.3563 - val_gamma_nll: 4.6948 - val_root_mean_squared_error: 4179.1118
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7616 - gamma_nll: 4.7660 - root_mean_squared_error: 4392.2310 - val_loss: 5.2690 - val_gamma_nll: 4.6760 - val_root_mean_squared_error: 4170.6240
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7618 - gamma_nll: 4.7531 - root_mean_squared_error: 4378.3091 - val_loss: 5.1968 - val_gamma_nll: 4.6970 - val_root_mean_squared_error: 4165.3599
# Epoch 21/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7686 - gamma_nll: 4.7610 - root_mean_squared_error: 4392.0322 - val_loss: 5.1496 - val_gamma_nll: 4.7428 - val_root_mean_squared_error: 4171.3306
# Epoch 22/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7622 - gamma_nll: 4.7631 - root_mean_squared_error: 4387.7148 - val_loss: 5.1767 - val_gamma_nll: 4.7763 - val_root_mean_squared_error: 4189.7861
# Epoch 23/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7609 - gamma_nll: 4.7477 - root_mean_squared_error: 4400.5552 - val_loss: 5.0372 - val_gamma_nll: 4.6776 - val_root_mean_squared_error: 4167.9028
# Epoch 24/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7571 - gamma_nll: 4.7628 - root_mean_squared_error: 4381.8062 - val_loss: 5.0624 - val_gamma_nll: 4.7450 - val_root_mean_squared_error: 4211.5781
# Epoch 25/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7663 - gamma_nll: 4.7564 - root_mean_squared_error: 4403.8750 - val_loss: 4.9389 - val_gamma_nll: 4.6700 - val_root_mean_squared_error: 4170.5977
# Epoch 26/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7622 - gamma_nll: 4.7472 - root_mean_squared_error: 4409.8989 - val_loss: 4.9280 - val_gamma_nll: 4.6984 - val_root_mean_squared_error: 4201.0557
# Epoch 27/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7583 - gamma_nll: 4.7552 - root_mean_squared_error: 4397.3936 - val_loss: 4.8770 - val_gamma_nll: 4.6778 - val_root_mean_squared_error: 4183.6870
# 1/1 [==============================] - 0s 17ms/step - loss: 5.4733 - gamma_nll: 4.6756 - root_mean_squared_error: 4154.1895
# Epoch 1/5000
# 12/12 [==============================] - 1s 26ms/step - loss: 4.8463 - gamma_nll: 4.8417 - root_mean_squared_error: 4500.6133 - val_loss: 5.2744 - val_gamma_nll: 5.0014 - val_root_mean_squared_error: 4584.2295
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7961 - gamma_nll: 4.7958 - root_mean_squared_error: 4217.1479 - val_loss: 5.2805 - val_gamma_nll: 5.0153 - val_root_mean_squared_error: 4615.0181
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7799 - gamma_nll: 4.7749 - root_mean_squared_error: 4201.2559 - val_loss: 5.1193 - val_gamma_nll: 4.8851 - val_root_mean_squared_error: 4187.6963
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7751 - gamma_nll: 4.7627 - root_mean_squared_error: 4196.1582 - val_loss: 5.2011 - val_gamma_nll: 4.9700 - val_root_mean_squared_error: 4227.3369
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7601 - gamma_nll: 4.7548 - root_mean_squared_error: 4177.5337 - val_loss: 5.2120 - val_gamma_nll: 4.9693 - val_root_mean_squared_error: 4211.8145
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7533 - gamma_nll: 4.7585 - root_mean_squared_error: 4189.6323 - val_loss: 5.1975 - val_gamma_nll: 4.8876 - val_root_mean_squared_error: 4148.9980
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7431 - gamma_nll: 4.7427 - root_mean_squared_error: 4169.4209 - val_loss: 5.4122 - val_gamma_nll: 5.1085 - val_root_mean_squared_error: 4264.9702
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7403 - gamma_nll: 4.7342 - root_mean_squared_error: 4166.2373 - val_loss: 5.4653 - val_gamma_nll: 5.1810 - val_root_mean_squared_error: 4205.0132
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7360 - gamma_nll: 4.7421 - root_mean_squared_error: 4164.7095 - val_loss: 5.4458 - val_gamma_nll: 5.2000 - val_root_mean_squared_error: 4126.1084
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7301 - gamma_nll: 4.7301 - root_mean_squared_error: 4157.1030 - val_loss: 5.4527 - val_gamma_nll: 5.2191 - val_root_mean_squared_error: 4129.3403
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7234 - gamma_nll: 4.7078 - root_mean_squared_error: 4160.4741 - val_loss: 5.3125 - val_gamma_nll: 5.0591 - val_root_mean_squared_error: 4130.6133
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7234 - gamma_nll: 4.7302 - root_mean_squared_error: 4167.2441 - val_loss: 5.4093 - val_gamma_nll: 5.2382 - val_root_mean_squared_error: 4140.9170
# Epoch 13/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7186 - gamma_nll: 4.7125 - root_mean_squared_error: 4159.8037 - val_loss: 5.4767 - val_gamma_nll: 5.4251 - val_root_mean_squared_error: 4160.7847
# 1/1 [==============================] - 0s 16ms/step - loss: 5.1375 - gamma_nll: 4.8916 - root_mean_squared_error: 4187.6963
# Epoch 1/5000
# 12/12 [==============================] - 1s 27ms/step - loss: 4.8207 - gamma_nll: 4.8147 - root_mean_squared_error: 4700.1338 - val_loss: 5.1682 - val_gamma_nll: 4.9490 - val_root_mean_squared_error: 4259.4067
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7400 - gamma_nll: 4.7397 - root_mean_squared_error: 4218.3530 - val_loss: 5.3353 - val_gamma_nll: 5.0993 - val_root_mean_squared_error: 4307.6470
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7340 - gamma_nll: 4.7311 - root_mean_squared_error: 4206.0601 - val_loss: 5.6496 - val_gamma_nll: 5.4576 - val_root_mean_squared_error: 4315.3389
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7321 - gamma_nll: 4.7219 - root_mean_squared_error: 4180.4868 - val_loss: 5.3965 - val_gamma_nll: 5.1938 - val_root_mean_squared_error: 4281.4663
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7192 - gamma_nll: 4.7161 - root_mean_squared_error: 4178.2490 - val_loss: 5.5606 - val_gamma_nll: 5.3594 - val_root_mean_squared_error: 4256.5464
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7192 - gamma_nll: 4.7274 - root_mean_squared_error: 4187.8477 - val_loss: 5.6225 - val_gamma_nll: 5.4102 - val_root_mean_squared_error: 4303.0449
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7183 - gamma_nll: 4.7177 - root_mean_squared_error: 4179.5791 - val_loss: 5.4261 - val_gamma_nll: 5.2205 - val_root_mean_squared_error: 4361.7852
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7079 - gamma_nll: 4.7008 - root_mean_squared_error: 4168.3936 - val_loss: 5.0131 - val_gamma_nll: 4.8526 - val_root_mean_squared_error: 4195.3857
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7195 - gamma_nll: 4.7263 - root_mean_squared_error: 4172.5786 - val_loss: 5.2493 - val_gamma_nll: 5.0560 - val_root_mean_squared_error: 4281.2378
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7172 - gamma_nll: 4.7144 - root_mean_squared_error: 4175.9199 - val_loss: 5.3137 - val_gamma_nll: 5.0017 - val_root_mean_squared_error: 4362.4922
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7092 - gamma_nll: 4.6918 - root_mean_squared_error: 4168.5317 - val_loss: 5.0800 - val_gamma_nll: 4.8449 - val_root_mean_squared_error: 4279.3027
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7066 - gamma_nll: 4.7114 - root_mean_squared_error: 4173.3564 - val_loss: 5.2109 - val_gamma_nll: 4.9951 - val_root_mean_squared_error: 4397.5410
# Epoch 13/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7108 - gamma_nll: 4.7039 - root_mean_squared_error: 4183.6914 - val_loss: 5.3556 - val_gamma_nll: 5.0313 - val_root_mean_squared_error: 4562.7261
# Epoch 14/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7090 - gamma_nll: 4.7032 - root_mean_squared_error: 4171.7710 - val_loss: 5.4385 - val_gamma_nll: 5.1253 - val_root_mean_squared_error: 4369.3979
# Epoch 15/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7096 - gamma_nll: 4.7118 - root_mean_squared_error: 4173.0459 - val_loss: 5.2922 - val_gamma_nll: 4.9476 - val_root_mean_squared_error: 4302.3403
# Epoch 16/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7017 - gamma_nll: 4.6876 - root_mean_squared_error: 4164.0176 - val_loss: 5.4510 - val_gamma_nll: 5.0988 - val_root_mean_squared_error: 4283.4321
# Epoch 17/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7094 - gamma_nll: 4.6945 - root_mean_squared_error: 4173.9263 - val_loss: 5.3941 - val_gamma_nll: 5.1773 - val_root_mean_squared_error: 4205.9971
# Epoch 18/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7002 - gamma_nll: 4.7046 - root_mean_squared_error: 4165.0381 - val_loss: 5.5105 - val_gamma_nll: 5.2007 - val_root_mean_squared_error: 4244.0757
# Epoch 19/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7035 - gamma_nll: 4.7062 - root_mean_squared_error: 4174.2954 - val_loss: 5.3312 - val_gamma_nll: 5.1401 - val_root_mean_squared_error: 4268.4932
# Epoch 20/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6984 - gamma_nll: 4.6909 - root_mean_squared_error: 4158.0757 - val_loss: 5.4438 - val_gamma_nll: 5.1221 - val_root_mean_squared_error: 4298.6426
# Epoch 21/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7115 - gamma_nll: 4.6976 - root_mean_squared_error: 4164.2036 - val_loss: 5.3828 - val_gamma_nll: 5.0352 - val_root_mean_squared_error: 4278.4707
# 1/1 [==============================] - 0s 16ms/step - loss: 5.1404 - gamma_nll: 4.8522 - root_mean_squared_error: 4279.3032
# Epoch 1/5000
# 12/12 [==============================] - 1s 26ms/step - loss: 4.9530 - gamma_nll: 4.9430 - root_mean_squared_error: 4329.3799 - val_loss: 5.2390 - val_gamma_nll: 5.1068 - val_root_mean_squared_error: 4232.1914
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7640 - gamma_nll: 4.7651 - root_mean_squared_error: 4158.2622 - val_loss: 5.4928 - val_gamma_nll: 5.4283 - val_root_mean_squared_error: 4243.6021
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7453 - gamma_nll: 4.7408 - root_mean_squared_error: 4155.0518 - val_loss: 6.3439 - val_gamma_nll: 6.2917 - val_root_mean_squared_error: 4370.3882
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7353 - gamma_nll: 4.7231 - root_mean_squared_error: 4163.1040 - val_loss: 5.8705 - val_gamma_nll: 5.8326 - val_root_mean_squared_error: 4269.7217
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7329 - gamma_nll: 4.7268 - root_mean_squared_error: 4165.1270 - val_loss: 5.7935 - val_gamma_nll: 5.6745 - val_root_mean_squared_error: 4293.2178
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7252 - gamma_nll: 4.7305 - root_mean_squared_error: 4160.0239 - val_loss: 5.7073 - val_gamma_nll: 5.6699 - val_root_mean_squared_error: 4288.0312
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7269 - gamma_nll: 4.7253 - root_mean_squared_error: 4151.3560 - val_loss: 6.0517 - val_gamma_nll: 5.9594 - val_root_mean_squared_error: 4334.4590
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7190 - gamma_nll: 4.7114 - root_mean_squared_error: 4156.5957 - val_loss: 5.2441 - val_gamma_nll: 4.9664 - val_root_mean_squared_error: 4323.3999
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7180 - gamma_nll: 4.7240 - root_mean_squared_error: 4156.5337 - val_loss: 5.2311 - val_gamma_nll: 5.1703 - val_root_mean_squared_error: 4453.1157
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7217 - gamma_nll: 4.7200 - root_mean_squared_error: 4152.0879 - val_loss: 5.6948 - val_gamma_nll: 5.5290 - val_root_mean_squared_error: 4512.6133
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7146 - gamma_nll: 4.6999 - root_mean_squared_error: 4147.6880 - val_loss: 5.2768 - val_gamma_nll: 5.1747 - val_root_mean_squared_error: 4519.5205
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7152 - gamma_nll: 4.7199 - root_mean_squared_error: 4151.6274 - val_loss: 5.3917 - val_gamma_nll: 5.3161 - val_root_mean_squared_error: 4783.8770
# Epoch 13/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7096 - gamma_nll: 4.7057 - root_mean_squared_error: 4149.3188 - val_loss: 5.3188 - val_gamma_nll: 5.2837 - val_root_mean_squared_error: 4811.0283
# Epoch 14/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7171 - gamma_nll: 4.7126 - root_mean_squared_error: 4151.0122 - val_loss: 5.3579 - val_gamma_nll: 5.3178 - val_root_mean_squared_error: 4569.0059
# Epoch 15/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7062 - gamma_nll: 4.7078 - root_mean_squared_error: 4149.7241 - val_loss: 4.9888 - val_gamma_nll: 4.9077 - val_root_mean_squared_error: 4482.7803
# Epoch 16/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7004 - gamma_nll: 4.6875 - root_mean_squared_error: 4143.9990 - val_loss: 5.4452 - val_gamma_nll: 5.1998 - val_root_mean_squared_error: 4864.0898
# Epoch 17/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7124 - gamma_nll: 4.6975 - root_mean_squared_error: 4146.9385 - val_loss: 5.0342 - val_gamma_nll: 4.9569 - val_root_mean_squared_error: 4780.5850
# Epoch 18/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7053 - gamma_nll: 4.7123 - root_mean_squared_error: 4149.2456 - val_loss: 5.2337 - val_gamma_nll: 4.9634 - val_root_mean_squared_error: 4684.3989
# Epoch 19/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7003 - gamma_nll: 4.7027 - root_mean_squared_error: 4139.7485 - val_loss: 4.9701 - val_gamma_nll: 4.9297 - val_root_mean_squared_error: 4822.8218
# Epoch 20/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7040 - gamma_nll: 4.6944 - root_mean_squared_error: 4146.3647 - val_loss: 5.0756 - val_gamma_nll: 5.0285 - val_root_mean_squared_error: 5214.4766
# Epoch 21/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7042 - gamma_nll: 4.6929 - root_mean_squared_error: 4150.5186 - val_loss: 5.1757 - val_gamma_nll: 5.0057 - val_root_mean_squared_error: 5321.7383
# Epoch 22/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7033 - gamma_nll: 4.7031 - root_mean_squared_error: 4146.1582 - val_loss: 5.1406 - val_gamma_nll: 4.9900 - val_root_mean_squared_error: 5270.2534
# Epoch 23/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6996 - gamma_nll: 4.6866 - root_mean_squared_error: 4146.3154 - val_loss: 5.1238 - val_gamma_nll: 5.0381 - val_root_mean_squared_error: 5317.8315
# Epoch 24/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6949 - gamma_nll: 4.7020 - root_mean_squared_error: 4139.1685 - val_loss: 5.2951 - val_gamma_nll: 5.0841 - val_root_mean_squared_error: 5628.7383
# Epoch 25/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7073 - gamma_nll: 4.6984 - root_mean_squared_error: 4141.6309 - val_loss: 5.1247 - val_gamma_nll: 4.9548 - val_root_mean_squared_error: 4813.3354
# 1/1 [==============================] - 0s 17ms/step - loss: 5.0007 - gamma_nll: 4.9192 - root_mean_squared_error: 4482.7803
# Epoch 1/5000
# 12/12 [==============================] - 1s 28ms/step - loss: 5.0039 - gamma_nll: 4.9967 - root_mean_squared_error: 7299.0225 - val_loss: 8.5490 - val_gamma_nll: 5.4082 - val_root_mean_squared_error: 5221.1465
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.8735 - gamma_nll: 4.8724 - root_mean_squared_error: 4879.6597 - val_loss: 8.2980 - val_gamma_nll: 5.3743 - val_root_mean_squared_error: 5169.2490
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.8512 - gamma_nll: 4.8427 - root_mean_squared_error: 4754.5454 - val_loss: 8.0024 - val_gamma_nll: 5.3121 - val_root_mean_squared_error: 4881.5249
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.8365 - gamma_nll: 4.8240 - root_mean_squared_error: 4658.2358 - val_loss: 7.8304 - val_gamma_nll: 5.3127 - val_root_mean_squared_error: 4932.8813
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8225 - gamma_nll: 4.8188 - root_mean_squared_error: 4578.8320 - val_loss: 7.4779 - val_gamma_nll: 5.1889 - val_root_mean_squared_error: 4716.3198
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.8081 - gamma_nll: 4.8103 - root_mean_squared_error: 4561.4072 - val_loss: 7.3753 - val_gamma_nll: 5.2218 - val_root_mean_squared_error: 4729.5186
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.8007 - gamma_nll: 4.7987 - root_mean_squared_error: 4496.4570 - val_loss: 6.9128 - val_gamma_nll: 4.9920 - val_root_mean_squared_error: 4319.6396
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7801 - gamma_nll: 4.7741 - root_mean_squared_error: 4442.6616 - val_loss: 6.7934 - val_gamma_nll: 5.0141 - val_root_mean_squared_error: 4305.8877
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7743 - gamma_nll: 4.7798 - root_mean_squared_error: 4395.8828 - val_loss: 6.7326 - val_gamma_nll: 5.0456 - val_root_mean_squared_error: 4383.6606
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7623 - gamma_nll: 4.7608 - root_mean_squared_error: 4361.0586 - val_loss: 6.5196 - val_gamma_nll: 4.9806 - val_root_mean_squared_error: 4365.4136
# Epoch 11/5000
# ...
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7166 - gamma_nll: 4.7158 - root_mean_squared_error: 4175.7456 - val_loss: 4.8620 - val_gamma_nll: 4.8160 - val_root_mean_squared_error: 4180.5225
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7156 - gamma_nll: 4.6987 - root_mean_squared_error: 4175.1016 - val_loss: 4.9582 - val_gamma_nll: 4.8241 - val_root_mean_squared_error: 4410.0083
# 1/1 [==============================] - 0s 16ms/step - loss: 5.6219 - gamma_nll: 4.8075 - root_mean_squared_error: 4214.6567
# Epoch 1/5000
# 12/12 [==============================] - 1s 26ms/step - loss: 4.9090 - gamma_nll: 4.9023 - root_mean_squared_error: 4251.3428 - val_loss: 5.1804 - val_gamma_nll: 4.9719 - val_root_mean_squared_error: 4664.3735
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7934 - gamma_nll: 4.7908 - root_mean_squared_error: 4145.2134 - val_loss: 5.5788 - val_gamma_nll: 5.2961 - val_root_mean_squared_error: 5092.7192
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7589 - gamma_nll: 4.7559 - root_mean_squared_error: 4150.5005 - val_loss: 6.1995 - val_gamma_nll: 5.9673 - val_root_mean_squared_error: 4997.9214
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7539 - gamma_nll: 4.7417 - root_mean_squared_error: 4157.8838 - val_loss: 5.9274 - val_gamma_nll: 5.6849 - val_root_mean_squared_error: 5140.0601
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7404 - gamma_nll: 4.7357 - root_mean_squared_error: 4154.0786 - val_loss: 6.0849 - val_gamma_nll: 5.8249 - val_root_mean_squared_error: 5124.6465
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7288 - gamma_nll: 4.7345 - root_mean_squared_error: 4157.1538 - val_loss: 5.5418 - val_gamma_nll: 5.2155 - val_root_mean_squared_error: 5664.4297
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7366 - gamma_nll: 4.7354 - root_mean_squared_error: 4155.2954 - val_loss: 5.7957 - val_gamma_nll: 5.4943 - val_root_mean_squared_error: 5512.8975
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7262 - gamma_nll: 4.7202 - root_mean_squared_error: 4158.9136 - val_loss: 5.5350 - val_gamma_nll: 5.2844 - val_root_mean_squared_error: 5250.9863
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7203 - gamma_nll: 4.7264 - root_mean_squared_error: 4153.7925 - val_loss: 5.6927 - val_gamma_nll: 5.3733 - val_root_mean_squared_error: 4887.0005
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7232 - gamma_nll: 4.7231 - root_mean_squared_error: 4153.5630 - val_loss: 6.1404 - val_gamma_nll: 5.8494 - val_root_mean_squared_error: 4833.4673
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7161 - gamma_nll: 4.7013 - root_mean_squared_error: 4147.5752 - val_loss: 5.5371 - val_gamma_nll: 5.3696 - val_root_mean_squared_error: 5507.5674
# 1/1 [==============================] - 0s 16ms/step - loss: 5.1922 - gamma_nll: 4.9862 - root_mean_squared_error: 4664.3735
# Epoch 1/5000
# 12/12 [==============================] - 1s 27ms/step - loss: 4.8919 - gamma_nll: 4.8833 - root_mean_squared_error: 4365.8687 - val_loss: 4.8841 - val_gamma_nll: 4.8135 - val_root_mean_squared_error: 4486.5962
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6835 - gamma_nll: 4.6814 - root_mean_squared_error: 4139.0366 - val_loss: 4.9116 - val_gamma_nll: 4.7751 - val_root_mean_squared_error: 4456.3394
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6206 - gamma_nll: 4.6155 - root_mean_squared_error: 4145.2676 - val_loss: 5.1299 - val_gamma_nll: 4.7968 - val_root_mean_squared_error: 4535.0879
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.6019 - gamma_nll: 4.5897 - root_mean_squared_error: 4191.9722 - val_loss: 4.9505 - val_gamma_nll: 4.7083 - val_root_mean_squared_error: 4267.0205
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.5560 - gamma_nll: 4.5532 - root_mean_squared_error: 4136.8799 - val_loss: 5.0032 - val_gamma_nll: 4.7577 - val_root_mean_squared_error: 4233.2642
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.5318 - gamma_nll: 4.5384 - root_mean_squared_error: 4156.2925 - val_loss: 4.9227 - val_gamma_nll: 4.7338 - val_root_mean_squared_error: 4363.8159
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.5567 - gamma_nll: 4.5560 - root_mean_squared_error: 4182.1802 - val_loss: 4.9857 - val_gamma_nll: 4.6565 - val_root_mean_squared_error: 4172.0938
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.5079 - gamma_nll: 4.5041 - root_mean_squared_error: 4145.0957 - val_loss: 4.9715 - val_gamma_nll: 4.6794 - val_root_mean_squared_error: 4197.7671
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.5028 - gamma_nll: 4.5041 - root_mean_squared_error: 4161.2988 - val_loss: 4.9373 - val_gamma_nll: 4.6803 - val_root_mean_squared_error: 4164.5425
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4961 - gamma_nll: 4.4924 - root_mean_squared_error: 4152.8535 - val_loss: 4.9787 - val_gamma_nll: 4.6827 - val_root_mean_squared_error: 4160.5073
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.5032 - gamma_nll: 4.4841 - root_mean_squared_error: 4122.8423 - val_loss: 5.0143 - val_gamma_nll: 4.7425 - val_root_mean_squared_error: 4176.0190
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4658 - gamma_nll: 4.4744 - root_mean_squared_error: 4120.2002 - val_loss: 5.0923 - val_gamma_nll: 4.8250 - val_root_mean_squared_error: 4170.2334
# Epoch 13/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.5001 - gamma_nll: 4.5029 - root_mean_squared_error: 4141.1118 - val_loss: 5.1867 - val_gamma_nll: 4.7859 - val_root_mean_squared_error: 4173.5630
# Epoch 14/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4521 - gamma_nll: 4.4464 - root_mean_squared_error: 4111.3208 - val_loss: 5.2776 - val_gamma_nll: 4.8292 - val_root_mean_squared_error: 4176.8921
# Epoch 15/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4704 - gamma_nll: 4.4717 - root_mean_squared_error: 4124.1489 - val_loss: 5.1667 - val_gamma_nll: 4.6466 - val_root_mean_squared_error: 4193.4277
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.4519 - gamma_nll: 4.4351 - root_mean_squared_error: 4117.8301 - val_loss: 5.0601 - val_gamma_nll: 4.6316 - val_root_mean_squared_error: 4146.3887
# Epoch 17/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4744 - gamma_nll: 4.4584 - root_mean_squared_error: 4125.0215 - val_loss: 4.9414 - val_gamma_nll: 4.6394 - val_root_mean_squared_error: 4152.4517
# Epoch 18/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4513 - gamma_nll: 4.4564 - root_mean_squared_error: 4118.4673 - val_loss: 4.9726 - val_gamma_nll: 4.6526 - val_root_mean_squared_error: 4168.5493
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.4514 - gamma_nll: 4.4503 - root_mean_squared_error: 4107.5337 - val_loss: 4.9663 - val_gamma_nll: 4.6148 - val_root_mean_squared_error: 4140.1841
# Epoch 20/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4334 - gamma_nll: 4.4237 - root_mean_squared_error: 4106.2314 - val_loss: 5.1081 - val_gamma_nll: 4.6225 - val_root_mean_squared_error: 4131.3350
# Epoch 21/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4853 - gamma_nll: 4.4728 - root_mean_squared_error: 4116.6230 - val_loss: 4.9418 - val_gamma_nll: 4.6557 - val_root_mean_squared_error: 4153.9204
# Epoch 22/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4306 - gamma_nll: 4.4328 - root_mean_squared_error: 4099.4062 - val_loss: 5.0842 - val_gamma_nll: 4.6240 - val_root_mean_squared_error: 4139.6494
# Epoch 23/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4461 - gamma_nll: 4.4348 - root_mean_squared_error: 4112.4087 - val_loss: 4.9399 - val_gamma_nll: 4.6332 - val_root_mean_squared_error: 4148.1050
# Epoch 24/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4201 - gamma_nll: 4.4212 - root_mean_squared_error: 4096.7305 - val_loss: 4.8840 - val_gamma_nll: 4.8436 - val_root_mean_squared_error: 4168.6343
# Epoch 25/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4494 - gamma_nll: 4.4425 - root_mean_squared_error: 4130.9546 - val_loss: 4.9153 - val_gamma_nll: 4.7761 - val_root_mean_squared_error: 4165.2856
# Epoch 26/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4414 - gamma_nll: 4.4290 - root_mean_squared_error: 4115.4829 - val_loss: 5.3260 - val_gamma_nll: 4.8836 - val_root_mean_squared_error: 4180.0952
# Epoch 27/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.4474 - gamma_nll: 4.4410 - root_mean_squared_error: 4113.0435 - val_loss: 4.6999 - val_gamma_nll: 4.6108 - val_root_mean_squared_error: 4136.9277
# Epoch 28/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4429 - gamma_nll: 4.4378 - root_mean_squared_error: 4117.5127 - val_loss: 4.9578 - val_gamma_nll: 4.6762 - val_root_mean_squared_error: 4158.6997
# Epoch 29/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4264 - gamma_nll: 4.4240 - root_mean_squared_error: 4117.5649 - val_loss: 4.6663 - val_gamma_nll: 4.6139 - val_root_mean_squared_error: 4139.7026
# Epoch 30/5000
# 12/12 [==============================] - 0s 7ms/step - loss: 4.4717 - gamma_nll: 4.4609 - root_mean_squared_error: 4119.7388 - val_loss: 4.9368 - val_gamma_nll: 4.5877 - val_root_mean_squared_error: 4128.9937
# Epoch 31/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4161 - gamma_nll: 4.4130 - root_mean_squared_error: 4080.8022 - val_loss: 5.0084 - val_gamma_nll: 4.7434 - val_root_mean_squared_error: 4161.5854
# Epoch 32/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4378 - gamma_nll: 4.4342 - root_mean_squared_error: 4107.1655 - val_loss: 4.8468 - val_gamma_nll: 4.6336 - val_root_mean_squared_error: 4144.1572
# Epoch 33/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4527 - gamma_nll: 4.4515 - root_mean_squared_error: 4121.3462 - val_loss: 5.1303 - val_gamma_nll: 4.6049 - val_root_mean_squared_error: 4137.1470
# Epoch 34/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4224 - gamma_nll: 4.4266 - root_mean_squared_error: 4110.7822 - val_loss: 5.1860 - val_gamma_nll: 4.5909 - val_root_mean_squared_error: 4138.4287
# Epoch 35/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.4496 - gamma_nll: 4.4479 - root_mean_squared_error: 4117.0977 - val_loss: 5.0587 - val_gamma_nll: 4.5495 - val_root_mean_squared_error: 4131.3877
# Epoch 36/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4248 - gamma_nll: 4.4105 - root_mean_squared_error: 4104.2607 - val_loss: 5.1734 - val_gamma_nll: 4.5850 - val_root_mean_squared_error: 4136.1089
# Epoch 37/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.4217 - gamma_nll: 4.4133 - root_mean_squared_error: 4112.2246 - val_loss: 5.2077 - val_gamma_nll: 4.5446 - val_root_mean_squared_error: 4126.8906
# Epoch 38/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.4509 - gamma_nll: 4.4505 - root_mean_squared_error: 4122.8105 - val_loss: 5.0202 - val_gamma_nll: 4.5125 - val_root_mean_squared_error: 4117.9399
# Epoch 39/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.3927 - gamma_nll: 4.3838 - root_mean_squared_error: 4087.7319 - val_loss: 4.9510 - val_gamma_nll: 4.4965 - val_root_mean_squared_error: 4105.0127
# Epoch 40/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4209 - gamma_nll: 4.4243 - root_mean_squared_error: 4078.8584 - val_loss: 5.6477 - val_gamma_nll: 4.4993 - val_root_mean_squared_error: 4117.9341
# Epoch 41/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.3948 - gamma_nll: 4.3935 - root_mean_squared_error: 4086.2446 - val_loss: 4.9200 - val_gamma_nll: 4.4966 - val_root_mean_squared_error: 4113.5591
# Epoch 42/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.4082 - gamma_nll: 4.4034 - root_mean_squared_error: 4092.2756 - val_loss: 5.0867 - val_gamma_nll: 4.4653 - val_root_mean_squared_error: 4098.1289
# Epoch 43/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4308 - gamma_nll: 4.4231 - root_mean_squared_error: 4099.4702 - val_loss: 5.1007 - val_gamma_nll: 4.4540 - val_root_mean_squared_error: 4094.1982
# Epoch 44/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.4207 - gamma_nll: 4.4087 - root_mean_squared_error: 4095.4121 - val_loss: 5.1507 - val_gamma_nll: 4.4425 - val_root_mean_squared_error: 4098.4644
# Epoch 45/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.3942 - gamma_nll: 4.3830 - root_mean_squared_error: 4093.8901 - val_loss: 4.9558 - val_gamma_nll: 4.4570 - val_root_mean_squared_error: 4100.0420
# Epoch 46/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.4074 - gamma_nll: 4.4125 - root_mean_squared_error: 4094.8042 - val_loss: 4.8653 - val_gamma_nll: 4.4411 - val_root_mean_squared_error: 4101.2256
# Epoch 47/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.4337 - gamma_nll: 4.4188 - root_mean_squared_error: 4116.4077 - val_loss: 4.5345 - val_gamma_nll: 4.4220 - val_root_mean_squared_error: 4092.6931
# Epoch 48/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4108 - gamma_nll: 4.4329 - root_mean_squared_error: 4102.6831 - val_loss: 5.0772 - val_gamma_nll: 4.4801 - val_root_mean_squared_error: 4126.4482
# Epoch 49/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.3921 - gamma_nll: 4.3966 - root_mean_squared_error: 4084.4995 - val_loss: 5.1387 - val_gamma_nll: 4.4532 - val_root_mean_squared_error: 4107.3188
# Epoch 50/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4021 - gamma_nll: 4.3847 - root_mean_squared_error: 4089.5327 - val_loss: 5.0784 - val_gamma_nll: 4.4817 - val_root_mean_squared_error: 4185.2852
# Epoch 51/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4009 - gamma_nll: 4.3995 - root_mean_squared_error: 4102.1289 - val_loss: 4.9183 - val_gamma_nll: 4.4984 - val_root_mean_squared_error: 4290.2300
# Epoch 52/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4095 - gamma_nll: 4.4149 - root_mean_squared_error: 4097.0161 - val_loss: 5.3020 - val_gamma_nll: 4.5797 - val_root_mean_squared_error: 4237.2236
# Epoch 53/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.3997 - gamma_nll: 4.3970 - root_mean_squared_error: 4091.0427 - val_loss: 5.7519 - val_gamma_nll: 4.6303 - val_root_mean_squared_error: 4311.5820
# Epoch 54/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4066 - gamma_nll: 4.4096 - root_mean_squared_error: 4101.6143 - val_loss: 4.8229 - val_gamma_nll: 4.6111 - val_root_mean_squared_error: 4224.6318
# Epoch 55/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.3831 - gamma_nll: 4.3739 - root_mean_squared_error: 4062.7366 - val_loss: 5.4978 - val_gamma_nll: 4.5403 - val_root_mean_squared_error: 4223.5176
# Epoch 56/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.3790 - gamma_nll: 4.3713 - root_mean_squared_error: 4075.1353 - val_loss: 4.5805 - val_gamma_nll: 4.4676 - val_root_mean_squared_error: 4127.9536
# Epoch 57/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4307 - gamma_nll: 4.4318 - root_mean_squared_error: 4114.0283 - val_loss: 4.8349 - val_gamma_nll: 4.4437 - val_root_mean_squared_error: 4110.8354
# 1/1 [==============================] - 0s 16ms/step - loss: 4.5246 - gamma_nll: 4.4289 - root_mean_squared_error: 4092.6929

# %%
# -------------------------- plot the validation loss --------------------------
# Convert interaction loss dictionary to a pandas DataFrame
interaction_df = pd.DataFrame(list(interaction_loss.items()), columns = ['Interaction_Pair', 'Validation_Loss'])

# Sort the DataFrame by Validation_Loss in increasing order
interaction_df = interaction_df.sort_values(by = 'Validation_Loss', ascending = True)

# Create the bar plot using Seaborn
plt.figure(figsize = (20, 12))
sns.lineplot(x = 'Interaction_Pair', y = 'Validation_Loss', data = interaction_df, marker = 'o')
plt.axhline(main_val_loss, color = 'red', linestyle = '--', label = 'Validation Loss of Main Effect Model')
plt.xlabel('Interaction Effect Pairs')
plt.ylabel('Validation Loss')
plt.title('Validation Loss for Interaction Effect Pairs (Sorted by Increasing Loss)')
plt.legend()
plt.show()

# %%
# # -------------------------- Create the Pairwise Only Model --------------------------
# # pairwise_effect = ("X3", "X4")  # the pairwise effect we want to view
# pairwise_effect = interactions[0]
# pairwise_index = interactions.index(pairwise_effect)
# subnet_output_layer = model_pairwise.get_layer("interaction_output")
# subnet_model = Model(inputs = model_pairwise.inputs, outputs = subnet_output_layer.output)


# # -------------------------- Generate the Input Grid --------------------------
# # Create a grid of values
# grid_length = 100
# var1_values = np.linspace(X_train[interactions[pairwise_index][0]].min(), 
#                           X_train[interactions[pairwise_index][0]].max(), 
#                           grid_length)
# var2_values = np.linspace(X_train[interactions[pairwise_index][1]].min(), 
#                           X_train[interactions[pairwise_index][1]].max(), 
#                           grid_length)

# # Create a meshgrid
# grid_var1, grid_var2 = np.meshgrid(var1_values, var2_values)

# # Flatten the grid
# grid_flat_var1 = grid_var1.ravel()
# grid_flat_var2 = grid_var2.ravel()


# # -------------------------- Prepare Inputs for the Model --------------------------
# grid_inputs = []
# for var in all_vars:
#     if var == interactions[pairwise_index][0]:
#         grid_inputs.append(grid_flat_var1)
#     elif var == interactions[pairwise_index][1]:
#         grid_inputs.append(grid_flat_var2)
#     else:
#         grid_inputs.append(np.zeros_like(grid_flat_var1))


# # -------------------------- Predict Using the Pairwise-Only Model --------------------------
# # Predict the pairwise interaction effect
# pairwise_predictions = np.log(subnet_model.predict(grid_inputs))

# # Reshape the predictions to the grid format
# heatmap_values = pairwise_predictions.reshape(grid_var1.shape)


# # -------------------------- Plot the Heatmap --------------------------
# plt.figure(figsize = (10, 8))
# contour = plt.contourf(grid_var1, grid_var2, heatmap_values, levels = 10)
# plt.colorbar(contour)
# plt.title('Predicted Function by the Model')
# plt.xlabel(f"{interactions[pairwise_index][0]}")
# plt.ylabel(f"{interactions[pairwise_index][1]}")
# plt.show()

# %%
# #-------------------------- view the shape function --------------------------
# # get the prediction
# main_output_layer = model_pairwise.get_layer("main_subnet")
# subnet_model = Model(inputs = model_pairwise.inputs, outputs = main_output_layer.output)
# subnet_output = subnet_model.predict(X_train_split)

# # create the plot
# var_name = "X3"
# var_index = all_vars.index(var_name)
# plt.figure(figsize = (12, 6))
# sns.lineplot(x = X_train_split[var_index], 
#              y = subnet_output[:,var_index])
# plt.xlabel(f"{var_name}")
# plt.ylabel('Subnetwork Output')
# plt.title(f"Shape function for {var_name}")
# plt.grid(True)
# plt.show()
