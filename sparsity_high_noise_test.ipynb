# %%
############################ 0. PREPARATION ############################

#-------------------------- import packages --------------------------
import random
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from itertools import combinations
import seaborn as sns
import copy
import itertools

import tensorflow as tf
import tensorflow_lattice as tfl
import tf_keras as keras # need keras 2 to fit Lattice model
from tf_keras.models import Sequential, Model
from tf_keras.layers import Dense, Input, Multiply, Add, Embedding, Reshape, Concatenate, Dropout, BatchNormalization, Lambda, Layer, CategoryEncoding, Activation
from tf_keras.constraints import Constraint
from tf_keras.callbacks import EarlyStopping
from tf_keras.initializers import Zeros, Constant
from tf_keras.optimizers import Adam, Nadam, RMSprop
from tf_keras.models import clone_model
import keras_tuner as kt
from tf_keras import backend as K
from tf_keras import regularizers
from tf_keras.utils import plot_model
from tf_keras.losses import Poisson, Loss
from tf_keras.metrics import MeanAbsoluteError, RootMeanSquaredError
from scipy.stats import gamma


from pygam import LinearGAM, GAM, s, f, l
from sklearn.linear_model import ElasticNet
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error as mae
from sklearn.tree import DecisionTreeRegressor
from interpret.glassbox import ExplainableBoostingClassifier

# %%
#-------------------------- for reproducibility --------------------------
seed_value = 28
keras.utils.set_random_seed(seed_value)

# %%
#-------------------------- import data --------------------------
data = pd.read_csv("synthetic_low_var.csv")

# %%
#-------------------------- remove outliers --------------------------
log_claim = np.log(data['Y'])
IQR = log_claim.quantile(0.75) - log_claim.quantile(0.25) # inter-quartile range
lower_whisker = log_claim.quantile(0.25)- 1.5*IQR
upper_whisker = log_claim.quantile(0.75) + 1.5*IQR

# remove outliers: filter rows where the log of 'Y' is within the whiskers
dt_cleaned = data[(log_claim >= lower_whisker) & (log_claim <= upper_whisker)]
dt_cleaned
# Out:
#              X1        X2        X3        X4        X5        X6        X7  \
# 0      0.097627 -0.215654 -0.261487  0.855910 -0.977807  0.070514  0.247397
# 1      0.430379 -0.917687 -0.577348  0.805874 -0.996460  0.808088 -0.727145
# 2      0.205527  0.846601 -0.046190 -0.144766 -0.689890  0.004793  0.787168
# 3      0.089766 -0.187530 -0.835531  0.021611 -0.366478 -0.798260 -0.363850
# 4     -0.152690  0.888564 -0.524681  0.166400  0.303690  0.055164  0.158018
# ...         ...       ...       ...       ...       ...       ...       ...
# 19995  0.496349  0.336766  0.766494 -0.723110  0.451842 -0.547824  0.165682
# 19996 -0.403467  0.989823 -0.239838  0.690306  0.015041  0.168038 -0.808643
# 19997 -0.107088  0.176448 -0.661992  0.568246  0.620266  0.669292 -0.267906
# 19998 -0.279747 -0.150770 -0.472139  0.238510  0.102065 -0.832383  0.539168
# 19999  0.251773  0.803265 -0.397666 -0.684942 -0.548488 -0.791774 -0.620137
#
#              X8        X9       X10            Y
# 0     -0.844805 -0.633014  0.932805   269.727579
# 1      0.592222  0.416902  0.949203   606.423722
# 2     -0.029304 -0.254262 -0.739165  6740.904922
# 3      0.669637 -0.150974  0.020263  6749.592779
# 4      0.046901 -0.468522 -0.772319    79.024055
# ...         ...       ...       ...          ...
# 19995 -0.515032  0.372611 -0.262674    30.561326
# 19996 -0.903895 -0.433667 -0.389854   105.129106
# 19997  0.006409  0.871063 -0.570751  1101.252426
# 19998  0.073274  0.110462 -0.408447   634.928937
# 19999  0.197031 -0.409905  0.685008  2295.828834
#
# [19825 rows x 11 columns]

# %%
#-------------------------- distribution of log(response) --------------------------
plt.figure(figsize = (10, 6)) # set the size of the figure
sns.set_style("darkgrid")
sns.histplot(np.log(dt_cleaned['Y']), bins = 30, kde = True) # draw the chart
plt.title('Distribution of log(Y)')
plt.xlabel('Log(Y)')
plt.ylabel('Frequency')
plt.tick_params(axis = 'x')
plt.tick_params(axis = 'y')
plt.grid(True)
plt.show()

# %%
#-------------------------- column lists --------------------------
target_var = "Y" # target feature
all_vars = list(dt_cleaned.columns)
all_vars.remove(target_var) # store all input features
cat_vars = [] # categorical features

# %%
############################ 1. MODEL FITTING ############################

#-------------------------- train-test split --------------------------
X_main, X_test, y_main, y_test = train_test_split(
    dt_cleaned[all_vars], dt_cleaned[["Y"]], test_size = 0.2, random_state = 1)
X_train, X_val, y_train, y_val  = train_test_split(
    X_main, y_main, test_size = 0.25, random_state = 1)

# %%
# -------------------------- function to create a subnetwork --------------------------
# subnet for numerical variables
def create_subnet(num_layers, units_per_layer, activation, model_name, dropout_rate = 0, trainable = True, seed = 1):
    model = Sequential(name = model_name)
    for _ in range(num_layers):
        model.add(Dense(units_per_layer, activation = activation, trainable = trainable))
        model.add(Dropout(dropout_rate, seed = seed))
    model.add(Dense(1, trainable = trainable))
    model.add(BatchNormalization(scale = False)) # for identifiability
    return model

# layer to add all subnets' outputs and a bias term
@keras.saving.register_keras_serializable()
class AddSubnetOutput(Layer):
    def __init__(self, activation = None, **kwargs):
        super().__init__(**kwargs)
        self.activation = keras.activations.get(activation)
        self.bias = self.add_weight(
            shape = (1,), initializer = 'zeros', trainable = True, name = 'bias'
        )   
    def call(self, inputs):
        subnet_sum = K.sum(inputs, axis = -1, keepdims = True)
        output = subnet_sum + self.bias
        if self.activation is not None:
            output = self.activation(output)
        return output

# %%
# -------------------------- define model architecture --------------------------
inputs = []  # input layers
sub_outputs_main = []  # main effect subnet output
num_neurons_main = 10
num_layers_main = 2
activation = 'leaky_relu'
keypoints = 10
monotonicity_list = {"X3" : "decreasing"} # either "increasing", "decreasing", or "none"

# main effect
for name in all_vars:
    input_layer = Input(shape = (1,), name = name)
    inputs.append(input_layer)

    # subnetworks for main effects
    if name in cat_vars: # categorical variables
        # categorical variables will be one-hot encoded
        embed_layer = Embedding(input_dim = X_train[name].nunique(), 
                                output_dim = 1, 
                                name = f"{name}_embed")(input_layer)
        embed_layer_reshape = Reshape(target_shape = (1,), name = f"{name}_reshape")(embed_layer)
        mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(embed_layer_reshape)
        sub_outputs_main.append(mean_layer)
    elif name in monotonicity_list: # variables with monotonicity constraint
        calibrator_layer = tfl.layers.PWLCalibration(
            input_keypoints =  np.linspace(X_train[name].min(), X_train[name].max(), num = keypoints), # keypoints
            monotonicity = monotonicity_list[name], # monotonicity constraint
            name = f"{name}_pwlcalibrator"
        )(input_layer)
        mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(calibrator_layer)
        sub_outputs_main.append(mean_layer)
    else: # numeric variables
        subnet = create_subnet(num_layers_main, num_neurons_main, activation, f"{name}_subnetwork")
        sub_output = subnet(input_layer)
        sub_outputs_main.append(sub_output)

# combine subnets' outputs
main_subnets = Concatenate(name = "main_subnet")(sub_outputs_main)
final_output = AddSubnetOutput(activation = 'exponential',
                     name = "main_output")(main_subnets)

# final model
model_main_effect = Model(inputs = inputs, outputs = final_output)

# %%
plot_model(model_main_effect)

# %%
# -------------------------- define loss function --------------------------
# we will use a Gamma loss function
def gamma_nll(y_true, y_pred):
    y_pred = K.clip(y_pred, 1e-7, 1e30)
    return K.mean(y_true/y_pred - K.log(y_true/y_pred))

# create training & validation data consistent with the model architecture
X_train_split = []
X_val_split = []
X_test_split = []
for i in range(len(X_train.columns)):
    X_train_split.append(X_train.iloc[:, i])
    X_val_split.append(X_val.iloc[:, i])
    X_test_split.append(X_test.iloc[:, i])

# compile and fit
model_main_effect.compile(optimizer = "rmsprop", loss = gamma_nll, metrics = [RootMeanSquaredError()])
es = EarlyStopping(restore_best_weights = True, patience = 10)
# %time hist_main = model_main_effect.fit(X_train_split, y_train, epochs = 5_000, \
    callbacks = [es], batch_size = 1_000, validation_data = (X_val_split, y_val))
# Out:
# Epoch 1/5000
# 12/12 [==============================] - 2s 26ms/step - loss: 16906.7871 - root_mean_squared_error: 2450.9612 - val_loss: 919.2094 - val_root_mean_squared_error: 2619.4668
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 9504.6572 - root_mean_squared_error: 2415.3411 - val_loss: 817.6498 - val_root_mean_squared_error: 2619.4243
# Epoch 3/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 6746.4097 - root_mean_squared_error: 2399.9993 - val_loss: 751.2767 - val_root_mean_squared_error: 2619.3923
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4855.9927 - root_mean_squared_error: 2396.6296 - val_loss: 671.0491 - val_root_mean_squared_error: 2619.3479
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2789.1682 - root_mean_squared_error: 2394.0803 - val_loss: 613.0065 - val_root_mean_squared_error: 2619.3115
# Epoch 6/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 1556.4285 - root_mean_squared_error: 2392.6592 - val_loss: 562.2798 - val_root_mean_squared_error: 2619.2725
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 1045.0273 - root_mean_squared_error: 2392.7883 - val_loss: 513.9258 - val_root_mean_squared_error: 2619.2344
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 604.1174 - root_mean_squared_error: 2394.0742 - val_loss: 494.6069 - val_root_mean_squared_error: 2619.2129
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 461.8718 - root_mean_squared_error: 2394.4775 - val_loss: 463.6653 - val_root_mean_squared_error: 2619.1719
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 363.9429 - root_mean_squared_error: 2394.6606 - val_loss: 386.6699 - val_root_mean_squared_error: 2619.0386
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 296.8462 - root_mean_squared_error: 2394.5762 - val_loss: 336.8481 - val_root_mean_squared_error: 2618.9204
# Epoch 12/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 235.9178 - root_mean_squared_error: 2394.5903 - val_loss: 298.9395 - val_root_mean_squared_error: 2618.8042
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 191.2889 - root_mean_squared_error: 2394.4258 - val_loss: 275.3257 - val_root_mean_squared_error: 2618.7151
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 165.9142 - root_mean_squared_error: 2394.0642 - val_loss: 234.3247 - val_root_mean_squared_error: 2618.5178
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 146.9191 - root_mean_squared_error: 2393.6357 - val_loss: 216.9928 - val_root_mean_squared_error: 2618.4106
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 128.3909 - root_mean_squared_error: 2392.9204 - val_loss: 177.4170 - val_root_mean_squared_error: 2618.0942
# Epoch 17/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 113.9331 - root_mean_squared_error: 2392.4609 - val_loss: 166.6035 - val_root_mean_squared_error: 2617.9785
# Epoch 18/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 100.8314 - root_mean_squared_error: 2391.5659 - val_loss: 153.4689 - val_root_mean_squared_error: 2617.8191
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 88.6594 - root_mean_squared_error: 2390.9309 - val_loss: 150.1302 - val_root_mean_squared_error: 2617.7712
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 78.0292 - root_mean_squared_error: 2390.1001 - val_loss: 129.8900 - val_root_mean_squared_error: 2617.4519
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 69.8671 - root_mean_squared_error: 2388.9324 - val_loss: 112.7994 - val_root_mean_squared_error: 2617.0928
# Epoch 22/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 60.2019 - root_mean_squared_error: 2387.8396 - val_loss: 92.4781 - val_root_mean_squared_error: 2616.4961
# Epoch 23/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 53.8496 - root_mean_squared_error: 2386.4656 - val_loss: 81.7648 - val_root_mean_squared_error: 2616.0559
# Epoch 24/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 47.1298 - root_mean_squared_error: 2385.0588 - val_loss: 64.8140 - val_root_mean_squared_error: 2615.0786
# Epoch 25/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 42.0419 - root_mean_squared_error: 2383.3464 - val_loss: 52.4842 - val_root_mean_squared_error: 2613.9873
# Epoch 26/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 37.1816 - root_mean_squared_error: 2381.5073 - val_loss: 41.0754 - val_root_mean_squared_error: 2612.3911
# Epoch 27/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 32.7992 - root_mean_squared_error: 2379.4197 - val_loss: 35.4493 - val_root_mean_squared_error: 2611.2268
# Epoch 28/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 28.8973 - root_mean_squared_error: 2377.0789 - val_loss: 31.9977 - val_root_mean_squared_error: 2610.3425
# Epoch 29/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 25.1664 - root_mean_squared_error: 2374.6143 - val_loss: 32.7042 - val_root_mean_squared_error: 2610.4790
# Epoch 30/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 22.4585 - root_mean_squared_error: 2371.3955 - val_loss: 30.8670 - val_root_mean_squared_error: 2609.9202
# Epoch 31/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 19.9103 - root_mean_squared_error: 2368.2795 - val_loss: 21.4919 - val_root_mean_squared_error: 2605.7278
# Epoch 32/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 17.5581 - root_mean_squared_error: 2364.9487 - val_loss: 18.5555 - val_root_mean_squared_error: 2603.5515
# Epoch 33/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 15.4593 - root_mean_squared_error: 2360.8013 - val_loss: 20.6184 - val_root_mean_squared_error: 2604.9512
# Epoch 34/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 13.6629 - root_mean_squared_error: 2356.3032 - val_loss: 16.8701 - val_root_mean_squared_error: 2601.6064
# Epoch 35/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 12.0616 - root_mean_squared_error: 2350.7925 - val_loss: 20.0736 - val_root_mean_squared_error: 2604.3550
# Epoch 36/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 10.5728 - root_mean_squared_error: 2345.2822 - val_loss: 12.6940 - val_root_mean_squared_error: 2595.7102
# Epoch 37/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 9.4348 - root_mean_squared_error: 2339.5002 - val_loss: 15.7904 - val_root_mean_squared_error: 2600.0613
# Epoch 38/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 8.6265 - root_mean_squared_error: 2333.2161 - val_loss: 11.9807 - val_root_mean_squared_error: 2593.7700
# Epoch 39/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 7.3759 - root_mean_squared_error: 2324.1558 - val_loss: 20.4609 - val_root_mean_squared_error: 2604.0288
# Epoch 40/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 6.7155 - root_mean_squared_error: 2316.6497 - val_loss: 17.8321 - val_root_mean_squared_error: 2601.7488
# Epoch 41/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 5.8883 - root_mean_squared_error: 2306.5679 - val_loss: 24.5739 - val_root_mean_squared_error: 2606.4937
# Epoch 42/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 5.3972 - root_mean_squared_error: 2299.0540 - val_loss: 26.7166 - val_root_mean_squared_error: 2607.1577
# Epoch 43/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7585 - root_mean_squared_error: 2288.3967 - val_loss: 13.5078 - val_root_mean_squared_error: 2594.7026
# Epoch 44/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.3085 - root_mean_squared_error: 2271.8220 - val_loss: 11.7944 - val_root_mean_squared_error: 2591.1177
# Epoch 45/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 3.9159 - root_mean_squared_error: 2265.5330 - val_loss: 9.2377 - val_root_mean_squared_error: 2583.2917
# Epoch 46/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 3.6202 - root_mean_squared_error: 2250.1309 - val_loss: 7.1023 - val_root_mean_squared_error: 2571.8335
# Epoch 47/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 3.3002 - root_mean_squared_error: 2235.1145 - val_loss: 4.8109 - val_root_mean_squared_error: 2546.4448
# Epoch 48/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.0685 - root_mean_squared_error: 2223.0986 - val_loss: 7.1430 - val_root_mean_squared_error: 2569.2729
# Epoch 49/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.8484 - root_mean_squared_error: 2205.0959 - val_loss: 5.9972 - val_root_mean_squared_error: 2558.5786
# Epoch 50/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.7191 - root_mean_squared_error: 2199.4734 - val_loss: 2.7406 - val_root_mean_squared_error: 2456.7646
# Epoch 51/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.5723 - root_mean_squared_error: 2192.7131 - val_loss: 2.5118 - val_root_mean_squared_error: 2418.6311
# Epoch 52/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.4751 - root_mean_squared_error: 2184.1238 - val_loss: 2.3174 - val_root_mean_squared_error: 2338.2258
# Epoch 53/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.4011 - root_mean_squared_error: 2174.7180 - val_loss: 2.3948 - val_root_mean_squared_error: 2386.3330
# Epoch 54/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3321 - root_mean_squared_error: 2173.8098 - val_loss: 2.3797 - val_root_mean_squared_error: 2359.6902
# Epoch 55/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2789 - root_mean_squared_error: 2167.1262 - val_loss: 2.4467 - val_root_mean_squared_error: 2431.4524
# Epoch 56/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2544 - root_mean_squared_error: 2195.7070 - val_loss: 2.8658 - val_root_mean_squared_error: 3710.1416
# Epoch 57/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2429 - root_mean_squared_error: 2200.4775 - val_loss: 2.9882 - val_root_mean_squared_error: 4806.9341
# Epoch 58/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2357 - root_mean_squared_error: 2254.5532 - val_loss: 3.2004 - val_root_mean_squared_error: 5947.3540
# Epoch 59/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2303 - root_mean_squared_error: 2218.0005 - val_loss: 2.6472 - val_root_mean_squared_error: 3305.4585
# Epoch 60/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2404 - root_mean_squared_error: 2257.6753 - val_loss: 3.0537 - val_root_mean_squared_error: 5082.3511
# Epoch 61/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2337 - root_mean_squared_error: 2277.3535 - val_loss: 2.3868 - val_root_mean_squared_error: 2472.4202
# Epoch 62/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2361 - root_mean_squared_error: 2260.3267 - val_loss: 2.4889 - val_root_mean_squared_error: 2776.5125
# CPU times: user 6.33 s, sys: 781 ms, total: 7.11 s
# Wall time: 5.77 s

# %%
# -------------------------- get validation loss --------------------------
main_val_loss, main_rmse = model_main_effect.evaluate(X_val_split, y_val, verbose = False) # get the validation loss and RMSE
print(f"Validation loss for main effect: {main_val_loss}")
print(f"Validation RMSE for main effect: {main_rmse}")
# Out:
# Validation loss for main effect: 2.3174352645874023
# Validation RMSE for main effect: 2338.225830078125

# %%
# -------------------------- quantify variable importance --------------------------
main_output_layer = model_main_effect.get_layer("main_subnet")  # Get the subnet output layer
main_model = Model(inputs = model_main_effect.inputs, outputs = main_output_layer.output)
main_output_values = main_model.predict(X_train_split)
# subnet_weights = model_main_effect.get_layer("main_output").get_weights()[0]


# Get the variance of each subnetwork across all data points
subnet_variance = []
for i in range(main_output_values.shape[1]):
    subnet_variance.append(np.var(main_output_values[:, i]))

# Define covariates
covariates = [name for name in all_vars]

# -------------------------- plot the variable importance --------------------------
# Create DataFrame for variable importance
var_importance = pd.DataFrame({"Covariates": covariates, "Subnet Variance": subnet_variance})

# Sort the DataFrame by subnet variance in decreasing order
varimp_sorted = var_importance.sort_values(by = "Subnet Variance", ascending = False)

# Create a bar plot using Seaborn
plt.figure(figsize = (10, 6))
sns.barplot(x = "Covariates", y = "Subnet Variance", data = varimp_sorted)
plt.title("Subnet Variance by Covariates")
plt.xlabel("Covariates")
plt.ylabel("Subnet Variance")
plt.show()
# Out:
# 372/372 [==============================] - 0s 779us/step

# %%
#-------------------------- view the shape function --------------------------
# create the plot
var_name = "X3"
var_index = all_vars.index(var_name)
plt.figure(figsize = (12, 6))
sns.lineplot(x = X_train_split[var_index], 
             y = main_output_values[:,var_index].flatten())
plt.xlabel(f"{var_name}")
plt.ylabel('Subnetwork Output')
plt.title(f"Shape function for {var_name}")
plt.grid(True)
plt.show()

# %%
############################   preparation for interaction selection   ############################
global_layers = ["main_subnet", "main_output", "interaction_output", "final_output"] # these layers are always trainable
interaction_loss = {} # this stores the validation loss when fitting each pair of interaction effect
imp_vars = [f"X{i}" for i in range(1,7)] # important variables
interactions = combinations(imp_vars, 2)
num_layers_interaction = 3 # number of layers for each interaction effect
num_neurons_interaction = 30 # number of neurons per dense layer for each interaction effect
keypoints = 20
lattice_sizes_pairwise = {}
for var in imp_vars:
    if var in cat_vars:
        lattice_sizes_pairwise[var] = X_train[var].nunique()
    else:
        lattice_sizes_pairwise[var] = 8

# %%
# -------------------------- create calibrator for lattice layer --------------------------
def add_calibrate_layer(var, data, monotonicity_list, lattice_sizes, keypoints, cat_vars, lattice_smooth_reg = [0,0]):
    if var in cat_vars:
        calibrator_layer = tfl.layers.CategoricalCalibration(
            num_buckets = data[var].nunique(),
            output_min = 0,
            output_max = lattice_sizes[var] - 1,
            name = f"{var}_calibrator_pairwise"
        )
    else:
        calibrator_layer = tfl.layers.PWLCalibration(
            input_keypoints =  np.linspace(data[var].min(), data[var].max(), num = keypoints), # keypoints
            kernel_regularizer = ('hessian', lattice_smooth_reg[0], lattice_smooth_reg[1]), # for smoothness
            monotonicity = monotonicity_list[var] if var in monotonicity_list else "none", # monotonicity constraint
            output_min = 0,
            output_max = lattice_sizes[var] - 1,
            name = f"{var}_calibrator_pairwise"
            )
    return calibrator_layer

# %%
############################   select interaction effect   ############################

# add pairwise effect and evaluate validation loss
for var1, var2 in interactions:

    # -------------------------- initialize a cloned model --------------------------
    model_main_cloned = clone_model(model_main_effect) # clone the main effect model
    model_main_cloned.build(model_main_effect.input_shape)
    model_main_cloned.set_weights(model_main_effect.get_weights()) # copy the weights


    # -------------------------- build a subnet for pairwise interaction effect --------------------------
    var1_input = model_main_cloned.inputs[all_vars.index(var1)]
    var2_input = model_main_cloned.inputs[all_vars.index(var2)]

    # Lattice model if the pair contains a monotonic variable
    if any(var in monotonicity_list for var in [var1, var2]):
        lattice_inputs = []

        # create calibrator_layer
        calibrator_var1 = add_calibrate_layer(var1, X_train, monotonicity_list, lattice_sizes_pairwise, keypoints, cat_vars)
        calibrator_var2 = add_calibrate_layer(var2, X_train, monotonicity_list, lattice_sizes_pairwise, keypoints, cat_vars)
        calibrator_layer_var1 = calibrator_var1(var1_input)
        calibrator_layer_var2 = calibrator_var2(var2_input)
        
        # lattice
        lattice_inputs.append(calibrator_layer_var1)
        lattice_inputs.append(calibrator_layer_var2)
        lattice_layer = tfl.layers.Lattice(lattice_sizes = [lattice_sizes_pairwise[var1],lattice_sizes_pairwise[var2]], 
                             monotonicities = ["increasing" if var1 in monotonicity_list else 'none',
                                                "increasing" if var2 in monotonicity_list else 'none'],
                             name = f"{var1}_{var2}_lattice")(lattice_inputs)
        pairwise_output = BatchNormalization(scale = False, name = f"{var1}_{var2}_mean")(lattice_layer)
    else:
        # Subnetwork if the pair contains no monotonic variables
        pairwise_input_layer = Concatenate(name = f"{var1}_{var2}_concat")([var1_input, var2_input])
        pairwise_subnet = create_subnet(num_layers_interaction, 
                                        num_neurons_interaction, 
                                        activation, 
                                        f"{var1}_{var2}_subnetwork")
        pairwise_output = pairwise_subnet(pairwise_input_layer)

    # final output
    interaction_subnet_output = Activation('exponential',
                        name = "interaction_output")(pairwise_output)
    main_subnet_output = model_main_cloned.output
    final_output = Multiply(name = "final_output")([main_subnet_output, interaction_subnet_output])
    model_pairwise = Model(inputs = model_main_cloned.inputs, outputs = final_output)


    # -------------------------- switch on/off layers --------------------------
    for layer in model_pairwise.layers:
        if layer.name not in global_layers and var1 not in layer.name and var2 not in layer.name:
            layer.trainable = False


    #-------------------------- custom loss function with marginal clarity constraint --------------------------
    # add marginal clarity constraint
    main_effects_output = model_pairwise.get_layer("main_subnet").output
    main_output_var1 = main_effects_output[all_vars.index(var1)]
    main_output_var2 = main_effects_output[all_vars.index(var2)]
    interaction_output = pairwise_output
    lambd = 5
    penalty = lambd * (
        K.abs(K.mean(main_output_var1 * interaction_output)) +
        K.abs(K.mean(main_output_var2 * interaction_output))
    )

    # Add the penalty to the model's total loss
    model_pairwise.add_loss(penalty)

    # -------------------------- compile and train the model --------------------------
    model_pairwise.compile(optimizer = 'rmsprop', 
                           loss = gamma_nll, 
                           metrics = [gamma_nll, RootMeanSquaredError()])
    es = EarlyStopping(patience = 10, restore_best_weights = True)
    model_pairwise.fit(X_train_split, y_train, epochs = 5_000, \
                            callbacks = [es], batch_size = 1_000, validation_data = (X_val_split, y_val))
    _, gamma_log_metric, _ = model_pairwise.evaluate(X_val_split, y_val, batch_size = X_val_split[0].shape[0])
    interaction_loss[f"{var1}_{var2}"] = gamma_log_metric # add to the val loss list
# Out:
# Epoch 1/5000
# 12/12 [==============================] - 2s 29ms/step - loss: 2.4437 - gamma_nll: 2.4366 - root_mean_squared_error: 2215.7883 - val_loss: 3.6532 - val_gamma_nll: 2.3912 - val_root_mean_squared_error: 2354.5784
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3100 - gamma_nll: 2.3060 - root_mean_squared_error: 2118.4719 - val_loss: 3.6844 - val_gamma_nll: 2.4395 - val_root_mean_squared_error: 2425.0264
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3072 - gamma_nll: 2.3041 - root_mean_squared_error: 2119.6091 - val_loss: 3.8147 - val_gamma_nll: 2.4950 - val_root_mean_squared_error: 2600.7893
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2818 - gamma_nll: 2.2787 - root_mean_squared_error: 2104.3132 - val_loss: 3.6991 - val_gamma_nll: 2.4742 - val_root_mean_squared_error: 2461.1396
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2869 - gamma_nll: 2.2845 - root_mean_squared_error: 2106.8962 - val_loss: 3.6762 - val_gamma_nll: 2.5113 - val_root_mean_squared_error: 2689.6863
# Epoch 6/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2700 - gamma_nll: 2.2666 - root_mean_squared_error: 2100.8477 - val_loss: 3.5424 - val_gamma_nll: 2.4780 - val_root_mean_squared_error: 2610.7798
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2735 - gamma_nll: 2.2703 - root_mean_squared_error: 2105.5383 - val_loss: 3.4319 - val_gamma_nll: 2.4320 - val_root_mean_squared_error: 2464.2507
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2757 - gamma_nll: 2.2723 - root_mean_squared_error: 2104.9482 - val_loss: 3.3852 - val_gamma_nll: 2.4504 - val_root_mean_squared_error: 2531.0342
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2631 - gamma_nll: 2.2597 - root_mean_squared_error: 2097.5173 - val_loss: 3.1941 - val_gamma_nll: 2.4683 - val_root_mean_squared_error: 2627.9421
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2618 - gamma_nll: 2.2587 - root_mean_squared_error: 2099.0442 - val_loss: 3.2205 - val_gamma_nll: 2.4957 - val_root_mean_squared_error: 2739.4729
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2631 - gamma_nll: 2.2604 - root_mean_squared_error: 2102.5161 - val_loss: 3.1001 - val_gamma_nll: 2.5071 - val_root_mean_squared_error: 2777.0940
# Epoch 12/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2611 - gamma_nll: 2.2578 - root_mean_squared_error: 2098.8257 - val_loss: 2.7716 - val_gamma_nll: 2.5212 - val_root_mean_squared_error: 2949.5122
# Epoch 13/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2604 - gamma_nll: 2.2570 - root_mean_squared_error: 2096.5906 - val_loss: 2.7771 - val_gamma_nll: 2.4563 - val_root_mean_squared_error: 2663.1272
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2506 - gamma_nll: 2.2478 - root_mean_squared_error: 2092.9055 - val_loss: 2.6125 - val_gamma_nll: 2.5023 - val_root_mean_squared_error: 2857.5393
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2455 - gamma_nll: 2.2431 - root_mean_squared_error: 2092.2239 - val_loss: 2.5993 - val_gamma_nll: 2.4782 - val_root_mean_squared_error: 2612.2068
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2469 - gamma_nll: 2.2437 - root_mean_squared_error: 2089.3696 - val_loss: 2.5802 - val_gamma_nll: 2.4906 - val_root_mean_squared_error: 2795.7520
# Epoch 17/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2428 - gamma_nll: 2.2399 - root_mean_squared_error: 2089.5808 - val_loss: 2.6333 - val_gamma_nll: 2.4476 - val_root_mean_squared_error: 2629.9897
# Epoch 18/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2424 - gamma_nll: 2.2391 - root_mean_squared_error: 2087.0479 - val_loss: 2.7060 - val_gamma_nll: 2.5166 - val_root_mean_squared_error: 2935.1189
# Epoch 19/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2446 - gamma_nll: 2.2421 - root_mean_squared_error: 2084.4102 - val_loss: 2.8201 - val_gamma_nll: 2.4702 - val_root_mean_squared_error: 2771.9678
# Epoch 20/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2399 - gamma_nll: 2.2361 - root_mean_squared_error: 2084.1394 - val_loss: 3.1929 - val_gamma_nll: 2.5174 - val_root_mean_squared_error: 3057.7246
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2433 - gamma_nll: 2.2406 - root_mean_squared_error: 2085.0374 - val_loss: 3.1927 - val_gamma_nll: 2.4800 - val_root_mean_squared_error: 2767.4636
# Epoch 22/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2404 - gamma_nll: 2.2374 - root_mean_squared_error: 2085.9873 - val_loss: 3.1722 - val_gamma_nll: 2.4570 - val_root_mean_squared_error: 2606.8079
# Epoch 23/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2376 - gamma_nll: 2.2347 - root_mean_squared_error: 2083.8411 - val_loss: 3.1232 - val_gamma_nll: 2.4012 - val_root_mean_squared_error: 2491.0991
# Epoch 24/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2319 - gamma_nll: 2.2287 - root_mean_squared_error: 2078.4001 - val_loss: 2.8928 - val_gamma_nll: 2.4240 - val_root_mean_squared_error: 2432.7454
# Epoch 25/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2382 - gamma_nll: 2.2354 - root_mean_squared_error: 2081.5854 - val_loss: 2.7918 - val_gamma_nll: 2.4179 - val_root_mean_squared_error: 2526.9287
# Epoch 26/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2332 - gamma_nll: 2.2299 - root_mean_squared_error: 2079.2717 - val_loss: 2.7969 - val_gamma_nll: 2.3793 - val_root_mean_squared_error: 2429.0527
# 1/1 [==============================] - 0s 18ms/step - loss: 2.5745 - gamma_nll: 2.4910 - root_mean_squared_error: 2795.7520
# Epoch 1/5000
# 12/12 [==============================] - 2s 31ms/step - loss: 2.5336 - gamma_nll: 2.5264 - root_mean_squared_error: 2853.3911 - val_loss: 6.4928 - val_gamma_nll: 3.1443 - val_root_mean_squared_error: 3951.3157
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3421 - gamma_nll: 2.3378 - root_mean_squared_error: 2234.9373 - val_loss: 6.2575 - val_gamma_nll: 3.1251 - val_root_mean_squared_error: 3940.0244
# Epoch 3/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3379 - gamma_nll: 2.3352 - root_mean_squared_error: 2234.3201 - val_loss: 5.7506 - val_gamma_nll: 2.9396 - val_root_mean_squared_error: 3279.2427
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3305 - gamma_nll: 2.3275 - root_mean_squared_error: 2245.7942 - val_loss: 5.5064 - val_gamma_nll: 2.8987 - val_root_mean_squared_error: 3151.8896
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3245 - gamma_nll: 2.3220 - root_mean_squared_error: 2253.2769 - val_loss: 5.3008 - val_gamma_nll: 2.8822 - val_root_mean_squared_error: 3136.3035
# Epoch 6/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3162 - gamma_nll: 2.3131 - root_mean_squared_error: 2235.8545 - val_loss: 5.0397 - val_gamma_nll: 2.8202 - val_root_mean_squared_error: 3017.5635
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3181 - gamma_nll: 2.3151 - root_mean_squared_error: 2258.5042 - val_loss: 5.1826 - val_gamma_nll: 3.0187 - val_root_mean_squared_error: 3722.1243
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3111 - gamma_nll: 2.3078 - root_mean_squared_error: 2273.5112 - val_loss: 4.7251 - val_gamma_nll: 2.7799 - val_root_mean_squared_error: 2988.1768
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3106 - gamma_nll: 2.3076 - root_mean_squared_error: 2266.9231 - val_loss: 4.6726 - val_gamma_nll: 2.8270 - val_root_mean_squared_error: 3131.4165
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3027 - gamma_nll: 2.2996 - root_mean_squared_error: 2277.1648 - val_loss: 4.5447 - val_gamma_nll: 2.7988 - val_root_mean_squared_error: 3089.8098
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3103 - gamma_nll: 2.3071 - root_mean_squared_error: 2306.2822 - val_loss: 4.4193 - val_gamma_nll: 2.7969 - val_root_mean_squared_error: 3142.7009
# Epoch 12/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3054 - gamma_nll: 2.3019 - root_mean_squared_error: 2300.2139 - val_loss: 4.1185 - val_gamma_nll: 2.6458 - val_root_mean_squared_error: 2751.7166
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3019 - gamma_nll: 2.2984 - root_mean_squared_error: 2297.2649 - val_loss: 3.9269 - val_gamma_nll: 2.5672 - val_root_mean_squared_error: 2685.6943
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3004 - gamma_nll: 2.2977 - root_mean_squared_error: 2315.6768 - val_loss: 3.6344 - val_gamma_nll: 2.4037 - val_root_mean_squared_error: 2390.1851
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2925 - gamma_nll: 2.2898 - root_mean_squared_error: 2312.5171 - val_loss: 3.7072 - val_gamma_nll: 2.5110 - val_root_mean_squared_error: 2564.6086
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2935 - gamma_nll: 2.2907 - root_mean_squared_error: 2318.9902 - val_loss: 3.8644 - val_gamma_nll: 2.6825 - val_root_mean_squared_error: 3050.9214
# Epoch 17/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2925 - gamma_nll: 2.2895 - root_mean_squared_error: 2322.5315 - val_loss: 3.6504 - val_gamma_nll: 2.5690 - val_root_mean_squared_error: 2764.2524
# Epoch 18/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2905 - gamma_nll: 2.2872 - root_mean_squared_error: 2325.2363 - val_loss: 3.3979 - val_gamma_nll: 2.4173 - val_root_mean_squared_error: 2472.6711
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2930 - gamma_nll: 2.2901 - root_mean_squared_error: 2326.3315 - val_loss: 3.3693 - val_gamma_nll: 2.4313 - val_root_mean_squared_error: 2572.2141
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2901 - gamma_nll: 2.2867 - root_mean_squared_error: 2327.8318 - val_loss: 3.3659 - val_gamma_nll: 2.4321 - val_root_mean_squared_error: 2529.8875
# Epoch 21/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2894 - gamma_nll: 2.2870 - root_mean_squared_error: 2333.0542 - val_loss: 3.3863 - val_gamma_nll: 2.4895 - val_root_mean_squared_error: 2679.0154
# Epoch 22/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2880 - gamma_nll: 2.2849 - root_mean_squared_error: 2340.3945 - val_loss: 3.2267 - val_gamma_nll: 2.3994 - val_root_mean_squared_error: 2515.6802
# Epoch 23/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2819 - gamma_nll: 2.2793 - root_mean_squared_error: 2350.4482 - val_loss: 3.1222 - val_gamma_nll: 2.3889 - val_root_mean_squared_error: 2539.5457
# Epoch 24/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2865 - gamma_nll: 2.2828 - root_mean_squared_error: 2345.2983 - val_loss: 3.0916 - val_gamma_nll: 2.4116 - val_root_mean_squared_error: 2593.4241
# Epoch 25/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2823 - gamma_nll: 2.2795 - root_mean_squared_error: 2334.4990 - val_loss: 3.0167 - val_gamma_nll: 2.4016 - val_root_mean_squared_error: 2676.6458
# Epoch 26/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2842 - gamma_nll: 2.2814 - root_mean_squared_error: 2337.5308 - val_loss: 2.8116 - val_gamma_nll: 2.2840 - val_root_mean_squared_error: 2368.5835
# Epoch 27/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2884 - gamma_nll: 2.2860 - root_mean_squared_error: 2338.4937 - val_loss: 2.7576 - val_gamma_nll: 2.2758 - val_root_mean_squared_error: 2329.9272
# Epoch 28/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2802 - gamma_nll: 2.2764 - root_mean_squared_error: 2341.9482 - val_loss: 2.7344 - val_gamma_nll: 2.3026 - val_root_mean_squared_error: 2325.5984
# Epoch 29/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2777 - gamma_nll: 2.2746 - root_mean_squared_error: 2337.6440 - val_loss: 2.6919 - val_gamma_nll: 2.2721 - val_root_mean_squared_error: 2352.3152
# Epoch 30/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2827 - gamma_nll: 2.2799 - root_mean_squared_error: 2324.4412 - val_loss: 2.6927 - val_gamma_nll: 2.2868 - val_root_mean_squared_error: 2333.5310
# Epoch 31/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2793 - gamma_nll: 2.2761 - root_mean_squared_error: 2316.1030 - val_loss: 2.6801 - val_gamma_nll: 2.2931 - val_root_mean_squared_error: 2417.6538
# Epoch 32/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2822 - gamma_nll: 2.2787 - root_mean_squared_error: 2324.6079 - val_loss: 2.6672 - val_gamma_nll: 2.2831 - val_root_mean_squared_error: 2360.8254
# Epoch 33/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2760 - gamma_nll: 2.2730 - root_mean_squared_error: 2302.5781 - val_loss: 2.6288 - val_gamma_nll: 2.2925 - val_root_mean_squared_error: 2359.2917
# Epoch 34/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2832 - gamma_nll: 2.2811 - root_mean_squared_error: 2309.4690 - val_loss: 2.6589 - val_gamma_nll: 2.3497 - val_root_mean_squared_error: 2327.5491
# Epoch 35/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2748 - gamma_nll: 2.2723 - root_mean_squared_error: 2303.2292 - val_loss: 2.6167 - val_gamma_nll: 2.3000 - val_root_mean_squared_error: 2329.9927
# Epoch 36/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2724 - gamma_nll: 2.2690 - root_mean_squared_error: 2286.6714 - val_loss: 2.6491 - val_gamma_nll: 2.2965 - val_root_mean_squared_error: 2475.5432
# Epoch 37/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2748 - gamma_nll: 2.2716 - root_mean_squared_error: 2291.4150 - val_loss: 2.6645 - val_gamma_nll: 2.2979 - val_root_mean_squared_error: 2460.0049
# Epoch 38/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2770 - gamma_nll: 2.2742 - root_mean_squared_error: 2273.8750 - val_loss: 2.6432 - val_gamma_nll: 2.2836 - val_root_mean_squared_error: 2415.3894
# Epoch 39/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2705 - gamma_nll: 2.2674 - root_mean_squared_error: 2271.9788 - val_loss: 2.6880 - val_gamma_nll: 2.2943 - val_root_mean_squared_error: 2453.8640
# Epoch 40/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2669 - gamma_nll: 2.2638 - root_mean_squared_error: 2251.9426 - val_loss: 2.7535 - val_gamma_nll: 2.3050 - val_root_mean_squared_error: 2509.2876
# Epoch 41/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2652 - gamma_nll: 2.2621 - root_mean_squared_error: 2251.2007 - val_loss: 2.7108 - val_gamma_nll: 2.2749 - val_root_mean_squared_error: 2366.3232
# Epoch 42/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2659 - gamma_nll: 2.2627 - root_mean_squared_error: 2237.0200 - val_loss: 2.7707 - val_gamma_nll: 2.3107 - val_root_mean_squared_error: 2344.6562
# Epoch 43/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2619 - gamma_nll: 2.2589 - root_mean_squared_error: 2229.8896 - val_loss: 2.7590 - val_gamma_nll: 2.2799 - val_root_mean_squared_error: 2341.3364
# Epoch 44/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2648 - gamma_nll: 2.2625 - root_mean_squared_error: 2217.8293 - val_loss: 2.7354 - val_gamma_nll: 2.2914 - val_root_mean_squared_error: 2376.7676
# Epoch 45/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2607 - gamma_nll: 2.2577 - root_mean_squared_error: 2235.9307 - val_loss: 2.6944 - val_gamma_nll: 2.3082 - val_root_mean_squared_error: 2334.0872
# 1/1 [==============================] - 0s 19ms/step - loss: 2.5878 - gamma_nll: 2.3001 - root_mean_squared_error: 2329.9924
# Epoch 1/5000
# 12/12 [==============================] - 1s 28ms/step - loss: 2.3761 - gamma_nll: 2.3697 - root_mean_squared_error: 2158.6287 - val_loss: 2.5767 - val_gamma_nll: 2.5513 - val_root_mean_squared_error: 2439.2610
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2974 - gamma_nll: 2.2935 - root_mean_squared_error: 2114.5037 - val_loss: 2.7545 - val_gamma_nll: 2.7385 - val_root_mean_squared_error: 2479.0518
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2932 - gamma_nll: 2.2906 - root_mean_squared_error: 2117.4775 - val_loss: 2.9579 - val_gamma_nll: 2.9248 - val_root_mean_squared_error: 2529.5552
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2851 - gamma_nll: 2.2826 - root_mean_squared_error: 2116.2292 - val_loss: 2.9464 - val_gamma_nll: 2.9013 - val_root_mean_squared_error: 2511.8008
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2802 - gamma_nll: 2.2774 - root_mean_squared_error: 2116.1626 - val_loss: 2.9118 - val_gamma_nll: 2.8894 - val_root_mean_squared_error: 2634.1633
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2731 - gamma_nll: 2.2698 - root_mean_squared_error: 2109.6313 - val_loss: 3.1955 - val_gamma_nll: 3.1673 - val_root_mean_squared_error: 2729.9004
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2783 - gamma_nll: 2.2754 - root_mean_squared_error: 2113.9688 - val_loss: 3.0268 - val_gamma_nll: 2.9901 - val_root_mean_squared_error: 2824.7283
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2712 - gamma_nll: 2.2683 - root_mean_squared_error: 2111.3391 - val_loss: 3.0950 - val_gamma_nll: 3.0436 - val_root_mean_squared_error: 2682.6230
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2693 - gamma_nll: 2.2661 - root_mean_squared_error: 2110.9219 - val_loss: 3.1939 - val_gamma_nll: 3.1190 - val_root_mean_squared_error: 2671.5259
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2673 - gamma_nll: 2.2642 - root_mean_squared_error: 2109.1777 - val_loss: 3.3290 - val_gamma_nll: 3.2342 - val_root_mean_squared_error: 2612.2390
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2718 - gamma_nll: 2.2693 - root_mean_squared_error: 2110.6689 - val_loss: 3.3147 - val_gamma_nll: 3.1703 - val_root_mean_squared_error: 2568.6626
# 1/1 [==============================] - 0s 18ms/step - loss: 2.5777 - gamma_nll: 2.5523 - root_mean_squared_error: 2439.2607
# Epoch 1/5000
# 12/12 [==============================] - 2s 28ms/step - loss: 2.3835 - gamma_nll: 2.3771 - root_mean_squared_error: 2228.4048 - val_loss: 2.7442 - val_gamma_nll: 2.4869 - val_root_mean_squared_error: 2444.0098
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2796 - gamma_nll: 2.2759 - root_mean_squared_error: 2133.4500 - val_loss: 2.7561 - val_gamma_nll: 2.5376 - val_root_mean_squared_error: 2546.6555
# Epoch 3/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2806 - gamma_nll: 2.2780 - root_mean_squared_error: 2131.1411 - val_loss: 2.7207 - val_gamma_nll: 2.5736 - val_root_mean_squared_error: 2653.6189
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2653 - gamma_nll: 2.2623 - root_mean_squared_error: 2121.8889 - val_loss: 2.7143 - val_gamma_nll: 2.5621 - val_root_mean_squared_error: 2589.2944
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2681 - gamma_nll: 2.2654 - root_mean_squared_error: 2129.7053 - val_loss: 2.7590 - val_gamma_nll: 2.6048 - val_root_mean_squared_error: 2747.0459
# Epoch 6/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2566 - gamma_nll: 2.2530 - root_mean_squared_error: 2113.6274 - val_loss: 2.7045 - val_gamma_nll: 2.5412 - val_root_mean_squared_error: 2557.5205
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2657 - gamma_nll: 2.2627 - root_mean_squared_error: 2119.0662 - val_loss: 2.6651 - val_gamma_nll: 2.6172 - val_root_mean_squared_error: 2858.3750
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2579 - gamma_nll: 2.2547 - root_mean_squared_error: 2120.8643 - val_loss: 2.6787 - val_gamma_nll: 2.5717 - val_root_mean_squared_error: 2820.2371
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2568 - gamma_nll: 2.2536 - root_mean_squared_error: 2122.3818 - val_loss: 2.7758 - val_gamma_nll: 2.6862 - val_root_mean_squared_error: 3602.4165
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2514 - gamma_nll: 2.2487 - root_mean_squared_error: 2110.8804 - val_loss: 2.8176 - val_gamma_nll: 2.7102 - val_root_mean_squared_error: 3632.4526
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2524 - gamma_nll: 2.2499 - root_mean_squared_error: 2108.7920 - val_loss: 2.7934 - val_gamma_nll: 2.6096 - val_root_mean_squared_error: 3098.2388
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2523 - gamma_nll: 2.2490 - root_mean_squared_error: 2118.9624 - val_loss: 2.8912 - val_gamma_nll: 2.6885 - val_root_mean_squared_error: 3474.0862
# Epoch 13/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2485 - gamma_nll: 2.2449 - root_mean_squared_error: 2109.8281 - val_loss: 2.8382 - val_gamma_nll: 2.6409 - val_root_mean_squared_error: 3154.3855
# Epoch 14/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2448 - gamma_nll: 2.2425 - root_mean_squared_error: 2108.8298 - val_loss: 2.7299 - val_gamma_nll: 2.6308 - val_root_mean_squared_error: 2863.0293
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2443 - gamma_nll: 2.2419 - root_mean_squared_error: 2111.0342 - val_loss: 2.7623 - val_gamma_nll: 2.5995 - val_root_mean_squared_error: 2862.2168
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2373 - gamma_nll: 2.2349 - root_mean_squared_error: 2107.7578 - val_loss: 2.7003 - val_gamma_nll: 2.6617 - val_root_mean_squared_error: 3043.7063
# Epoch 17/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2416 - gamma_nll: 2.2386 - root_mean_squared_error: 2107.2075 - val_loss: 2.5570 - val_gamma_nll: 2.5204 - val_root_mean_squared_error: 2649.2180
# Epoch 18/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2396 - gamma_nll: 2.2363 - root_mean_squared_error: 2116.1389 - val_loss: 2.5710 - val_gamma_nll: 2.5315 - val_root_mean_squared_error: 2635.3511
# Epoch 19/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2449 - gamma_nll: 2.2423 - root_mean_squared_error: 2105.0881 - val_loss: 2.5855 - val_gamma_nll: 2.5379 - val_root_mean_squared_error: 2467.3623
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2365 - gamma_nll: 2.2330 - root_mean_squared_error: 2101.2432 - val_loss: 2.6343 - val_gamma_nll: 2.5531 - val_root_mean_squared_error: 2472.5828
# Epoch 21/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2422 - gamma_nll: 2.2392 - root_mean_squared_error: 2103.0808 - val_loss: 2.5719 - val_gamma_nll: 2.5062 - val_root_mean_squared_error: 2417.1208
# Epoch 22/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2404 - gamma_nll: 2.2371 - root_mean_squared_error: 2108.2100 - val_loss: 2.6343 - val_gamma_nll: 2.5862 - val_root_mean_squared_error: 2397.8164
# Epoch 23/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2290 - gamma_nll: 2.2261 - root_mean_squared_error: 2102.3047 - val_loss: 2.7899 - val_gamma_nll: 2.6235 - val_root_mean_squared_error: 2380.7986
# Epoch 24/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2372 - gamma_nll: 2.2336 - root_mean_squared_error: 2104.3003 - val_loss: 2.7313 - val_gamma_nll: 2.6003 - val_root_mean_squared_error: 2388.9365
# Epoch 25/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2300 - gamma_nll: 2.2272 - root_mean_squared_error: 2093.2388 - val_loss: 2.7000 - val_gamma_nll: 2.6348 - val_root_mean_squared_error: 2392.2432
# Epoch 26/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2341 - gamma_nll: 2.2311 - root_mean_squared_error: 2101.2581 - val_loss: 2.5353 - val_gamma_nll: 2.4742 - val_root_mean_squared_error: 2361.2258
# Epoch 27/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2334 - gamma_nll: 2.2306 - root_mean_squared_error: 2091.8599 - val_loss: 2.6244 - val_gamma_nll: 2.5607 - val_root_mean_squared_error: 2371.8340
# Epoch 28/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2322 - gamma_nll: 2.2282 - root_mean_squared_error: 2103.2161 - val_loss: 2.7105 - val_gamma_nll: 2.5932 - val_root_mean_squared_error: 2376.0244
# Epoch 29/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2274 - gamma_nll: 2.2240 - root_mean_squared_error: 2092.8984 - val_loss: 2.9095 - val_gamma_nll: 2.8331 - val_root_mean_squared_error: 2406.1736
# Epoch 30/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2237 - gamma_nll: 2.2207 - root_mean_squared_error: 2095.8413 - val_loss: 4.0708 - val_gamma_nll: 3.6635 - val_root_mean_squared_error: 2454.1780
# Epoch 31/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2271 - gamma_nll: 2.2240 - root_mean_squared_error: 2090.3169 - val_loss: 3.1209 - val_gamma_nll: 2.7046 - val_root_mean_squared_error: 2391.7256
# Epoch 32/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2289 - gamma_nll: 2.2254 - root_mean_squared_error: 2092.3328 - val_loss: 3.2171 - val_gamma_nll: 2.7073 - val_root_mean_squared_error: 2404.8857
# Epoch 33/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2220 - gamma_nll: 2.2190 - root_mean_squared_error: 2092.7319 - val_loss: 2.9791 - val_gamma_nll: 2.6007 - val_root_mean_squared_error: 2379.3843
# Epoch 34/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2272 - gamma_nll: 2.2252 - root_mean_squared_error: 2096.6492 - val_loss: 3.0344 - val_gamma_nll: 2.6160 - val_root_mean_squared_error: 2379.8008
# Epoch 35/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2254 - gamma_nll: 2.2231 - root_mean_squared_error: 2086.7056 - val_loss: 2.7714 - val_gamma_nll: 2.4655 - val_root_mean_squared_error: 2369.2449
# Epoch 36/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2190 - gamma_nll: 2.2157 - root_mean_squared_error: 2085.0908 - val_loss: 2.4443 - val_gamma_nll: 2.3626 - val_root_mean_squared_error: 2344.2261
# Epoch 37/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2240 - gamma_nll: 2.2209 - root_mean_squared_error: 2094.2671 - val_loss: 2.6239 - val_gamma_nll: 2.5088 - val_root_mean_squared_error: 2366.5225
# Epoch 38/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2218 - gamma_nll: 2.2189 - root_mean_squared_error: 2085.4927 - val_loss: 2.5389 - val_gamma_nll: 2.4391 - val_root_mean_squared_error: 2358.9941
# Epoch 39/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2280 - gamma_nll: 2.2250 - root_mean_squared_error: 2102.2268 - val_loss: 2.4535 - val_gamma_nll: 2.3504 - val_root_mean_squared_error: 2342.8147
# Epoch 40/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2157 - gamma_nll: 2.2126 - root_mean_squared_error: 2084.3364 - val_loss: 2.4465 - val_gamma_nll: 2.3511 - val_root_mean_squared_error: 2337.9446
# Epoch 41/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2249 - gamma_nll: 2.2216 - root_mean_squared_error: 2089.9590 - val_loss: 2.6493 - val_gamma_nll: 2.3456 - val_root_mean_squared_error: 2352.2371
# Epoch 42/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2160 - gamma_nll: 2.2125 - root_mean_squared_error: 2082.8242 - val_loss: 2.7715 - val_gamma_nll: 2.2758 - val_root_mean_squared_error: 2319.5811
# Epoch 43/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2183 - gamma_nll: 2.2150 - root_mean_squared_error: 2095.9688 - val_loss: 2.7573 - val_gamma_nll: 2.2926 - val_root_mean_squared_error: 2332.4004
# Epoch 44/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2261 - gamma_nll: 2.2235 - root_mean_squared_error: 2090.3049 - val_loss: 2.7430 - val_gamma_nll: 2.3936 - val_root_mean_squared_error: 2358.2217
# Epoch 45/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2176 - gamma_nll: 2.2152 - root_mean_squared_error: 2100.8577 - val_loss: 2.4970 - val_gamma_nll: 2.2753 - val_root_mean_squared_error: 2317.6208
# Epoch 46/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2248 - gamma_nll: 2.2219 - root_mean_squared_error: 2092.7078 - val_loss: 2.5633 - val_gamma_nll: 2.2979 - val_root_mean_squared_error: 2332.2102
# 1/1 [==============================] - 0s 18ms/step - loss: 2.4049 - gamma_nll: 2.3628 - root_mean_squared_error: 2344.2261
# Epoch 1/5000
# 12/12 [==============================] - 1s 29ms/step - loss: 2.4566 - gamma_nll: 2.4494 - root_mean_squared_error: 2273.2678 - val_loss: 2.7251 - val_gamma_nll: 2.5951 - val_root_mean_squared_error: 2418.1194
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2829 - gamma_nll: 2.2792 - root_mean_squared_error: 2107.6643 - val_loss: 2.5755 - val_gamma_nll: 2.4741 - val_root_mean_squared_error: 2523.3699
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3064 - gamma_nll: 2.3038 - root_mean_squared_error: 2140.3320 - val_loss: 2.5787 - val_gamma_nll: 2.5144 - val_root_mean_squared_error: 2571.6951
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2812 - gamma_nll: 2.2779 - root_mean_squared_error: 2120.3804 - val_loss: 2.5693 - val_gamma_nll: 2.5328 - val_root_mean_squared_error: 2554.9705
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2909 - gamma_nll: 2.2886 - root_mean_squared_error: 2135.0022 - val_loss: 2.5478 - val_gamma_nll: 2.5104 - val_root_mean_squared_error: 2604.4426
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2819 - gamma_nll: 2.2787 - root_mean_squared_error: 2118.1631 - val_loss: 2.6135 - val_gamma_nll: 2.5529 - val_root_mean_squared_error: 2667.7002
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2697 - gamma_nll: 2.2671 - root_mean_squared_error: 2102.1807 - val_loss: 2.6293 - val_gamma_nll: 2.5915 - val_root_mean_squared_error: 2779.0012
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2734 - gamma_nll: 2.2701 - root_mean_squared_error: 2112.2908 - val_loss: 2.7399 - val_gamma_nll: 2.5629 - val_root_mean_squared_error: 2810.1589
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2758 - gamma_nll: 2.2724 - root_mean_squared_error: 2105.9888 - val_loss: 2.6528 - val_gamma_nll: 2.5463 - val_root_mean_squared_error: 3079.2300
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2724 - gamma_nll: 2.2701 - root_mean_squared_error: 2118.3816 - val_loss: 2.6637 - val_gamma_nll: 2.5328 - val_root_mean_squared_error: 3057.2871
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2487 - gamma_nll: 2.2458 - root_mean_squared_error: 2090.7646 - val_loss: 2.5713 - val_gamma_nll: 2.4816 - val_root_mean_squared_error: 2498.9211
# Epoch 12/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 2.2594 - gamma_nll: 2.2563 - root_mean_squared_error: 2093.7566 - val_loss: 2.4936 - val_gamma_nll: 2.4758 - val_root_mean_squared_error: 2555.5017
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2603 - gamma_nll: 2.2569 - root_mean_squared_error: 2111.4766 - val_loss: 2.5891 - val_gamma_nll: 2.5160 - val_root_mean_squared_error: 2761.0042
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2540 - gamma_nll: 2.2510 - root_mean_squared_error: 2093.8777 - val_loss: 2.5615 - val_gamma_nll: 2.4697 - val_root_mean_squared_error: 2784.5557
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2468 - gamma_nll: 2.2443 - root_mean_squared_error: 2094.4453 - val_loss: 2.5860 - val_gamma_nll: 2.4713 - val_root_mean_squared_error: 2594.0374
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2475 - gamma_nll: 2.2445 - root_mean_squared_error: 2093.6765 - val_loss: 2.4872 - val_gamma_nll: 2.4644 - val_root_mean_squared_error: 2786.4233
# Epoch 17/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 2.2409 - gamma_nll: 2.2377 - root_mean_squared_error: 2089.2742 - val_loss: 2.4559 - val_gamma_nll: 2.4356 - val_root_mean_squared_error: 2605.1868
# Epoch 18/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2422 - gamma_nll: 2.2388 - root_mean_squared_error: 2085.5574 - val_loss: 2.5343 - val_gamma_nll: 2.4360 - val_root_mean_squared_error: 2590.0344
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2469 - gamma_nll: 2.2445 - root_mean_squared_error: 2102.5979 - val_loss: 2.6275 - val_gamma_nll: 2.4568 - val_root_mean_squared_error: 2653.4463
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2375 - gamma_nll: 2.2340 - root_mean_squared_error: 2090.2812 - val_loss: 2.6385 - val_gamma_nll: 2.4105 - val_root_mean_squared_error: 2414.7747
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2436 - gamma_nll: 2.2405 - root_mean_squared_error: 2092.0837 - val_loss: 2.6122 - val_gamma_nll: 2.5060 - val_root_mean_squared_error: 2446.8318
# Epoch 22/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2366 - gamma_nll: 2.2334 - root_mean_squared_error: 2086.2483 - val_loss: 2.7109 - val_gamma_nll: 2.6100 - val_root_mean_squared_error: 2381.4895
# Epoch 23/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2400 - gamma_nll: 2.2371 - root_mean_squared_error: 2094.3196 - val_loss: 2.9738 - val_gamma_nll: 2.8138 - val_root_mean_squared_error: 2395.6411
# Epoch 24/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2359 - gamma_nll: 2.2324 - root_mean_squared_error: 2082.9060 - val_loss: 3.1388 - val_gamma_nll: 3.0807 - val_root_mean_squared_error: 2412.9883
# Epoch 25/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2348 - gamma_nll: 2.2321 - root_mean_squared_error: 2078.2605 - val_loss: 3.2372 - val_gamma_nll: 3.1255 - val_root_mean_squared_error: 2407.5393
# Epoch 26/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2368 - gamma_nll: 2.2342 - root_mean_squared_error: 2089.8560 - val_loss: 3.3275 - val_gamma_nll: 3.2974 - val_root_mean_squared_error: 2411.6353
# Epoch 27/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2411 - gamma_nll: 2.2380 - root_mean_squared_error: 2084.8240 - val_loss: 3.7641 - val_gamma_nll: 3.7343 - val_root_mean_squared_error: 2433.8547
# 1/1 [==============================] - 0s 18ms/step - loss: 2.4412 - gamma_nll: 2.4354 - root_mean_squared_error: 2605.1870
# Epoch 1/5000
# 12/12 [==============================] - 2s 32ms/step - loss: 2.5374 - gamma_nll: 2.5305 - root_mean_squared_error: 2814.8042 - val_loss: 5.9287 - val_gamma_nll: 2.8179 - val_root_mean_squared_error: 2836.3210
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3392 - gamma_nll: 2.3355 - root_mean_squared_error: 2224.3643 - val_loss: 5.7535 - val_gamma_nll: 2.8286 - val_root_mean_squared_error: 2876.6477
# Epoch 3/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3439 - gamma_nll: 2.3412 - root_mean_squared_error: 2232.7971 - val_loss: 5.3412 - val_gamma_nll: 2.6920 - val_root_mean_squared_error: 2630.2190
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3300 - gamma_nll: 2.3268 - root_mean_squared_error: 2242.1218 - val_loss: 5.2464 - val_gamma_nll: 2.7658 - val_root_mean_squared_error: 2779.5566
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3352 - gamma_nll: 2.3331 - root_mean_squared_error: 2243.9336 - val_loss: 4.9995 - val_gamma_nll: 2.7131 - val_root_mean_squared_error: 2693.5110
# Epoch 6/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3297 - gamma_nll: 2.3264 - root_mean_squared_error: 2258.1458 - val_loss: 4.9268 - val_gamma_nll: 2.7743 - val_root_mean_squared_error: 2853.7183
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3248 - gamma_nll: 2.3216 - root_mean_squared_error: 2276.1326 - val_loss: 4.8125 - val_gamma_nll: 2.8036 - val_root_mean_squared_error: 2958.0327
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3293 - gamma_nll: 2.3259 - root_mean_squared_error: 2294.4226 - val_loss: 4.4635 - val_gamma_nll: 2.6478 - val_root_mean_squared_error: 2633.3743
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3260 - gamma_nll: 2.3227 - root_mean_squared_error: 2285.0566 - val_loss: 4.2241 - val_gamma_nll: 2.5641 - val_root_mean_squared_error: 2511.3005
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3210 - gamma_nll: 2.3179 - root_mean_squared_error: 2298.6072 - val_loss: 3.9488 - val_gamma_nll: 2.4452 - val_root_mean_squared_error: 2386.1462
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3211 - gamma_nll: 2.3182 - root_mean_squared_error: 2306.4407 - val_loss: 3.9195 - val_gamma_nll: 2.4906 - val_root_mean_squared_error: 2441.7007
# Epoch 12/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3224 - gamma_nll: 2.3192 - root_mean_squared_error: 2299.7012 - val_loss: 3.7316 - val_gamma_nll: 2.4066 - val_root_mean_squared_error: 2364.3809
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3239 - gamma_nll: 2.3205 - root_mean_squared_error: 2307.9272 - val_loss: 3.5627 - val_gamma_nll: 2.3515 - val_root_mean_squared_error: 2328.0679
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3187 - gamma_nll: 2.3158 - root_mean_squared_error: 2311.7756 - val_loss: 3.4838 - val_gamma_nll: 2.3523 - val_root_mean_squared_error: 2335.0498
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3168 - gamma_nll: 2.3138 - root_mean_squared_error: 2311.9360 - val_loss: 3.3569 - val_gamma_nll: 2.3190 - val_root_mean_squared_error: 2317.6392
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3228 - gamma_nll: 2.3195 - root_mean_squared_error: 2324.2124 - val_loss: 3.2470 - val_gamma_nll: 2.3006 - val_root_mean_squared_error: 2314.0566
# Epoch 17/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3163 - gamma_nll: 2.3132 - root_mean_squared_error: 2303.6289 - val_loss: 3.2637 - val_gamma_nll: 2.3473 - val_root_mean_squared_error: 2354.7354
# Epoch 18/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3122 - gamma_nll: 2.3090 - root_mean_squared_error: 2324.7229 - val_loss: 3.2073 - val_gamma_nll: 2.3438 - val_root_mean_squared_error: 2377.8694
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3162 - gamma_nll: 2.3132 - root_mean_squared_error: 2307.9268 - val_loss: 3.1774 - val_gamma_nll: 2.3644 - val_root_mean_squared_error: 2397.6292
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3158 - gamma_nll: 2.3121 - root_mean_squared_error: 2309.2075 - val_loss: 3.1555 - val_gamma_nll: 2.3916 - val_root_mean_squared_error: 2463.4966
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3172 - gamma_nll: 2.3144 - root_mean_squared_error: 2324.6851 - val_loss: 3.0079 - val_gamma_nll: 2.3320 - val_root_mean_squared_error: 2378.2637
# Epoch 22/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3131 - gamma_nll: 2.3105 - root_mean_squared_error: 2342.2737 - val_loss: 2.8878 - val_gamma_nll: 2.2957 - val_root_mean_squared_error: 2337.4763
# Epoch 23/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3169 - gamma_nll: 2.3142 - root_mean_squared_error: 2322.3108 - val_loss: 2.8258 - val_gamma_nll: 2.2901 - val_root_mean_squared_error: 2331.1023
# Epoch 24/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3135 - gamma_nll: 2.3101 - root_mean_squared_error: 2332.4622 - val_loss: 2.7951 - val_gamma_nll: 2.3029 - val_root_mean_squared_error: 2360.4041
# Epoch 25/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3100 - gamma_nll: 2.3071 - root_mean_squared_error: 2309.9619 - val_loss: 2.7482 - val_gamma_nll: 2.3153 - val_root_mean_squared_error: 2344.1565
# Epoch 26/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3156 - gamma_nll: 2.3132 - root_mean_squared_error: 2325.9688 - val_loss: 2.7189 - val_gamma_nll: 2.3081 - val_root_mean_squared_error: 2374.2014
# Epoch 27/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3102 - gamma_nll: 2.3075 - root_mean_squared_error: 2327.2385 - val_loss: 2.6992 - val_gamma_nll: 2.3044 - val_root_mean_squared_error: 2383.8923
# Epoch 28/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3116 - gamma_nll: 2.3073 - root_mean_squared_error: 2326.7104 - val_loss: 2.6406 - val_gamma_nll: 2.3019 - val_root_mean_squared_error: 2365.0376
# Epoch 29/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3113 - gamma_nll: 2.3080 - root_mean_squared_error: 2333.9338 - val_loss: 2.6303 - val_gamma_nll: 2.3032 - val_root_mean_squared_error: 2383.5725
# Epoch 30/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3108 - gamma_nll: 2.3074 - root_mean_squared_error: 2321.5698 - val_loss: 2.5977 - val_gamma_nll: 2.3376 - val_root_mean_squared_error: 2514.0928
# Epoch 31/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3055 - gamma_nll: 2.3025 - root_mean_squared_error: 2298.9485 - val_loss: 2.5653 - val_gamma_nll: 2.3282 - val_root_mean_squared_error: 2492.7419
# Epoch 32/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3080 - gamma_nll: 2.3051 - root_mean_squared_error: 2320.3213 - val_loss: 2.5051 - val_gamma_nll: 2.3101 - val_root_mean_squared_error: 2414.7495
# Epoch 33/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3129 - gamma_nll: 2.3099 - root_mean_squared_error: 2307.2498 - val_loss: 2.5235 - val_gamma_nll: 2.3149 - val_root_mean_squared_error: 2437.0142
# Epoch 34/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3058 - gamma_nll: 2.3035 - root_mean_squared_error: 2318.3098 - val_loss: 2.5139 - val_gamma_nll: 2.3210 - val_root_mean_squared_error: 2407.5488
# Epoch 35/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3086 - gamma_nll: 2.3060 - root_mean_squared_error: 2318.2742 - val_loss: 2.5236 - val_gamma_nll: 2.3506 - val_root_mean_squared_error: 2346.2424
# Epoch 36/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3076 - gamma_nll: 2.3048 - root_mean_squared_error: 2325.1025 - val_loss: 2.5219 - val_gamma_nll: 2.3358 - val_root_mean_squared_error: 2378.1653
# Epoch 37/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3066 - gamma_nll: 2.3036 - root_mean_squared_error: 2306.6831 - val_loss: 2.5938 - val_gamma_nll: 2.4225 - val_root_mean_squared_error: 2358.7256
# Epoch 38/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3088 - gamma_nll: 2.3062 - root_mean_squared_error: 2307.4985 - val_loss: 2.5502 - val_gamma_nll: 2.3766 - val_root_mean_squared_error: 2351.0571
# Epoch 39/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3084 - gamma_nll: 2.3058 - root_mean_squared_error: 2320.3267 - val_loss: 2.4904 - val_gamma_nll: 2.3145 - val_root_mean_squared_error: 2436.1091
# Epoch 40/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3063 - gamma_nll: 2.3037 - root_mean_squared_error: 2308.1062 - val_loss: 2.5202 - val_gamma_nll: 2.3159 - val_root_mean_squared_error: 2461.5427
# Epoch 41/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3032 - gamma_nll: 2.2999 - root_mean_squared_error: 2314.7058 - val_loss: 2.4982 - val_gamma_nll: 2.3179 - val_root_mean_squared_error: 2439.3367
# Epoch 42/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3101 - gamma_nll: 2.3066 - root_mean_squared_error: 2323.6582 - val_loss: 2.5176 - val_gamma_nll: 2.3477 - val_root_mean_squared_error: 2366.6162
# Epoch 43/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3062 - gamma_nll: 2.3036 - root_mean_squared_error: 2297.8286 - val_loss: 2.5791 - val_gamma_nll: 2.4278 - val_root_mean_squared_error: 2347.5632
# Epoch 44/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3009 - gamma_nll: 2.2988 - root_mean_squared_error: 2282.7056 - val_loss: 2.5556 - val_gamma_nll: 2.3994 - val_root_mean_squared_error: 2359.1091
# Epoch 45/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3029 - gamma_nll: 2.3001 - root_mean_squared_error: 2296.9841 - val_loss: 2.5828 - val_gamma_nll: 2.4286 - val_root_mean_squared_error: 2344.7563
# Epoch 46/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3020 - gamma_nll: 2.2996 - root_mean_squared_error: 2285.6436 - val_loss: 2.5920 - val_gamma_nll: 2.4237 - val_root_mean_squared_error: 2358.2854
# Epoch 47/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3045 - gamma_nll: 2.3015 - root_mean_squared_error: 2291.0444 - val_loss: 2.8037 - val_gamma_nll: 2.6492 - val_root_mean_squared_error: 2360.4436
# Epoch 48/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2994 - gamma_nll: 2.2963 - root_mean_squared_error: 2286.5095 - val_loss: 2.6236 - val_gamma_nll: 2.4760 - val_root_mean_squared_error: 2349.1311
# Epoch 49/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3033 - gamma_nll: 2.3004 - root_mean_squared_error: 2276.5164 - val_loss: 2.7704 - val_gamma_nll: 2.6270 - val_root_mean_squared_error: 2364.4370
# 1/1 [==============================] - 0s 18ms/step - loss: 2.4389 - gamma_nll: 2.3146 - root_mean_squared_error: 2436.1091
# Epoch 1/5000
# 12/12 [==============================] - 1s 29ms/step - loss: 2.3916 - gamma_nll: 2.3856 - root_mean_squared_error: 2319.1663 - val_loss: 2.6748 - val_gamma_nll: 2.5089 - val_root_mean_squared_error: 2380.4590
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2859 - gamma_nll: 2.2820 - root_mean_squared_error: 2122.3801 - val_loss: 2.7171 - val_gamma_nll: 2.5585 - val_root_mean_squared_error: 2381.5190
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2888 - gamma_nll: 2.2865 - root_mean_squared_error: 2121.8591 - val_loss: 2.7100 - val_gamma_nll: 2.5379 - val_root_mean_squared_error: 2373.7175
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2796 - gamma_nll: 2.2763 - root_mean_squared_error: 2121.0771 - val_loss: 2.9205 - val_gamma_nll: 2.8291 - val_root_mean_squared_error: 2393.9368
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2807 - gamma_nll: 2.2780 - root_mean_squared_error: 2118.1250 - val_loss: 2.8464 - val_gamma_nll: 2.7325 - val_root_mean_squared_error: 2386.4795
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2806 - gamma_nll: 2.2773 - root_mean_squared_error: 2117.6177 - val_loss: 2.8829 - val_gamma_nll: 2.7810 - val_root_mean_squared_error: 2393.4841
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2843 - gamma_nll: 2.2815 - root_mean_squared_error: 2128.0828 - val_loss: 2.8505 - val_gamma_nll: 2.7087 - val_root_mean_squared_error: 2384.3164
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2811 - gamma_nll: 2.2782 - root_mean_squared_error: 2121.2324 - val_loss: 2.6958 - val_gamma_nll: 2.5791 - val_root_mean_squared_error: 2400.2122
# Epoch 9/5000
# ...
# Epoch 1/5000
# 12/12 [==============================] - 1s 29ms/step - loss: 2.4913 - gamma_nll: 2.4849 - root_mean_squared_error: 2191.4822 - val_loss: 3.0768 - val_gamma_nll: 2.4372 - val_root_mean_squared_error: 2370.8396
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2941 - gamma_nll: 2.2900 - root_mean_squared_error: 2133.3271 - val_loss: 2.8926 - val_gamma_nll: 2.4764 - val_root_mean_squared_error: 2400.2957
# Epoch 3/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2858 - gamma_nll: 2.2834 - root_mean_squared_error: 2137.6243 - val_loss: 2.7661 - val_gamma_nll: 2.4606 - val_root_mean_squared_error: 2415.0793
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2832 - gamma_nll: 2.2802 - root_mean_squared_error: 2144.5234 - val_loss: 2.8509 - val_gamma_nll: 2.5624 - val_root_mean_squared_error: 2396.9858
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2764 - gamma_nll: 2.2739 - root_mean_squared_error: 2144.5647 - val_loss: 2.7562 - val_gamma_nll: 2.5088 - val_root_mean_squared_error: 2386.5034
# Epoch 6/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2832 - gamma_nll: 2.2797 - root_mean_squared_error: 2139.0178 - val_loss: 2.7471 - val_gamma_nll: 2.5333 - val_root_mean_squared_error: 2404.3425
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2766 - gamma_nll: 2.2741 - root_mean_squared_error: 2141.2310 - val_loss: 2.7221 - val_gamma_nll: 2.5520 - val_root_mean_squared_error: 2413.8787
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2801 - gamma_nll: 2.2769 - root_mean_squared_error: 2144.6960 - val_loss: 2.6966 - val_gamma_nll: 2.5579 - val_root_mean_squared_error: 2399.5195
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2755 - gamma_nll: 2.2721 - root_mean_squared_error: 2139.3479 - val_loss: 2.5881 - val_gamma_nll: 2.5355 - val_root_mean_squared_error: 2382.2673
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2814 - gamma_nll: 2.2790 - root_mean_squared_error: 2143.7192 - val_loss: 2.7089 - val_gamma_nll: 2.6013 - val_root_mean_squared_error: 2384.4426
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2726 - gamma_nll: 2.2698 - root_mean_squared_error: 2139.4031 - val_loss: 2.8710 - val_gamma_nll: 2.6798 - val_root_mean_squared_error: 2394.3020
# Epoch 12/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2780 - gamma_nll: 2.2749 - root_mean_squared_error: 2146.4470 - val_loss: 3.1738 - val_gamma_nll: 3.0474 - val_root_mean_squared_error: 2422.6743
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2745 - gamma_nll: 2.2709 - root_mean_squared_error: 2137.7078 - val_loss: 2.8205 - val_gamma_nll: 2.6025 - val_root_mean_squared_error: 2396.3840
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2739 - gamma_nll: 2.2709 - root_mean_squared_error: 2145.4448 - val_loss: 2.8017 - val_gamma_nll: 2.6457 - val_root_mean_squared_error: 2393.5645
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2759 - gamma_nll: 2.2736 - root_mean_squared_error: 2143.3723 - val_loss: 2.7407 - val_gamma_nll: 2.5239 - val_root_mean_squared_error: 2370.1704
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2786 - gamma_nll: 2.2758 - root_mean_squared_error: 2146.7136 - val_loss: 2.5962 - val_gamma_nll: 2.3678 - val_root_mean_squared_error: 2356.7673
# Epoch 17/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2781 - gamma_nll: 2.2750 - root_mean_squared_error: 2144.7744 - val_loss: 2.5761 - val_gamma_nll: 2.4467 - val_root_mean_squared_error: 2377.4973
# Epoch 18/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2768 - gamma_nll: 2.2730 - root_mean_squared_error: 2143.3262 - val_loss: 2.5058 - val_gamma_nll: 2.3964 - val_root_mean_squared_error: 2353.5398
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2727 - gamma_nll: 2.2704 - root_mean_squared_error: 2143.9509 - val_loss: 2.5131 - val_gamma_nll: 2.3776 - val_root_mean_squared_error: 2340.7573
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2786 - gamma_nll: 2.2749 - root_mean_squared_error: 2142.8433 - val_loss: 2.5345 - val_gamma_nll: 2.3723 - val_root_mean_squared_error: 2353.5879
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2756 - gamma_nll: 2.2724 - root_mean_squared_error: 2141.8484 - val_loss: 2.4649 - val_gamma_nll: 2.3120 - val_root_mean_squared_error: 2381.2480
# Epoch 22/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2756 - gamma_nll: 2.2732 - root_mean_squared_error: 2148.6306 - val_loss: 2.4995 - val_gamma_nll: 2.3393 - val_root_mean_squared_error: 2337.3481
# Epoch 23/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2738 - gamma_nll: 2.2710 - root_mean_squared_error: 2139.1062 - val_loss: 2.4806 - val_gamma_nll: 2.3116 - val_root_mean_squared_error: 2352.2644
# Epoch 24/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2724 - gamma_nll: 2.2693 - root_mean_squared_error: 2143.3511 - val_loss: 2.6238 - val_gamma_nll: 2.3287 - val_root_mean_squared_error: 2336.0957
# Epoch 25/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2784 - gamma_nll: 2.2752 - root_mean_squared_error: 2143.7412 - val_loss: 2.5288 - val_gamma_nll: 2.3256 - val_root_mean_squared_error: 2354.0417
# Epoch 26/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2743 - gamma_nll: 2.2715 - root_mean_squared_error: 2141.7817 - val_loss: 2.4886 - val_gamma_nll: 2.3270 - val_root_mean_squared_error: 2367.8647
# Epoch 27/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2735 - gamma_nll: 2.2705 - root_mean_squared_error: 2142.3557 - val_loss: 2.5173 - val_gamma_nll: 2.3150 - val_root_mean_squared_error: 2338.8989
# Epoch 28/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2746 - gamma_nll: 2.2704 - root_mean_squared_error: 2144.3767 - val_loss: 2.5032 - val_gamma_nll: 2.2979 - val_root_mean_squared_error: 2341.5078
# Epoch 29/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2740 - gamma_nll: 2.2703 - root_mean_squared_error: 2141.6589 - val_loss: 2.5561 - val_gamma_nll: 2.3015 - val_root_mean_squared_error: 2352.8186
# Epoch 30/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2731 - gamma_nll: 2.2701 - root_mean_squared_error: 2143.2905 - val_loss: 2.4921 - val_gamma_nll: 2.2941 - val_root_mean_squared_error: 2354.9380
# Epoch 31/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2688 - gamma_nll: 2.2660 - root_mean_squared_error: 2138.5276 - val_loss: 2.6043 - val_gamma_nll: 2.3003 - val_root_mean_squared_error: 2369.7527
# 1/1 [==============================] - 0s 18ms/step - loss: 2.3376 - gamma_nll: 2.3120 - root_mean_squared_error: 2381.2480
# Epoch 1/5000
# 12/12 [==============================] - 1s 28ms/step - loss: 2.4475 - gamma_nll: 2.4410 - root_mean_squared_error: 2147.5654 - val_loss: 2.7303 - val_gamma_nll: 2.6528 - val_root_mean_squared_error: 2439.7192
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2932 - gamma_nll: 2.2893 - root_mean_squared_error: 2107.0901 - val_loss: 3.1075 - val_gamma_nll: 3.0609 - val_root_mean_squared_error: 2506.9834
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2776 - gamma_nll: 2.2752 - root_mean_squared_error: 2109.4299 - val_loss: 3.2304 - val_gamma_nll: 3.2042 - val_root_mean_squared_error: 2617.9431
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2814 - gamma_nll: 2.2783 - root_mean_squared_error: 2120.7097 - val_loss: 2.9502 - val_gamma_nll: 2.9267 - val_root_mean_squared_error: 2594.8259
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2766 - gamma_nll: 2.2739 - root_mean_squared_error: 2114.5342 - val_loss: 3.2996 - val_gamma_nll: 3.2726 - val_root_mean_squared_error: 2671.7888
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2801 - gamma_nll: 2.2769 - root_mean_squared_error: 2116.8772 - val_loss: 3.4127 - val_gamma_nll: 3.3797 - val_root_mean_squared_error: 2659.7822
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2762 - gamma_nll: 2.2738 - root_mean_squared_error: 2118.3516 - val_loss: 3.2326 - val_gamma_nll: 3.1823 - val_root_mean_squared_error: 2693.0449
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2725 - gamma_nll: 2.2695 - root_mean_squared_error: 2113.7930 - val_loss: 3.4707 - val_gamma_nll: 3.4342 - val_root_mean_squared_error: 2623.8948
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2769 - gamma_nll: 2.2734 - root_mean_squared_error: 2115.7986 - val_loss: 3.1527 - val_gamma_nll: 3.1123 - val_root_mean_squared_error: 2648.0217
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2719 - gamma_nll: 2.2698 - root_mean_squared_error: 2112.4526 - val_loss: 2.9625 - val_gamma_nll: 2.9017 - val_root_mean_squared_error: 2636.3726
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2736 - gamma_nll: 2.2705 - root_mean_squared_error: 2112.5576 - val_loss: 3.2949 - val_gamma_nll: 3.1368 - val_root_mean_squared_error: 2606.1458
# 1/1 [==============================] - 0s 18ms/step - loss: 2.7307 - gamma_nll: 2.6542 - root_mean_squared_error: 2439.7192
# Epoch 1/5000
# 12/12 [==============================] - 1s 26ms/step - loss: 2.4236 - gamma_nll: 2.4171 - root_mean_squared_error: 2131.7898 - val_loss: 2.6491 - val_gamma_nll: 2.4443 - val_root_mean_squared_error: 2406.2629
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1870 - gamma_nll: 2.1830 - root_mean_squared_error: 2071.1980 - val_loss: 2.3749 - val_gamma_nll: 2.3321 - val_root_mean_squared_error: 2382.9717
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1399 - gamma_nll: 2.1373 - root_mean_squared_error: 2138.7319 - val_loss: 2.4617 - val_gamma_nll: 2.3701 - val_root_mean_squared_error: 2405.0735
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.1060 - gamma_nll: 2.1030 - root_mean_squared_error: 2149.6125 - val_loss: 2.3710 - val_gamma_nll: 2.2949 - val_root_mean_squared_error: 2362.5603
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.0716 - gamma_nll: 2.0692 - root_mean_squared_error: 2098.9563 - val_loss: 2.3283 - val_gamma_nll: 2.2742 - val_root_mean_squared_error: 2342.4031
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0849 - gamma_nll: 2.0814 - root_mean_squared_error: 2133.6516 - val_loss: 2.4220 - val_gamma_nll: 2.3025 - val_root_mean_squared_error: 2377.4688
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0498 - gamma_nll: 2.0470 - root_mean_squared_error: 2107.7378 - val_loss: 2.4299 - val_gamma_nll: 2.2783 - val_root_mean_squared_error: 2353.6689
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0572 - gamma_nll: 2.0541 - root_mean_squared_error: 2100.4246 - val_loss: 2.4181 - val_gamma_nll: 2.2898 - val_root_mean_squared_error: 2368.2605
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0489 - gamma_nll: 2.0454 - root_mean_squared_error: 2118.3279 - val_loss: 2.4311 - val_gamma_nll: 2.3135 - val_root_mean_squared_error: 2373.1575
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0346 - gamma_nll: 2.0328 - root_mean_squared_error: 2106.8877 - val_loss: 2.3798 - val_gamma_nll: 2.2533 - val_root_mean_squared_error: 2346.4131
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.0296 - gamma_nll: 2.0267 - root_mean_squared_error: 2078.4419 - val_loss: 2.4463 - val_gamma_nll: 2.3199 - val_root_mean_squared_error: 2375.9832
# Epoch 12/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.0264 - gamma_nll: 2.0229 - root_mean_squared_error: 2078.8621 - val_loss: 2.3748 - val_gamma_nll: 2.3137 - val_root_mean_squared_error: 2375.4890
# Epoch 13/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0082 - gamma_nll: 2.0049 - root_mean_squared_error: 2099.7966 - val_loss: 2.3789 - val_gamma_nll: 2.3188 - val_root_mean_squared_error: 2374.2231
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.0194 - gamma_nll: 2.0160 - root_mean_squared_error: 2102.1838 - val_loss: 2.3180 - val_gamma_nll: 2.2372 - val_root_mean_squared_error: 2335.3599
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.0117 - gamma_nll: 2.0097 - root_mean_squared_error: 2111.6631 - val_loss: 2.3385 - val_gamma_nll: 2.2625 - val_root_mean_squared_error: 2349.5586
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.0027 - gamma_nll: 1.9997 - root_mean_squared_error: 2071.4458 - val_loss: 2.3026 - val_gamma_nll: 2.2876 - val_root_mean_squared_error: 2347.9663
# Epoch 17/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.0257 - gamma_nll: 2.0231 - root_mean_squared_error: 2089.5271 - val_loss: 2.3938 - val_gamma_nll: 2.2654 - val_root_mean_squared_error: 2361.6125
# Epoch 18/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 1.9952 - gamma_nll: 1.9931 - root_mean_squared_error: 2060.2302 - val_loss: 2.2707 - val_gamma_nll: 2.2412 - val_root_mean_squared_error: 2335.8342
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.0068 - gamma_nll: 2.0047 - root_mean_squared_error: 2083.9319 - val_loss: 2.3053 - val_gamma_nll: 2.2403 - val_root_mean_squared_error: 2360.3669
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 1.9924 - gamma_nll: 1.9890 - root_mean_squared_error: 2064.8779 - val_loss: 2.3976 - val_gamma_nll: 2.2127 - val_root_mean_squared_error: 2293.0591
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.0055 - gamma_nll: 2.0019 - root_mean_squared_error: 2086.5708 - val_loss: 2.4013 - val_gamma_nll: 2.2167 - val_root_mean_squared_error: 2303.3984
# Epoch 22/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 1.9922 - gamma_nll: 1.9898 - root_mean_squared_error: 2054.9736 - val_loss: 2.5463 - val_gamma_nll: 2.2722 - val_root_mean_squared_error: 2313.9736
# Epoch 23/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 1.9982 - gamma_nll: 1.9956 - root_mean_squared_error: 2079.5933 - val_loss: 2.4788 - val_gamma_nll: 2.2761 - val_root_mean_squared_error: 2350.6594
# Epoch 24/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9815 - gamma_nll: 1.9782 - root_mean_squared_error: 2044.6112 - val_loss: 2.6796 - val_gamma_nll: 2.2355 - val_root_mean_squared_error: 2307.7405
# Epoch 25/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.0020 - gamma_nll: 1.9990 - root_mean_squared_error: 2084.4885 - val_loss: 2.7138 - val_gamma_nll: 2.1902 - val_root_mean_squared_error: 2288.1382
# Epoch 26/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 1.9875 - gamma_nll: 1.9849 - root_mean_squared_error: 2046.6003 - val_loss: 2.6654 - val_gamma_nll: 2.1702 - val_root_mean_squared_error: 2300.3208
# Epoch 27/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9846 - gamma_nll: 1.9819 - root_mean_squared_error: 2078.0334 - val_loss: 2.7181 - val_gamma_nll: 2.1825 - val_root_mean_squared_error: 2321.7830
# Epoch 28/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 1.9781 - gamma_nll: 1.9742 - root_mean_squared_error: 2046.7484 - val_loss: 2.9924 - val_gamma_nll: 2.1940 - val_root_mean_squared_error: 2332.1785
# 1/1 [==============================] - 0s 18ms/step - loss: 2.2713 - gamma_nll: 2.2412 - root_mean_squared_error: 2335.8340

# %%
# -------------------------- plot the validation loss --------------------------
# Convert interaction loss dictionary to a pandas DataFrame
interaction_df = pd.DataFrame(list(interaction_loss.items()), columns = ['Interaction_Pair', 'Validation_Loss'])

# Sort the DataFrame by Validation_Loss in increasing order
interaction_df = interaction_df.sort_values(by = 'Validation_Loss', ascending = True)

# Create the bar plot using Seaborn
plt.figure(figsize = (20, 12))
sns.lineplot(x = 'Interaction_Pair', y = 'Validation_Loss', data = interaction_df, marker = 'o')
plt.axhline(main_val_loss, color = 'red', linestyle = '--', label = 'Validation Loss of Main Effect Model')
plt.xlabel('Interaction Effect Pairs')
plt.ylabel('Validation Loss')
plt.title('Validation Loss for Interaction Effect Pairs (Sorted by Increasing Loss)')
plt.legend()
plt.show()

# %%
# # -------------------------- Create the Pairwise Only Model --------------------------
# # pairwise_effect = ("X3", "X4")  # the pairwise effect we want to view
# pairwise_effect = interactions[0]
# pairwise_index = interactions.index(pairwise_effect)
# subnet_output_layer = model_pairwise.get_layer("interaction_output")
# subnet_model = Model(inputs = model_pairwise.inputs, outputs = subnet_output_layer.output)


# # -------------------------- Generate the Input Grid --------------------------
# # Create a grid of values
# grid_length = 100
# var1_values = np.linspace(X_train[interactions[pairwise_index][0]].min(), 
#                           X_train[interactions[pairwise_index][0]].max(), 
#                           grid_length)
# var2_values = np.linspace(X_train[interactions[pairwise_index][1]].min(), 
#                           X_train[interactions[pairwise_index][1]].max(), 
#                           grid_length)

# # Create a meshgrid
# grid_var1, grid_var2 = np.meshgrid(var1_values, var2_values)

# # Flatten the grid
# grid_flat_var1 = grid_var1.ravel()
# grid_flat_var2 = grid_var2.ravel()


# # -------------------------- Prepare Inputs for the Model --------------------------
# grid_inputs = []
# for var in all_vars:
#     if var == interactions[pairwise_index][0]:
#         grid_inputs.append(grid_flat_var1)
#     elif var == interactions[pairwise_index][1]:
#         grid_inputs.append(grid_flat_var2)
#     else:
#         grid_inputs.append(np.zeros_like(grid_flat_var1))


# # -------------------------- Predict Using the Pairwise-Only Model --------------------------
# # Predict the pairwise interaction effect
# pairwise_predictions = np.log(subnet_model.predict(grid_inputs))

# # Reshape the predictions to the grid format
# heatmap_values = pairwise_predictions.reshape(grid_var1.shape)


# # -------------------------- Plot the Heatmap --------------------------
# plt.figure(figsize = (10, 8))
# contour = plt.contourf(grid_var1, grid_var2, heatmap_values, levels = 10)
# plt.colorbar(contour)
# plt.title('Predicted Function by the Model')
# plt.xlabel(f"{interactions[pairwise_index][0]}")
# plt.ylabel(f"{interactions[pairwise_index][1]}")
# plt.show()

# %%
# #-------------------------- view the shape function --------------------------
# # get the prediction
# main_output_layer = model_pairwise.get_layer("main_subnet")
# subnet_model = Model(inputs = model_pairwise.inputs, outputs = main_output_layer.output)
# subnet_output = subnet_model.predict(X_train_split)

# # create the plot
# var_name = "X3"
# var_index = all_vars.index(var_name)
# plt.figure(figsize = (12, 6))
# sns.lineplot(x = X_train_split[var_index], 
#              y = subnet_output[:,var_index])
# plt.xlabel(f"{var_name}")
# plt.ylabel('Subnetwork Output')
# plt.title(f"Shape function for {var_name}")
# plt.grid(True)
# plt.show()
