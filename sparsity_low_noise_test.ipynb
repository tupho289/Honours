# %%
############################ 0. PREPARATION ############################

#-------------------------- import packages --------------------------
import random
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from itertools import combinations
import seaborn as sns
import copy
import itertools

import tensorflow as tf
import tensorflow_lattice as tfl
import tf_keras as keras # need keras 2 to fit Lattice model
from tf_keras.models import Sequential, Model
from tf_keras.layers import Dense, Input, Multiply, Add, Embedding, Reshape, Concatenate, Dropout, BatchNormalization, Lambda, Layer, CategoryEncoding, Activation
from tf_keras.constraints import Constraint
from tf_keras.callbacks import EarlyStopping
from tf_keras.initializers import Zeros, Constant
from tf_keras.optimizers import Adam, Nadam, RMSprop
from tf_keras.models import clone_model
import keras_tuner as kt
from tf_keras import backend as K
from tf_keras import regularizers
from tf_keras.utils import plot_model
from tf_keras.losses import Poisson, Loss
from tf_keras.metrics import MeanAbsoluteError, RootMeanSquaredError
from scipy.stats import gamma


from pygam import LinearGAM, GAM, s, f, l
from sklearn.linear_model import ElasticNet
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error as mae
from sklearn.tree import DecisionTreeRegressor
from interpret.glassbox import ExplainableBoostingClassifier

# %%
#-------------------------- for reproducibility --------------------------
seed_value = 2024
keras.utils.set_random_seed(seed_value)

# %%
#-------------------------- import data --------------------------
data = pd.read_csv("synthetic_low_var_test_sparsity.csv")

# %%
#-------------------------- remove outliers --------------------------
log_claim = np.log(data['Y'])
IQR = log_claim.quantile(0.75) - log_claim.quantile(0.25) # inter-quartile range
lower_whisker = log_claim.quantile(0.25)- 1.5*IQR
upper_whisker = log_claim.quantile(0.75) + 1.5*IQR

# remove outliers: filter rows where the log of 'Y' is within the whiskers
dt_cleaned = data[(log_claim >= lower_whisker) & (log_claim <= upper_whisker)]
dt_cleaned
# Out:
#              X1        X2        X3        X4        X5        X6        X7  \
# 0      0.097627 -0.384709  0.070514  0.245303 -0.564460 -0.450318  0.531209
# 1      0.430379 -0.875990  0.808088  0.648436  0.174499 -0.765558 -0.898927
# 2      0.205527  0.977570  0.004793 -0.431433  0.975227  0.473320  0.995090
# 3      0.089766  0.438181 -0.798260  0.756793  0.901734  0.431272 -0.864656
# 4     -0.152690  0.515139  0.055164  0.282328 -0.314057  0.639535 -0.581069
# ...         ...       ...       ...       ...       ...       ...       ...
# 49995  0.092658  0.451842  0.805609 -0.262674  0.758215 -0.205461  0.443849
# 49996  0.386621  0.015041 -0.538708 -0.389854 -0.632906 -0.311577  0.027367
# 49997 -0.532650  0.620266  0.162028 -0.570751  0.005453  0.235543  0.099723
# 49998  0.661848  0.102065 -0.526136 -0.408447  0.373860 -0.328123  0.756798
# 49999  0.102636 -0.548488 -0.907552  0.685008 -0.631395  0.158764 -0.255068
#
#              X8        X9       X10             Y
# 0     -0.139983 -0.999956  0.009359     43.018616
# 1     -0.168761  0.081209 -0.263657    580.644273
# 2      0.794291 -0.802390 -0.861454    516.366318
# 3      0.512576  0.085770 -0.545924  17228.820557
# 4      0.940797 -0.261984 -0.425629    200.194381
# ...         ...       ...       ...           ...
# 49995 -0.978784  0.740276  0.645713      7.545498
# 49996 -0.845545  0.010439  0.868084      8.951832
# 49997  0.663875  0.851769  0.066433      9.645558
# 49998 -0.514888  0.618938  0.761628   1447.660375
# 49999 -0.854587 -0.912670 -0.468766    834.022557
#
# [49563 rows x 11 columns]

# %%
#-------------------------- distribution of log(response) --------------------------
plt.figure(figsize = (10, 6)) # set the size of the figure
sns.set_style("darkgrid")
sns.histplot(np.log(dt_cleaned['Y']), bins = 30, kde = True) # draw the chart
plt.title('Distribution of log(Y)')
plt.xlabel('Log(Y)')
plt.ylabel('Frequency')
plt.tick_params(axis = 'x')
plt.tick_params(axis = 'y')
plt.grid(True)
plt.show()

# %%
# remove unnecessary columns
# dt_cleaned = dt_cleaned.drop(columns=["X7", "X8", "X9", "X10"])
dt_cleaned = dt_cleaned.drop(columns = ["X9", "X10"])

# %%
#-------------------------- column lists --------------------------
target_var = "Y" # target feature
all_vars = list(dt_cleaned.columns)
all_vars.remove(target_var) # store all input features
cat_vars = [] # categorical features

# %%
############################ 1. MODEL FITTING ############################

#-------------------------- train-test split --------------------------
X_main, X_test, y_main, y_test = train_test_split(
    dt_cleaned[all_vars], dt_cleaned[["Y"]], test_size = 0.2, random_state = 1)
X_train, X_val, y_train, y_val  = train_test_split(
    X_main, y_main, test_size = 0.25, random_state = 1)

# %%
# -------------------------- function to create a subnetwork --------------------------
# subnet for numerical variables
def create_subnet(num_layers, units_first_layer, activation, model_name, dropout_rate = 0, trainable = True, seed = 1):
    model = Sequential(name = model_name)
    for i in range(num_layers):
        num_units = units_first_layer - i*int(units_first_layer/num_layers)
        model.add(Dense(num_units, activation = activation, trainable = trainable))
        model.add(Dropout(dropout_rate, seed = seed))
    model.add(Dense(1, trainable = trainable))
    model.add(BatchNormalization(scale = False)) # for identifiability
    return model

# layer to add all subnets' outputs and a bias term
@keras.saving.register_keras_serializable()
class AddSubnetOutput(Layer):
    def __init__(self, activation = None, **kwargs):
        super().__init__(**kwargs)
        self.activation = keras.activations.get(activation)
        self.bias = self.add_weight(
            shape = (1,), initializer = 'zeros', trainable = True, name = 'bias'
        )   
    def call(self, inputs):
        subnet_sum = K.sum(inputs, axis = -1, keepdims = True)
        output = subnet_sum + self.bias
        if self.activation is not None:
            output = self.activation(output)
        return output

# %%
# -------------------------- define model architecture --------------------------
inputs = []  # input layers
sub_outputs_main = []  # main effect subnet output
num_neurons_main = 20
num_layers_main = 2
activation = 'leaky_relu'
keypoints = 10
monotonicity_list = {"X3" : "decreasing"} # either "increasing", "decreasing", or "none"

# main effect
for name in all_vars:
    input_layer = Input(shape = (1,), name = name)
    inputs.append(input_layer)

    # subnetworks for main effects
    if name in cat_vars: # categorical variables
        # categorical variables will be one-hot encoded
        embed_layer = Embedding(input_dim = X_train[name].nunique(), 
                                output_dim = 1, 
                                name = f"{name}_embed")(input_layer)
        embed_layer_reshape = Reshape(target_shape = (1,), name = f"{name}_reshape")(embed_layer)
        mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(embed_layer_reshape)
        sub_outputs_main.append(mean_layer)
    elif name in monotonicity_list: # variables with monotonicity constraint
        calibrator_layer = tfl.layers.PWLCalibration(
            input_keypoints =  np.linspace(X_train[name].min(), X_train[name].max(), num = keypoints), # keypoints
            monotonicity = monotonicity_list[name], # monotonicity constraint
            name = f"{name}_pwlcalibrator"
        )(input_layer)
        mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(calibrator_layer)
        sub_outputs_main.append(mean_layer)
    else: # numeric variables
        subnet = create_subnet(num_layers_main, num_neurons_main, activation, f"{name}_subnetwork")
        sub_output = subnet(input_layer)
        sub_outputs_main.append(sub_output)

# combine subnets' outputs
main_subnets = Concatenate(name = "main_subnet")(sub_outputs_main)
final_output = Dense(1, activation = "exponential", name = "main_output")(main_subnets)
# final_output = AddSubnetOutput(activation = 'exponential',
#                      name = "main_output")(main_subnets)

# final model
model_main_effect = Model(inputs = inputs, outputs = final_output)

# %%
plot_model(model_main_effect)

# %%
# -------------------------- define loss function --------------------------
# we will use a Gamma loss function
def gamma_nll(y_true, y_pred):
    y_pred = K.clip(y_pred, 1e-7, 1e30)
    return K.mean(y_true/y_pred - K.log(y_true/y_pred))

# create training & validation data consistent with the model architecture
X_train_split = []
X_val_split = []
X_test_split = []
for i in range(len(X_train.columns)):
    X_train_split.append(X_train.iloc[:, i])
    X_val_split.append(X_val.iloc[:, i])
    X_test_split.append(X_test.iloc[:, i])

# compile and fit
model_main_effect.compile(optimizer = "adam", loss = gamma_nll, metrics = [RootMeanSquaredError()])
es = EarlyStopping(restore_best_weights = True, patience = 20)
# %time hist_main = model_main_effect.fit(X_train_split, y_train, epochs = 5_000, \
    callbacks = [es], batch_size = 1_000, validation_data = (X_val_split, y_val))
# Out:
# Epoch 1/5000
# 30/30 [==============================] - 1s 9ms/step - loss: 1379.5402 - root_mean_squared_error: 2615.0398 - val_loss: 731.6932 - val_root_mean_squared_error: 2664.3743
# Epoch 2/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 849.1501 - root_mean_squared_error: 2615.1658 - val_loss: 716.3116 - val_root_mean_squared_error: 2664.3696
# Epoch 3/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 634.2004 - root_mean_squared_error: 2615.3228 - val_loss: 635.9583 - val_root_mean_squared_error: 2664.3157
# Epoch 4/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 567.8922 - root_mean_squared_error: 2615.2712 - val_loss: 592.1810 - val_root_mean_squared_error: 2664.2798
# Epoch 5/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 510.0503 - root_mean_squared_error: 2615.2075 - val_loss: 548.7804 - val_root_mean_squared_error: 2664.2388
# Epoch 6/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 459.1485 - root_mean_squared_error: 2615.1296 - val_loss: 494.6796 - val_root_mean_squared_error: 2664.1772
# Epoch 7/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 414.5478 - root_mean_squared_error: 2615.0408 - val_loss: 446.1276 - val_root_mean_squared_error: 2664.1091
# Epoch 8/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 366.5343 - root_mean_squared_error: 2614.9324 - val_loss: 397.0110 - val_root_mean_squared_error: 2664.0237
# Epoch 9/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 325.5738 - root_mean_squared_error: 2614.7993 - val_loss: 360.6654 - val_root_mean_squared_error: 2663.9448
# Epoch 10/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 291.5110 - root_mean_squared_error: 2614.6748 - val_loss: 312.0009 - val_root_mean_squared_error: 2663.8101
# Epoch 11/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 256.3836 - root_mean_squared_error: 2614.5056 - val_loss: 277.7006 - val_root_mean_squared_error: 2663.6863
# Epoch 12/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 225.1214 - root_mean_squared_error: 2614.3293 - val_loss: 257.9586 - val_root_mean_squared_error: 2663.5952
# Epoch 13/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 199.3596 - root_mean_squared_error: 2614.1135 - val_loss: 236.3477 - val_root_mean_squared_error: 2663.4807
# Epoch 14/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 176.3161 - root_mean_squared_error: 2613.8689 - val_loss: 201.9034 - val_root_mean_squared_error: 2663.2449
# Epoch 15/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 156.8344 - root_mean_squared_error: 2613.6040 - val_loss: 181.9350 - val_root_mean_squared_error: 2663.0544
# Epoch 16/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 139.6507 - root_mean_squared_error: 2613.3064 - val_loss: 157.1523 - val_root_mean_squared_error: 2662.7605
# Epoch 17/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 125.3655 - root_mean_squared_error: 2612.9854 - val_loss: 148.4882 - val_root_mean_squared_error: 2662.6091
# Epoch 18/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 112.3690 - root_mean_squared_error: 2612.5962 - val_loss: 128.4573 - val_root_mean_squared_error: 2662.2117
# Epoch 19/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 101.0794 - root_mean_squared_error: 2612.2339 - val_loss: 117.2273 - val_root_mean_squared_error: 2661.8599
# Epoch 20/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 91.3987 - root_mean_squared_error: 2611.7517 - val_loss: 107.8191 - val_root_mean_squared_error: 2661.5818
# Epoch 21/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 82.3414 - root_mean_squared_error: 2611.2979 - val_loss: 86.6687 - val_root_mean_squared_error: 2660.7180
# Epoch 22/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 74.8638 - root_mean_squared_error: 2610.7576 - val_loss: 83.4637 - val_root_mean_squared_error: 2660.4485
# Epoch 23/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 67.8213 - root_mean_squared_error: 2610.1946 - val_loss: 81.4248 - val_root_mean_squared_error: 2660.2185
# Epoch 24/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 61.7190 - root_mean_squared_error: 2609.6743 - val_loss: 74.6992 - val_root_mean_squared_error: 2659.8057
# Epoch 25/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 56.5891 - root_mean_squared_error: 2609.0627 - val_loss: 68.8704 - val_root_mean_squared_error: 2659.1067
# Epoch 26/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 51.6415 - root_mean_squared_error: 2608.3889 - val_loss: 62.7814 - val_root_mean_squared_error: 2658.5740
# Epoch 27/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 47.4471 - root_mean_squared_error: 2607.7998 - val_loss: 53.2578 - val_root_mean_squared_error: 2657.1418
# Epoch 28/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 43.7414 - root_mean_squared_error: 2607.0208 - val_loss: 54.9995 - val_root_mean_squared_error: 2657.4375
# Epoch 29/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 40.4088 - root_mean_squared_error: 2606.1965 - val_loss: 45.1333 - val_root_mean_squared_error: 2655.7810
# Epoch 30/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 37.2994 - root_mean_squared_error: 2605.3699 - val_loss: 47.7042 - val_root_mean_squared_error: 2656.1313
# Epoch 31/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 34.5165 - root_mean_squared_error: 2604.4768 - val_loss: 44.7913 - val_root_mean_squared_error: 2655.3962
# Epoch 32/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 32.0626 - root_mean_squared_error: 2603.7683 - val_loss: 39.3926 - val_root_mean_squared_error: 2654.1489
# Epoch 33/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 29.8620 - root_mean_squared_error: 2602.7380 - val_loss: 39.4858 - val_root_mean_squared_error: 2653.6580
# Epoch 34/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 27.8161 - root_mean_squared_error: 2601.7422 - val_loss: 35.5302 - val_root_mean_squared_error: 2653.0315
# Epoch 35/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 25.9157 - root_mean_squared_error: 2600.6582 - val_loss: 31.2070 - val_root_mean_squared_error: 2651.4136
# Epoch 36/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 24.2625 - root_mean_squared_error: 2599.7271 - val_loss: 26.8037 - val_root_mean_squared_error: 2649.1301
# Epoch 37/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 22.7227 - root_mean_squared_error: 2598.7686 - val_loss: 22.9044 - val_root_mean_squared_error: 2646.7979
# Epoch 38/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 21.2658 - root_mean_squared_error: 2597.6055 - val_loss: 23.4985 - val_root_mean_squared_error: 2647.2021
# Epoch 39/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 19.9916 - root_mean_squared_error: 2596.4004 - val_loss: 23.6673 - val_root_mean_squared_error: 2647.3152
# Epoch 40/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 18.8531 - root_mean_squared_error: 2595.3167 - val_loss: 20.6317 - val_root_mean_squared_error: 2645.1528
# Epoch 41/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 17.7554 - root_mean_squared_error: 2594.5391 - val_loss: 17.4637 - val_root_mean_squared_error: 2640.6567
# Epoch 42/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 16.7413 - root_mean_squared_error: 2592.9824 - val_loss: 16.3423 - val_root_mean_squared_error: 2640.9968
# Epoch 43/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 15.7958 - root_mean_squared_error: 2592.2427 - val_loss: 15.0002 - val_root_mean_squared_error: 2638.0339
# Epoch 44/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 14.9221 - root_mean_squared_error: 2590.7820 - val_loss: 15.7822 - val_root_mean_squared_error: 2639.2056
# Epoch 45/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 14.1297 - root_mean_squared_error: 2589.3948 - val_loss: 15.3006 - val_root_mean_squared_error: 2638.5510
# Epoch 46/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 13.3915 - root_mean_squared_error: 2588.2075 - val_loss: 14.4478 - val_root_mean_squared_error: 2637.4290
# Epoch 47/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 12.7272 - root_mean_squared_error: 2586.9114 - val_loss: 14.1944 - val_root_mean_squared_error: 2636.4766
# Epoch 48/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 12.1617 - root_mean_squared_error: 2585.3198 - val_loss: 12.4870 - val_root_mean_squared_error: 2633.0449
# Epoch 49/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 11.5168 - root_mean_squared_error: 2584.0557 - val_loss: 11.1852 - val_root_mean_squared_error: 2629.3845
# Epoch 50/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 10.9885 - root_mean_squared_error: 2582.6255 - val_loss: 10.4808 - val_root_mean_squared_error: 2627.1079
# Epoch 51/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 10.4979 - root_mean_squared_error: 2581.1682 - val_loss: 10.0534 - val_root_mean_squared_error: 2625.6375
# Epoch 52/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 10.0252 - root_mean_squared_error: 2579.4070 - val_loss: 10.7615 - val_root_mean_squared_error: 2627.9536
# Epoch 53/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 9.5957 - root_mean_squared_error: 2577.9441 - val_loss: 9.4495 - val_root_mean_squared_error: 2623.1108
# Epoch 54/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 9.1915 - root_mean_squared_error: 2576.4688 - val_loss: 9.7623 - val_root_mean_squared_error: 2624.2292
# Epoch 55/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 8.8256 - root_mean_squared_error: 2574.3943 - val_loss: 9.3871 - val_root_mean_squared_error: 2623.3950
# Epoch 56/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 8.4707 - root_mean_squared_error: 2572.9045 - val_loss: 8.6684 - val_root_mean_squared_error: 2619.3474
# Epoch 57/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 8.1396 - root_mean_squared_error: 2571.3643 - val_loss: 8.7449 - val_root_mean_squared_error: 2619.7212
# Epoch 58/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 7.8284 - root_mean_squared_error: 2569.2698 - val_loss: 8.3408 - val_root_mean_squared_error: 2617.9148
# Epoch 59/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 7.5421 - root_mean_squared_error: 2567.7371 - val_loss: 8.0072 - val_root_mean_squared_error: 2615.6211
# Epoch 60/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 7.2835 - root_mean_squared_error: 2565.7803 - val_loss: 7.5604 - val_root_mean_squared_error: 2612.9775
# Epoch 61/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 7.0252 - root_mean_squared_error: 2563.8452 - val_loss: 7.3444 - val_root_mean_squared_error: 2610.9255
# Epoch 62/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 6.8039 - root_mean_squared_error: 2562.4194 - val_loss: 7.2223 - val_root_mean_squared_error: 2609.1746
# Epoch 63/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 6.5663 - root_mean_squared_error: 2560.0413 - val_loss: 7.0547 - val_root_mean_squared_error: 2609.0281
# Epoch 64/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 6.3547 - root_mean_squared_error: 2558.1599 - val_loss: 6.5800 - val_root_mean_squared_error: 2603.7603
# Epoch 65/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 6.1545 - root_mean_squared_error: 2556.4802 - val_loss: 6.4069 - val_root_mean_squared_error: 2602.8523
# Epoch 66/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 5.9511 - root_mean_squared_error: 2553.6033 - val_loss: 6.1150 - val_root_mean_squared_error: 2599.7490
# Epoch 67/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 5.7831 - root_mean_squared_error: 2552.4243 - val_loss: 6.2734 - val_root_mean_squared_error: 2600.2961
# Epoch 68/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 5.6153 - root_mean_squared_error: 2549.7576 - val_loss: 6.5410 - val_root_mean_squared_error: 2604.0242
# Epoch 69/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 5.4535 - root_mean_squared_error: 2547.9897 - val_loss: 6.3813 - val_root_mean_squared_error: 2602.4087
# Epoch 70/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 5.3036 - root_mean_squared_error: 2545.8860 - val_loss: 5.7032 - val_root_mean_squared_error: 2593.7058
# Epoch 71/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 5.1669 - root_mean_squared_error: 2543.9797 - val_loss: 5.5903 - val_root_mean_squared_error: 2592.1230
# Epoch 72/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 5.0297 - root_mean_squared_error: 2541.4663 - val_loss: 5.3556 - val_root_mean_squared_error: 2588.8696
# Epoch 73/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.9034 - root_mean_squared_error: 2539.6711 - val_loss: 4.6552 - val_root_mean_squared_error: 2576.3569
# Epoch 74/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.7894 - root_mean_squared_error: 2537.4365 - val_loss: 4.8356 - val_root_mean_squared_error: 2580.0205
# Epoch 75/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.6734 - root_mean_squared_error: 2535.0522 - val_loss: 5.1680 - val_root_mean_squared_error: 2585.9434
# Epoch 76/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.5689 - root_mean_squared_error: 2532.6279 - val_loss: 4.9593 - val_root_mean_squared_error: 2583.5161
# Epoch 77/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.4646 - root_mean_squared_error: 2531.1252 - val_loss: 4.5515 - val_root_mean_squared_error: 2574.4590
# Epoch 78/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.3614 - root_mean_squared_error: 2528.4365 - val_loss: 4.3767 - val_root_mean_squared_error: 2569.9509
# Epoch 79/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.2766 - root_mean_squared_error: 2526.0408 - val_loss: 4.2836 - val_root_mean_squared_error: 2567.3496
# Epoch 80/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.1926 - root_mean_squared_error: 2524.1169 - val_loss: 4.2970 - val_root_mean_squared_error: 2568.1809
# Epoch 81/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.1077 - root_mean_squared_error: 2522.1479 - val_loss: 4.3442 - val_root_mean_squared_error: 2568.1899
# Epoch 82/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 4.0241 - root_mean_squared_error: 2519.6067 - val_loss: 4.2185 - val_root_mean_squared_error: 2564.9028
# Epoch 83/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.9559 - root_mean_squared_error: 2517.2959 - val_loss: 3.9924 - val_root_mean_squared_error: 2559.0330
# Epoch 84/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.8839 - root_mean_squared_error: 2514.5784 - val_loss: 3.8421 - val_root_mean_squared_error: 2553.8606
# Epoch 85/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.8280 - root_mean_squared_error: 2512.9653 - val_loss: 3.5968 - val_root_mean_squared_error: 2543.3931
# Epoch 86/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.7554 - root_mean_squared_error: 2510.0073 - val_loss: 3.5805 - val_root_mean_squared_error: 2543.2654
# Epoch 87/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.7019 - root_mean_squared_error: 2508.1946 - val_loss: 3.6930 - val_root_mean_squared_error: 2547.6941
# Epoch 88/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.6421 - root_mean_squared_error: 2506.2129 - val_loss: 3.7210 - val_root_mean_squared_error: 2547.7119
# Epoch 89/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.5835 - root_mean_squared_error: 2503.6445 - val_loss: 3.6539 - val_root_mean_squared_error: 2546.7014
# Epoch 90/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.5339 - root_mean_squared_error: 2501.7834 - val_loss: 3.6493 - val_root_mean_squared_error: 2545.9221
# Epoch 91/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.4817 - root_mean_squared_error: 2498.9424 - val_loss: 3.6180 - val_root_mean_squared_error: 2543.7764
# Epoch 92/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.4357 - root_mean_squared_error: 2497.3357 - val_loss: 3.5470 - val_root_mean_squared_error: 2540.5652
# Epoch 93/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.3905 - root_mean_squared_error: 2494.9346 - val_loss: 3.4615 - val_root_mean_squared_error: 2536.3606
# Epoch 94/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.3476 - root_mean_squared_error: 2492.8271 - val_loss: 3.4923 - val_root_mean_squared_error: 2537.4944
# Epoch 95/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.3116 - root_mean_squared_error: 2490.0713 - val_loss: 3.3977 - val_root_mean_squared_error: 2532.0215
# Epoch 96/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.2682 - root_mean_squared_error: 2488.9922 - val_loss: 3.3180 - val_root_mean_squared_error: 2526.8103
# Epoch 97/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.2304 - root_mean_squared_error: 2485.8870 - val_loss: 3.3870 - val_root_mean_squared_error: 2532.5095
# Epoch 98/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.1965 - root_mean_squared_error: 2483.7776 - val_loss: 3.2716 - val_root_mean_squared_error: 2526.3582
# Epoch 99/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.1639 - root_mean_squared_error: 2482.2563 - val_loss: 3.2563 - val_root_mean_squared_error: 2525.2786
# Epoch 100/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.1344 - root_mean_squared_error: 2479.7437 - val_loss: 3.2680 - val_root_mean_squared_error: 2526.4124
# Epoch 101/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.1036 - root_mean_squared_error: 2478.3516 - val_loss: 3.2320 - val_root_mean_squared_error: 2521.9246
# Epoch 102/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.0721 - root_mean_squared_error: 2475.5220 - val_loss: 3.1601 - val_root_mean_squared_error: 2517.8430
# Epoch 103/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.0461 - root_mean_squared_error: 2473.8821 - val_loss: 3.0666 - val_root_mean_squared_error: 2511.6189
# Epoch 104/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.0224 - root_mean_squared_error: 2472.5029 - val_loss: 3.1201 - val_root_mean_squared_error: 2514.8142
# Epoch 105/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.0028 - root_mean_squared_error: 2470.3635 - val_loss: 3.1686 - val_root_mean_squared_error: 2516.4697
# Epoch 106/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.9749 - root_mean_squared_error: 2467.8208 - val_loss: 3.0393 - val_root_mean_squared_error: 2508.6758
# Epoch 107/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.9519 - root_mean_squared_error: 2465.6316 - val_loss: 3.0431 - val_root_mean_squared_error: 2508.5767
# Epoch 108/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.9334 - root_mean_squared_error: 2464.4773 - val_loss: 2.9633 - val_root_mean_squared_error: 2502.0125
# Epoch 109/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.9112 - root_mean_squared_error: 2462.4478 - val_loss: 2.9702 - val_root_mean_squared_error: 2502.2637
# Epoch 110/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.8941 - root_mean_squared_error: 2461.6938 - val_loss: 2.9574 - val_root_mean_squared_error: 2500.1821
# Epoch 111/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.8734 - root_mean_squared_error: 2459.0347 - val_loss: 2.9050 - val_root_mean_squared_error: 2497.2000
# Epoch 112/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.8585 - root_mean_squared_error: 2457.4771 - val_loss: 2.8549 - val_root_mean_squared_error: 2490.4480
# Epoch 113/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.8401 - root_mean_squared_error: 2455.4702 - val_loss: 2.8703 - val_root_mean_squared_error: 2492.1365
# Epoch 114/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.8266 - root_mean_squared_error: 2455.0486 - val_loss: 2.7974 - val_root_mean_squared_error: 2483.9446
# Epoch 115/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.8119 - root_mean_squared_error: 2452.7046 - val_loss: 2.7569 - val_root_mean_squared_error: 2480.2539
# Epoch 116/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.7965 - root_mean_squared_error: 2451.1155 - val_loss: 2.7206 - val_root_mean_squared_error: 2474.9624
# Epoch 117/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.7831 - root_mean_squared_error: 2449.5974 - val_loss: 2.7370 - val_root_mean_squared_error: 2477.1980
# Epoch 118/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.7703 - root_mean_squared_error: 2448.7578 - val_loss: 2.7155 - val_root_mean_squared_error: 2474.3235
# Epoch 119/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.7635 - root_mean_squared_error: 2447.2827 - val_loss: 2.6950 - val_root_mean_squared_error: 2468.6321
# Epoch 120/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.7510 - root_mean_squared_error: 2446.9492 - val_loss: 2.7004 - val_root_mean_squared_error: 2469.7351
# Epoch 121/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.7384 - root_mean_squared_error: 2444.1738 - val_loss: 2.6894 - val_root_mean_squared_error: 2468.4050
# Epoch 122/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.7259 - root_mean_squared_error: 2441.5535 - val_loss: 2.6623 - val_root_mean_squared_error: 2465.9009
# Epoch 123/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.7182 - root_mean_squared_error: 2441.7695 - val_loss: 2.6485 - val_root_mean_squared_error: 2462.5876
# Epoch 124/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.7073 - root_mean_squared_error: 2441.5505 - val_loss: 2.6706 - val_root_mean_squared_error: 2467.0317
# Epoch 125/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6983 - root_mean_squared_error: 2439.3621 - val_loss: 2.6860 - val_root_mean_squared_error: 2468.9817
# Epoch 126/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6893 - root_mean_squared_error: 2437.3167 - val_loss: 2.6897 - val_root_mean_squared_error: 2470.2871
# Epoch 127/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6830 - root_mean_squared_error: 2437.1382 - val_loss: 2.6740 - val_root_mean_squared_error: 2467.1978
# Epoch 128/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6772 - root_mean_squared_error: 2436.2327 - val_loss: 2.6591 - val_root_mean_squared_error: 2464.8718
# Epoch 129/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6680 - root_mean_squared_error: 2435.0251 - val_loss: 2.6511 - val_root_mean_squared_error: 2464.3242
# Epoch 130/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6641 - root_mean_squared_error: 2434.7991 - val_loss: 2.6707 - val_root_mean_squared_error: 2466.3269
# Epoch 131/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6596 - root_mean_squared_error: 2432.1670 - val_loss: 2.6783 - val_root_mean_squared_error: 2466.9016
# Epoch 132/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6509 - root_mean_squared_error: 2432.1833 - val_loss: 2.6597 - val_root_mean_squared_error: 2465.8525
# Epoch 133/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6439 - root_mean_squared_error: 2431.4880 - val_loss: 2.6447 - val_root_mean_squared_error: 2461.9690
# Epoch 134/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6374 - root_mean_squared_error: 2430.5925 - val_loss: 2.6302 - val_root_mean_squared_error: 2461.0703
# Epoch 135/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6359 - root_mean_squared_error: 2428.6055 - val_loss: 2.6184 - val_root_mean_squared_error: 2459.0684
# Epoch 136/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6309 - root_mean_squared_error: 2430.9475 - val_loss: 2.6287 - val_root_mean_squared_error: 2459.5725
# Epoch 137/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6250 - root_mean_squared_error: 2427.2412 - val_loss: 2.6209 - val_root_mean_squared_error: 2456.2751
# Epoch 138/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6240 - root_mean_squared_error: 2430.0151 - val_loss: 2.6527 - val_root_mean_squared_error: 2463.6770
# Epoch 139/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6180 - root_mean_squared_error: 2426.9556 - val_loss: 2.6364 - val_root_mean_squared_error: 2460.3389
# Epoch 140/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6144 - root_mean_squared_error: 2429.6331 - val_loss: 2.6303 - val_root_mean_squared_error: 2457.0535
# Epoch 141/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6124 - root_mean_squared_error: 2425.9734 - val_loss: 2.5975 - val_root_mean_squared_error: 2453.3855
# Epoch 142/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6075 - root_mean_squared_error: 2424.4133 - val_loss: 2.6087 - val_root_mean_squared_error: 2455.3940
# Epoch 143/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6032 - root_mean_squared_error: 2428.2163 - val_loss: 2.6010 - val_root_mean_squared_error: 2454.3069
# Epoch 144/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.6013 - root_mean_squared_error: 2424.0347 - val_loss: 2.5840 - val_root_mean_squared_error: 2451.8359
# Epoch 145/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5980 - root_mean_squared_error: 2425.2703 - val_loss: 2.5776 - val_root_mean_squared_error: 2449.9846
# Epoch 146/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5953 - root_mean_squared_error: 2423.5374 - val_loss: 2.5798 - val_root_mean_squared_error: 2451.9451
# Epoch 147/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5946 - root_mean_squared_error: 2424.3311 - val_loss: 2.5868 - val_root_mean_squared_error: 2452.3623
# Epoch 148/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5915 - root_mean_squared_error: 2423.4480 - val_loss: 2.5815 - val_root_mean_squared_error: 2452.4250
# Epoch 149/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5901 - root_mean_squared_error: 2426.2319 - val_loss: 2.5849 - val_root_mean_squared_error: 2452.5039
# Epoch 150/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5887 - root_mean_squared_error: 2423.9285 - val_loss: 2.5718 - val_root_mean_squared_error: 2454.9226
# Epoch 151/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5869 - root_mean_squared_error: 2423.1624 - val_loss: 2.5683 - val_root_mean_squared_error: 2449.2097
# Epoch 152/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5854 - root_mean_squared_error: 2424.2070 - val_loss: 2.5743 - val_root_mean_squared_error: 2450.6760
# Epoch 153/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5852 - root_mean_squared_error: 2424.4380 - val_loss: 2.5651 - val_root_mean_squared_error: 2448.4270
# Epoch 154/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5817 - root_mean_squared_error: 2423.6116 - val_loss: 2.5688 - val_root_mean_squared_error: 2450.3506
# Epoch 155/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5814 - root_mean_squared_error: 2424.5940 - val_loss: 2.5769 - val_root_mean_squared_error: 2449.5703
# Epoch 156/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5790 - root_mean_squared_error: 2422.0251 - val_loss: 2.5797 - val_root_mean_squared_error: 2453.5005
# Epoch 157/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5789 - root_mean_squared_error: 2425.1777 - val_loss: 2.5702 - val_root_mean_squared_error: 2449.5562
# Epoch 158/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5775 - root_mean_squared_error: 2424.0593 - val_loss: 2.5824 - val_root_mean_squared_error: 2450.8118
# Epoch 159/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5742 - root_mean_squared_error: 2421.9729 - val_loss: 2.5888 - val_root_mean_squared_error: 2453.7903
# Epoch 160/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5772 - root_mean_squared_error: 2423.8752 - val_loss: 2.5623 - val_root_mean_squared_error: 2450.5864
# Epoch 161/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5736 - root_mean_squared_error: 2423.9263 - val_loss: 2.5639 - val_root_mean_squared_error: 2448.4216
# Epoch 162/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5725 - root_mean_squared_error: 2424.2217 - val_loss: 2.5660 - val_root_mean_squared_error: 2445.6809
# Epoch 163/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5718 - root_mean_squared_error: 2420.4998 - val_loss: 2.5649 - val_root_mean_squared_error: 2450.1252
# Epoch 164/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5719 - root_mean_squared_error: 2423.7454 - val_loss: 2.5559 - val_root_mean_squared_error: 2446.8955
# Epoch 165/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5710 - root_mean_squared_error: 2422.1011 - val_loss: 2.5527 - val_root_mean_squared_error: 2446.9387
# Epoch 166/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5723 - root_mean_squared_error: 2424.8284 - val_loss: 2.5505 - val_root_mean_squared_error: 2444.2385
# Epoch 167/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5702 - root_mean_squared_error: 2426.4053 - val_loss: 2.5556 - val_root_mean_squared_error: 2448.4060
# Epoch 168/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5698 - root_mean_squared_error: 2423.7939 - val_loss: 2.5548 - val_root_mean_squared_error: 2443.7854
# Epoch 169/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5686 - root_mean_squared_error: 2423.3374 - val_loss: 2.5571 - val_root_mean_squared_error: 2451.9756
# Epoch 170/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5684 - root_mean_squared_error: 2422.5000 - val_loss: 2.5601 - val_root_mean_squared_error: 2453.3357
# Epoch 171/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5703 - root_mean_squared_error: 2428.0002 - val_loss: 2.5575 - val_root_mean_squared_error: 2448.6204
# Epoch 172/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5671 - root_mean_squared_error: 2424.9814 - val_loss: 2.5544 - val_root_mean_squared_error: 2448.4463
# Epoch 173/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5668 - root_mean_squared_error: 2420.5244 - val_loss: 2.5660 - val_root_mean_squared_error: 2448.2524
# Epoch 174/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5672 - root_mean_squared_error: 2425.3923 - val_loss: 2.5569 - val_root_mean_squared_error: 2446.8521
# Epoch 175/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5688 - root_mean_squared_error: 2425.0339 - val_loss: 2.5543 - val_root_mean_squared_error: 2442.8926
# Epoch 176/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5654 - root_mean_squared_error: 2420.5801 - val_loss: 2.5571 - val_root_mean_squared_error: 2448.7046
# Epoch 177/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5675 - root_mean_squared_error: 2423.6626 - val_loss: 2.5552 - val_root_mean_squared_error: 2445.4121
# Epoch 178/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5671 - root_mean_squared_error: 2424.8284 - val_loss: 2.5547 - val_root_mean_squared_error: 2450.0132
# Epoch 179/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5686 - root_mean_squared_error: 2428.4019 - val_loss: 2.5510 - val_root_mean_squared_error: 2447.6926
# Epoch 180/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5684 - root_mean_squared_error: 2426.6904 - val_loss: 2.5553 - val_root_mean_squared_error: 2448.5503
# Epoch 181/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5648 - root_mean_squared_error: 2425.1335 - val_loss: 2.5511 - val_root_mean_squared_error: 2445.2942
# Epoch 182/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5655 - root_mean_squared_error: 2421.9692 - val_loss: 2.5535 - val_root_mean_squared_error: 2449.7927
# Epoch 183/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5656 - root_mean_squared_error: 2427.9707 - val_loss: 2.5632 - val_root_mean_squared_error: 2443.6323
# Epoch 184/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5671 - root_mean_squared_error: 2427.3784 - val_loss: 2.5536 - val_root_mean_squared_error: 2448.2041
# Epoch 185/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5661 - root_mean_squared_error: 2426.4094 - val_loss: 2.5639 - val_root_mean_squared_error: 2449.9187
# Epoch 186/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.5653 - root_mean_squared_error: 2425.2664 - val_loss: 2.5547 - val_root_mean_squared_error: 2452.5002
# CPU times: user 21.5 s, sys: 2.8 s, total: 24.3 s
# Wall time: 18.2 s

# %%
# -------------------------- get validation loss --------------------------
main_val_loss, main_rmse = model_main_effect.evaluate(X_val_split, y_val, verbose = False) # get the validation loss and RMSE
print(f"Validation loss for main effect: {main_val_loss}")
print(f"Validation RMSE for main effect: {main_rmse}")
# Out:
# Validation loss for main effect: 2.550511360168457
# Validation RMSE for main effect: 2444.23828125

# %%
# -------------------------- quantify variable importance --------------------------
main_output_layer = model_main_effect.get_layer("main_subnet")  # Get the subnet output layer
main_model = Model(inputs = model_main_effect.inputs, outputs = main_output_layer.output)
main_output_values = main_model.predict(X_train_split, batch_size = 1_000)
subnet_weights = model_main_effect.get_layer("main_output").get_weights()[0]

# Get the variance of each subnetwork across all data points
subnet_variance = []
for i in range(main_output_values.shape[1]):
    subnet_variance.append(np.var(main_output_values[:, i])*subnet_weights[i][0]**2)

# Define covariates
covariates = [name for name in all_vars]

# -------------------------- plot the variable importance --------------------------
# Create DataFrame for variable importance
var_importance = pd.DataFrame({"Covariates": covariates, "Subnet Variance": subnet_variance})

# Sort the DataFrame by subnet variance in decreasing order
varimp_sorted = var_importance.sort_values(by = "Subnet Variance", ascending = False)

# Create a bar plot using Seaborn
plt.figure(figsize = (10, 6))
sns.barplot(x = "Covariates", y = "Subnet Variance", data = varimp_sorted)
plt.title("Subnet Variance by Covariates")
plt.xlabel("Covariates")
plt.ylabel("Subnet Variance")
plt.show()
# Out:
# 30/30 [==============================] - 0s 847us/step

# %%
#-------------------------- view the shape function --------------------------
# create the plot
var_name = "X1"
var_index = all_vars.index(var_name)
plt.figure(figsize = (12, 6))
sns.lineplot(x = X_train_split[var_index], 
             y = main_output_values[:,var_index]*subnet_weights[i].flatten())
plt.xlabel(f"{var_name}")
plt.ylabel('Subnetwork Output')
plt.title(f"Shape function for {var_name}")
plt.grid(True)
plt.show()

# %%
############################   preparation for interaction selection   ############################
global_layers = ["main_subnet", "main_output", "interaction_output", "final_output"] # these layers are always trainable
imp_vars = [f"X{i}" for i in range(1,9)] # important variables
num_layers_interaction = 10 # number of layers for each interaction effect
num_neurons_interaction = 100 # number of neurons per dense layer for each interaction effect
keypoints = 20
lattice_sizes_pairwise = {}
for var in imp_vars:
    if var in cat_vars:
        lattice_sizes_pairwise[var] = X_train[var].nunique()
    else:
        lattice_sizes_pairwise[var] = 8

# %%
# -------------------------- create calibrator for lattice layer --------------------------
def add_calibrate_layer(var, data, monotonicity_list, lattice_sizes, keypoints, cat_vars, lattice_smooth_reg = [0,0]):
    if var in cat_vars:
        calibrator_layer = tfl.layers.CategoricalCalibration(
            num_buckets = data[var].nunique(),
            output_min = 0,
            output_max = lattice_sizes[var] - 1,
            name = f"{var}_calibrator_pairwise"
        )
    else:
        calibrator_layer = tfl.layers.PWLCalibration(
            input_keypoints =  np.linspace(data[var].min(), data[var].max(), num = keypoints), # keypoints
            kernel_regularizer = ('hessian', lattice_smooth_reg[0], lattice_smooth_reg[1]), # for smoothness
            monotonicity = monotonicity_list[var] if var in monotonicity_list else "none", # monotonicity constraint
            output_min = 0,
            output_max = lattice_sizes[var] - 1,
            name = f"{var}_calibrator_pairwise"
            )
    return calibrator_layer

# %%
############################   select interaction effect   ############################

lambd_val_loss = {}
# add pairwise effect and evaluate validation loss
for  lambd in [0]:

    interactions = combinations(imp_vars, 2)
    # interactions = [("X3","X4"),("X5","X6"),("X7","X8")]
    interaction_loss = {} # this stores the validation loss when fitting each pair of interaction effect
    for var1, var2 in interactions:

        # -------------------------- initialize a cloned model --------------------------
        model_main_cloned = clone_model(model_main_effect) # clone the main effect model
        model_main_cloned.build(model_main_effect.input_shape)
        model_main_cloned.set_weights(model_main_effect.get_weights()) # copy the weights


        # -------------------------- build a subnet for pairwise interaction effect --------------------------
        var1_input = model_main_cloned.inputs[all_vars.index(var1)]
        var2_input = model_main_cloned.inputs[all_vars.index(var2)]

        # Lattice model if the pair contains a monotonic variable
        if any(var in monotonicity_list for var in [var1, var2]):
            lattice_inputs = []

            # create calibrator_layer
            calibrator_var1 = add_calibrate_layer(var1, X_train, monotonicity_list, lattice_sizes_pairwise, keypoints, cat_vars)
            calibrator_var2 = add_calibrate_layer(var2, X_train, monotonicity_list, lattice_sizes_pairwise, keypoints, cat_vars)
            calibrator_layer_var1 = calibrator_var1(var1_input)
            calibrator_layer_var2 = calibrator_var2(var2_input)
            
            # lattice
            lattice_inputs.append(calibrator_layer_var1)
            lattice_inputs.append(calibrator_layer_var2)
            lattice_layer = tfl.layers.Lattice(lattice_sizes = [lattice_sizes_pairwise[var1],lattice_sizes_pairwise[var2]], 
                                monotonicities = ["increasing" if var1 in monotonicity_list else 'none',
                                                    "increasing" if var2 in monotonicity_list else 'none'],
                                name = f"{var1}_{var2}_lattice")(lattice_inputs)
            pairwise_output = BatchNormalization(scale = False, name = f"{var1}_{var2}_mean")(lattice_layer)
        else:
            # Subnetwork if the pair contains no monotonic variables
            pairwise_input_layer = Concatenate(name = f"{var1}_{var2}_concat")([var1_input, var2_input])
            pairwise_subnet = create_subnet(num_layers_interaction, 
                                            num_neurons_interaction, 
                                            activation, 
                                            f"{var1}_{var2}_subnetwork")
            pairwise_output = pairwise_subnet(pairwise_input_layer)

        # final output
        interaction_subnet_output = Activation('exponential',
                            name = "interaction_output")(pairwise_output)
        main_subnet_output = model_main_cloned.output
        final_output = Multiply(name = "final_output")([main_subnet_output, interaction_subnet_output])
        model_pairwise = Model(inputs = model_main_cloned.inputs, outputs = final_output)


        # -------------------------- switch on/off layers --------------------------
        for layer in model_pairwise.layers:
            if layer.name not in global_layers and var1 not in layer.name and var2 not in layer.name:
                layer.trainable = False

        # -------------------------- compile and train the model --------------------------
        model_pairwise.compile(optimizer = 'adam', 
                            loss = gamma_nll, 
                            metrics = [gamma_nll, RootMeanSquaredError()])
        es = EarlyStopping(patience = 25, restore_best_weights = True)
        model_pairwise.fit(X_train_split, y_train, epochs = 5_000, \
                                callbacks = [es], batch_size = 1_000, validation_data = (X_val_split, y_val))
        _, gamma_log_metric, _ = model_pairwise.evaluate(X_val_split, y_val, batch_size = X_val_split[0].shape[0])
        interaction_loss[f"{var1}_{var2}"] = gamma_log_metric # add to the val loss list
    
    lambd_val_loss[lambd] = interaction_loss
# Out:
# Epoch 1/5000
# 30/30 [==============================] - 1s 13ms/step - loss: 2.5819 - gamma_nll: 2.5822 - root_mean_squared_error: 2438.2478 - val_loss: 2.5671 - val_gamma_nll: 2.5661 - val_root_mean_squared_error: 2449.6819
# Epoch 2/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5694 - gamma_nll: 2.5693 - root_mean_squared_error: 2426.8079 - val_loss: 2.5576 - val_gamma_nll: 2.5564 - val_root_mean_squared_error: 2448.1575
# Epoch 3/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5716 - gamma_nll: 2.5717 - root_mean_squared_error: 2428.3452 - val_loss: 2.5587 - val_gamma_nll: 2.5575 - val_root_mean_squared_error: 2455.4041
# Epoch 4/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5689 - gamma_nll: 2.5688 - root_mean_squared_error: 2427.9128 - val_loss: 2.6036 - val_gamma_nll: 2.6026 - val_root_mean_squared_error: 2535.1467
# Epoch 5/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5683 - gamma_nll: 2.5685 - root_mean_squared_error: 2428.6584 - val_loss: 2.5607 - val_gamma_nll: 2.5595 - val_root_mean_squared_error: 2463.7026
# Epoch 6/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5712 - gamma_nll: 2.5716 - root_mean_squared_error: 2426.8254 - val_loss: 2.5642 - val_gamma_nll: 2.5628 - val_root_mean_squared_error: 2459.8940
# Epoch 7/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5688 - gamma_nll: 2.5695 - root_mean_squared_error: 2426.8896 - val_loss: 2.5940 - val_gamma_nll: 2.5926 - val_root_mean_squared_error: 2452.3513
# Epoch 8/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5721 - gamma_nll: 2.5730 - root_mean_squared_error: 2430.0159 - val_loss: 2.5856 - val_gamma_nll: 2.5842 - val_root_mean_squared_error: 2449.9465
# Epoch 9/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5729 - gamma_nll: 2.5724 - root_mean_squared_error: 2431.2917 - val_loss: 2.5529 - val_gamma_nll: 2.5517 - val_root_mean_squared_error: 2466.9988
# Epoch 10/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5709 - gamma_nll: 2.5717 - root_mean_squared_error: 2426.5808 - val_loss: 2.5675 - val_gamma_nll: 2.5663 - val_root_mean_squared_error: 2446.0042
# Epoch 11/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5703 - gamma_nll: 2.5698 - root_mean_squared_error: 2427.0896 - val_loss: 2.5531 - val_gamma_nll: 2.5520 - val_root_mean_squared_error: 2462.1821
# Epoch 12/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5675 - gamma_nll: 2.5681 - root_mean_squared_error: 2426.2534 - val_loss: 2.5581 - val_gamma_nll: 2.5568 - val_root_mean_squared_error: 2461.1062
# Epoch 13/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5731 - gamma_nll: 2.5732 - root_mean_squared_error: 2429.8325 - val_loss: 2.5853 - val_gamma_nll: 2.5841 - val_root_mean_squared_error: 2459.0562
# Epoch 14/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5688 - gamma_nll: 2.5683 - root_mean_squared_error: 2426.2363 - val_loss: 2.6934 - val_gamma_nll: 2.6921 - val_root_mean_squared_error: 2468.0293
# Epoch 15/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5683 - gamma_nll: 2.5681 - root_mean_squared_error: 2425.5713 - val_loss: 2.5961 - val_gamma_nll: 2.5947 - val_root_mean_squared_error: 2453.1677
# Epoch 16/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5657 - gamma_nll: 2.5664 - root_mean_squared_error: 2424.7480 - val_loss: 2.5735 - val_gamma_nll: 2.5724 - val_root_mean_squared_error: 2448.7058
# Epoch 17/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5682 - gamma_nll: 2.5690 - root_mean_squared_error: 2424.3477 - val_loss: 2.5783 - val_gamma_nll: 2.5771 - val_root_mean_squared_error: 2495.7429
# Epoch 18/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5640 - gamma_nll: 2.5639 - root_mean_squared_error: 2422.0049 - val_loss: 2.5658 - val_gamma_nll: 2.5648 - val_root_mean_squared_error: 2463.0103
# Epoch 19/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5676 - gamma_nll: 2.5671 - root_mean_squared_error: 2424.2424 - val_loss: 2.5639 - val_gamma_nll: 2.5627 - val_root_mean_squared_error: 2479.2534
# Epoch 20/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5719 - gamma_nll: 2.5715 - root_mean_squared_error: 2426.5146 - val_loss: 2.6238 - val_gamma_nll: 2.6227 - val_root_mean_squared_error: 2585.5908
# Epoch 21/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5612 - gamma_nll: 2.5610 - root_mean_squared_error: 2419.2754 - val_loss: 2.6361 - val_gamma_nll: 2.6351 - val_root_mean_squared_error: 2562.1460
# Epoch 22/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5642 - gamma_nll: 2.5656 - root_mean_squared_error: 2423.4607 - val_loss: 2.5739 - val_gamma_nll: 2.5728 - val_root_mean_squared_error: 2484.3623
# Epoch 23/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5643 - gamma_nll: 2.5641 - root_mean_squared_error: 2420.7605 - val_loss: 2.5761 - val_gamma_nll: 2.5750 - val_root_mean_squared_error: 2478.9080
# Epoch 24/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5635 - gamma_nll: 2.5635 - root_mean_squared_error: 2421.0251 - val_loss: 2.7049 - val_gamma_nll: 2.7038 - val_root_mean_squared_error: 2713.4949
# Epoch 25/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5650 - gamma_nll: 2.5652 - root_mean_squared_error: 2423.8740 - val_loss: 2.6470 - val_gamma_nll: 2.6459 - val_root_mean_squared_error: 2593.1372
# Epoch 26/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5634 - gamma_nll: 2.5648 - root_mean_squared_error: 2420.9761 - val_loss: 2.6408 - val_gamma_nll: 2.6397 - val_root_mean_squared_error: 2554.5627
# Epoch 27/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5636 - gamma_nll: 2.5639 - root_mean_squared_error: 2422.5449 - val_loss: 2.6350 - val_gamma_nll: 2.6338 - val_root_mean_squared_error: 2573.9116
# Epoch 28/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5699 - gamma_nll: 2.5682 - root_mean_squared_error: 2427.2224 - val_loss: 2.5912 - val_gamma_nll: 2.5902 - val_root_mean_squared_error: 2527.2725
# Epoch 29/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5714 - gamma_nll: 2.5713 - root_mean_squared_error: 2433.8083 - val_loss: 2.5735 - val_gamma_nll: 2.5724 - val_root_mean_squared_error: 2488.0989
# Epoch 30/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5682 - gamma_nll: 2.5673 - root_mean_squared_error: 2428.7922 - val_loss: 2.5581 - val_gamma_nll: 2.5571 - val_root_mean_squared_error: 2453.3318
# Epoch 31/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5668 - gamma_nll: 2.5657 - root_mean_squared_error: 2426.4573 - val_loss: 2.5692 - val_gamma_nll: 2.5680 - val_root_mean_squared_error: 2446.8799
# Epoch 32/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5637 - gamma_nll: 2.5635 - root_mean_squared_error: 2420.7583 - val_loss: 2.6067 - val_gamma_nll: 2.6053 - val_root_mean_squared_error: 2453.1746
# Epoch 33/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5630 - gamma_nll: 2.5625 - root_mean_squared_error: 2422.7131 - val_loss: 2.6185 - val_gamma_nll: 2.6174 - val_root_mean_squared_error: 2455.8896
# Epoch 34/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5687 - gamma_nll: 2.5685 - root_mean_squared_error: 2425.5793 - val_loss: 2.5851 - val_gamma_nll: 2.5837 - val_root_mean_squared_error: 2449.6619
# 1/1 [==============================] - 0s 21ms/step - loss: 2.5529 - gamma_nll: 2.5529 - root_mean_squared_error: 2466.9988
# Epoch 1/5000
# 30/30 [==============================] - 3s 70ms/step - loss: 2.4066 - gamma_nll: 2.4067 - root_mean_squared_error: 2400.3040 - val_loss: 2.8336 - val_gamma_nll: 2.8326 - val_root_mean_squared_error: 2938.7192
# Epoch 2/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3890 - gamma_nll: 2.3889 - root_mean_squared_error: 2360.6938 - val_loss: 2.5913 - val_gamma_nll: 2.5903 - val_root_mean_squared_error: 2515.7952
# Epoch 3/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3870 - gamma_nll: 2.3874 - root_mean_squared_error: 2358.7405 - val_loss: 2.5132 - val_gamma_nll: 2.5122 - val_root_mean_squared_error: 2427.9741
# Epoch 4/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3896 - gamma_nll: 2.3896 - root_mean_squared_error: 2369.2202 - val_loss: 2.5982 - val_gamma_nll: 2.5971 - val_root_mean_squared_error: 2511.4961
# Epoch 5/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3870 - gamma_nll: 2.3871 - root_mean_squared_error: 2364.9028 - val_loss: 2.4813 - val_gamma_nll: 2.4804 - val_root_mean_squared_error: 2411.0432
# Epoch 6/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3894 - gamma_nll: 2.3895 - root_mean_squared_error: 2362.0762 - val_loss: 2.5557 - val_gamma_nll: 2.5545 - val_root_mean_squared_error: 2471.4536
# Epoch 7/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3871 - gamma_nll: 2.3876 - root_mean_squared_error: 2360.8762 - val_loss: 2.4579 - val_gamma_nll: 2.4570 - val_root_mean_squared_error: 2407.6929
# Epoch 8/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3854 - gamma_nll: 2.3859 - root_mean_squared_error: 2362.1746 - val_loss: 2.4275 - val_gamma_nll: 2.4267 - val_root_mean_squared_error: 2393.0210
# Epoch 9/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3857 - gamma_nll: 2.3849 - root_mean_squared_error: 2362.8945 - val_loss: 2.3881 - val_gamma_nll: 2.3875 - val_root_mean_squared_error: 2376.1738
# Epoch 10/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3857 - gamma_nll: 2.3861 - root_mean_squared_error: 2359.5449 - val_loss: 2.4143 - val_gamma_nll: 2.4136 - val_root_mean_squared_error: 2383.6956
# Epoch 11/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3851 - gamma_nll: 2.3853 - root_mean_squared_error: 2362.2954 - val_loss: 2.4383 - val_gamma_nll: 2.4376 - val_root_mean_squared_error: 2454.7434
# Epoch 12/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3829 - gamma_nll: 2.3833 - root_mean_squared_error: 2363.8406 - val_loss: 2.5054 - val_gamma_nll: 2.5045 - val_root_mean_squared_error: 2501.1731
# Epoch 13/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3895 - gamma_nll: 2.3887 - root_mean_squared_error: 2371.5588 - val_loss: 2.3787 - val_gamma_nll: 2.3782 - val_root_mean_squared_error: 2386.9380
# Epoch 14/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3830 - gamma_nll: 2.3829 - root_mean_squared_error: 2365.2214 - val_loss: 2.4816 - val_gamma_nll: 2.4810 - val_root_mean_squared_error: 2555.0923
# Epoch 15/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3844 - gamma_nll: 2.3844 - root_mean_squared_error: 2365.6516 - val_loss: 2.5023 - val_gamma_nll: 2.5016 - val_root_mean_squared_error: 2571.0459
# Epoch 16/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3804 - gamma_nll: 2.3812 - root_mean_squared_error: 2364.2158 - val_loss: 2.4229 - val_gamma_nll: 2.4223 - val_root_mean_squared_error: 2431.2402
# Epoch 17/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3810 - gamma_nll: 2.3815 - root_mean_squared_error: 2360.6411 - val_loss: 2.4796 - val_gamma_nll: 2.4789 - val_root_mean_squared_error: 2534.8042
# Epoch 18/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3829 - gamma_nll: 2.3829 - root_mean_squared_error: 2370.2385 - val_loss: 2.4079 - val_gamma_nll: 2.4073 - val_root_mean_squared_error: 2422.6833
# Epoch 19/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3820 - gamma_nll: 2.3821 - root_mean_squared_error: 2366.2109 - val_loss: 2.4372 - val_gamma_nll: 2.4365 - val_root_mean_squared_error: 2452.0872
# Epoch 20/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3849 - gamma_nll: 2.3844 - root_mean_squared_error: 2366.2312 - val_loss: 2.3836 - val_gamma_nll: 2.3832 - val_root_mean_squared_error: 2407.7244
# Epoch 21/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3810 - gamma_nll: 2.3813 - root_mean_squared_error: 2360.4404 - val_loss: 2.4413 - val_gamma_nll: 2.4408 - val_root_mean_squared_error: 2388.4756
# Epoch 22/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3773 - gamma_nll: 2.3782 - root_mean_squared_error: 2361.4509 - val_loss: 2.4940 - val_gamma_nll: 2.4938 - val_root_mean_squared_error: 2398.7207
# Epoch 23/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3784 - gamma_nll: 2.3786 - root_mean_squared_error: 2366.3386 - val_loss: 2.4536 - val_gamma_nll: 2.4533 - val_root_mean_squared_error: 2381.4087
# Epoch 24/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3802 - gamma_nll: 2.3804 - root_mean_squared_error: 2369.6360 - val_loss: 2.5550 - val_gamma_nll: 2.5547 - val_root_mean_squared_error: 2415.0100
# Epoch 25/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3794 - gamma_nll: 2.3798 - root_mean_squared_error: 2364.5005 - val_loss: 2.4246 - val_gamma_nll: 2.4242 - val_root_mean_squared_error: 2386.9705
# Epoch 26/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3777 - gamma_nll: 2.3786 - root_mean_squared_error: 2362.3889 - val_loss: 2.4356 - val_gamma_nll: 2.4352 - val_root_mean_squared_error: 2383.4836
# Epoch 27/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3805 - gamma_nll: 2.3803 - root_mean_squared_error: 2373.9968 - val_loss: 2.4164 - val_gamma_nll: 2.4159 - val_root_mean_squared_error: 2383.3779
# Epoch 28/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3803 - gamma_nll: 2.3790 - root_mean_squared_error: 2366.7419 - val_loss: 2.4403 - val_gamma_nll: 2.4400 - val_root_mean_squared_error: 2385.7527
# Epoch 29/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3820 - gamma_nll: 2.3819 - root_mean_squared_error: 2376.8232 - val_loss: 2.3792 - val_gamma_nll: 2.3787 - val_root_mean_squared_error: 2384.5393
# Epoch 30/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3778 - gamma_nll: 2.3773 - root_mean_squared_error: 2363.5466 - val_loss: 2.3861 - val_gamma_nll: 2.3855 - val_root_mean_squared_error: 2384.2375
# Epoch 31/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3781 - gamma_nll: 2.3774 - root_mean_squared_error: 2367.0400 - val_loss: 2.3802 - val_gamma_nll: 2.3797 - val_root_mean_squared_error: 2374.7781
# Epoch 32/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3767 - gamma_nll: 2.3765 - root_mean_squared_error: 2367.2117 - val_loss: 2.4263 - val_gamma_nll: 2.4261 - val_root_mean_squared_error: 2378.8391
# Epoch 33/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3772 - gamma_nll: 2.3769 - root_mean_squared_error: 2364.2632 - val_loss: 2.3811 - val_gamma_nll: 2.3805 - val_root_mean_squared_error: 2384.3198
# Epoch 34/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3825 - gamma_nll: 2.3826 - root_mean_squared_error: 2370.5283 - val_loss: 2.3877 - val_gamma_nll: 2.3873 - val_root_mean_squared_error: 2379.9160
# Epoch 35/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3774 - gamma_nll: 2.3769 - root_mean_squared_error: 2368.0603 - val_loss: 2.3801 - val_gamma_nll: 2.3795 - val_root_mean_squared_error: 2390.9131
# Epoch 36/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3789 - gamma_nll: 2.3795 - root_mean_squared_error: 2369.1162 - val_loss: 2.4289 - val_gamma_nll: 2.4285 - val_root_mean_squared_error: 2380.3484
# Epoch 37/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3785 - gamma_nll: 2.3789 - root_mean_squared_error: 2365.6750 - val_loss: 2.4085 - val_gamma_nll: 2.4080 - val_root_mean_squared_error: 2381.5347
# Epoch 38/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.3803 - gamma_nll: 2.3802 - root_mean_squared_error: 2372.7170 - val_loss: 2.5469 - val_gamma_nll: 2.5466 - val_root_mean_squared_error: 2406.1675
# 1/1 [==============================] - 0s 17ms/step - loss: 2.3787 - gamma_nll: 2.3787 - root_mean_squared_error: 2386.9380
# Epoch 1/5000
# 30/30 [==============================] - 1s 13ms/step - loss: 2.5745 - gamma_nll: 2.5750 - root_mean_squared_error: 2430.4666 - val_loss: 2.5568 - val_gamma_nll: 2.5559 - val_root_mean_squared_error: 2454.3367
# Epoch 2/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5717 - gamma_nll: 2.5717 - root_mean_squared_error: 2429.1272 - val_loss: 2.5780 - val_gamma_nll: 2.5770 - val_root_mean_squared_error: 2487.5750
# Epoch 3/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5683 - gamma_nll: 2.5686 - root_mean_squared_error: 2425.5288 - val_loss: 2.5965 - val_gamma_nll: 2.5955 - val_root_mean_squared_error: 2515.9397
# Epoch 4/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5722 - gamma_nll: 2.5721 - root_mean_squared_error: 2429.3267 - val_loss: 2.6820 - val_gamma_nll: 2.6810 - val_root_mean_squared_error: 2669.3733
# Epoch 5/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5685 - gamma_nll: 2.5687 - root_mean_squared_error: 2428.8889 - val_loss: 2.6187 - val_gamma_nll: 2.6177 - val_root_mean_squared_error: 2522.1777
# Epoch 6/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5684 - gamma_nll: 2.5688 - root_mean_squared_error: 2423.5696 - val_loss: 2.6288 - val_gamma_nll: 2.6276 - val_root_mean_squared_error: 2548.1460
# Epoch 7/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5726 - gamma_nll: 2.5733 - root_mean_squared_error: 2429.3982 - val_loss: 2.5555 - val_gamma_nll: 2.5544 - val_root_mean_squared_error: 2453.0129
# Epoch 8/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5694 - gamma_nll: 2.5702 - root_mean_squared_error: 2426.1130 - val_loss: 2.5507 - val_gamma_nll: 2.5495 - val_root_mean_squared_error: 2445.5142
# Epoch 9/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5715 - gamma_nll: 2.5710 - root_mean_squared_error: 2430.5974 - val_loss: 2.5542 - val_gamma_nll: 2.5532 - val_root_mean_squared_error: 2460.9285
# Epoch 10/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5702 - gamma_nll: 2.5709 - root_mean_squared_error: 2425.0959 - val_loss: 2.5623 - val_gamma_nll: 2.5611 - val_root_mean_squared_error: 2446.6748
# Epoch 11/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5733 - gamma_nll: 2.5728 - root_mean_squared_error: 2429.1946 - val_loss: 2.5552 - val_gamma_nll: 2.5540 - val_root_mean_squared_error: 2468.2563
# Epoch 12/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5694 - gamma_nll: 2.5700 - root_mean_squared_error: 2427.5620 - val_loss: 2.5638 - val_gamma_nll: 2.5624 - val_root_mean_squared_error: 2465.1606
# Epoch 13/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5738 - gamma_nll: 2.5737 - root_mean_squared_error: 2431.7317 - val_loss: 2.6242 - val_gamma_nll: 2.6231 - val_root_mean_squared_error: 2458.2024
# Epoch 14/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5695 - gamma_nll: 2.5690 - root_mean_squared_error: 2424.8162 - val_loss: 2.6335 - val_gamma_nll: 2.6322 - val_root_mean_squared_error: 2457.9062
# Epoch 15/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5679 - gamma_nll: 2.5677 - root_mean_squared_error: 2423.5830 - val_loss: 2.6768 - val_gamma_nll: 2.6755 - val_root_mean_squared_error: 2465.4014
# Epoch 16/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5674 - gamma_nll: 2.5679 - root_mean_squared_error: 2424.6121 - val_loss: 2.5713 - val_gamma_nll: 2.5702 - val_root_mean_squared_error: 2447.6453
# Epoch 17/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5713 - gamma_nll: 2.5720 - root_mean_squared_error: 2428.6738 - val_loss: 2.6179 - val_gamma_nll: 2.6167 - val_root_mean_squared_error: 2455.1426
# Epoch 18/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5678 - gamma_nll: 2.5677 - root_mean_squared_error: 2425.3665 - val_loss: 2.5712 - val_gamma_nll: 2.5700 - val_root_mean_squared_error: 2447.5085
# Epoch 19/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5709 - gamma_nll: 2.5704 - root_mean_squared_error: 2426.9421 - val_loss: 2.5964 - val_gamma_nll: 2.5951 - val_root_mean_squared_error: 2452.4070
# Epoch 20/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5715 - gamma_nll: 2.5711 - root_mean_squared_error: 2426.5564 - val_loss: 2.5559 - val_gamma_nll: 2.5548 - val_root_mean_squared_error: 2449.1746
# Epoch 21/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5656 - gamma_nll: 2.5654 - root_mean_squared_error: 2424.4407 - val_loss: 2.5680 - val_gamma_nll: 2.5670 - val_root_mean_squared_error: 2457.0098
# Epoch 22/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5659 - gamma_nll: 2.5674 - root_mean_squared_error: 2424.5547 - val_loss: 2.5558 - val_gamma_nll: 2.5547 - val_root_mean_squared_error: 2460.7251
# Epoch 23/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5645 - gamma_nll: 2.5643 - root_mean_squared_error: 2420.5356 - val_loss: 2.5774 - val_gamma_nll: 2.5762 - val_root_mean_squared_error: 2483.3279
# Epoch 24/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5670 - gamma_nll: 2.5670 - root_mean_squared_error: 2421.9209 - val_loss: 2.5595 - val_gamma_nll: 2.5582 - val_root_mean_squared_error: 2448.4880
# Epoch 25/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5657 - gamma_nll: 2.5658 - root_mean_squared_error: 2425.7363 - val_loss: 2.7146 - val_gamma_nll: 2.7132 - val_root_mean_squared_error: 2468.8047
# Epoch 26/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5623 - gamma_nll: 2.5636 - root_mean_squared_error: 2420.4583 - val_loss: 2.6625 - val_gamma_nll: 2.6614 - val_root_mean_squared_error: 2465.7856
# Epoch 27/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5662 - gamma_nll: 2.5665 - root_mean_squared_error: 2424.6187 - val_loss: 2.7142 - val_gamma_nll: 2.7127 - val_root_mean_squared_error: 2471.0674
# Epoch 28/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5652 - gamma_nll: 2.5635 - root_mean_squared_error: 2421.7925 - val_loss: 2.8063 - val_gamma_nll: 2.8048 - val_root_mean_squared_error: 2479.3162
# Epoch 29/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5701 - gamma_nll: 2.5700 - root_mean_squared_error: 2430.1921 - val_loss: 2.7917 - val_gamma_nll: 2.7902 - val_root_mean_squared_error: 2479.8445
# Epoch 30/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5652 - gamma_nll: 2.5643 - root_mean_squared_error: 2425.2400 - val_loss: 2.6986 - val_gamma_nll: 2.6976 - val_root_mean_squared_error: 2671.6296
# Epoch 31/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5635 - gamma_nll: 2.5622 - root_mean_squared_error: 2423.2351 - val_loss: 2.5645 - val_gamma_nll: 2.5632 - val_root_mean_squared_error: 2446.4128
# Epoch 32/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5665 - gamma_nll: 2.5661 - root_mean_squared_error: 2422.8748 - val_loss: 2.6159 - val_gamma_nll: 2.6146 - val_root_mean_squared_error: 2453.7986
# Epoch 33/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5643 - gamma_nll: 2.5637 - root_mean_squared_error: 2422.1943 - val_loss: 2.5710 - val_gamma_nll: 2.5698 - val_root_mean_squared_error: 2447.4678
# 1/1 [==============================] - 0s 23ms/step - loss: 2.5507 - gamma_nll: 2.5507 - root_mean_squared_error: 2445.5142
# Epoch 1/5000
# 30/30 [==============================] - 1s 13ms/step - loss: 2.5713 - gamma_nll: 2.5719 - root_mean_squared_error: 2425.5686 - val_loss: 2.5666 - val_gamma_nll: 2.5655 - val_root_mean_squared_error: 2492.0764
# Epoch 2/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5676 - gamma_nll: 2.5678 - root_mean_squared_error: 2423.5393 - val_loss: 2.5510 - val_gamma_nll: 2.5498 - val_root_mean_squared_error: 2460.1038
# Epoch 3/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5719 - gamma_nll: 2.5722 - root_mean_squared_error: 2424.5662 - val_loss: 2.6232 - val_gamma_nll: 2.6222 - val_root_mean_squared_error: 2485.2476
# Epoch 4/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5695 - gamma_nll: 2.5694 - root_mean_squared_error: 2431.1917 - val_loss: 2.5758 - val_gamma_nll: 2.5746 - val_root_mean_squared_error: 2452.6184
# Epoch 5/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5686 - gamma_nll: 2.5689 - root_mean_squared_error: 2428.6121 - val_loss: 2.5583 - val_gamma_nll: 2.5571 - val_root_mean_squared_error: 2439.8457
# Epoch 6/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5702 - gamma_nll: 2.5706 - root_mean_squared_error: 2422.2637 - val_loss: 2.5777 - val_gamma_nll: 2.5765 - val_root_mean_squared_error: 2504.0781
# Epoch 7/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5877 - gamma_nll: 2.5885 - root_mean_squared_error: 2440.9399 - val_loss: 2.5758 - val_gamma_nll: 2.5746 - val_root_mean_squared_error: 2472.9783
# Epoch 8/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5765 - gamma_nll: 2.5772 - root_mean_squared_error: 2431.5774 - val_loss: 2.5527 - val_gamma_nll: 2.5515 - val_root_mean_squared_error: 2460.5813
# Epoch 9/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5716 - gamma_nll: 2.5711 - root_mean_squared_error: 2430.3799 - val_loss: 2.5493 - val_gamma_nll: 2.5482 - val_root_mean_squared_error: 2456.0435
# Epoch 10/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5687 - gamma_nll: 2.5695 - root_mean_squared_error: 2423.2505 - val_loss: 2.5573 - val_gamma_nll: 2.5561 - val_root_mean_squared_error: 2440.0364
# Epoch 11/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5692 - gamma_nll: 2.5689 - root_mean_squared_error: 2421.8577 - val_loss: 2.5566 - val_gamma_nll: 2.5554 - val_root_mean_squared_error: 2450.4868
# Epoch 12/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5681 - gamma_nll: 2.5687 - root_mean_squared_error: 2425.1692 - val_loss: 2.5932 - val_gamma_nll: 2.5917 - val_root_mean_squared_error: 2445.6953
# Epoch 13/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5737 - gamma_nll: 2.5737 - root_mean_squared_error: 2434.6067 - val_loss: 2.6864 - val_gamma_nll: 2.6852 - val_root_mean_squared_error: 2467.4836
# Epoch 14/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5709 - gamma_nll: 2.5704 - root_mean_squared_error: 2425.7793 - val_loss: 2.8438 - val_gamma_nll: 2.8425 - val_root_mean_squared_error: 2487.0078
# Epoch 15/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5651 - gamma_nll: 2.5649 - root_mean_squared_error: 2420.6016 - val_loss: 2.7818 - val_gamma_nll: 2.7804 - val_root_mean_squared_error: 2480.0151
# Epoch 16/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5684 - gamma_nll: 2.5688 - root_mean_squared_error: 2422.5891 - val_loss: 2.6992 - val_gamma_nll: 2.6980 - val_root_mean_squared_error: 2476.0845
# Epoch 17/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5722 - gamma_nll: 2.5728 - root_mean_squared_error: 2434.6436 - val_loss: 2.6811 - val_gamma_nll: 2.6798 - val_root_mean_squared_error: 2469.8975
# Epoch 18/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5661 - gamma_nll: 2.5659 - root_mean_squared_error: 2422.1758 - val_loss: 2.7896 - val_gamma_nll: 2.7884 - val_root_mean_squared_error: 2485.0920
# Epoch 19/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5637 - gamma_nll: 2.5634 - root_mean_squared_error: 2420.2805 - val_loss: 2.5846 - val_gamma_nll: 2.5832 - val_root_mean_squared_error: 2446.2078
# Epoch 20/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5715 - gamma_nll: 2.5710 - root_mean_squared_error: 2432.4822 - val_loss: 2.5645 - val_gamma_nll: 2.5632 - val_root_mean_squared_error: 2442.6780
# Epoch 21/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5708 - gamma_nll: 2.5706 - root_mean_squared_error: 2429.8574 - val_loss: 2.5561 - val_gamma_nll: 2.5548 - val_root_mean_squared_error: 2444.3762
# Epoch 22/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5650 - gamma_nll: 2.5664 - root_mean_squared_error: 2421.9514 - val_loss: 2.5833 - val_gamma_nll: 2.5821 - val_root_mean_squared_error: 2447.2307
# Epoch 23/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5671 - gamma_nll: 2.5669 - root_mean_squared_error: 2422.3320 - val_loss: 2.5693 - val_gamma_nll: 2.5680 - val_root_mean_squared_error: 2443.8345
# Epoch 24/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5611 - gamma_nll: 2.5612 - root_mean_squared_error: 2414.1914 - val_loss: 2.5496 - val_gamma_nll: 2.5485 - val_root_mean_squared_error: 2456.5701
# Epoch 25/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5664 - gamma_nll: 2.5666 - root_mean_squared_error: 2424.7131 - val_loss: 2.5498 - val_gamma_nll: 2.5487 - val_root_mean_squared_error: 2439.9980
# Epoch 26/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5621 - gamma_nll: 2.5636 - root_mean_squared_error: 2417.1995 - val_loss: 2.5468 - val_gamma_nll: 2.5457 - val_root_mean_squared_error: 2453.8525
# Epoch 27/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5600 - gamma_nll: 2.5603 - root_mean_squared_error: 2415.6890 - val_loss: 2.5479 - val_gamma_nll: 2.5467 - val_root_mean_squared_error: 2444.7397
# Epoch 28/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5617 - gamma_nll: 2.5601 - root_mean_squared_error: 2418.7095 - val_loss: 2.5498 - val_gamma_nll: 2.5487 - val_root_mean_squared_error: 2450.5220
# Epoch 29/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5672 - gamma_nll: 2.5671 - root_mean_squared_error: 2429.9680 - val_loss: 2.5639 - val_gamma_nll: 2.5628 - val_root_mean_squared_error: 2468.6587
# Epoch 30/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5608 - gamma_nll: 2.5598 - root_mean_squared_error: 2414.5898 - val_loss: 2.5426 - val_gamma_nll: 2.5415 - val_root_mean_squared_error: 2450.3049
# Epoch 31/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5623 - gamma_nll: 2.5610 - root_mean_squared_error: 2418.5376 - val_loss: 2.5450 - val_gamma_nll: 2.5439 - val_root_mean_squared_error: 2440.0054
# Epoch 32/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5578 - gamma_nll: 2.5576 - root_mean_squared_error: 2413.4114 - val_loss: 2.5640 - val_gamma_nll: 2.5628 - val_root_mean_squared_error: 2433.1431
# Epoch 33/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5604 - gamma_nll: 2.5598 - root_mean_squared_error: 2418.1331 - val_loss: 2.6630 - val_gamma_nll: 2.6616 - val_root_mean_squared_error: 2459.6021
# Epoch 34/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5621 - gamma_nll: 2.5621 - root_mean_squared_error: 2413.3193 - val_loss: 2.6935 - val_gamma_nll: 2.6920 - val_root_mean_squared_error: 2462.9006
# Epoch 35/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5602 - gamma_nll: 2.5600 - root_mean_squared_error: 2420.4863 - val_loss: 2.5727 - val_gamma_nll: 2.5715 - val_root_mean_squared_error: 2440.7917
# Epoch 36/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5605 - gamma_nll: 2.5610 - root_mean_squared_error: 2418.6265 - val_loss: 2.6832 - val_gamma_nll: 2.6819 - val_root_mean_squared_error: 2464.1467
# Epoch 37/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5606 - gamma_nll: 2.5613 - root_mean_squared_error: 2419.8374 - val_loss: 2.8072 - val_gamma_nll: 2.8057 - val_root_mean_squared_error: 2480.1226
# Epoch 38/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5594 - gamma_nll: 2.5587 - root_mean_squared_error: 2418.9348 - val_loss: 2.6254 - val_gamma_nll: 2.6240 - val_root_mean_squared_error: 2445.0352
# Epoch 39/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5560 - gamma_nll: 2.5556 - root_mean_squared_error: 2411.9246 - val_loss: 2.6693 - val_gamma_nll: 2.6683 - val_root_mean_squared_error: 2460.8130
# Epoch 40/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5589 - gamma_nll: 2.5593 - root_mean_squared_error: 2415.9761 - val_loss: 2.7029 - val_gamma_nll: 2.7015 - val_root_mean_squared_error: 2462.2175
# Epoch 41/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5630 - gamma_nll: 2.5645 - root_mean_squared_error: 2420.5134 - val_loss: 2.6052 - val_gamma_nll: 2.6038 - val_root_mean_squared_error: 2441.1304
# Epoch 42/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5584 - gamma_nll: 2.5590 - root_mean_squared_error: 2412.8333 - val_loss: 2.5571 - val_gamma_nll: 2.5560 - val_root_mean_squared_error: 2448.9263
# Epoch 43/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5616 - gamma_nll: 2.5610 - root_mean_squared_error: 2422.1084 - val_loss: 2.5506 - val_gamma_nll: 2.5494 - val_root_mean_squared_error: 2443.6604
# Epoch 44/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5599 - gamma_nll: 2.5596 - root_mean_squared_error: 2429.3679 - val_loss: 2.6500 - val_gamma_nll: 2.6489 - val_root_mean_squared_error: 2465.2932
# Epoch 45/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5619 - gamma_nll: 2.5611 - root_mean_squared_error: 2422.1692 - val_loss: 2.5820 - val_gamma_nll: 2.5809 - val_root_mean_squared_error: 2457.3618
# Epoch 46/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5607 - gamma_nll: 2.5611 - root_mean_squared_error: 2423.7083 - val_loss: 2.7040 - val_gamma_nll: 2.7028 - val_root_mean_squared_error: 2464.4407
# Epoch 47/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5584 - gamma_nll: 2.5584 - root_mean_squared_error: 2415.6365 - val_loss: 3.0144 - val_gamma_nll: 3.0131 - val_root_mean_squared_error: 2498.7288
# Epoch 48/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5620 - gamma_nll: 2.5618 - root_mean_squared_error: 2418.3601 - val_loss: 2.8487 - val_gamma_nll: 2.8476 - val_root_mean_squared_error: 2487.2080
# Epoch 49/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5585 - gamma_nll: 2.5592 - root_mean_squared_error: 2413.6543 - val_loss: 2.7411 - val_gamma_nll: 2.7398 - val_root_mean_squared_error: 2473.9053
# Epoch 50/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5553 - gamma_nll: 2.5548 - root_mean_squared_error: 2412.6892 - val_loss: 2.5826 - val_gamma_nll: 2.5813 - val_root_mean_squared_error: 2442.0830
# Epoch 51/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5647 - gamma_nll: 2.5640 - root_mean_squared_error: 2427.3394 - val_loss: 2.6422 - val_gamma_nll: 2.6409 - val_root_mean_squared_error: 2459.1687
# Epoch 52/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5581 - gamma_nll: 2.5574 - root_mean_squared_error: 2415.5466 - val_loss: 2.6198 - val_gamma_nll: 2.6186 - val_root_mean_squared_error: 2456.6621
# Epoch 53/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5560 - gamma_nll: 2.5561 - root_mean_squared_error: 2413.1648 - val_loss: 2.7190 - val_gamma_nll: 2.7178 - val_root_mean_squared_error: 2467.6526
# Epoch 54/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5564 - gamma_nll: 2.5561 - root_mean_squared_error: 2414.0825 - val_loss: 2.5468 - val_gamma_nll: 2.5456 - val_root_mean_squared_error: 2436.0586
# Epoch 55/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5607 - gamma_nll: 2.5601 - root_mean_squared_error: 2417.9348 - val_loss: 2.5965 - val_gamma_nll: 2.5953 - val_root_mean_squared_error: 2445.5959
# 1/1 [==============================] - 0s 26ms/step - loss: 2.5426 - gamma_nll: 2.5426 - root_mean_squared_error: 2450.3049
# Epoch 1/5000
# 30/30 [==============================] - 1s 13ms/step - loss: 2.5719 - gamma_nll: 2.5727 - root_mean_squared_error: 2433.9338 - val_loss: 2.6244 - val_gamma_nll: 2.6233 - val_root_mean_squared_error: 2454.0530
# Epoch 2/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5696 - gamma_nll: 2.5696 - root_mean_squared_error: 2432.6538 - val_loss: 2.6147 - val_gamma_nll: 2.6134 - val_root_mean_squared_error: 2452.5781
# Epoch 3/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5659 - gamma_nll: 2.5659 - root_mean_squared_error: 2428.5110 - val_loss: 2.6001 - val_gamma_nll: 2.5989 - val_root_mean_squared_error: 2453.3772
# Epoch 4/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5699 - gamma_nll: 2.5699 - root_mean_squared_error: 2431.3477 - val_loss: 2.5540 - val_gamma_nll: 2.5529 - val_root_mean_squared_error: 2445.6936
# Epoch 5/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5665 - gamma_nll: 2.5667 - root_mean_squared_error: 2436.1545 - val_loss: 2.5582 - val_gamma_nll: 2.5570 - val_root_mean_squared_error: 2453.6587
# Epoch 6/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5682 - gamma_nll: 2.5685 - root_mean_squared_error: 2426.3091 - val_loss: 2.5713 - val_gamma_nll: 2.5700 - val_root_mean_squared_error: 2473.6724
# Epoch 7/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5697 - gamma_nll: 2.5704 - root_mean_squared_error: 2436.2080 - val_loss: 2.5659 - val_gamma_nll: 2.5648 - val_root_mean_squared_error: 2466.8127
# Epoch 8/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5717 - gamma_nll: 2.5724 - root_mean_squared_error: 2432.1165 - val_loss: 2.5597 - val_gamma_nll: 2.5586 - val_root_mean_squared_error: 2474.6768
# Epoch 9/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5740 - gamma_nll: 2.5735 - root_mean_squared_error: 2439.2910 - val_loss: 2.5572 - val_gamma_nll: 2.5561 - val_root_mean_squared_error: 2474.2207
# Epoch 10/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5674 - gamma_nll: 2.5681 - root_mean_squared_error: 2430.8521 - val_loss: 2.5816 - val_gamma_nll: 2.5804 - val_root_mean_squared_error: 2452.2561
# Epoch 11/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5696 - gamma_nll: 2.5692 - root_mean_squared_error: 2433.0186 - val_loss: 2.5510 - val_gamma_nll: 2.5499 - val_root_mean_squared_error: 2462.7468
# Epoch 12/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5682 - gamma_nll: 2.5688 - root_mean_squared_error: 2431.1565 - val_loss: 2.5559 - val_gamma_nll: 2.5547 - val_root_mean_squared_error: 2463.6604
# Epoch 13/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5727 - gamma_nll: 2.5727 - root_mean_squared_error: 2439.1382 - val_loss: 2.5652 - val_gamma_nll: 2.5642 - val_root_mean_squared_error: 2499.5103
# Epoch 14/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5694 - gamma_nll: 2.5689 - root_mean_squared_error: 2434.1528 - val_loss: 2.5615 - val_gamma_nll: 2.5604 - val_root_mean_squared_error: 2478.2986
# Epoch 15/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5666 - gamma_nll: 2.5664 - root_mean_squared_error: 2432.7681 - val_loss: 2.5497 - val_gamma_nll: 2.5485 - val_root_mean_squared_error: 2454.8572
# Epoch 16/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5678 - gamma_nll: 2.5682 - root_mean_squared_error: 2433.1377 - val_loss: 2.5576 - val_gamma_nll: 2.5565 - val_root_mean_squared_error: 2466.1101
# Epoch 17/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5713 - gamma_nll: 2.5724 - root_mean_squared_error: 2434.6272 - val_loss: 2.5796 - val_gamma_nll: 2.5785 - val_root_mean_squared_error: 2489.2405
# Epoch 18/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5667 - gamma_nll: 2.5665 - root_mean_squared_error: 2429.7339 - val_loss: 2.5814 - val_gamma_nll: 2.5804 - val_root_mean_squared_error: 2492.5742
# Epoch 19/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5663 - gamma_nll: 2.5658 - root_mean_squared_error: 2429.2070 - val_loss: 2.5975 - val_gamma_nll: 2.5964 - val_root_mean_squared_error: 2526.4934
# Epoch 20/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5741 - gamma_nll: 2.5737 - root_mean_squared_error: 2439.6521 - val_loss: 2.5563 - val_gamma_nll: 2.5552 - val_root_mean_squared_error: 2470.9834
# Epoch 21/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5635 - gamma_nll: 2.5634 - root_mean_squared_error: 2425.7222 - val_loss: 2.5712 - val_gamma_nll: 2.5700 - val_root_mean_squared_error: 2484.4207
# Epoch 22/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5633 - gamma_nll: 2.5647 - root_mean_squared_error: 2427.7517 - val_loss: 2.5633 - val_gamma_nll: 2.5622 - val_root_mean_squared_error: 2474.0449
# Epoch 23/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5641 - gamma_nll: 2.5640 - root_mean_squared_error: 2426.7202 - val_loss: 2.5514 - val_gamma_nll: 2.5502 - val_root_mean_squared_error: 2455.5867
# Epoch 24/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5634 - gamma_nll: 2.5634 - root_mean_squared_error: 2427.5571 - val_loss: 2.5703 - val_gamma_nll: 2.5692 - val_root_mean_squared_error: 2474.3552
# Epoch 25/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5655 - gamma_nll: 2.5656 - root_mean_squared_error: 2434.7483 - val_loss: 2.5537 - val_gamma_nll: 2.5527 - val_root_mean_squared_error: 2476.3381
# Epoch 26/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5652 - gamma_nll: 2.5667 - root_mean_squared_error: 2425.9763 - val_loss: 2.5831 - val_gamma_nll: 2.5820 - val_root_mean_squared_error: 2497.7056
# Epoch 27/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5649 - gamma_nll: 2.5653 - root_mean_squared_error: 2430.9990 - val_loss: 2.6029 - val_gamma_nll: 2.6019 - val_root_mean_squared_error: 2515.2749
# Epoch 28/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5646 - gamma_nll: 2.5628 - root_mean_squared_error: 2426.8225 - val_loss: 2.5773 - val_gamma_nll: 2.5762 - val_root_mean_squared_error: 2525.3452
# Epoch 29/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5697 - gamma_nll: 2.5696 - root_mean_squared_error: 2439.2236 - val_loss: 2.6041 - val_gamma_nll: 2.6030 - val_root_mean_squared_error: 2561.4534
# Epoch 30/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5656 - gamma_nll: 2.5646 - root_mean_squared_error: 2433.6382 - val_loss: 2.5519 - val_gamma_nll: 2.5508 - val_root_mean_squared_error: 2459.2275
# Epoch 31/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5652 - gamma_nll: 2.5640 - root_mean_squared_error: 2427.8843 - val_loss: 2.5640 - val_gamma_nll: 2.5629 - val_root_mean_squared_error: 2450.2524
# Epoch 32/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5655 - gamma_nll: 2.5651 - root_mean_squared_error: 2428.9917 - val_loss: 2.5500 - val_gamma_nll: 2.5489 - val_root_mean_squared_error: 2457.5840
# Epoch 33/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5642 - gamma_nll: 2.5636 - root_mean_squared_error: 2428.1755 - val_loss: 2.5664 - val_gamma_nll: 2.5653 - val_root_mean_squared_error: 2471.2197
# Epoch 34/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5708 - gamma_nll: 2.5706 - root_mean_squared_error: 2436.4275 - val_loss: 2.5493 - val_gamma_nll: 2.5481 - val_root_mean_squared_error: 2450.4023
# Epoch 35/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5628 - gamma_nll: 2.5625 - root_mean_squared_error: 2429.0876 - val_loss: 2.5884 - val_gamma_nll: 2.5871 - val_root_mean_squared_error: 2450.8828
# Epoch 36/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5676 - gamma_nll: 2.5682 - root_mean_squared_error: 2432.6089 - val_loss: 2.5733 - val_gamma_nll: 2.5719 - val_root_mean_squared_error: 2447.5984
# Epoch 37/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5660 - gamma_nll: 2.5667 - root_mean_squared_error: 2429.4087 - val_loss: 2.5476 - val_gamma_nll: 2.5465 - val_root_mean_squared_error: 2453.1846
# Epoch 38/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5651 - gamma_nll: 2.5645 - root_mean_squared_error: 2430.7598 - val_loss: 2.5518 - val_gamma_nll: 2.5506 - val_root_mean_squared_error: 2446.6516
# Epoch 39/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5633 - gamma_nll: 2.5631 - root_mean_squared_error: 2428.2942 - val_loss: 2.5822 - val_gamma_nll: 2.5813 - val_root_mean_squared_error: 2477.7551
# Epoch 40/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5678 - gamma_nll: 2.5682 - root_mean_squared_error: 2435.1682 - val_loss: 2.5494 - val_gamma_nll: 2.5482 - val_root_mean_squared_error: 2446.2144
# Epoch 41/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5680 - gamma_nll: 2.5693 - root_mean_squared_error: 2434.1907 - val_loss: 2.5629 - val_gamma_nll: 2.5616 - val_root_mean_squared_error: 2451.0378
# Epoch 42/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5641 - gamma_nll: 2.5647 - root_mean_squared_error: 2431.8296 - val_loss: 2.5714 - val_gamma_nll: 2.5703 - val_root_mean_squared_error: 2447.6548
# Epoch 43/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5692 - gamma_nll: 2.5686 - root_mean_squared_error: 2431.6985 - val_loss: 2.5779 - val_gamma_nll: 2.5767 - val_root_mean_squared_error: 2456.3606
# Epoch 44/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5657 - gamma_nll: 2.5654 - root_mean_squared_error: 2436.3398 - val_loss: 2.5640 - val_gamma_nll: 2.5630 - val_root_mean_squared_error: 2470.6067
# Epoch 45/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5668 - gamma_nll: 2.5659 - root_mean_squared_error: 2432.4377 - val_loss: 2.5610 - val_gamma_nll: 2.5599 - val_root_mean_squared_error: 2473.3147
# Epoch 46/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5661 - gamma_nll: 2.5665 - root_mean_squared_error: 2433.7527 - val_loss: 2.5807 - val_gamma_nll: 2.5795 - val_root_mean_squared_error: 2451.3445
# Epoch 47/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5639 - gamma_nll: 2.5638 - root_mean_squared_error: 2431.4639 - val_loss: 2.5679 - val_gamma_nll: 2.5668 - val_root_mean_squared_error: 2454.2678
# Epoch 48/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5700 - gamma_nll: 2.5697 - root_mean_squared_error: 2431.4429 - val_loss: 2.5522 - val_gamma_nll: 2.5509 - val_root_mean_squared_error: 2445.0703
# Epoch 49/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5634 - gamma_nll: 2.5643 - root_mean_squared_error: 2429.8345 - val_loss: 2.5595 - val_gamma_nll: 2.5583 - val_root_mean_squared_error: 2448.4421
# Epoch 50/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5635 - gamma_nll: 2.5628 - root_mean_squared_error: 2432.2144 - val_loss: 2.5528 - val_gamma_nll: 2.5516 - val_root_mean_squared_error: 2446.4712
# Epoch 51/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5676 - gamma_nll: 2.5668 - root_mean_squared_error: 2433.9158 - val_loss: 2.5854 - val_gamma_nll: 2.5842 - val_root_mean_squared_error: 2460.6726
# Epoch 52/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5692 - gamma_nll: 2.5686 - root_mean_squared_error: 2436.9507 - val_loss: 2.5998 - val_gamma_nll: 2.5985 - val_root_mean_squared_error: 2453.4695
# Epoch 53/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5638 - gamma_nll: 2.5637 - root_mean_squared_error: 2427.9143 - val_loss: 2.5732 - val_gamma_nll: 2.5720 - val_root_mean_squared_error: 2451.2024
# Epoch 54/5000
# ...
# Epoch 302/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2684 - gamma_nll: 2.2686 - root_mean_squared_error: 2343.2847 - val_loss: 2.3065 - val_gamma_nll: 2.3058 - val_root_mean_squared_error: 2402.3425
# Epoch 303/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2594 - gamma_nll: 2.2592 - root_mean_squared_error: 2347.7957 - val_loss: 2.2966 - val_gamma_nll: 2.2958 - val_root_mean_squared_error: 2410.3220
# Epoch 304/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2754 - gamma_nll: 2.2756 - root_mean_squared_error: 2347.9407 - val_loss: 2.3221 - val_gamma_nll: 2.3214 - val_root_mean_squared_error: 2391.0383
# Epoch 305/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2719 - gamma_nll: 2.2715 - root_mean_squared_error: 2352.5125 - val_loss: 2.3278 - val_gamma_nll: 2.3269 - val_root_mean_squared_error: 2386.1353
# Epoch 306/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2609 - gamma_nll: 2.2603 - root_mean_squared_error: 2343.8667 - val_loss: 2.3560 - val_gamma_nll: 2.3554 - val_root_mean_squared_error: 2373.4070
# Epoch 307/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2498 - gamma_nll: 2.2497 - root_mean_squared_error: 2332.9705 - val_loss: 2.3189 - val_gamma_nll: 2.3185 - val_root_mean_squared_error: 2422.3503
# Epoch 308/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2445 - gamma_nll: 2.2443 - root_mean_squared_error: 2342.6372 - val_loss: 2.3255 - val_gamma_nll: 2.3249 - val_root_mean_squared_error: 2361.5701
# Epoch 309/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2508 - gamma_nll: 2.2504 - root_mean_squared_error: 2337.8286 - val_loss: 2.3713 - val_gamma_nll: 2.3706 - val_root_mean_squared_error: 2363.3279
# Epoch 310/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2425 - gamma_nll: 2.2424 - root_mean_squared_error: 2336.1726 - val_loss: 2.2938 - val_gamma_nll: 2.2932 - val_root_mean_squared_error: 2395.5435
# Epoch 311/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2411 - gamma_nll: 2.2411 - root_mean_squared_error: 2332.3711 - val_loss: 2.3318 - val_gamma_nll: 2.3310 - val_root_mean_squared_error: 2372.3701
# Epoch 312/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2442 - gamma_nll: 2.2448 - root_mean_squared_error: 2334.8447 - val_loss: 2.3384 - val_gamma_nll: 2.3375 - val_root_mean_squared_error: 2532.1260
# Epoch 313/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2462 - gamma_nll: 2.2459 - root_mean_squared_error: 2345.4087 - val_loss: 2.2880 - val_gamma_nll: 2.2875 - val_root_mean_squared_error: 2426.6550
# Epoch 314/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2478 - gamma_nll: 2.2473 - root_mean_squared_error: 2332.7925 - val_loss: 2.2964 - val_gamma_nll: 2.2954 - val_root_mean_squared_error: 2368.7969
# Epoch 315/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2505 - gamma_nll: 2.2498 - root_mean_squared_error: 2341.5503 - val_loss: 2.3041 - val_gamma_nll: 2.3033 - val_root_mean_squared_error: 2365.9775
# Epoch 316/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2366 - gamma_nll: 2.2364 - root_mean_squared_error: 2334.1096 - val_loss: 2.2921 - val_gamma_nll: 2.2912 - val_root_mean_squared_error: 2359.8982
# Epoch 317/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2451 - gamma_nll: 2.2462 - root_mean_squared_error: 2334.8958 - val_loss: 2.3040 - val_gamma_nll: 2.3035 - val_root_mean_squared_error: 2392.9121
# Epoch 318/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2659 - gamma_nll: 2.2662 - root_mean_squared_error: 2352.9910 - val_loss: 2.3036 - val_gamma_nll: 2.3027 - val_root_mean_squared_error: 2463.7822
# Epoch 319/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2467 - gamma_nll: 2.2480 - root_mean_squared_error: 2339.9089 - val_loss: 2.3039 - val_gamma_nll: 2.3028 - val_root_mean_squared_error: 2372.8918
# Epoch 320/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2391 - gamma_nll: 2.2388 - root_mean_squared_error: 2340.5142 - val_loss: 2.2876 - val_gamma_nll: 2.2867 - val_root_mean_squared_error: 2360.0957
# Epoch 321/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2470 - gamma_nll: 2.2471 - root_mean_squared_error: 2334.1370 - val_loss: 2.2988 - val_gamma_nll: 2.2982 - val_root_mean_squared_error: 2393.6113
# Epoch 322/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2618 - gamma_nll: 2.2611 - root_mean_squared_error: 2364.3704 - val_loss: 2.3300 - val_gamma_nll: 2.3294 - val_root_mean_squared_error: 2451.4727
# Epoch 323/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2564 - gamma_nll: 2.2558 - root_mean_squared_error: 2353.4888 - val_loss: 2.3206 - val_gamma_nll: 2.3200 - val_root_mean_squared_error: 2403.5442
# Epoch 324/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2581 - gamma_nll: 2.2587 - root_mean_squared_error: 2355.0750 - val_loss: 2.2926 - val_gamma_nll: 2.2919 - val_root_mean_squared_error: 2453.0166
# Epoch 325/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2588 - gamma_nll: 2.2580 - root_mean_squared_error: 2335.4175 - val_loss: 2.2953 - val_gamma_nll: 2.2944 - val_root_mean_squared_error: 2404.5066
# Epoch 326/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2418 - gamma_nll: 2.2417 - root_mean_squared_error: 2335.6943 - val_loss: 2.2985 - val_gamma_nll: 2.2977 - val_root_mean_squared_error: 2424.5525
# Epoch 327/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2350 - gamma_nll: 2.2360 - root_mean_squared_error: 2325.7512 - val_loss: 2.3138 - val_gamma_nll: 2.3132 - val_root_mean_squared_error: 2355.9055
# Epoch 328/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2456 - gamma_nll: 2.2468 - root_mean_squared_error: 2329.2083 - val_loss: 2.3407 - val_gamma_nll: 2.3404 - val_root_mean_squared_error: 2374.0305
# Epoch 329/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2383 - gamma_nll: 2.2388 - root_mean_squared_error: 2333.9958 - val_loss: 2.3382 - val_gamma_nll: 2.3382 - val_root_mean_squared_error: 2369.3359
# Epoch 330/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2578 - gamma_nll: 2.2587 - root_mean_squared_error: 2338.8298 - val_loss: 2.3499 - val_gamma_nll: 2.3492 - val_root_mean_squared_error: 2377.4580
# Epoch 331/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2425 - gamma_nll: 2.2423 - root_mean_squared_error: 2334.3286 - val_loss: 2.3120 - val_gamma_nll: 2.3113 - val_root_mean_squared_error: 2370.6084
# Epoch 332/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2423 - gamma_nll: 2.2422 - root_mean_squared_error: 2328.1665 - val_loss: 2.3374 - val_gamma_nll: 2.3366 - val_root_mean_squared_error: 2402.2913
# Epoch 333/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2455 - gamma_nll: 2.2454 - root_mean_squared_error: 2339.2915 - val_loss: 2.2828 - val_gamma_nll: 2.2820 - val_root_mean_squared_error: 2374.7036
# Epoch 334/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2399 - gamma_nll: 2.2403 - root_mean_squared_error: 2326.3865 - val_loss: 2.3308 - val_gamma_nll: 2.3298 - val_root_mean_squared_error: 2393.1675
# Epoch 335/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2556 - gamma_nll: 2.2553 - root_mean_squared_error: 2347.3308 - val_loss: 2.3000 - val_gamma_nll: 2.2995 - val_root_mean_squared_error: 2404.1355
# Epoch 336/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2386 - gamma_nll: 2.2388 - root_mean_squared_error: 2330.1355 - val_loss: 2.2768 - val_gamma_nll: 2.2761 - val_root_mean_squared_error: 2395.6094
# Epoch 337/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2428 - gamma_nll: 2.2433 - root_mean_squared_error: 2326.6484 - val_loss: 2.3136 - val_gamma_nll: 2.3131 - val_root_mean_squared_error: 2404.1282
# Epoch 338/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2673 - gamma_nll: 2.2670 - root_mean_squared_error: 2352.0396 - val_loss: 2.3047 - val_gamma_nll: 2.3040 - val_root_mean_squared_error: 2443.7866
# Epoch 339/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2436 - gamma_nll: 2.2433 - root_mean_squared_error: 2336.5342 - val_loss: 2.2985 - val_gamma_nll: 2.2980 - val_root_mean_squared_error: 2386.0732
# Epoch 340/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2479 - gamma_nll: 2.2486 - root_mean_squared_error: 2330.8481 - val_loss: 2.3255 - val_gamma_nll: 2.3246 - val_root_mean_squared_error: 2402.9080
# Epoch 341/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2494 - gamma_nll: 2.2493 - root_mean_squared_error: 2343.0559 - val_loss: 2.3290 - val_gamma_nll: 2.3283 - val_root_mean_squared_error: 2377.1243
# Epoch 342/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2377 - gamma_nll: 2.2380 - root_mean_squared_error: 2337.8674 - val_loss: 2.3086 - val_gamma_nll: 2.3080 - val_root_mean_squared_error: 2370.6389
# Epoch 343/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2332 - gamma_nll: 2.2335 - root_mean_squared_error: 2329.0757 - val_loss: 2.2826 - val_gamma_nll: 2.2821 - val_root_mean_squared_error: 2371.4351
# Epoch 344/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2433 - gamma_nll: 2.2431 - root_mean_squared_error: 2329.7034 - val_loss: 2.3248 - val_gamma_nll: 2.3238 - val_root_mean_squared_error: 2419.6995
# Epoch 345/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2430 - gamma_nll: 2.2433 - root_mean_squared_error: 2341.0718 - val_loss: 2.3228 - val_gamma_nll: 2.3222 - val_root_mean_squared_error: 2383.0481
# Epoch 346/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2471 - gamma_nll: 2.2470 - root_mean_squared_error: 2340.4534 - val_loss: 2.2740 - val_gamma_nll: 2.2733 - val_root_mean_squared_error: 2421.6187
# Epoch 347/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2219 - gamma_nll: 2.2229 - root_mean_squared_error: 2323.6982 - val_loss: 2.2972 - val_gamma_nll: 2.2961 - val_root_mean_squared_error: 2368.6965
# Epoch 348/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2258 - gamma_nll: 2.2250 - root_mean_squared_error: 2328.2534 - val_loss: 2.2889 - val_gamma_nll: 2.2884 - val_root_mean_squared_error: 2379.2371
# Epoch 349/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2385 - gamma_nll: 2.2383 - root_mean_squared_error: 2339.6831 - val_loss: 2.3469 - val_gamma_nll: 2.3463 - val_root_mean_squared_error: 2377.2065
# Epoch 350/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2395 - gamma_nll: 2.2395 - root_mean_squared_error: 2333.3840 - val_loss: 2.3010 - val_gamma_nll: 2.3004 - val_root_mean_squared_error: 2365.5938
# Epoch 351/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2367 - gamma_nll: 2.2369 - root_mean_squared_error: 2339.1333 - val_loss: 2.2971 - val_gamma_nll: 2.2964 - val_root_mean_squared_error: 2374.2395
# Epoch 352/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2212 - gamma_nll: 2.2220 - root_mean_squared_error: 2326.5012 - val_loss: 2.2872 - val_gamma_nll: 2.2863 - val_root_mean_squared_error: 2406.9226
# Epoch 353/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2316 - gamma_nll: 2.2317 - root_mean_squared_error: 2337.9036 - val_loss: 2.2842 - val_gamma_nll: 2.2834 - val_root_mean_squared_error: 2350.2881
# Epoch 354/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2542 - gamma_nll: 2.2544 - root_mean_squared_error: 2346.0244 - val_loss: 2.3025 - val_gamma_nll: 2.3019 - val_root_mean_squared_error: 2412.3877
# Epoch 355/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2477 - gamma_nll: 2.2481 - root_mean_squared_error: 2347.2649 - val_loss: 2.3085 - val_gamma_nll: 2.3078 - val_root_mean_squared_error: 2453.0786
# Epoch 356/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2414 - gamma_nll: 2.2411 - root_mean_squared_error: 2338.8540 - val_loss: 2.4217 - val_gamma_nll: 2.4209 - val_root_mean_squared_error: 2369.3904
# Epoch 357/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2406 - gamma_nll: 2.2412 - root_mean_squared_error: 2334.9858 - val_loss: 2.3332 - val_gamma_nll: 2.3325 - val_root_mean_squared_error: 2366.3184
# Epoch 358/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2502 - gamma_nll: 2.2504 - root_mean_squared_error: 2329.6675 - val_loss: 2.2944 - val_gamma_nll: 2.2942 - val_root_mean_squared_error: 2409.5952
# Epoch 359/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2402 - gamma_nll: 2.2396 - root_mean_squared_error: 2333.3174 - val_loss: 2.3278 - val_gamma_nll: 2.3272 - val_root_mean_squared_error: 2377.5581
# Epoch 360/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2388 - gamma_nll: 2.2389 - root_mean_squared_error: 2334.9219 - val_loss: 2.2981 - val_gamma_nll: 2.2977 - val_root_mean_squared_error: 2365.7310
# Epoch 361/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2266 - gamma_nll: 2.2271 - root_mean_squared_error: 2328.2439 - val_loss: 2.2760 - val_gamma_nll: 2.2753 - val_root_mean_squared_error: 2378.8015
# Epoch 362/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2270 - gamma_nll: 2.2278 - root_mean_squared_error: 2326.1394 - val_loss: 2.2932 - val_gamma_nll: 2.2923 - val_root_mean_squared_error: 2402.9036
# Epoch 363/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2366 - gamma_nll: 2.2364 - root_mean_squared_error: 2334.1108 - val_loss: 2.2894 - val_gamma_nll: 2.2885 - val_root_mean_squared_error: 2364.1792
# Epoch 364/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2627 - gamma_nll: 2.2628 - root_mean_squared_error: 2352.6506 - val_loss: 2.2973 - val_gamma_nll: 2.2968 - val_root_mean_squared_error: 2475.0151
# Epoch 365/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2291 - gamma_nll: 2.2291 - root_mean_squared_error: 2341.7771 - val_loss: 2.2978 - val_gamma_nll: 2.2972 - val_root_mean_squared_error: 2367.0137
# Epoch 366/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2269 - gamma_nll: 2.2273 - root_mean_squared_error: 2325.8381 - val_loss: 2.2844 - val_gamma_nll: 2.2837 - val_root_mean_squared_error: 2397.0896
# Epoch 367/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2573 - gamma_nll: 2.2568 - root_mean_squared_error: 2347.0159 - val_loss: 2.3207 - val_gamma_nll: 2.3201 - val_root_mean_squared_error: 2384.4148
# Epoch 368/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2359 - gamma_nll: 2.2356 - root_mean_squared_error: 2337.5410 - val_loss: 2.3320 - val_gamma_nll: 2.3314 - val_root_mean_squared_error: 2402.4343
# Epoch 369/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2258 - gamma_nll: 2.2271 - root_mean_squared_error: 2326.9202 - val_loss: 2.2862 - val_gamma_nll: 2.2855 - val_root_mean_squared_error: 2386.3672
# Epoch 370/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2448 - gamma_nll: 2.2452 - root_mean_squared_error: 2332.1992 - val_loss: 2.2997 - val_gamma_nll: 2.2993 - val_root_mean_squared_error: 2401.6584
# Epoch 371/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2197 - gamma_nll: 2.2188 - root_mean_squared_error: 2326.6682 - val_loss: 2.2808 - val_gamma_nll: 2.2799 - val_root_mean_squared_error: 2423.5591
# 1/1 [==============================] - 0s 22ms/step - loss: 2.2740 - gamma_nll: 2.2740 - root_mean_squared_error: 2421.6189

# %%
average_val_loss = {}

# Iterate over each lambda and its corresponding interaction losses
for lambd, loss_dict in lambd_val_loss.items():
    # Calculate the average validation loss for the current lambda
    avg_loss = sum(loss_dict.values()) / len(loss_dict)
    average_val_loss[lambd] = avg_loss

# Optionally, sort the lambdas for better readability
average_val_loss = dict(sorted(average_val_loss.items()))
average_val_loss
# Out:
# {0: 2.4783762778554643}

# %%
# -------------------------- plot the validation loss --------------------------
# Convert interaction loss dictionary to a pandas DataFrame
interaction_df = pd.DataFrame(list(lambd_val_loss[0].items()), columns = ['Interaction_Pair', 'Validation_Loss'])

# Sort the DataFrame by Validation_Loss in increasing order
interaction_df = interaction_df.sort_values(by = 'Validation_Loss', ascending = True)

# Create the bar plot using Seaborn
plt.figure(figsize = (20, 12))
sns.lineplot(x = 'Interaction_Pair', y = 'Validation_Loss', data = interaction_df, marker = 'o')
plt.axhline(main_val_loss, color = 'red', linestyle = '--', label = 'Validation Loss of Main Effect Model')
plt.xlabel('Interaction Effect Pairs')
plt.ylabel('Validation Loss')
plt.title('Validation Loss for Interaction Effect Pairs (Sorted by Increasing Loss)')
plt.legend()
plt.show()

# %%
# # -------------------------- Create the Pairwise Only Model --------------------------
# # pairwise_effect = ("X3", "X4")  # the pairwise effect we want to view
# pairwise_effect = interactions[0]
# pairwise_index = interactions.index(pairwise_effect)
# subnet_output_layer = model_pairwise.get_layer("interaction_output")
# subnet_model = Model(inputs = model_pairwise.inputs, outputs = subnet_output_layer.output)


# # -------------------------- Generate the Input Grid --------------------------
# # Create a grid of values
# grid_length = 100
# var1_values = np.linspace(X_train[interactions[pairwise_index][0]].min(), 
#                           X_train[interactions[pairwise_index][0]].max(), 
#                           grid_length)
# var2_values = np.linspace(X_train[interactions[pairwise_index][1]].min(), 
#                           X_train[interactions[pairwise_index][1]].max(), 
#                           grid_length)

# # Create a meshgrid
# grid_var1, grid_var2 = np.meshgrid(var1_values, var2_values)

# # Flatten the grid
# grid_flat_var1 = grid_var1.ravel()
# grid_flat_var2 = grid_var2.ravel()


# # -------------------------- Prepare Inputs for the Model --------------------------
# grid_inputs = []
# for var in all_vars:
#     if var == interactions[pairwise_index][0]:
#         grid_inputs.append(grid_flat_var1)
#     elif var == interactions[pairwise_index][1]:
#         grid_inputs.append(grid_flat_var2)
#     else:
#         grid_inputs.append(np.zeros_like(grid_flat_var1))


# # -------------------------- Predict Using the Pairwise-Only Model --------------------------
# # Predict the pairwise interaction effect
# pairwise_predictions = np.log(subnet_model.predict(grid_inputs))

# # Reshape the predictions to the grid format
# heatmap_values = pairwise_predictions.reshape(grid_var1.shape)


# # -------------------------- Plot the Heatmap --------------------------
# plt.figure(figsize = (10, 8))
# contour = plt.contourf(grid_var1, grid_var2, heatmap_values, levels = 10)
# plt.colorbar(contour)
# plt.title('Predicted Function by the Model')
# plt.xlabel(f"{interactions[pairwise_index][0]}")
# plt.ylabel(f"{interactions[pairwise_index][1]}")
# plt.show()

# %%
# #-------------------------- view the shape function --------------------------
# # get the prediction
# main_output_layer = model_pairwise.get_layer("main_subnet")
# subnet_model = Model(inputs = model_pairwise.inputs, outputs = main_output_layer.output)
# subnet_output = subnet_model.predict(X_train_split)

# # create the plot
# var_name = "X3"
# var_index = all_vars.index(var_name)
# plt.figure(figsize = (12, 6))
# sns.lineplot(x = X_train_split[var_index], 
#              y = subnet_output[:,var_index])
# plt.xlabel(f"{var_name}")
# plt.ylabel('Subnetwork Output')
# plt.title(f"Shape function for {var_name}")
# plt.grid(True)
# plt.show()
