# %%
############################ 0. PREPARATION ############################

#-------------------------- import packages --------------------------
import random
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from itertools import combinations
import seaborn as sns
import copy
import itertools

import tensorflow as tf
import tensorflow_lattice as tfl
import tf_keras as keras # need keras 2 to fit Lattice model
from tf_keras.models import Sequential, Model
from tf_keras.layers import Dense, Input, Multiply, Add, Embedding, Reshape, Concatenate, Dropout, BatchNormalization, Lambda, Layer, CategoryEncoding, Activation
from tf_keras.constraints import Constraint
from tf_keras.callbacks import EarlyStopping
from tf_keras.initializers import Zeros, Constant
from tf_keras.optimizers import Adam, Nadam, RMSprop
from tf_keras.models import clone_model
import keras_tuner as kt
from tf_keras import backend as K
from tf_keras import regularizers
from tf_keras.utils import plot_model
from tf_keras.losses import Poisson, Loss
from tf_keras.metrics import MeanAbsoluteError, RootMeanSquaredError
from scipy.stats import gamma


from pygam import LinearGAM, GAM, s, f, l
from sklearn.linear_model import ElasticNet
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error as mae
from sklearn.tree import DecisionTreeRegressor
from interpret.glassbox import ExplainableBoostingClassifier

# %%
#-------------------------- for reproducibility --------------------------
seed_value = 28
keras.utils.set_random_seed(seed_value)

# %%
#-------------------------- import data --------------------------
data = pd.read_csv("synthetic_low_var.csv")

# %%
#-------------------------- remove outliers --------------------------
log_claim = np.log(data['Y'])
IQR = log_claim.quantile(0.75) - log_claim.quantile(0.25) # inter-quartile range
lower_whisker = log_claim.quantile(0.25)- 1.5*IQR
upper_whisker = log_claim.quantile(0.75) + 1.5*IQR

# remove outliers: filter rows where the log of 'Y' is within the whiskers
dt_cleaned = data[(log_claim >= lower_whisker) & (log_claim <= upper_whisker)]
dt_cleaned
# Out:
#              X1        X2        X3        X4        X5        X6        X7  \
# 0      0.097627 -0.215654 -0.261487  0.855910 -0.977807  0.070514  0.247397
# 1      0.430379 -0.917687 -0.577348  0.805874 -0.996460  0.808088 -0.727145
# 2      0.205527  0.846601 -0.046190 -0.144766 -0.689890  0.004793  0.787168
# 3      0.089766 -0.187530 -0.835531  0.021611 -0.366478 -0.798260 -0.363850
# 4     -0.152690  0.888564 -0.524681  0.166400  0.303690  0.055164  0.158018
# ...         ...       ...       ...       ...       ...       ...       ...
# 19995  0.496349  0.336766  0.766494 -0.723110  0.451842 -0.547824  0.165682
# 19996 -0.403467  0.989823 -0.239838  0.690306  0.015041  0.168038 -0.808643
# 19997 -0.107088  0.176448 -0.661992  0.568246  0.620266  0.669292 -0.267906
# 19998 -0.279747 -0.150770 -0.472139  0.238510  0.102065 -0.832383  0.539168
# 19999  0.251773  0.803265 -0.397666 -0.684942 -0.548488 -0.791774 -0.620137
#
#              X8        X9       X10            Y
# 0     -0.844805 -0.633014  0.932805   269.727579
# 1      0.592222  0.416902  0.949203   606.423722
# 2     -0.029304 -0.254262 -0.739165  6740.904922
# 3      0.669637 -0.150974  0.020263  6749.592779
# 4      0.046901 -0.468522 -0.772319    79.024055
# ...         ...       ...       ...          ...
# 19995 -0.515032  0.372611 -0.262674    30.561326
# 19996 -0.903895 -0.433667 -0.389854   105.129106
# 19997  0.006409  0.871063 -0.570751  1101.252426
# 19998  0.073274  0.110462 -0.408447   634.928937
# 19999  0.197031 -0.409905  0.685008  2295.828834
#
# [19825 rows x 11 columns]

# %%
#-------------------------- distribution of log(response) --------------------------
plt.figure(figsize = (10, 6)) # set the size of the figure
sns.set_style("darkgrid")
sns.histplot(np.log(dt_cleaned['Y']), bins = 30, kde = True) # draw the chart
plt.title('Distribution of log(Y)')
plt.xlabel('Log(Y)')
plt.ylabel('Frequency')
plt.tick_params(axis = 'x')
plt.tick_params(axis = 'y')
plt.grid(True)
plt.show()

# %%
#-------------------------- column lists --------------------------
target_var = "Y" # target feature
all_vars = list(dt_cleaned.columns)
all_vars.remove(target_var) # store all input features
cat_vars = [] # categorical features

# %%
############################ 1. MODEL FITTING ############################

#-------------------------- train-test split --------------------------
X_main, X_test, y_main, y_test = train_test_split(
    dt_cleaned[all_vars], dt_cleaned[["Y"]], test_size = 0.2, random_state = 1)
X_train, X_val, y_train, y_val  = train_test_split(
    X_main, y_main, test_size = 0.25, random_state = 1)

# %%
# -------------------------- function to create a subnetwork --------------------------
# subnet for numerical variables
def create_subnet(num_layers, units_per_layer, activation, model_name, dropout_rate = 0, trainable = True, seed = 1):
    model = Sequential(name = model_name)
    for _ in range(num_layers):
        model.add(Dense(units_per_layer, activation = activation, trainable = trainable))
        model.add(Dropout(dropout_rate, seed = seed))
    model.add(Dense(1, trainable = trainable))
    model.add(BatchNormalization(scale = False)) # for identifiability
    return model

# layer to add all subnets' outputs and a bias term
@keras.saving.register_keras_serializable()
class AddSubnetOutput(Layer):
    def __init__(self, activation = None, **kwargs):
        super().__init__(**kwargs)
        self.activation = keras.activations.get(activation)
        self.bias = self.add_weight(
            shape = (1,), initializer = 'zeros', trainable = True, name = 'bias'
        )   
    def call(self, inputs):
        subnet_sum = K.sum(inputs, axis = -1, keepdims = True)
        output = subnet_sum + self.bias
        if self.activation is not None:
            output = self.activation(output)
        return output

# %%
# -------------------------- define model architecture --------------------------
inputs = []  # input layers
sub_outputs_main = []  # main effect subnet output
num_neurons_main = 10
num_layers_main = 2
activation = 'leaky_relu'
keypoints = 10
monotonicity_list = {"X3" : "decreasing"} # either "increasing", "decreasing", or "none"

# main effect
for name in all_vars:
    input_layer = Input(shape = (1,), name = name)
    inputs.append(input_layer)

    # subnetworks for main effects
    if name in cat_vars: # categorical variables
        # categorical variables will be one-hot encoded
        embed_layer = Embedding(input_dim = X_train[name].nunique(), 
                                output_dim = 1, 
                                name = f"{name}_embed")(input_layer)
        embed_layer_reshape = Reshape(target_shape = (1,), name = f"{name}_reshape")(embed_layer)
        mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(embed_layer_reshape)
        sub_outputs_main.append(mean_layer)
    elif name in monotonicity_list: # variables with monotonicity constraint
        calibrator_layer = tfl.layers.PWLCalibration(
            input_keypoints =  np.linspace(X_train[name].min(), X_train[name].max(), num = keypoints), # keypoints
            monotonicity = monotonicity_list[name], # monotonicity constraint
            name = f"{name}_pwlcalibrator"
        )(input_layer)
        mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(calibrator_layer)
        sub_outputs_main.append(mean_layer)
    else: # numeric variables
        subnet = create_subnet(num_layers_main, num_neurons_main, activation, f"{name}_subnetwork")
        sub_output = subnet(input_layer)
        sub_outputs_main.append(sub_output)

# combine subnets' outputs
main_subnets = Concatenate(name = "main_subnet")(sub_outputs_main)
final_output = AddSubnetOutput(activation = 'exponential',
                     name = "main_output")(main_subnets)

# final model
model_main_effect = Model(inputs = inputs, outputs = final_output)

# %%
plot_model(model_main_effect)

# %%
# -------------------------- define loss function --------------------------
# we will use a Gamma loss function
def gamma_log_likelihood(y_true, y_pred):
    y_pred = K.clip(y_pred, 1e-7, 1e30)
    return K.mean(y_true/y_pred - K.log(y_true/y_pred))

# create training & validation data consistent with the model architecture
X_train_split = []
X_val_split = []
X_test_split = []
for i in range(len(X_train.columns)):
    X_train_split.append(X_train.iloc[:, i])
    X_val_split.append(X_val.iloc[:, i])
    X_test_split.append(X_test.iloc[:, i])

# compile and fit
model_main_effect.compile(optimizer = "rmsprop", loss = gamma_log_likelihood, metrics = [RootMeanSquaredError()])
es = EarlyStopping(restore_best_weights = True, patience = 10)
# %time hist_main = model_main_effect.fit(X_train_split, y_train, epochs = 5_000, \
    callbacks = [es], batch_size = 1_000, validation_data = (X_val_split, y_val))
# Out:
# Epoch 1/5000
# 12/12 [==============================] - 2s 27ms/step - loss: 16906.7871 - root_mean_squared_error: 2450.9612 - val_loss: 919.2094 - val_root_mean_squared_error: 2619.4668
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 9504.6572 - root_mean_squared_error: 2415.3411 - val_loss: 817.6498 - val_root_mean_squared_error: 2619.4243
# Epoch 3/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 6746.4097 - root_mean_squared_error: 2399.9993 - val_loss: 751.2767 - val_root_mean_squared_error: 2619.3923
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4855.9927 - root_mean_squared_error: 2396.6296 - val_loss: 671.0491 - val_root_mean_squared_error: 2619.3479
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2789.1682 - root_mean_squared_error: 2394.0803 - val_loss: 613.0065 - val_root_mean_squared_error: 2619.3115
# Epoch 6/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 1556.4285 - root_mean_squared_error: 2392.6592 - val_loss: 562.2798 - val_root_mean_squared_error: 2619.2725
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 1045.0273 - root_mean_squared_error: 2392.7883 - val_loss: 513.9258 - val_root_mean_squared_error: 2619.2344
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 604.1174 - root_mean_squared_error: 2394.0742 - val_loss: 494.6069 - val_root_mean_squared_error: 2619.2129
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 461.8718 - root_mean_squared_error: 2394.4775 - val_loss: 463.6653 - val_root_mean_squared_error: 2619.1719
# Epoch 10/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 363.9429 - root_mean_squared_error: 2394.6606 - val_loss: 386.6699 - val_root_mean_squared_error: 2619.0386
# Epoch 11/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 296.8462 - root_mean_squared_error: 2394.5762 - val_loss: 336.8481 - val_root_mean_squared_error: 2618.9204
# Epoch 12/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 235.9178 - root_mean_squared_error: 2394.5903 - val_loss: 298.9395 - val_root_mean_squared_error: 2618.8042
# Epoch 13/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 191.2889 - root_mean_squared_error: 2394.4258 - val_loss: 275.3257 - val_root_mean_squared_error: 2618.7151
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 165.9142 - root_mean_squared_error: 2394.0642 - val_loss: 234.3247 - val_root_mean_squared_error: 2618.5178
# Epoch 15/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 146.9191 - root_mean_squared_error: 2393.6357 - val_loss: 216.9928 - val_root_mean_squared_error: 2618.4106
# Epoch 16/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 128.3909 - root_mean_squared_error: 2392.9204 - val_loss: 177.4170 - val_root_mean_squared_error: 2618.0942
# Epoch 17/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 113.9331 - root_mean_squared_error: 2392.4609 - val_loss: 166.6035 - val_root_mean_squared_error: 2617.9785
# Epoch 18/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 100.8314 - root_mean_squared_error: 2391.5659 - val_loss: 153.4689 - val_root_mean_squared_error: 2617.8191
# Epoch 19/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 88.6594 - root_mean_squared_error: 2390.9309 - val_loss: 150.1302 - val_root_mean_squared_error: 2617.7712
# Epoch 20/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 78.0292 - root_mean_squared_error: 2390.1001 - val_loss: 129.8900 - val_root_mean_squared_error: 2617.4519
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 69.8671 - root_mean_squared_error: 2388.9324 - val_loss: 112.7994 - val_root_mean_squared_error: 2617.0928
# Epoch 22/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 60.2019 - root_mean_squared_error: 2387.8396 - val_loss: 92.4781 - val_root_mean_squared_error: 2616.4961
# Epoch 23/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 53.8496 - root_mean_squared_error: 2386.4656 - val_loss: 81.7648 - val_root_mean_squared_error: 2616.0559
# Epoch 24/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 47.1298 - root_mean_squared_error: 2385.0588 - val_loss: 64.8140 - val_root_mean_squared_error: 2615.0786
# Epoch 25/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 42.0419 - root_mean_squared_error: 2383.3464 - val_loss: 52.4842 - val_root_mean_squared_error: 2613.9873
# Epoch 26/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 37.1816 - root_mean_squared_error: 2381.5073 - val_loss: 41.0754 - val_root_mean_squared_error: 2612.3911
# Epoch 27/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 32.7992 - root_mean_squared_error: 2379.4197 - val_loss: 35.4493 - val_root_mean_squared_error: 2611.2268
# Epoch 28/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 28.8973 - root_mean_squared_error: 2377.0789 - val_loss: 31.9977 - val_root_mean_squared_error: 2610.3425
# Epoch 29/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 25.1664 - root_mean_squared_error: 2374.6143 - val_loss: 32.7042 - val_root_mean_squared_error: 2610.4790
# Epoch 30/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 22.4585 - root_mean_squared_error: 2371.3955 - val_loss: 30.8670 - val_root_mean_squared_error: 2609.9202
# Epoch 31/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 19.9103 - root_mean_squared_error: 2368.2795 - val_loss: 21.4919 - val_root_mean_squared_error: 2605.7278
# Epoch 32/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 17.5581 - root_mean_squared_error: 2364.9487 - val_loss: 18.5555 - val_root_mean_squared_error: 2603.5515
# Epoch 33/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 15.4593 - root_mean_squared_error: 2360.8013 - val_loss: 20.6184 - val_root_mean_squared_error: 2604.9512
# Epoch 34/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 13.6629 - root_mean_squared_error: 2356.3032 - val_loss: 16.8701 - val_root_mean_squared_error: 2601.6064
# Epoch 35/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 12.0616 - root_mean_squared_error: 2350.7925 - val_loss: 20.0736 - val_root_mean_squared_error: 2604.3550
# Epoch 36/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 10.5728 - root_mean_squared_error: 2345.2822 - val_loss: 12.6940 - val_root_mean_squared_error: 2595.7102
# Epoch 37/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 9.4348 - root_mean_squared_error: 2339.5002 - val_loss: 15.7904 - val_root_mean_squared_error: 2600.0613
# Epoch 38/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 8.6265 - root_mean_squared_error: 2333.2161 - val_loss: 11.9807 - val_root_mean_squared_error: 2593.7700
# Epoch 39/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 7.3759 - root_mean_squared_error: 2324.1558 - val_loss: 20.4609 - val_root_mean_squared_error: 2604.0288
# Epoch 40/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 6.7155 - root_mean_squared_error: 2316.6497 - val_loss: 17.8321 - val_root_mean_squared_error: 2601.7488
# Epoch 41/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 5.8883 - root_mean_squared_error: 2306.5679 - val_loss: 24.5739 - val_root_mean_squared_error: 2606.4937
# Epoch 42/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 5.3972 - root_mean_squared_error: 2299.0540 - val_loss: 26.7166 - val_root_mean_squared_error: 2607.1577
# Epoch 43/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7585 - root_mean_squared_error: 2288.3967 - val_loss: 13.5078 - val_root_mean_squared_error: 2594.7026
# Epoch 44/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.3085 - root_mean_squared_error: 2271.8220 - val_loss: 11.7944 - val_root_mean_squared_error: 2591.1177
# Epoch 45/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 3.9159 - root_mean_squared_error: 2265.5330 - val_loss: 9.2377 - val_root_mean_squared_error: 2583.2917
# Epoch 46/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 3.6202 - root_mean_squared_error: 2250.1309 - val_loss: 7.1023 - val_root_mean_squared_error: 2571.8335
# Epoch 47/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 3.3002 - root_mean_squared_error: 2235.1145 - val_loss: 4.8109 - val_root_mean_squared_error: 2546.4448
# Epoch 48/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 3.0685 - root_mean_squared_error: 2223.0986 - val_loss: 7.1430 - val_root_mean_squared_error: 2569.2729
# Epoch 49/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.8484 - root_mean_squared_error: 2205.0959 - val_loss: 5.9972 - val_root_mean_squared_error: 2558.5786
# Epoch 50/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 2.7191 - root_mean_squared_error: 2199.4734 - val_loss: 2.7406 - val_root_mean_squared_error: 2456.7646
# Epoch 51/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 2.5723 - root_mean_squared_error: 2192.7131 - val_loss: 2.5118 - val_root_mean_squared_error: 2418.6311
# Epoch 52/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 2.4751 - root_mean_squared_error: 2184.1238 - val_loss: 2.3174 - val_root_mean_squared_error: 2338.2258
# Epoch 53/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.4011 - root_mean_squared_error: 2174.7180 - val_loss: 2.3948 - val_root_mean_squared_error: 2386.3330
# Epoch 54/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3321 - root_mean_squared_error: 2173.8098 - val_loss: 2.3797 - val_root_mean_squared_error: 2359.6902
# Epoch 55/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2789 - root_mean_squared_error: 2167.1262 - val_loss: 2.4467 - val_root_mean_squared_error: 2431.4524
# Epoch 56/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2544 - root_mean_squared_error: 2195.7070 - val_loss: 2.8658 - val_root_mean_squared_error: 3710.1416
# Epoch 57/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2429 - root_mean_squared_error: 2200.4775 - val_loss: 2.9882 - val_root_mean_squared_error: 4806.9341
# Epoch 58/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2357 - root_mean_squared_error: 2254.5532 - val_loss: 3.2004 - val_root_mean_squared_error: 5947.3540
# Epoch 59/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2303 - root_mean_squared_error: 2218.0005 - val_loss: 2.6472 - val_root_mean_squared_error: 3305.4585
# Epoch 60/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2404 - root_mean_squared_error: 2257.6753 - val_loss: 3.0537 - val_root_mean_squared_error: 5082.3511
# Epoch 61/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2337 - root_mean_squared_error: 2277.3535 - val_loss: 2.3868 - val_root_mean_squared_error: 2472.4202
# Epoch 62/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2361 - root_mean_squared_error: 2260.3267 - val_loss: 2.4889 - val_root_mean_squared_error: 2776.5125
# CPU times: user 6.48 s, sys: 971 ms, total: 7.45 s
# Wall time: 6.09 s

# %%
# -------------------------- get validation loss --------------------------
main_val_loss, main_rmse = model_main_effect.evaluate(X_val_split, y_val, verbose = False) # get the validation loss and RMSE
print(f"Validation loss for main effect: {main_val_loss}")
print(f"Validation RMSE for main effect: {main_rmse}")
# Out:
# Validation loss for main effect: 2.3174352645874023
# Validation RMSE for main effect: 2338.225830078125

# %%
# -------------------------- quantify variable importance --------------------------
main_output_layer = model_main_effect.get_layer("main_subnet")  # Get the subnet output layer
main_model = Model(inputs = model_main_effect.inputs, outputs = main_output_layer.output)
main_output_values = main_model.predict(X_train_split)
# subnet_weights = model_main_effect.get_layer("main_output").get_weights()[0]


# Get the variance of each subnetwork across all data points
subnet_variance = []
for i in range(main_output_values.shape[1]):
    subnet_variance.append(np.var(main_output_values[:, i]))

# Define covariates
covariates = [name for name in all_vars]

# -------------------------- plot the variable importance --------------------------
# Create DataFrame for variable importance
var_importance = pd.DataFrame({"Covariates": covariates, "Subnet Variance": subnet_variance})

# Sort the DataFrame by subnet variance in decreasing order
varimp_sorted = var_importance.sort_values(by = "Subnet Variance", ascending = False)

# Create a bar plot using Seaborn
plt.figure(figsize = (10, 6))
sns.barplot(x = "Covariates", y = "Subnet Variance", data = varimp_sorted)
plt.title("Subnet Variance by Covariates")
plt.xlabel("Covariates")
plt.ylabel("Subnet Variance")
plt.show()
# Out:
# 372/372 [==============================] - 0s 805us/step

# %%
#-------------------------- view the shape function --------------------------
# create the plot
var_name = "X3"
var_index = all_vars.index(var_name)
plt.figure(figsize = (12, 6))
sns.lineplot(x = X_train_split[var_index], 
             y = main_output_values[:,var_index].flatten())
plt.xlabel(f"{var_name}")
plt.ylabel('Subnetwork Output')
plt.title(f"Shape function for {var_name}")
plt.grid(True)
plt.show()

# %%
############################   preparation for interaction selection   ############################
global_layers = ["main_subnet", "main_output", "interaction_output", "final_output"] # these layers are always trainable
interaction_loss = {} # this stores the validation loss when fitting each pair of interaction effect
imp_vars = [f"X{i}" for i in range(1,7)] # important variables
interactions = combinations(imp_vars, 2)
# interactions = [("X3","X4")]
num_layers_interaction = 3 # number of layers for each interaction effect
num_neurons_interaction = 30 # number of neurons per dense layer for each interaction effect
keypoints = 20
lattice_sizes_pairwise = {}
for var in imp_vars:
    if var in cat_vars:
        lattice_sizes_pairwise[var] = X_train[var].nunique()
    else:
        lattice_sizes_pairwise[var] = 5

# %%
# -------------------------- create calibrator for lattice layer --------------------------
def add_calibrate_layer(var, data, monotonicity_list, lattice_sizes, keypoints, cat_vars, lattice_smooth_reg = [0,0]):
    if var in cat_vars:
        calibrator_layer = tfl.layers.CategoricalCalibration(
            num_buckets = data[var].nunique(),
            output_min = 0,
            output_max = lattice_sizes[var] - 1,
            name = f"{var}_calibrator_pairwise"
        )
    else:
        calibrator_layer = tfl.layers.PWLCalibration(
            input_keypoints =  np.linspace(data[var].min(), data[var].max(), num = keypoints), # keypoints
            kernel_regularizer = ('hessian', lattice_smooth_reg[0], lattice_smooth_reg[1]), # for smoothness
            monotonicity = monotonicity_list[var] if var in monotonicity_list else "none", # monotonicity constraint
            output_min = 0,
            output_max = lattice_sizes[var] - 1,
            name = f"{var}_calibrator_pairwise"
            )
    return calibrator_layer

# %%
############################   select interaction effect   ############################

# add pairwise effect and evaluate validation loss
for var1, var2 in interactions:

    # -------------------------- initialize a cloned model --------------------------
    model_main_cloned = clone_model(model_main_effect) # clone the main effect model
    model_main_cloned.build(model_main_effect.input_shape)
    model_main_cloned.set_weights(model_main_effect.get_weights()) # copy the weights


    # -------------------------- build a subnet for pairwise interaction effect --------------------------
    var1_input = model_main_cloned.inputs[all_vars.index(var1)]
    var2_input = model_main_cloned.inputs[all_vars.index(var2)]

    # Lattice model if the pair contains a monotonic variable
    if any(var in monotonicity_list for var in [var1, var2]):
        lattice_inputs = []

        # create calibrator_layer
        calibrator_var1 = add_calibrate_layer(var1, X_train, monotonicity_list, lattice_sizes_pairwise, keypoints, cat_vars)
        calibrator_var2 = add_calibrate_layer(var2, X_train, monotonicity_list, lattice_sizes_pairwise, keypoints, cat_vars)
        calibrator_layer_var1 = calibrator_var1(var1_input)
        calibrator_layer_var2 = calibrator_var2(var2_input)
        
        # lattice
        lattice_inputs.append(calibrator_layer_var1)
        lattice_inputs.append(calibrator_layer_var2)
        lattice_layer = tfl.layers.Lattice(lattice_sizes = [lattice_sizes_pairwise[var1],lattice_sizes_pairwise[var2]], 
                             monotonicities = ["increasing" if var1 in monotonicity_list else 'none',
                                                "increasing" if var2 in monotonicity_list else 'none'],
                             name = f"{var1}_{var2}_lattice")(lattice_inputs)
        pairwise_output = BatchNormalization(scale = False, name = f"{var1}_{var2}_mean")(lattice_layer)
    else:
        # Subnetwork if the pair contains no monotonic variables
        pairwise_input_layer = Concatenate(name = f"{var1}_{var2}_concat")([var1_input, var2_input])
        pairwise_subnet = create_subnet(num_layers_interaction, 
                                        num_neurons_interaction, 
                                        activation, 
                                        f"{var1}_{var2}_subnetwork")
        pairwise_output = pairwise_subnet(pairwise_input_layer)

    # final output
    interaction_subnet_output = Activation('exponential',
                        name = "interaction_output")(pairwise_output)
    main_subnet_output = model_main_cloned.output
    final_output = Multiply(name = "final_output")([main_subnet_output, interaction_subnet_output])
    model_pairwise = Model(inputs = model_main_cloned.inputs, outputs = final_output)


    # -------------------------- switch on/off layers --------------------------
    for layer in model_pairwise.layers:
        if layer.name not in global_layers and var1 not in layer.name and var2 not in layer.name:
            layer.trainable = False


    #-------------------------- custom loss function with marginal clarity constraint --------------------------
    # add marginal clarity constraint
    main_effects_output = model_pairwise.get_layer("main_subnet").output
    main_output_var1 = main_effects_output[all_vars.index(var1)]
    main_output_var2 = main_effects_output[all_vars.index(var2)]
    interaction_output = pairwise_output
    lambd = 3
    penalty = lambd * (
        K.abs(K.mean(main_output_var1 * interaction_output)) +
        K.abs(K.mean(main_output_var2 * interaction_output))
    )

    # Add the penalty to the model's total loss
    model_pairwise.add_loss(penalty)

    # -------------------------- compile and train the model --------------------------
    model_pairwise.compile(optimizer = 'rmsprop', 
                           loss = gamma_log_likelihood, 
                           metrics = [gamma_log_likelihood, RootMeanSquaredError()])
    es = EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)
    model_pairwise.fit(X_train_split, y_train, epochs = 5_000, \
                            callbacks = [es], batch_size = 1_000, validation_data = (X_val_split, y_val))
    _, gamma_log_metric, _ = model_pairwise.evaluate(X_val_split, y_val, batch_size = X_val_split[0].shape[0])
    interaction_loss[f"{var1}_{var2}"] = gamma_log_metric # add to the val loss list
# Out:
# Epoch 1/5000
# 12/12 [==============================] - 2s 29ms/step - loss: 2.4414 - gamma_log_likelihood: 2.4365 - root_mean_squared_error: 2215.8154 - val_loss: 3.1484 - val_gamma_log_likelihood: 2.4084 - val_root_mean_squared_error: 2355.3564
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3088 - gamma_log_likelihood: 2.3061 - root_mean_squared_error: 2118.4976 - val_loss: 3.1587 - val_gamma_log_likelihood: 2.4390 - val_root_mean_squared_error: 2416.4443
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3059 - gamma_log_likelihood: 2.3041 - root_mean_squared_error: 2119.4436 - val_loss: 3.2014 - val_gamma_log_likelihood: 2.4873 - val_root_mean_squared_error: 2479.0071
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2806 - gamma_log_likelihood: 2.2787 - root_mean_squared_error: 2104.1909 - val_loss: 3.1704 - val_gamma_log_likelihood: 2.4900 - val_root_mean_squared_error: 2575.6426
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2860 - gamma_log_likelihood: 2.2847 - root_mean_squared_error: 2106.5044 - val_loss: 3.1129 - val_gamma_log_likelihood: 2.5012 - val_root_mean_squared_error: 2495.6921
# Epoch 6/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2685 - gamma_log_likelihood: 2.2664 - root_mean_squared_error: 2100.7646 - val_loss: 3.0247 - val_gamma_log_likelihood: 2.4849 - val_root_mean_squared_error: 2426.1909
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2719 - gamma_log_likelihood: 2.2701 - root_mean_squared_error: 2105.2712 - val_loss: 2.9456 - val_gamma_log_likelihood: 2.4284 - val_root_mean_squared_error: 2378.9705
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2740 - gamma_log_likelihood: 2.2719 - root_mean_squared_error: 2104.7012 - val_loss: 2.9563 - val_gamma_log_likelihood: 2.4171 - val_root_mean_squared_error: 2393.6848
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2620 - gamma_log_likelihood: 2.2598 - root_mean_squared_error: 2097.3618 - val_loss: 2.8719 - val_gamma_log_likelihood: 2.4407 - val_root_mean_squared_error: 2444.3987
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2599 - gamma_log_likelihood: 2.2580 - root_mean_squared_error: 2098.4497 - val_loss: 2.8601 - val_gamma_log_likelihood: 2.4767 - val_root_mean_squared_error: 2452.7104
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2618 - gamma_log_likelihood: 2.2602 - root_mean_squared_error: 2102.4377 - val_loss: 2.7579 - val_gamma_log_likelihood: 2.4213 - val_root_mean_squared_error: 2402.7827
# Epoch 12/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2594 - gamma_log_likelihood: 2.2575 - root_mean_squared_error: 2098.6873 - val_loss: 2.7174 - val_gamma_log_likelihood: 2.5764 - val_root_mean_squared_error: 2510.6729
# Epoch 13/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 2.2591 - gamma_log_likelihood: 2.2568 - root_mean_squared_error: 2096.5786 - val_loss: 2.6529 - val_gamma_log_likelihood: 2.4690 - val_root_mean_squared_error: 2376.9160
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2496 - gamma_log_likelihood: 2.2478 - root_mean_squared_error: 2093.2676 - val_loss: 2.5590 - val_gamma_log_likelihood: 2.5179 - val_root_mean_squared_error: 2498.3726
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2444 - gamma_log_likelihood: 2.2432 - root_mean_squared_error: 2092.4058 - val_loss: 2.5854 - val_gamma_log_likelihood: 2.5461 - val_root_mean_squared_error: 2438.4333
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2455 - gamma_log_likelihood: 2.2436 - root_mean_squared_error: 2089.2825 - val_loss: 2.6247 - val_gamma_log_likelihood: 2.5607 - val_root_mean_squared_error: 2461.8643
# Epoch 17/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2419 - gamma_log_likelihood: 2.2401 - root_mean_squared_error: 2089.7197 - val_loss: 2.7658 - val_gamma_log_likelihood: 2.5976 - val_root_mean_squared_error: 2396.7070
# Epoch 18/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2413 - gamma_log_likelihood: 2.2392 - root_mean_squared_error: 2086.6860 - val_loss: 2.5718 - val_gamma_log_likelihood: 2.4853 - val_root_mean_squared_error: 2395.0610
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2436 - gamma_log_likelihood: 2.2422 - root_mean_squared_error: 2084.0994 - val_loss: 2.6468 - val_gamma_log_likelihood: 2.5487 - val_root_mean_squared_error: 2380.7017
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2388 - gamma_log_likelihood: 2.2363 - root_mean_squared_error: 2084.0073 - val_loss: 2.7748 - val_gamma_log_likelihood: 2.4505 - val_root_mean_squared_error: 2466.6328
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2426 - gamma_log_likelihood: 2.2409 - root_mean_squared_error: 2085.2339 - val_loss: 2.7763 - val_gamma_log_likelihood: 2.4782 - val_root_mean_squared_error: 2430.5493
# Epoch 22/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2394 - gamma_log_likelihood: 2.2375 - root_mean_squared_error: 2086.1677 - val_loss: 2.7246 - val_gamma_log_likelihood: 2.4570 - val_root_mean_squared_error: 2476.6501
# Epoch 23/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2364 - gamma_log_likelihood: 2.2347 - root_mean_squared_error: 2084.3442 - val_loss: 2.7248 - val_gamma_log_likelihood: 2.3933 - val_root_mean_squared_error: 2440.2732
# Epoch 24/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2308 - gamma_log_likelihood: 2.2287 - root_mean_squared_error: 2078.0120 - val_loss: 2.7596 - val_gamma_log_likelihood: 2.4276 - val_root_mean_squared_error: 2557.4219
# 1/1 [==============================] - 0s 18ms/step - loss: 2.5268 - gamma_log_likelihood: 2.5185 - root_mean_squared_error: 2498.3726
# Epoch 1/5000
# 12/12 [==============================] - 2s 32ms/step - loss: 2.5314 - gamma_log_likelihood: 2.5263 - root_mean_squared_error: 2856.2620 - val_loss: 5.0031 - val_gamma_log_likelihood: 3.0460 - val_root_mean_squared_error: 3548.0864
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3417 - gamma_log_likelihood: 2.3388 - root_mean_squared_error: 2241.2124 - val_loss: 4.8429 - val_gamma_log_likelihood: 3.0346 - val_root_mean_squared_error: 3564.1528
# Epoch 3/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3380 - gamma_log_likelihood: 2.3366 - root_mean_squared_error: 2244.2610 - val_loss: 4.6334 - val_gamma_log_likelihood: 2.9815 - val_root_mean_squared_error: 3420.1963
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3306 - gamma_log_likelihood: 2.3290 - root_mean_squared_error: 2261.7314 - val_loss: 4.2902 - val_gamma_log_likelihood: 2.8037 - val_root_mean_squared_error: 2882.1699
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3254 - gamma_log_likelihood: 2.3240 - root_mean_squared_error: 2272.9817 - val_loss: 4.1885 - val_gamma_log_likelihood: 2.7977 - val_root_mean_squared_error: 2891.2415
# Epoch 6/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3168 - gamma_log_likelihood: 2.3149 - root_mean_squared_error: 2259.5493 - val_loss: 4.0447 - val_gamma_log_likelihood: 2.7554 - val_root_mean_squared_error: 2838.0420
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3191 - gamma_log_likelihood: 2.3173 - root_mean_squared_error: 2285.3740 - val_loss: 3.9614 - val_gamma_log_likelihood: 2.7399 - val_root_mean_squared_error: 2796.6948
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3122 - gamma_log_likelihood: 2.3101 - root_mean_squared_error: 2305.3337 - val_loss: 3.9510 - val_gamma_log_likelihood: 2.7710 - val_root_mean_squared_error: 2930.7085
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3119 - gamma_log_likelihood: 2.3100 - root_mean_squared_error: 2296.1909 - val_loss: 3.7413 - val_gamma_log_likelihood: 2.6458 - val_root_mean_squared_error: 2641.2000
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3038 - gamma_log_likelihood: 2.3019 - root_mean_squared_error: 2310.7297 - val_loss: 3.6265 - val_gamma_log_likelihood: 2.5759 - val_root_mean_squared_error: 2533.9089
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3108 - gamma_log_likelihood: 2.3088 - root_mean_squared_error: 2344.2302 - val_loss: 3.4280 - val_gamma_log_likelihood: 2.4645 - val_root_mean_squared_error: 2401.6741
# Epoch 12/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 2.3050 - gamma_log_likelihood: 2.3027 - root_mean_squared_error: 2332.9575 - val_loss: 3.3745 - val_gamma_log_likelihood: 2.4497 - val_root_mean_squared_error: 2391.3909
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3015 - gamma_log_likelihood: 2.2992 - root_mean_squared_error: 2323.8022 - val_loss: 3.3709 - val_gamma_log_likelihood: 2.4790 - val_root_mean_squared_error: 2476.4226
# Epoch 14/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 2.2993 - gamma_log_likelihood: 2.2977 - root_mean_squared_error: 2336.4744 - val_loss: 3.2539 - val_gamma_log_likelihood: 2.3846 - val_root_mean_squared_error: 2347.4363
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2900 - gamma_log_likelihood: 2.2884 - root_mean_squared_error: 2331.6938 - val_loss: 3.1733 - val_gamma_log_likelihood: 2.3397 - val_root_mean_squared_error: 2327.0437
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2896 - gamma_log_likelihood: 2.2880 - root_mean_squared_error: 2327.2295 - val_loss: 3.0765 - val_gamma_log_likelihood: 2.3047 - val_root_mean_squared_error: 2331.4934
# Epoch 17/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 2.2876 - gamma_log_likelihood: 2.2857 - root_mean_squared_error: 2331.0959 - val_loss: 3.0511 - val_gamma_log_likelihood: 2.2911 - val_root_mean_squared_error: 2325.5449
# Epoch 18/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2841 - gamma_log_likelihood: 2.2818 - root_mean_squared_error: 2324.2766 - val_loss: 3.0659 - val_gamma_log_likelihood: 2.2993 - val_root_mean_squared_error: 2338.1646
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2851 - gamma_log_likelihood: 2.2834 - root_mean_squared_error: 2308.4780 - val_loss: 3.1271 - val_gamma_log_likelihood: 2.3119 - val_root_mean_squared_error: 2336.0771
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2802 - gamma_log_likelihood: 2.2780 - root_mean_squared_error: 2299.1736 - val_loss: 3.3100 - val_gamma_log_likelihood: 2.3957 - val_root_mean_squared_error: 2366.1045
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2776 - gamma_log_likelihood: 2.2762 - root_mean_squared_error: 2290.1777 - val_loss: 3.1885 - val_gamma_log_likelihood: 2.2923 - val_root_mean_squared_error: 2317.8608
# Epoch 22/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2737 - gamma_log_likelihood: 2.2718 - root_mean_squared_error: 2278.9475 - val_loss: 3.2545 - val_gamma_log_likelihood: 2.2979 - val_root_mean_squared_error: 2317.8982
# Epoch 23/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2659 - gamma_log_likelihood: 2.2643 - root_mean_squared_error: 2263.8992 - val_loss: 3.2385 - val_gamma_log_likelihood: 2.3119 - val_root_mean_squared_error: 2339.9460
# Epoch 24/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2671 - gamma_log_likelihood: 2.2646 - root_mean_squared_error: 2235.9065 - val_loss: 3.2651 - val_gamma_log_likelihood: 2.2980 - val_root_mean_squared_error: 2332.2446
# Epoch 25/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2590 - gamma_log_likelihood: 2.2573 - root_mean_squared_error: 2197.2388 - val_loss: 3.3620 - val_gamma_log_likelihood: 2.3782 - val_root_mean_squared_error: 2365.1621
# Epoch 26/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2565 - gamma_log_likelihood: 2.2548 - root_mean_squared_error: 2179.0969 - val_loss: 3.3927 - val_gamma_log_likelihood: 2.3601 - val_root_mean_squared_error: 2361.2937
# Epoch 27/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2558 - gamma_log_likelihood: 2.2545 - root_mean_squared_error: 2156.3118 - val_loss: 3.5012 - val_gamma_log_likelihood: 2.4099 - val_root_mean_squared_error: 2377.6572
# 1/1 [==============================] - 0s 17ms/step - loss: 2.9832 - gamma_log_likelihood: 2.2909 - root_mean_squared_error: 2325.5449
# Epoch 1/5000
# 12/12 [==============================] - 1s 29ms/step - loss: 2.3738 - gamma_log_likelihood: 2.3697 - root_mean_squared_error: 2158.4624 - val_loss: 2.4887 - val_gamma_log_likelihood: 2.4530 - val_root_mean_squared_error: 2524.2019
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2962 - gamma_log_likelihood: 2.2936 - root_mean_squared_error: 2114.8826 - val_loss: 2.5765 - val_gamma_log_likelihood: 2.5695 - val_root_mean_squared_error: 2578.0188
# Epoch 3/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2924 - gamma_log_likelihood: 2.2909 - root_mean_squared_error: 2117.4543 - val_loss: 2.6763 - val_gamma_log_likelihood: 2.6640 - val_root_mean_squared_error: 2717.8489
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2840 - gamma_log_likelihood: 2.2826 - root_mean_squared_error: 2116.7463 - val_loss: 2.9529 - val_gamma_log_likelihood: 2.9182 - val_root_mean_squared_error: 2511.0134
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2791 - gamma_log_likelihood: 2.2775 - root_mean_squared_error: 2115.8450 - val_loss: 3.0853 - val_gamma_log_likelihood: 3.0603 - val_root_mean_squared_error: 2564.1177
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2719 - gamma_log_likelihood: 2.2698 - root_mean_squared_error: 2109.9790 - val_loss: 3.5896 - val_gamma_log_likelihood: 3.5674 - val_root_mean_squared_error: 2601.8643
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2770 - gamma_log_likelihood: 2.2752 - root_mean_squared_error: 2113.9666 - val_loss: 3.8746 - val_gamma_log_likelihood: 3.8446 - val_root_mean_squared_error: 2542.1482
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2699 - gamma_log_likelihood: 2.2681 - root_mean_squared_error: 2111.4160 - val_loss: 3.3637 - val_gamma_log_likelihood: 3.2960 - val_root_mean_squared_error: 2575.4309
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2679 - gamma_log_likelihood: 2.2659 - root_mean_squared_error: 2111.1179 - val_loss: 3.3049 - val_gamma_log_likelihood: 3.2405 - val_root_mean_squared_error: 2617.5674
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2652 - gamma_log_likelihood: 2.2635 - root_mean_squared_error: 2108.6934 - val_loss: 3.0074 - val_gamma_log_likelihood: 2.9568 - val_root_mean_squared_error: 2781.5540
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2700 - gamma_log_likelihood: 2.2686 - root_mean_squared_error: 2110.5740 - val_loss: 2.8338 - val_gamma_log_likelihood: 2.7517 - val_root_mean_squared_error: 2925.2949
# 1/1 [==============================] - 0s 19ms/step - loss: 2.4895 - gamma_log_likelihood: 2.4536 - root_mean_squared_error: 2524.2017
# Epoch 1/5000
# 12/12 [==============================] - 2s 29ms/step - loss: 2.3814 - gamma_log_likelihood: 2.3772 - root_mean_squared_error: 2228.0110 - val_loss: 2.5891 - val_gamma_log_likelihood: 2.4868 - val_root_mean_squared_error: 2443.6479
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2777 - gamma_log_likelihood: 2.2751 - root_mean_squared_error: 2132.6057 - val_loss: 2.6162 - val_gamma_log_likelihood: 2.5500 - val_root_mean_squared_error: 2482.4358
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2787 - gamma_log_likelihood: 2.2771 - root_mean_squared_error: 2130.5034 - val_loss: 2.6247 - val_gamma_log_likelihood: 2.5921 - val_root_mean_squared_error: 2513.9199
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2637 - gamma_log_likelihood: 2.2618 - root_mean_squared_error: 2122.1814 - val_loss: 2.6646 - val_gamma_log_likelihood: 2.6078 - val_root_mean_squared_error: 2463.8767
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2662 - gamma_log_likelihood: 2.2647 - root_mean_squared_error: 2130.4895 - val_loss: 2.6724 - val_gamma_log_likelihood: 2.6468 - val_root_mean_squared_error: 2521.3425
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2545 - gamma_log_likelihood: 2.2522 - root_mean_squared_error: 2114.1125 - val_loss: 2.6400 - val_gamma_log_likelihood: 2.5922 - val_root_mean_squared_error: 2445.6111
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2637 - gamma_log_likelihood: 2.2620 - root_mean_squared_error: 2118.9644 - val_loss: 2.7207 - val_gamma_log_likelihood: 2.6581 - val_root_mean_squared_error: 2523.0564
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2557 - gamma_log_likelihood: 2.2538 - root_mean_squared_error: 2121.1968 - val_loss: 2.6403 - val_gamma_log_likelihood: 2.5535 - val_root_mean_squared_error: 2563.3325
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2549 - gamma_log_likelihood: 2.2529 - root_mean_squared_error: 2122.7478 - val_loss: 2.6996 - val_gamma_log_likelihood: 2.6155 - val_root_mean_squared_error: 2803.5300
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2504 - gamma_log_likelihood: 2.2490 - root_mean_squared_error: 2112.1406 - val_loss: 2.7578 - val_gamma_log_likelihood: 2.6757 - val_root_mean_squared_error: 2920.9360
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2516 - gamma_log_likelihood: 2.2500 - root_mean_squared_error: 2109.2319 - val_loss: 2.5907 - val_gamma_log_likelihood: 2.5077 - val_root_mean_squared_error: 2446.2700
# 1/1 [==============================] - 0s 19ms/step - loss: 2.5840 - gamma_log_likelihood: 2.4869 - root_mean_squared_error: 2443.6479
# Epoch 1/5000
# 12/12 [==============================] - 1s 28ms/step - loss: 2.4545 - gamma_log_likelihood: 2.4495 - root_mean_squared_error: 2273.1497 - val_loss: 2.7325 - val_gamma_log_likelihood: 2.6218 - val_root_mean_squared_error: 2415.5078
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2788 - gamma_log_likelihood: 2.2761 - root_mean_squared_error: 2103.8462 - val_loss: 2.5654 - val_gamma_log_likelihood: 2.4667 - val_root_mean_squared_error: 2528.3416
# Epoch 3/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3031 - gamma_log_likelihood: 2.3016 - root_mean_squared_error: 2146.9578 - val_loss: 2.6036 - val_gamma_log_likelihood: 2.5531 - val_root_mean_squared_error: 2512.4324
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2772 - gamma_log_likelihood: 2.2753 - root_mean_squared_error: 2118.1165 - val_loss: 2.7166 - val_gamma_log_likelihood: 2.6809 - val_root_mean_squared_error: 2428.3345
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2935 - gamma_log_likelihood: 2.2922 - root_mean_squared_error: 2138.6279 - val_loss: 2.7128 - val_gamma_log_likelihood: 2.6748 - val_root_mean_squared_error: 2434.6196
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2797 - gamma_log_likelihood: 2.2776 - root_mean_squared_error: 2117.1560 - val_loss: 2.7110 - val_gamma_log_likelihood: 2.6417 - val_root_mean_squared_error: 2502.6396
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2688 - gamma_log_likelihood: 2.2674 - root_mean_squared_error: 2102.5718 - val_loss: 2.8023 - val_gamma_log_likelihood: 2.7384 - val_root_mean_squared_error: 2528.1023
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2673 - gamma_log_likelihood: 2.2654 - root_mean_squared_error: 2108.6963 - val_loss: 2.8797 - val_gamma_log_likelihood: 2.7617 - val_root_mean_squared_error: 2440.8701
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2689 - gamma_log_likelihood: 2.2667 - root_mean_squared_error: 2101.8467 - val_loss: 2.9280 - val_gamma_log_likelihood: 2.8492 - val_root_mean_squared_error: 2408.0015
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2687 - gamma_log_likelihood: 2.2675 - root_mean_squared_error: 2116.7593 - val_loss: 2.6927 - val_gamma_log_likelihood: 2.6268 - val_root_mean_squared_error: 2401.9141
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2485 - gamma_log_likelihood: 2.2467 - root_mean_squared_error: 2092.1152 - val_loss: 2.7203 - val_gamma_log_likelihood: 2.6634 - val_root_mean_squared_error: 2408.1794
# Epoch 12/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2573 - gamma_log_likelihood: 2.2556 - root_mean_squared_error: 2099.9976 - val_loss: 2.6593 - val_gamma_log_likelihood: 2.6325 - val_root_mean_squared_error: 2419.1582
# 1/1 [==============================] - 0s 18ms/step - loss: 2.5697 - gamma_log_likelihood: 2.4667 - root_mean_squared_error: 2528.3416
# Epoch 1/5000
# 12/12 [==============================] - 2s 30ms/step - loss: 2.5352 - gamma_log_likelihood: 2.5304 - root_mean_squared_error: 2818.4541 - val_loss: 5.0309 - val_gamma_log_likelihood: 3.0744 - val_root_mean_squared_error: 3628.1350
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3381 - gamma_log_likelihood: 2.3356 - root_mean_squared_error: 2227.2722 - val_loss: 4.6455 - val_gamma_log_likelihood: 2.8903 - val_root_mean_squared_error: 3037.3647
# Epoch 3/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3431 - gamma_log_likelihood: 2.3417 - root_mean_squared_error: 2238.7959 - val_loss: 4.4236 - val_gamma_log_likelihood: 2.8218 - val_root_mean_squared_error: 2910.5444
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3291 - gamma_log_likelihood: 2.3272 - root_mean_squared_error: 2252.4019 - val_loss: 4.3382 - val_gamma_log_likelihood: 2.8567 - val_root_mean_squared_error: 3003.6074
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3348 - gamma_log_likelihood: 2.3338 - root_mean_squared_error: 2257.4478 - val_loss: 4.1531 - val_gamma_log_likelihood: 2.7949 - val_root_mean_squared_error: 2875.9390
# Epoch 6/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3295 - gamma_log_likelihood: 2.3274 - root_mean_squared_error: 2275.1318 - val_loss: 3.9366 - val_gamma_log_likelihood: 2.6964 - val_root_mean_squared_error: 2678.2527
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3249 - gamma_log_likelihood: 2.3230 - root_mean_squared_error: 2296.9402 - val_loss: 3.7816 - val_gamma_log_likelihood: 2.6444 - val_root_mean_squared_error: 2599.0977
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3299 - gamma_log_likelihood: 2.3277 - root_mean_squared_error: 2319.3521 - val_loss: 3.7200 - val_gamma_log_likelihood: 2.6584 - val_root_mean_squared_error: 2648.3611
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3274 - gamma_log_likelihood: 2.3252 - root_mean_squared_error: 2307.9094 - val_loss: 3.5911 - val_gamma_log_likelihood: 2.6160 - val_root_mean_squared_error: 2592.4810
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3221 - gamma_log_likelihood: 2.3203 - root_mean_squared_error: 2323.7004 - val_loss: 3.3931 - val_gamma_log_likelihood: 2.5072 - val_root_mean_squared_error: 2453.9636
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3231 - gamma_log_likelihood: 2.3214 - root_mean_squared_error: 2331.6545 - val_loss: 3.2800 - val_gamma_log_likelihood: 2.4653 - val_root_mean_squared_error: 2408.9255
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3248 - gamma_log_likelihood: 2.3227 - root_mean_squared_error: 2325.8948 - val_loss: 3.1613 - val_gamma_log_likelihood: 2.4036 - val_root_mean_squared_error: 2363.8484
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3267 - gamma_log_likelihood: 2.3245 - root_mean_squared_error: 2334.2622 - val_loss: 3.0889 - val_gamma_log_likelihood: 2.3932 - val_root_mean_squared_error: 2358.5862
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3213 - gamma_log_likelihood: 2.3196 - root_mean_squared_error: 2335.4165 - val_loss: 3.0766 - val_gamma_log_likelihood: 2.4263 - val_root_mean_squared_error: 2402.7917
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3206 - gamma_log_likelihood: 2.3188 - root_mean_squared_error: 2337.9299 - val_loss: 2.8980 - val_gamma_log_likelihood: 2.3221 - val_root_mean_squared_error: 2320.7502
# Epoch 16/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3256 - gamma_log_likelihood: 2.3235 - root_mean_squared_error: 2347.3164 - val_loss: 2.8993 - val_gamma_log_likelihood: 2.3585 - val_root_mean_squared_error: 2354.9221
# Epoch 17/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3197 - gamma_log_likelihood: 2.3176 - root_mean_squared_error: 2327.9614 - val_loss: 2.9414 - val_gamma_log_likelihood: 2.4283 - val_root_mean_squared_error: 2460.4744
# Epoch 18/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3165 - gamma_log_likelihood: 2.3143 - root_mean_squared_error: 2347.9187 - val_loss: 2.8442 - val_gamma_log_likelihood: 2.3768 - val_root_mean_squared_error: 2429.9644
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3198 - gamma_log_likelihood: 2.3180 - root_mean_squared_error: 2329.5647 - val_loss: 2.7664 - val_gamma_log_likelihood: 2.3388 - val_root_mean_squared_error: 2366.1802
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3196 - gamma_log_likelihood: 2.3170 - root_mean_squared_error: 2330.4456 - val_loss: 2.7411 - val_gamma_log_likelihood: 2.3389 - val_root_mean_squared_error: 2377.4551
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3214 - gamma_log_likelihood: 2.3199 - root_mean_squared_error: 2345.3608 - val_loss: 2.6727 - val_gamma_log_likelihood: 2.3088 - val_root_mean_squared_error: 2347.2605
# Epoch 22/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3168 - gamma_log_likelihood: 2.3153 - root_mean_squared_error: 2360.7297 - val_loss: 2.6395 - val_gamma_log_likelihood: 2.3109 - val_root_mean_squared_error: 2360.0000
# Epoch 23/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3218 - gamma_log_likelihood: 2.3202 - root_mean_squared_error: 2342.6785 - val_loss: 2.5911 - val_gamma_log_likelihood: 2.2894 - val_root_mean_squared_error: 2327.6169
# Epoch 24/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3163 - gamma_log_likelihood: 2.3140 - root_mean_squared_error: 2348.4106 - val_loss: 2.5779 - val_gamma_log_likelihood: 2.3046 - val_root_mean_squared_error: 2335.0605
# Epoch 25/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3147 - gamma_log_likelihood: 2.3129 - root_mean_squared_error: 2329.1753 - val_loss: 2.5871 - val_gamma_log_likelihood: 2.3150 - val_root_mean_squared_error: 2360.0608
# Epoch 26/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3194 - gamma_log_likelihood: 2.3181 - root_mean_squared_error: 2342.3274 - val_loss: 2.5712 - val_gamma_log_likelihood: 2.3217 - val_root_mean_squared_error: 2406.7615
# Epoch 27/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3141 - gamma_log_likelihood: 2.3126 - root_mean_squared_error: 2339.8518 - val_loss: 2.5656 - val_gamma_log_likelihood: 2.3107 - val_root_mean_squared_error: 2390.4858
# Epoch 28/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3148 - gamma_log_likelihood: 2.3118 - root_mean_squared_error: 2336.7861 - val_loss: 2.5738 - val_gamma_log_likelihood: 2.3043 - val_root_mean_squared_error: 2371.2388
# Epoch 29/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3148 - gamma_log_likelihood: 2.3126 - root_mean_squared_error: 2343.7383 - val_loss: 2.6297 - val_gamma_log_likelihood: 2.2996 - val_root_mean_squared_error: 2363.7517
# Epoch 30/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3131 - gamma_log_likelihood: 2.3109 - root_mean_squared_error: 2325.7856 - val_loss: 2.6203 - val_gamma_log_likelihood: 2.3067 - val_root_mean_squared_error: 2385.0044
# Epoch 31/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3070 - gamma_log_likelihood: 2.3051 - root_mean_squared_error: 2302.3159 - val_loss: 2.6416 - val_gamma_log_likelihood: 2.3184 - val_root_mean_squared_error: 2327.4971
# Epoch 32/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3086 - gamma_log_likelihood: 2.3066 - root_mean_squared_error: 2316.2510 - val_loss: 2.6964 - val_gamma_log_likelihood: 2.3412 - val_root_mean_squared_error: 2338.2051
# Epoch 33/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3125 - gamma_log_likelihood: 2.3107 - root_mean_squared_error: 2303.7998 - val_loss: 2.7482 - val_gamma_log_likelihood: 2.3901 - val_root_mean_squared_error: 2342.8818
# Epoch 34/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3049 - gamma_log_likelihood: 2.3037 - root_mean_squared_error: 2312.7319 - val_loss: 2.8130 - val_gamma_log_likelihood: 2.4540 - val_root_mean_squared_error: 2347.0615
# Epoch 35/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3045 - gamma_log_likelihood: 2.3032 - root_mean_squared_error: 2302.2637 - val_loss: 2.7651 - val_gamma_log_likelihood: 2.3678 - val_root_mean_squared_error: 2335.6707
# Epoch 36/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3043 - gamma_log_likelihood: 2.3027 - root_mean_squared_error: 2304.0281 - val_loss: 2.7235 - val_gamma_log_likelihood: 2.3049 - val_root_mean_squared_error: 2334.2053
# Epoch 37/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2985 - gamma_log_likelihood: 2.2968 - root_mean_squared_error: 2270.2498 - val_loss: 2.8105 - val_gamma_log_likelihood: 2.3536 - val_root_mean_squared_error: 2350.3770
# 1/1 [==============================] - 0s 18ms/step - loss: 2.5462 - gamma_log_likelihood: 2.3107 - root_mean_squared_error: 2390.4858
# Epoch 1/5000
# 12/12 [==============================] - 1s 25ms/step - loss: 2.3896 - gamma_log_likelihood: 2.3857 - root_mean_squared_error: 2319.0933 - val_loss: 2.6332 - val_gamma_log_likelihood: 2.5357 - val_root_mean_squared_error: 2375.0940
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2845 - gamma_log_likelihood: 2.2820 - root_mean_squared_error: 2122.4973 - val_loss: 2.6561 - val_gamma_log_likelihood: 2.5889 - val_root_mean_squared_error: 2379.2087
# Epoch 3/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2880 - gamma_log_likelihood: 2.2867 - root_mean_squared_error: 2122.1040 - val_loss: 2.5474 - val_gamma_log_likelihood: 2.4716 - val_root_mean_squared_error: 2386.3259
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2785 - gamma_log_likelihood: 2.2765 - root_mean_squared_error: 2121.0210 - val_loss: 2.6556 - val_gamma_log_likelihood: 2.6179 - val_root_mean_squared_error: 2453.5691
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2794 - gamma_log_likelihood: 2.2780 - root_mean_squared_error: 2118.0537 - val_loss: 2.5834 - val_gamma_log_likelihood: 2.5428 - val_root_mean_squared_error: 2396.3184
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2792 - gamma_log_likelihood: 2.2772 - root_mean_squared_error: 2117.6733 - val_loss: 2.6784 - val_gamma_log_likelihood: 2.6644 - val_root_mean_squared_error: 2377.7234
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2828 - gamma_log_likelihood: 2.2812 - root_mean_squared_error: 2127.8560 - val_loss: 2.6639 - val_gamma_log_likelihood: 2.6420 - val_root_mean_squared_error: 2395.6680
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2801 - gamma_log_likelihood: 2.2783 - root_mean_squared_error: 2121.1096 - val_loss: 2.6081 - val_gamma_log_likelihood: 2.5835 - val_root_mean_squared_error: 2396.0283
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2782 - gamma_log_likelihood: 2.2758 - root_mean_squared_error: 2118.4749 - val_loss: 2.5775 - val_gamma_log_likelihood: 2.5447 - val_root_mean_squared_error: 2426.9438
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2729 - gamma_log_likelihood: 2.2714 - root_mean_squared_error: 2116.3491 - val_loss: 2.6479 - val_gamma_log_likelihood: 2.6265 - val_root_mean_squared_error: 2402.9583
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2769 - gamma_log_likelihood: 2.2752 - root_mean_squared_error: 2113.9849 - val_loss: 2.6017 - val_gamma_log_likelihood: 2.5623 - val_root_mean_squared_error: 2380.4812
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2790 - gamma_log_likelihood: 2.2772 - root_mean_squared_error: 2119.9331 - val_loss: 2.6357 - val_gamma_log_likelihood: 2.6101 - val_root_mean_squared_error: 2372.9102
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2778 - gamma_log_likelihood: 2.2756 - root_mean_squared_error: 2117.9358 - val_loss: 2.5077 - val_gamma_log_likelihood: 2.4750 - val_root_mean_squared_error: 2380.7725
# Epoch 14/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2728 - gamma_log_likelihood: 2.2707 - root_mean_squared_error: 2114.2751 - val_loss: 2.5657 - val_gamma_log_likelihood: 2.5268 - val_root_mean_squared_error: 2373.9446
# Epoch 15/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2776 - gamma_log_likelihood: 2.2764 - root_mean_squared_error: 2117.1274 - val_loss: 2.5910 - val_gamma_log_likelihood: 2.5564 - val_root_mean_squared_error: 2374.5520
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2740 - gamma_log_likelihood: 2.2719 - root_mean_squared_error: 2113.0867 - val_loss: 2.4974 - val_gamma_log_likelihood: 2.4188 - val_root_mean_squared_error: 2349.3511
# Epoch 17/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2774 - gamma_log_likelihood: 2.2755 - root_mean_squared_error: 2115.7788 - val_loss: 2.5842 - val_gamma_log_likelihood: 2.5343 - val_root_mean_squared_error: 2352.3582
# Epoch 18/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2762 - gamma_log_likelihood: 2.2740 - root_mean_squared_error: 2115.7722 - val_loss: 2.6398 - val_gamma_log_likelihood: 2.5901 - val_root_mean_squared_error: 2358.4229
# Epoch 19/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2733 - gamma_log_likelihood: 2.2719 - root_mean_squared_error: 2112.3359 - val_loss: 2.7232 - val_gamma_log_likelihood: 2.6770 - val_root_mean_squared_error: 2378.6526
# Epoch 20/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2758 - gamma_log_likelihood: 2.2732 - root_mean_squared_error: 2109.9060 - val_loss: 2.7659 - val_gamma_log_likelihood: 2.7154 - val_root_mean_squared_error: 2384.1794
# Epoch 21/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2737 - gamma_log_likelihood: 2.2720 - root_mean_squared_error: 2116.0056 - val_loss: 2.6856 - val_gamma_log_likelihood: 2.6323 - val_root_mean_squared_error: 2400.4041
# Epoch 22/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2718 - gamma_log_likelihood: 2.2703 - root_mean_squared_error: 2118.2732 - val_loss: 2.8322 - val_gamma_log_likelihood: 2.7755 - val_root_mean_squared_error: 2411.3208
# Epoch 23/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2772 - gamma_log_likelihood: 2.2755 - root_mean_squared_error: 2110.6821 - val_loss: 2.7340 - val_gamma_log_likelihood: 2.6743 - val_root_mean_squared_error: 2389.1006
# Epoch 24/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2730 - gamma_log_likelihood: 2.2708 - root_mean_squared_error: 2114.8389 - val_loss: 2.7770 - val_gamma_log_likelihood: 2.6978 - val_root_mean_squared_error: 2409.0789
# Epoch 25/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2714 - gamma_log_likelihood: 2.2698 - root_mean_squared_error: 2111.4607 - val_loss: 2.8307 - val_gamma_log_likelihood: 2.7604 - val_root_mean_squared_error: 2415.9565
# Epoch 26/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2735 - gamma_log_likelihood: 2.2717 - root_mean_squared_error: 2114.2087 - val_loss: 2.9681 - val_gamma_log_likelihood: 2.8792 - val_root_mean_squared_error: 2407.0093
# 1/1 [==============================] - 0s 16ms/step - loss: 2.5033 - gamma_log_likelihood: 2.4184 - root_mean_squared_error: 2349.3511
# Epoch 1/5000
# 12/12 [==============================] - 1s 26ms/step - loss: 2.3220 - gamma_log_likelihood: 2.3186 - root_mean_squared_error: 2246.7673 - val_loss: 3.0444 - val_gamma_log_likelihood: 2.9405 - val_root_mean_squared_error: 2414.1570
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2786 - gamma_log_likelihood: 2.2763 - root_mean_squared_error: 2139.0647 - val_loss: 3.0722 - val_gamma_log_likelihood: 2.9807 - val_root_mean_squared_error: 2418.7556
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2780 - gamma_log_likelihood: 2.2764 - root_mean_squared_error: 2133.5325 - val_loss: 3.2713 - val_gamma_log_likelihood: 3.1778 - val_root_mean_squared_error: 2430.7007
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2699 - gamma_log_likelihood: 2.2682 - root_mean_squared_error: 2126.8911 - val_loss: 2.9354 - val_gamma_log_likelihood: 2.8228 - val_root_mean_squared_error: 2410.3823
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2734 - gamma_log_likelihood: 2.2725 - root_mean_squared_error: 2128.9238 - val_loss: 3.1364 - val_gamma_log_likelihood: 3.0281 - val_root_mean_squared_error: 2444.4255
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2634 - gamma_log_likelihood: 2.2612 - root_mean_squared_error: 2124.4465 - val_loss: 2.9057 - val_gamma_log_likelihood: 2.8269 - val_root_mean_squared_error: 2414.1672
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2650 - gamma_log_likelihood: 2.2634 - root_mean_squared_error: 2132.1592 - val_loss: 2.8878 - val_gamma_log_likelihood: 2.8379 - val_root_mean_squared_error: 2432.8416
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2701 - gamma_log_likelihood: 2.2683 - root_mean_squared_error: 2128.0999 - val_loss: 2.6940 - val_gamma_log_likelihood: 2.6476 - val_root_mean_squared_error: 2441.5376
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2599 - gamma_log_likelihood: 2.2576 - root_mean_squared_error: 2126.1648 - val_loss: 2.8219 - val_gamma_log_likelihood: 2.7726 - val_root_mean_squared_error: 2457.6804
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2641 - gamma_log_likelihood: 2.2625 - root_mean_squared_error: 2131.0029 - val_loss: 2.8294 - val_gamma_log_likelihood: 2.7959 - val_root_mean_squared_error: 2468.8066
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2630 - gamma_log_likelihood: 2.2613 - root_mean_squared_error: 2128.8572 - val_loss: 2.6339 - val_gamma_log_likelihood: 2.6062 - val_root_mean_squared_error: 2448.2529
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2664 - gamma_log_likelihood: 2.2645 - root_mean_squared_error: 2132.2559 - val_loss: 2.7251 - val_gamma_log_likelihood: 2.6950 - val_root_mean_squared_error: 2473.4644
# Epoch 13/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2638 - gamma_log_likelihood: 2.2617 - root_mean_squared_error: 2129.7314 - val_loss: 2.8291 - val_gamma_log_likelihood: 2.8055 - val_root_mean_squared_error: 2453.5916
# Epoch 14/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2597 - gamma_log_likelihood: 2.2580 - root_mean_squared_error: 2130.2002 - val_loss: 2.8563 - val_gamma_log_likelihood: 2.8193 - val_root_mean_squared_error: 2506.7991
# Epoch 15/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2577 - gamma_log_likelihood: 2.2564 - root_mean_squared_error: 2123.8826 - val_loss: 2.6567 - val_gamma_log_likelihood: 2.5671 - val_root_mean_squared_error: 2456.7324
# Epoch 16/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2629 - gamma_log_likelihood: 2.2612 - root_mean_squared_error: 2130.2556 - val_loss: 2.7144 - val_gamma_log_likelihood: 2.6518 - val_root_mean_squared_error: 2422.4392
# Epoch 17/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2605 - gamma_log_likelihood: 2.2586 - root_mean_squared_error: 2121.8501 - val_loss: 2.5503 - val_gamma_log_likelihood: 2.4988 - val_root_mean_squared_error: 2421.5225
# Epoch 18/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2623 - gamma_log_likelihood: 2.2601 - root_mean_squared_error: 2128.8591 - val_loss: 2.6498 - val_gamma_log_likelihood: 2.6019 - val_root_mean_squared_error: 2429.6021
# Epoch 19/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2580 - gamma_log_likelihood: 2.2564 - root_mean_squared_error: 2125.2341 - val_loss: 2.7441 - val_gamma_log_likelihood: 2.6263 - val_root_mean_squared_error: 2398.6960
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2599 - gamma_log_likelihood: 2.2575 - root_mean_squared_error: 2120.3801 - val_loss: 2.5252 - val_gamma_log_likelihood: 2.4668 - val_root_mean_squared_error: 2375.5791
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2590 - gamma_log_likelihood: 2.2571 - root_mean_squared_error: 2122.5562 - val_loss: 2.4816 - val_gamma_log_likelihood: 2.4405 - val_root_mean_squared_error: 2381.4043
# Epoch 22/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2585 - gamma_log_likelihood: 2.2570 - root_mean_squared_error: 2129.9763 - val_loss: 2.5286 - val_gamma_log_likelihood: 2.4624 - val_root_mean_squared_error: 2369.1853
# Epoch 23/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2610 - gamma_log_likelihood: 2.2593 - root_mean_squared_error: 2127.0388 - val_loss: 2.5482 - val_gamma_log_likelihood: 2.4392 - val_root_mean_squared_error: 2393.2117
# Epoch 24/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2586 - gamma_log_likelihood: 2.2564 - root_mean_squared_error: 2123.2334 - val_loss: 2.5059 - val_gamma_log_likelihood: 2.4468 - val_root_mean_squared_error: 2366.4434
# Epoch 25/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2551 - gamma_log_likelihood: 2.2533 - root_mean_squared_error: 2120.6167 - val_loss: 2.5113 - val_gamma_log_likelihood: 2.4680 - val_root_mean_squared_error: 2405.5940
# Epoch 26/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2586 - gamma_log_likelihood: 2.2572 - root_mean_squared_error: 2122.7429 - val_loss: 2.4128 - val_gamma_log_likelihood: 2.3229 - val_root_mean_squared_error: 2327.2119
# Epoch 27/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2587 - gamma_log_likelihood: 2.2572 - root_mean_squared_error: 2131.0132 - val_loss: 2.4159 - val_gamma_log_likelihood: 2.3608 - val_root_mean_squared_error: 2347.6943
# Epoch 28/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2545 - gamma_log_likelihood: 2.2516 - root_mean_squared_error: 2123.8999 - val_loss: 2.3933 - val_gamma_log_likelihood: 2.3387 - val_root_mean_squared_error: 2340.5249
# Epoch 29/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2554 - gamma_log_likelihood: 2.2531 - root_mean_squared_error: 2123.7336 - val_loss: 2.4669 - val_gamma_log_likelihood: 2.3313 - val_root_mean_squared_error: 2342.5657
# Epoch 30/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2592 - gamma_log_likelihood: 2.2570 - root_mean_squared_error: 2126.1699 - val_loss: 2.4627 - val_gamma_log_likelihood: 2.3266 - val_root_mean_squared_error: 2325.1443
# Epoch 31/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2523 - gamma_log_likelihood: 2.2505 - root_mean_squared_error: 2115.2017 - val_loss: 2.3851 - val_gamma_log_likelihood: 2.3337 - val_root_mean_squared_error: 2339.9890
# Epoch 32/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2551 - gamma_log_likelihood: 2.2529 - root_mean_squared_error: 2121.3242 - val_loss: 2.4260 - val_gamma_log_likelihood: 2.3522 - val_root_mean_squared_error: 2347.1035
# Epoch 33/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2546 - gamma_log_likelihood: 2.2527 - root_mean_squared_error: 2120.2156 - val_loss: 2.6618 - val_gamma_log_likelihood: 2.4296 - val_root_mean_squared_error: 2360.8638
# Epoch 34/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2522 - gamma_log_likelihood: 2.2513 - root_mean_squared_error: 2119.1099 - val_loss: 2.6651 - val_gamma_log_likelihood: 2.4549 - val_root_mean_squared_error: 2368.4246
# Epoch 35/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2500 - gamma_log_likelihood: 2.2485 - root_mean_squared_error: 2118.7507 - val_loss: 2.6376 - val_gamma_log_likelihood: 2.4345 - val_root_mean_squared_error: 2367.0559
# Epoch 36/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2531 - gamma_log_likelihood: 2.2513 - root_mean_squared_error: 2120.1621 - val_loss: 2.5635 - val_gamma_log_likelihood: 2.3453 - val_root_mean_squared_error: 2349.6060
# Epoch 37/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2508 - gamma_log_likelihood: 2.2490 - root_mean_squared_error: 2123.9595 - val_loss: 2.5925 - val_gamma_log_likelihood: 2.3824 - val_root_mean_squared_error: 2358.4500
# Epoch 38/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2533 - gamma_log_likelihood: 2.2516 - root_mean_squared_error: 2120.0105 - val_loss: 2.6872 - val_gamma_log_likelihood: 2.4064 - val_root_mean_squared_error: 2368.4937
# Epoch 39/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2540 - gamma_log_likelihood: 2.2526 - root_mean_squared_error: 2121.2600 - val_loss: 2.7207 - val_gamma_log_likelihood: 2.4641 - val_root_mean_squared_error: 2379.6199
# Epoch 40/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2573 - gamma_log_likelihood: 2.2554 - root_mean_squared_error: 2119.9189 - val_loss: 2.5341 - val_gamma_log_likelihood: 2.3278 - val_root_mean_squared_error: 2349.8638
# Epoch 41/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2486 - gamma_log_likelihood: 2.2463 - root_mean_squared_error: 2116.7522 - val_loss: 2.4460 - val_gamma_log_likelihood: 2.3273 - val_root_mean_squared_error: 2342.9355
# 1/1 [==============================] - 0s 17ms/step - loss: 2.3800 - gamma_log_likelihood: 2.3340 - root_mean_squared_error: 2339.9890
# Epoch 1/5000
# 12/12 [==============================] - 1s 26ms/step - loss: 2.3536 - gamma_log_likelihood: 2.3495 - root_mean_squared_error: 2151.8464 - val_loss: 2.7818 - val_gamma_log_likelihood: 2.7590 - val_root_mean_squared_error: 2428.7476
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2753 - gamma_log_likelihood: 2.2728 - root_mean_squared_error: 2113.9966 - val_loss: 2.8895 - val_gamma_log_likelihood: 2.8635 - val_root_mean_squared_error: 2431.7056
# Epoch 3/5000
# ...
# Epoch 37/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3125 - gamma_log_likelihood: 2.3106 - root_mean_squared_error: 2386.7559 - val_loss: 2.5883 - val_gamma_log_likelihood: 2.3189 - val_root_mean_squared_error: 2511.3723
# Epoch 38/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3159 - gamma_log_likelihood: 2.3140 - root_mean_squared_error: 2373.5215 - val_loss: 2.7264 - val_gamma_log_likelihood: 2.4384 - val_root_mean_squared_error: 3069.8286
# Epoch 39/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3082 - gamma_log_likelihood: 2.3068 - root_mean_squared_error: 2362.5242 - val_loss: 2.8842 - val_gamma_log_likelihood: 2.5895 - val_root_mean_squared_error: 3845.0051
# Epoch 40/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3135 - gamma_log_likelihood: 2.3123 - root_mean_squared_error: 2370.8577 - val_loss: 2.7755 - val_gamma_log_likelihood: 2.4838 - val_root_mean_squared_error: 3270.0952
# Epoch 41/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3068 - gamma_log_likelihood: 2.3047 - root_mean_squared_error: 2357.2502 - val_loss: 2.7909 - val_gamma_log_likelihood: 2.4425 - val_root_mean_squared_error: 3054.6108
# 1/1 [==============================] - 0s 16ms/step - loss: 2.5657 - gamma_log_likelihood: 2.3106 - root_mean_squared_error: 2423.6501
# Epoch 1/5000
# 12/12 [==============================] - 1s 25ms/step - loss: 2.4893 - gamma_log_likelihood: 2.4849 - root_mean_squared_error: 2191.4602 - val_loss: 2.8020 - val_gamma_log_likelihood: 2.4480 - val_root_mean_squared_error: 2364.2031
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2927 - gamma_log_likelihood: 2.2900 - root_mean_squared_error: 2133.3174 - val_loss: 2.7305 - val_gamma_log_likelihood: 2.4951 - val_root_mean_squared_error: 2380.5188
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2848 - gamma_log_likelihood: 2.2834 - root_mean_squared_error: 2137.6187 - val_loss: 2.5891 - val_gamma_log_likelihood: 2.4618 - val_root_mean_squared_error: 2440.0024
# Epoch 4/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2820 - gamma_log_likelihood: 2.2802 - root_mean_squared_error: 2144.4561 - val_loss: 2.6196 - val_gamma_log_likelihood: 2.5037 - val_root_mean_squared_error: 2459.2476
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2751 - gamma_log_likelihood: 2.2738 - root_mean_squared_error: 2144.4888 - val_loss: 2.5312 - val_gamma_log_likelihood: 2.4788 - val_root_mean_squared_error: 2424.5310
# Epoch 6/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2820 - gamma_log_likelihood: 2.2797 - root_mean_squared_error: 2139.1035 - val_loss: 2.5430 - val_gamma_log_likelihood: 2.4936 - val_root_mean_squared_error: 2456.5874
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2754 - gamma_log_likelihood: 2.2740 - root_mean_squared_error: 2141.2866 - val_loss: 2.5655 - val_gamma_log_likelihood: 2.5350 - val_root_mean_squared_error: 2427.8015
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2787 - gamma_log_likelihood: 2.2767 - root_mean_squared_error: 2144.8684 - val_loss: 2.5234 - val_gamma_log_likelihood: 2.4936 - val_root_mean_squared_error: 2443.9871
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2741 - gamma_log_likelihood: 2.2719 - root_mean_squared_error: 2138.8584 - val_loss: 2.5094 - val_gamma_log_likelihood: 2.4535 - val_root_mean_squared_error: 2395.3687
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2800 - gamma_log_likelihood: 2.2787 - root_mean_squared_error: 2143.2800 - val_loss: 2.5451 - val_gamma_log_likelihood: 2.4981 - val_root_mean_squared_error: 2382.5630
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2714 - gamma_log_likelihood: 2.2696 - root_mean_squared_error: 2138.9778 - val_loss: 2.4987 - val_gamma_log_likelihood: 2.4542 - val_root_mean_squared_error: 2376.9316
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2765 - gamma_log_likelihood: 2.2745 - root_mean_squared_error: 2146.2676 - val_loss: 2.6294 - val_gamma_log_likelihood: 2.5459 - val_root_mean_squared_error: 2402.7344
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2727 - gamma_log_likelihood: 2.2703 - root_mean_squared_error: 2137.3184 - val_loss: 2.4921 - val_gamma_log_likelihood: 2.4029 - val_root_mean_squared_error: 2380.2268
# Epoch 14/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2725 - gamma_log_likelihood: 2.2707 - root_mean_squared_error: 2145.2864 - val_loss: 2.5838 - val_gamma_log_likelihood: 2.4223 - val_root_mean_squared_error: 2376.3083
# Epoch 15/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2738 - gamma_log_likelihood: 2.2726 - root_mean_squared_error: 2142.9612 - val_loss: 2.5282 - val_gamma_log_likelihood: 2.4110 - val_root_mean_squared_error: 2356.6763
# Epoch 16/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2773 - gamma_log_likelihood: 2.2755 - root_mean_squared_error: 2146.5017 - val_loss: 2.4998 - val_gamma_log_likelihood: 2.3692 - val_root_mean_squared_error: 2354.0449
# Epoch 17/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2764 - gamma_log_likelihood: 2.2745 - root_mean_squared_error: 2144.1968 - val_loss: 2.5665 - val_gamma_log_likelihood: 2.4218 - val_root_mean_squared_error: 2434.3071
# Epoch 18/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2752 - gamma_log_likelihood: 2.2727 - root_mean_squared_error: 2142.4026 - val_loss: 2.6027 - val_gamma_log_likelihood: 2.4196 - val_root_mean_squared_error: 2401.4561
# Epoch 19/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2713 - gamma_log_likelihood: 2.2701 - root_mean_squared_error: 2143.7322 - val_loss: 2.5963 - val_gamma_log_likelihood: 2.4405 - val_root_mean_squared_error: 2405.6716
# Epoch 20/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2773 - gamma_log_likelihood: 2.2748 - root_mean_squared_error: 2142.6941 - val_loss: 2.6587 - val_gamma_log_likelihood: 2.4584 - val_root_mean_squared_error: 2466.6836
# Epoch 21/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2742 - gamma_log_likelihood: 2.2722 - root_mean_squared_error: 2141.6917 - val_loss: 2.7462 - val_gamma_log_likelihood: 2.4385 - val_root_mean_squared_error: 2584.7505
# Epoch 22/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2743 - gamma_log_likelihood: 2.2729 - root_mean_squared_error: 2148.3774 - val_loss: 2.6487 - val_gamma_log_likelihood: 2.4756 - val_root_mean_squared_error: 2453.1113
# Epoch 23/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2726 - gamma_log_likelihood: 2.2709 - root_mean_squared_error: 2139.1138 - val_loss: 2.5888 - val_gamma_log_likelihood: 2.4191 - val_root_mean_squared_error: 2470.5007
# 1/1 [==============================] - 0s 16ms/step - loss: 2.4870 - gamma_log_likelihood: 2.4025 - root_mean_squared_error: 2380.2271
# Epoch 1/5000
# 12/12 [==============================] - 1s 25ms/step - loss: 2.4453 - gamma_log_likelihood: 2.4410 - root_mean_squared_error: 2147.5779 - val_loss: 2.6224 - val_gamma_log_likelihood: 2.5648 - val_root_mean_squared_error: 2455.0923
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2917 - gamma_log_likelihood: 2.2891 - root_mean_squared_error: 2106.9783 - val_loss: 2.9112 - val_gamma_log_likelihood: 2.8573 - val_root_mean_squared_error: 2565.1831
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2765 - gamma_log_likelihood: 2.2751 - root_mean_squared_error: 2109.3547 - val_loss: 3.0060 - val_gamma_log_likelihood: 2.9826 - val_root_mean_squared_error: 2745.7708
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2804 - gamma_log_likelihood: 2.2785 - root_mean_squared_error: 2120.9585 - val_loss: 2.8932 - val_gamma_log_likelihood: 2.8502 - val_root_mean_squared_error: 2641.9607
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2755 - gamma_log_likelihood: 2.2740 - root_mean_squared_error: 2114.9194 - val_loss: 2.9629 - val_gamma_log_likelihood: 2.9448 - val_root_mean_squared_error: 2927.5776
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2790 - gamma_log_likelihood: 2.2769 - root_mean_squared_error: 2116.9976 - val_loss: 2.8998 - val_gamma_log_likelihood: 2.8670 - val_root_mean_squared_error: 3169.7876
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2751 - gamma_log_likelihood: 2.2738 - root_mean_squared_error: 2118.1714 - val_loss: 2.8069 - val_gamma_log_likelihood: 2.7652 - val_root_mean_squared_error: 3319.8889
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2712 - gamma_log_likelihood: 2.2694 - root_mean_squared_error: 2113.6541 - val_loss: 2.8840 - val_gamma_log_likelihood: 2.8150 - val_root_mean_squared_error: 3311.0227
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2754 - gamma_log_likelihood: 2.2731 - root_mean_squared_error: 2115.8672 - val_loss: 2.8032 - val_gamma_log_likelihood: 2.7163 - val_root_mean_squared_error: 3218.9614
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2711 - gamma_log_likelihood: 2.2700 - root_mean_squared_error: 2112.7688 - val_loss: 2.8327 - val_gamma_log_likelihood: 2.6968 - val_root_mean_squared_error: 2944.5918
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2723 - gamma_log_likelihood: 2.2705 - root_mean_squared_error: 2112.9324 - val_loss: 3.0466 - val_gamma_log_likelihood: 2.8761 - val_root_mean_squared_error: 2783.1082
# 1/1 [==============================] - 0s 18ms/step - loss: 2.6228 - gamma_log_likelihood: 2.5659 - root_mean_squared_error: 2455.0925
# Epoch 1/5000
# 12/12 [==============================] - 1s 25ms/step - loss: 2.4201 - gamma_log_likelihood: 2.4155 - root_mean_squared_error: 2130.8718 - val_loss: 2.5038 - val_gamma_log_likelihood: 2.4389 - val_root_mean_squared_error: 2405.6255
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.1787 - gamma_log_likelihood: 2.1759 - root_mean_squared_error: 2069.5852 - val_loss: 2.3717 - val_gamma_log_likelihood: 2.3108 - val_root_mean_squared_error: 2375.2488
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1335 - gamma_log_likelihood: 2.1319 - root_mean_squared_error: 2138.1860 - val_loss: 2.4899 - val_gamma_log_likelihood: 2.3658 - val_root_mean_squared_error: 2401.8579
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0985 - gamma_log_likelihood: 2.0967 - root_mean_squared_error: 2147.7605 - val_loss: 2.3898 - val_gamma_log_likelihood: 2.3174 - val_root_mean_squared_error: 2371.5862
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0664 - gamma_log_likelihood: 2.0651 - root_mean_squared_error: 2093.0574 - val_loss: 2.3610 - val_gamma_log_likelihood: 2.2949 - val_root_mean_squared_error: 2354.9312
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0802 - gamma_log_likelihood: 2.0779 - root_mean_squared_error: 2120.0920 - val_loss: 2.4880 - val_gamma_log_likelihood: 2.4043 - val_root_mean_squared_error: 2400.1077
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0468 - gamma_log_likelihood: 2.0451 - root_mean_squared_error: 2100.4531 - val_loss: 2.4802 - val_gamma_log_likelihood: 2.3916 - val_root_mean_squared_error: 2394.2727
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0538 - gamma_log_likelihood: 2.0520 - root_mean_squared_error: 2091.9441 - val_loss: 2.3867 - val_gamma_log_likelihood: 2.3096 - val_root_mean_squared_error: 2375.1309
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0455 - gamma_log_likelihood: 2.0430 - root_mean_squared_error: 2095.5906 - val_loss: 2.4185 - val_gamma_log_likelihood: 2.3739 - val_root_mean_squared_error: 2390.1904
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.0311 - gamma_log_likelihood: 2.0304 - root_mean_squared_error: 2104.2153 - val_loss: 2.3226 - val_gamma_log_likelihood: 2.2726 - val_root_mean_squared_error: 2356.4277
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0260 - gamma_log_likelihood: 2.0242 - root_mean_squared_error: 2073.7288 - val_loss: 2.4014 - val_gamma_log_likelihood: 2.3179 - val_root_mean_squared_error: 2374.0312
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0224 - gamma_log_likelihood: 2.0201 - root_mean_squared_error: 2072.0144 - val_loss: 2.3291 - val_gamma_log_likelihood: 2.2551 - val_root_mean_squared_error: 2349.4653
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.0045 - gamma_log_likelihood: 2.0023 - root_mean_squared_error: 2085.6089 - val_loss: 2.2852 - val_gamma_log_likelihood: 2.2484 - val_root_mean_squared_error: 2343.7896
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.0100 - gamma_log_likelihood: 2.0079 - root_mean_squared_error: 2083.4822 - val_loss: 2.2845 - val_gamma_log_likelihood: 2.2517 - val_root_mean_squared_error: 2346.3638
# Epoch 15/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0149 - gamma_log_likelihood: 2.0135 - root_mean_squared_error: 2066.1443 - val_loss: 2.2886 - val_gamma_log_likelihood: 2.2803 - val_root_mean_squared_error: 2358.9109
# Epoch 16/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0218 - gamma_log_likelihood: 2.0197 - root_mean_squared_error: 2096.3733 - val_loss: 2.3901 - val_gamma_log_likelihood: 2.3183 - val_root_mean_squared_error: 2375.1223
# Epoch 17/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0054 - gamma_log_likelihood: 2.0044 - root_mean_squared_error: 2067.2673 - val_loss: 2.3151 - val_gamma_log_likelihood: 2.2873 - val_root_mean_squared_error: 2369.3970
# Epoch 18/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9960 - gamma_log_likelihood: 1.9948 - root_mean_squared_error: 2058.8628 - val_loss: 2.3040 - val_gamma_log_likelihood: 2.2810 - val_root_mean_squared_error: 2356.8218
# Epoch 19/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0064 - gamma_log_likelihood: 2.0055 - root_mean_squared_error: 2081.8479 - val_loss: 2.3262 - val_gamma_log_likelihood: 2.2557 - val_root_mean_squared_error: 2359.8677
# Epoch 20/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9868 - gamma_log_likelihood: 1.9846 - root_mean_squared_error: 2059.2495 - val_loss: 2.4509 - val_gamma_log_likelihood: 2.2724 - val_root_mean_squared_error: 2357.6064
# Epoch 21/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9995 - gamma_log_likelihood: 1.9971 - root_mean_squared_error: 2079.1863 - val_loss: 2.4752 - val_gamma_log_likelihood: 2.3198 - val_root_mean_squared_error: 2374.0474
# Epoch 22/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9883 - gamma_log_likelihood: 1.9869 - root_mean_squared_error: 2051.1533 - val_loss: 2.4621 - val_gamma_log_likelihood: 2.3101 - val_root_mean_squared_error: 2365.5269
# Epoch 23/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9974 - gamma_log_likelihood: 1.9957 - root_mean_squared_error: 2081.7375 - val_loss: 2.4044 - val_gamma_log_likelihood: 2.2628 - val_root_mean_squared_error: 2356.0642
# Epoch 24/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9776 - gamma_log_likelihood: 1.9754 - root_mean_squared_error: 2041.3087 - val_loss: 2.3123 - val_gamma_log_likelihood: 2.1970 - val_root_mean_squared_error: 2322.6348
# 1/1 [==============================] - 0s 16ms/step - loss: 2.2856 - gamma_log_likelihood: 2.2518 - root_mean_squared_error: 2346.3638

# %%
# -------------------------- plot the validation loss --------------------------
# Convert interaction loss dictionary to a pandas DataFrame
interaction_df = pd.DataFrame(list(interaction_loss.items()), columns = ['Interaction_Pair', 'Validation_Loss'])

# Sort the DataFrame by Validation_Loss in increasing order
interaction_df = interaction_df.sort_values(by = 'Validation_Loss', ascending = True)

# Create the bar plot using Seaborn
plt.figure(figsize = (20, 12))
sns.lineplot(x = 'Interaction_Pair', y = 'Validation_Loss', data = interaction_df, marker = 'o')
plt.axhline(main_val_loss, color = 'red', linestyle = '--', label = 'Validation Loss of Main Effect Model')
plt.xlabel('Interaction Effect Pairs')
plt.ylabel('Validation Loss')
plt.title('Validation Loss for Interaction Effect Pairs (Sorted by Increasing Loss)')
plt.legend()
plt.show()

# %%
# # -------------------------- Create the Pairwise Only Model --------------------------
# # pairwise_effect = ("X3", "X4")  # the pairwise effect we want to view
# pairwise_effect = interactions[0]
# pairwise_index = interactions.index(pairwise_effect)
# subnet_output_layer = model_pairwise.get_layer("interaction_output")
# subnet_model = Model(inputs = model_pairwise.inputs, outputs = subnet_output_layer.output)


# # -------------------------- Generate the Input Grid --------------------------
# # Create a grid of values
# grid_length = 100
# var1_values = np.linspace(X_train[interactions[pairwise_index][0]].min(), 
#                           X_train[interactions[pairwise_index][0]].max(), 
#                           grid_length)
# var2_values = np.linspace(X_train[interactions[pairwise_index][1]].min(), 
#                           X_train[interactions[pairwise_index][1]].max(), 
#                           grid_length)

# # Create a meshgrid
# grid_var1, grid_var2 = np.meshgrid(var1_values, var2_values)

# # Flatten the grid
# grid_flat_var1 = grid_var1.ravel()
# grid_flat_var2 = grid_var2.ravel()


# # -------------------------- Prepare Inputs for the Model --------------------------
# grid_inputs = []
# for var in all_vars:
#     if var == interactions[pairwise_index][0]:
#         grid_inputs.append(grid_flat_var1)
#     elif var == interactions[pairwise_index][1]:
#         grid_inputs.append(grid_flat_var2)
#     else:
#         grid_inputs.append(np.zeros_like(grid_flat_var1))


# # -------------------------- Predict Using the Pairwise-Only Model --------------------------
# # Predict the pairwise interaction effect
# pairwise_predictions = np.log(subnet_model.predict(grid_inputs))

# # Reshape the predictions to the grid format
# heatmap_values = pairwise_predictions.reshape(grid_var1.shape)


# # -------------------------- Plot the Heatmap --------------------------
# plt.figure(figsize = (10, 8))
# contour = plt.contourf(grid_var1, grid_var2, heatmap_values, levels = 10)
# plt.colorbar(contour)
# plt.title('Predicted Function by the Model')
# plt.xlabel(f"{interactions[pairwise_index][0]}")
# plt.ylabel(f"{interactions[pairwise_index][1]}")
# plt.show()

# %%
# #-------------------------- view the shape function --------------------------
# # get the prediction
# main_output_layer = model_pairwise.get_layer("main_subnet")
# subnet_model = Model(inputs = model_pairwise.inputs, outputs = main_output_layer.output)
# subnet_output = subnet_model.predict(X_train_split)

# # create the plot
# var_name = "X3"
# var_index = all_vars.index(var_name)
# plt.figure(figsize = (12, 6))
# sns.lineplot(x = X_train_split[var_index], 
#              y = subnet_output[:,var_index])
# plt.xlabel(f"{var_name}")
# plt.ylabel('Subnetwork Output')
# plt.title(f"Shape function for {var_name}")
# plt.grid(True)
# plt.show()
