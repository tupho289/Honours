# %%
############################ 0. PREPARATION ############################

#-------------------------- import packages --------------------------
import random
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from itertools import combinations
import seaborn as sns
import copy
import itertools

import tensorflow as tf
import tensorflow_lattice as tfl
import tf_keras as keras # need keras 2 to fit Lattice model
from tf_keras.models import Sequential, Model
from tf_keras.layers import Dense, Input, Multiply, Add, Embedding, Reshape, Concatenate, Dropout, BatchNormalization, Lambda, Layer, CategoryEncoding, Activation
from tf_keras.constraints import Constraint
from tf_keras.callbacks import EarlyStopping
from tf_keras.initializers import Zeros, Constant
from tf_keras.optimizers import Adam, Nadam, RMSprop
from tf_keras.models import clone_model
import keras_tuner as kt
from tf_keras import backend as K
from tf_keras import regularizers
from tf_keras.utils import plot_model
from tf_keras.losses import Poisson, Loss
from tf_keras.metrics import MeanAbsoluteError, RootMeanSquaredError
from scipy.stats import gamma


from pygam import LinearGAM, GAM, s, f, l
from sklearn.linear_model import ElasticNet
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error as mae
from sklearn.tree import DecisionTreeRegressor
from interpret.glassbox import ExplainableBoostingClassifier

# %%
#-------------------------- for reproducibility --------------------------
seed_value = 2024
keras.utils.set_random_seed(seed_value)

# %%
#-------------------------- import data --------------------------
data = pd.read_csv("synthetic_low_var.csv")

# %%
#-------------------------- remove outliers --------------------------
log_claim = np.log(data['Y'])
IQR = log_claim.quantile(0.75) - log_claim.quantile(0.25) # inter-quartile range
lower_whisker = log_claim.quantile(0.25)- 1.5*IQR
upper_whisker = log_claim.quantile(0.75) + 1.5*IQR

# remove outliers: filter rows where the log of 'Y' is within the whiskers
dt_cleaned = data[(log_claim >= lower_whisker) & (log_claim <= upper_whisker)]
dt_cleaned
# Out:
#              X1        X2        X3        X4        X5        X6        X7  \
# 0      0.097627 -0.384709  0.070514  0.245303 -0.564460 -0.450318  0.531209
# 1      0.430379 -0.875990  0.808088  0.648436  0.174499 -0.765558 -0.898927
# 2      0.205527  0.977570  0.004793 -0.431433  0.975227  0.473320  0.995090
# 3      0.089766  0.438181 -0.798260  0.756793  0.901734  0.431272 -0.864656
# 4     -0.152690  0.515139  0.055164  0.282328 -0.314057  0.639535 -0.581069
# ...         ...       ...       ...       ...       ...       ...       ...
# 49995  0.092658  0.451842  0.805609 -0.262674  0.758215 -0.205461  0.443849
# 49996  0.386621  0.015041 -0.538708 -0.389854 -0.632906 -0.311577  0.027367
# 49997 -0.532650  0.620266  0.162028 -0.570751  0.005453  0.235543  0.099723
# 49998  0.661848  0.102065 -0.526136 -0.408447  0.373860 -0.328123  0.756798
# 49999  0.102636 -0.548488 -0.907552  0.685008 -0.631395  0.158764 -0.255068
#
#              X8        X9       X10             Y
# 0     -0.139983 -0.999956  0.009359    317.866963
# 1     -0.168761  0.081209 -0.263657     78.581657
# 2      0.794291 -0.802390 -0.861454    516.366318
# 3      0.512576  0.085770 -0.545924  17229.567290
# 4      0.940797 -0.261984 -0.425629    200.194269
# ...         ...       ...       ...           ...
# 49995 -0.978784  0.740276  0.645713     55.754110
# 49996 -0.845545  0.010439  0.868084      8.951832
# 49997  0.663875  0.851769  0.066433      9.645558
# 49998 -0.514888  0.618938  0.761628   1447.660375
# 49999 -0.854587 -0.912670 -0.468766   6162.639458
#
# [49557 rows x 11 columns]

# %%
#-------------------------- distribution of log(response) --------------------------
plt.figure(figsize = (10, 6)) # set the size of the figure
sns.set_style("darkgrid")
sns.histplot(np.log(dt_cleaned['Y']), bins = 30, kde = True) # draw the chart
plt.title('Distribution of log(Y)')
plt.xlabel('Log(Y)')
plt.ylabel('Frequency')
plt.tick_params(axis = 'x')
plt.tick_params(axis = 'y')
plt.grid(True)
plt.show()

# %%
#-------------------------- column lists --------------------------
target_var = "Y" # target feature
all_vars = list(dt_cleaned.columns)
all_vars.remove(target_var) # store all input features
cat_vars = [] # categorical features

# %%
############################ 1. MAIN EFFECT SELECTION ############################

#-------------------------- train-test split --------------------------
X_main, X_test, y_main, y_test = train_test_split(
    dt_cleaned[all_vars], dt_cleaned[["Y"]], test_size = 0.2, random_state = 1)
X_train, X_val, y_train, y_val  = train_test_split(
    X_main, y_main, test_size = 0.25, random_state = 1)

# %%
# -------------------------- function to create a subnetwork --------------------------
# subnet for numerical variables
def create_subnet(num_layers, units_first_layer, activation, model_name, dropout_rate = 0, trainable = True, seed = 1):
    model = Sequential(name = model_name)
    for i in range(num_layers):
        num_units = units_first_layer - i*int(units_first_layer/num_layers)
        model.add(Dense(num_units, activation = activation, trainable = trainable))
        model.add(Dropout(dropout_rate, seed = seed))
    model.add(Dense(1, trainable = trainable))
    model.add(BatchNormalization(scale = False)) # for identifiability
    return model

# %%
# -------------------------- custom loss function --------------------------
def gamma_nll(y_true, y_pred):
    y_pred = K.clip(y_pred, 1e-7, 1e30)
    return K.mean(y_true/y_pred - K.log(y_true/y_pred))

# %%
#-------------------------- prepare the data for NAM --------------------------
X_train_split = []
X_val_split = []
for i in range(X_train.shape[1]):
    X_train_split.append(X_train.iloc[:, i])
    X_val_split.append(X_val.iloc[:, i])

# %%
# -------------------------- Fit an ensemble of 10 NAMs --------------------------
seed = 0
num_models = 10
all_variance = []

# create ensemble and get subnet variance
for i in range(num_models):
    
    keras.utils.set_random_seed(seed)

    # -------------------------- define model architecture --------------------------
    inputs = []  # input layers
    sub_outputs_main = []  # main effect subnet output
    num_neurons_main = 20
    num_layers_main = 2
    activation = 'leaky_relu'
    keypoints = 10
    monotonicity_list = {"X3" : "decreasing"} # either "increasing", "decreasing", or "none"

    # main effect
    for name in all_vars:

        # input layer
        input_layer = Input(shape = (1,), name = name)
        inputs.append(input_layer)

        # subnetworks for main effects
        if name in cat_vars: # categorical variables
            # categorical variables will be one-hot encoded
            embed_layer = Embedding(input_dim = X_train[name].nunique(), 
                                    output_dim = 1, 
                                    name = f"{name}_embed")(input_layer)
            embed_layer_reshape = Reshape(target_shape = (1,), name = f"{name}_reshape")(embed_layer)
            mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(embed_layer_reshape)
            sub_outputs_main.append(mean_layer)
        elif name in monotonicity_list: # variables with monotonicity constraint
            calibrator_layer = tfl.layers.PWLCalibration(
                input_keypoints =  np.linspace(X_train[name].min(), X_train[name].max(), num = keypoints), # keypoints
                monotonicity = monotonicity_list[name], # monotonicity constraint
                name = f"{name}_pwlcalibrator"
            )(input_layer)
            mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(calibrator_layer)
            sub_outputs_main.append(mean_layer)
        else: # numeric variables
            subnet = create_subnet(num_layers_main, num_neurons_main, activation, f"{name}_subnetwork")
            sub_output = subnet(input_layer)
            sub_outputs_main.append(sub_output)

    # combine subnets' outputs and create model
    main_subnets = Concatenate(name = "main_subnet")(sub_outputs_main)
    final_output = Dense(1, activation = "exponential", name = "main_output")(main_subnets)
    model_all_vars = Model(inputs = inputs, outputs = final_output)

    # -------------------------- fit the model --------------------------
    model_all_vars.compile(optimizer = "adam", loss = gamma_nll, metrics = [RootMeanSquaredError(), MeanAbsoluteError()])
    es = EarlyStopping(restore_best_weights = True, patience = 10)
    model_all_vars.fit(X_train_split, y_train, epochs = 5_000, \
        callbacks = [es], batch_size = 5_000, validation_data = (X_val_split, y_val), verbose = 0)
    

    # -------------------------- quantify variable importance --------------------------
    main_output_layer = model_all_vars.get_layer("main_subnet")  # Get the subnet output layer
    main_model = Model(inputs = model_all_vars.inputs, outputs = main_output_layer.output)
    main_output_values = main_model.predict(X_train_split, batch_size = 5_000)

    # Get the variance of each subnetwork across all data points
    subnet_weights = model_all_vars.get_layer("main_output").get_weights()[0]
    subnet_variance = [np.var(main_output_values[:, i])*subnet_weights[i][0]**2 for i in range(main_output_values.shape[1])]
    all_variance.append(subnet_variance)

    # update seed
    seed += 1
# Out:
# 6/6 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 7ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 5ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 4ms/step

# %%
# -------------------------- plot the variable importance --------------------------
average_variances = np.mean(all_variance, axis = 0) # get the average variance

# Create DataFrame for variable importance
var_importance = pd.DataFrame({"Covariates": all_vars, "Subnet Variance": average_variances})

# Sort the DataFrame by subnet variance in decreasing order
varimp_sorted = var_importance.sort_values(by = "Subnet Variance", ascending = False)

# Create a bar plot using Seaborn
# plt.figure(figsize = (8, 6))
sns.barplot(x = "Covariates", y = "Subnet Variance", data = varimp_sorted)
plt.title("Subnet Variance - Low Noise")
plt.xlabel("")
plt.ylabel("")

plt.rcParams["figure.figsize"] = (5, 2) # (for square figures)
plt.rcParams["figure.dpi"] = 350
plt.rcParams["savefig.bbox"] = "tight"
plt.rcParams["font.family"] = "serif"
plt.rcParams["axes.spines.right"] = False
plt.rcParams["axes.spines.top"] = False

plt.show()

# %%
#-------------------------- reset keras seed --------------------------
keras.utils.set_random_seed(seed_value)

# %%
############################ 1. MODEL FITTING ############################

# extract important variables
imp_vars = [f"X{i}" for i in range(1,9)]

#-------------------------- train-test split --------------------------
X_main, X_test, y_main, y_test = train_test_split(
    dt_cleaned[imp_vars], dt_cleaned[["Y"]], test_size = 0.2, random_state = 1)
X_train, X_val, y_train, y_val  = train_test_split(
    X_main, y_main, test_size = 0.25, random_state = 1)

# %%
# -------------------------- define model architecture --------------------------
inputs = []  # input layers
sub_outputs_main = []  # main effect subnet output
num_neurons_main = 20
num_layers_main = 2
activation = 'leaky_relu'
keypoints = 10
monotonicity_list = {"X3" : "decreasing"} # either "increasing", "decreasing", or "none"

# main effect
for name in imp_vars:
    input_layer = Input(shape = (1,), name = name)
    inputs.append(input_layer)

    # subnetworks for main effects
    if name in cat_vars: # categorical variables
        # categorical variables will be one-hot encoded
        embed_layer = Embedding(input_dim = X_train[name].nunique(), 
                                output_dim = 1, 
                                name = f"{name}_embed")(input_layer)
        embed_layer_reshape = Reshape(target_shape = (1,), name = f"{name}_reshape")(embed_layer)
        mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(embed_layer_reshape)
        sub_outputs_main.append(mean_layer)
    elif name in monotonicity_list: # variables with monotonicity constraint
        calibrator_layer = tfl.layers.PWLCalibration(
            input_keypoints =  np.linspace(X_train[name].min(), X_train[name].max(), num = keypoints), # keypoints
            monotonicity = monotonicity_list[name], # monotonicity constraint
            name = f"{name}_pwlcalibrator"
        )(input_layer)
        mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(calibrator_layer)
        sub_outputs_main.append(mean_layer)
    else: # numeric variables
        subnet = create_subnet(num_layers_main, num_neurons_main, activation, f"{name}_subnetwork")
        sub_output = subnet(input_layer)
        sub_outputs_main.append(sub_output)

# combine subnets' outputs
main_subnets = Concatenate(name = "main_subnet")(sub_outputs_main)
final_output = Dense(1, activation = "exponential", name = "main_output")(main_subnets)

# final model
model_main_effect = Model(inputs = inputs, outputs = final_output)

# %%
# -------------------------- compile and fit --------------------------
# create training & validation data consistent with the model architecture
X_train_split = []
X_val_split = []
X_test_split = []
for i in range(len(X_train.columns)):
    X_train_split.append(X_train.iloc[:, i])
    X_val_split.append(X_val.iloc[:, i])
    X_test_split.append(X_test.iloc[:, i])

# compile and fit
model_main_effect.compile(optimizer = "adam", loss = gamma_nll, metrics = [RootMeanSquaredError()])
es = EarlyStopping(restore_best_weights = True, patience = 20)
# %time hist_main = model_main_effect.fit(X_train_split, y_train, epochs = 5_000, \
    callbacks = [es], batch_size = 1_000, validation_data = (X_val_split, y_val))
# Out:
# Epoch 1/5000
# 30/30 [==============================] - 1s 11ms/step - loss: 1418.6163 - root_mean_squared_error: 2690.1201 - val_loss: 631.8301 - val_root_mean_squared_error: 2589.9741
# Epoch 2/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 802.7068 - root_mean_squared_error: 2690.2922 - val_loss: 654.5873 - val_root_mean_squared_error: 2589.9910
# Epoch 3/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 631.1340 - root_mean_squared_error: 2690.3179 - val_loss: 588.2626 - val_root_mean_squared_error: 2589.9446
# Epoch 4/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 566.0699 - root_mean_squared_error: 2690.2693 - val_loss: 545.1439 - val_root_mean_squared_error: 2589.9084
# Epoch 5/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 507.2028 - root_mean_squared_error: 2690.2009 - val_loss: 488.0994 - val_root_mean_squared_error: 2589.8503
# Epoch 6/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 458.7532 - root_mean_squared_error: 2690.1150 - val_loss: 440.9303 - val_root_mean_squared_error: 2589.7913
# Epoch 7/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 404.0211 - root_mean_squared_error: 2690.0232 - val_loss: 407.8191 - val_root_mean_squared_error: 2589.7412
# Epoch 8/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 359.6587 - root_mean_squared_error: 2689.9089 - val_loss: 375.2610 - val_root_mean_squared_error: 2589.6829
# Epoch 9/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 317.7785 - root_mean_squared_error: 2689.7715 - val_loss: 331.9658 - val_root_mean_squared_error: 2589.5879
# Epoch 10/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 282.1382 - root_mean_squared_error: 2689.6033 - val_loss: 308.2275 - val_root_mean_squared_error: 2589.5249
# Epoch 11/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 247.4344 - root_mean_squared_error: 2689.4348 - val_loss: 266.2922 - val_root_mean_squared_error: 2589.3840
# Epoch 12/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 218.0293 - root_mean_squared_error: 2689.2322 - val_loss: 239.6918 - val_root_mean_squared_error: 2589.2661
# Epoch 13/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 191.7513 - root_mean_squared_error: 2688.9949 - val_loss: 217.1047 - val_root_mean_squared_error: 2589.1411
# Epoch 14/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 170.2533 - root_mean_squared_error: 2688.7363 - val_loss: 191.6295 - val_root_mean_squared_error: 2588.9624
# Epoch 15/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 151.2472 - root_mean_squared_error: 2688.4421 - val_loss: 170.0835 - val_root_mean_squared_error: 2588.7546
# Epoch 16/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 134.9540 - root_mean_squared_error: 2688.0820 - val_loss: 162.7789 - val_root_mean_squared_error: 2588.6638
# Epoch 17/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 120.7348 - root_mean_squared_error: 2687.7202 - val_loss: 134.9516 - val_root_mean_squared_error: 2588.2424
# Epoch 18/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 108.1527 - root_mean_squared_error: 2687.2883 - val_loss: 124.7027 - val_root_mean_squared_error: 2588.0461
# Epoch 19/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 97.3479 - root_mean_squared_error: 2686.7786 - val_loss: 102.2358 - val_root_mean_squared_error: 2587.4895
# Epoch 20/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 87.9418 - root_mean_squared_error: 2686.3933 - val_loss: 78.8140 - val_root_mean_squared_error: 2586.4678
# Epoch 21/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 79.4331 - root_mean_squared_error: 2685.7908 - val_loss: 69.0712 - val_root_mean_squared_error: 2585.8203
# Epoch 22/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 72.1847 - root_mean_squared_error: 2685.2759 - val_loss: 62.0109 - val_root_mean_squared_error: 2585.1775
# Epoch 23/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 65.4868 - root_mean_squared_error: 2684.6929 - val_loss: 59.3114 - val_root_mean_squared_error: 2584.8174
# Epoch 24/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 59.8226 - root_mean_squared_error: 2683.9587 - val_loss: 61.9053 - val_root_mean_squared_error: 2584.8447
# Epoch 25/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 54.6968 - root_mean_squared_error: 2683.2861 - val_loss: 49.6319 - val_root_mean_squared_error: 2583.3494
# Epoch 26/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 50.1403 - root_mean_squared_error: 2682.4766 - val_loss: 52.6061 - val_root_mean_squared_error: 2583.4363
# Epoch 27/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 46.2280 - root_mean_squared_error: 2681.7468 - val_loss: 47.6040 - val_root_mean_squared_error: 2582.4478
# Epoch 28/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 42.4334 - root_mean_squared_error: 2680.8928 - val_loss: 44.8351 - val_root_mean_squared_error: 2582.3359
# Epoch 29/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 39.1615 - root_mean_squared_error: 2680.1365 - val_loss: 41.2958 - val_root_mean_squared_error: 2581.3733
# Epoch 30/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 36.2266 - root_mean_squared_error: 2679.1367 - val_loss: 40.7485 - val_root_mean_squared_error: 2581.0469
# Epoch 31/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 33.4769 - root_mean_squared_error: 2678.4019 - val_loss: 39.2734 - val_root_mean_squared_error: 2580.9343
# Epoch 32/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 31.0607 - root_mean_squared_error: 2677.2183 - val_loss: 38.8627 - val_root_mean_squared_error: 2580.8267
# Epoch 33/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 28.9250 - root_mean_squared_error: 2676.4336 - val_loss: 42.0590 - val_root_mean_squared_error: 2581.3630
# Epoch 34/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 26.9134 - root_mean_squared_error: 2675.5029 - val_loss: 37.9106 - val_root_mean_squared_error: 2580.3186
# Epoch 35/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 25.0926 - root_mean_squared_error: 2674.6348 - val_loss: 33.2950 - val_root_mean_squared_error: 2579.1125
# Epoch 36/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 23.4104 - root_mean_squared_error: 2673.6667 - val_loss: 26.8638 - val_root_mean_squared_error: 2576.6885
# Epoch 37/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 21.9462 - root_mean_squared_error: 2672.6353 - val_loss: 25.8365 - val_root_mean_squared_error: 2575.9653
# Epoch 38/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 20.6242 - root_mean_squared_error: 2671.4375 - val_loss: 26.2467 - val_root_mean_squared_error: 2576.0601
# Epoch 39/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 19.3546 - root_mean_squared_error: 2670.1833 - val_loss: 23.7549 - val_root_mean_squared_error: 2574.6118
# Epoch 40/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 18.2548 - root_mean_squared_error: 2668.9980 - val_loss: 22.3861 - val_root_mean_squared_error: 2573.6101
# Epoch 41/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 17.1682 - root_mean_squared_error: 2667.5139 - val_loss: 20.2352 - val_root_mean_squared_error: 2571.9512
# Epoch 42/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 16.2127 - root_mean_squared_error: 2666.4294 - val_loss: 19.0693 - val_root_mean_squared_error: 2570.7913
# Epoch 43/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 15.3126 - root_mean_squared_error: 2664.9214 - val_loss: 18.2221 - val_root_mean_squared_error: 2570.0330
# Epoch 44/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 14.5080 - root_mean_squared_error: 2663.7053 - val_loss: 16.7900 - val_root_mean_squared_error: 2568.0312
# Epoch 45/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 13.7355 - root_mean_squared_error: 2662.1404 - val_loss: 14.8657 - val_root_mean_squared_error: 2565.7134
# Epoch 46/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 13.0298 - root_mean_squared_error: 2660.8845 - val_loss: 15.0689 - val_root_mean_squared_error: 2566.3176
# Epoch 47/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 12.3567 - root_mean_squared_error: 2659.3315 - val_loss: 14.2071 - val_root_mean_squared_error: 2564.7134
# Epoch 48/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 11.7903 - root_mean_squared_error: 2657.2090 - val_loss: 14.0949 - val_root_mean_squared_error: 2564.6514
# Epoch 49/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 11.2149 - root_mean_squared_error: 2656.2952 - val_loss: 13.6580 - val_root_mean_squared_error: 2563.3347
# Epoch 50/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 10.6868 - root_mean_squared_error: 2655.0249 - val_loss: 12.9442 - val_root_mean_squared_error: 2562.5393
# Epoch 51/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 10.1990 - root_mean_squared_error: 2652.9827 - val_loss: 11.5377 - val_root_mean_squared_error: 2558.8254
# Epoch 52/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 9.7512 - root_mean_squared_error: 2651.3604 - val_loss: 11.3301 - val_root_mean_squared_error: 2558.2905
# Epoch 53/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 9.3248 - root_mean_squared_error: 2649.4070 - val_loss: 11.2850 - val_root_mean_squared_error: 2557.8684
# Epoch 54/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 8.9395 - root_mean_squared_error: 2647.6074 - val_loss: 9.7428 - val_root_mean_squared_error: 2553.6914
# Epoch 55/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 8.5809 - root_mean_squared_error: 2645.8157 - val_loss: 8.7599 - val_root_mean_squared_error: 2550.0522
# Epoch 56/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 8.2469 - root_mean_squared_error: 2643.9744 - val_loss: 8.8225 - val_root_mean_squared_error: 2549.4829
# Epoch 57/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 7.9032 - root_mean_squared_error: 2641.9697 - val_loss: 8.1566 - val_root_mean_squared_error: 2546.6243
# Epoch 58/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 7.6119 - root_mean_squared_error: 2640.0537 - val_loss: 8.1523 - val_root_mean_squared_error: 2546.1453
# Epoch 59/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 7.3308 - root_mean_squared_error: 2638.2224 - val_loss: 8.0880 - val_root_mean_squared_error: 2545.5625
# Epoch 60/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 7.0805 - root_mean_squared_error: 2636.6758 - val_loss: 7.4473 - val_root_mean_squared_error: 2541.6406
# Epoch 61/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 6.8300 - root_mean_squared_error: 2633.2651 - val_loss: 6.4530 - val_root_mean_squared_error: 2534.2095
# Epoch 62/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 6.5860 - root_mean_squared_error: 2632.2200 - val_loss: 6.5737 - val_root_mean_squared_error: 2534.4875
# Epoch 63/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 6.3746 - root_mean_squared_error: 2629.0449 - val_loss: 6.6165 - val_root_mean_squared_error: 2535.1462
# Epoch 64/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 6.1581 - root_mean_squared_error: 2627.9414 - val_loss: 6.4382 - val_root_mean_squared_error: 2533.7114
# Epoch 65/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 5.9675 - root_mean_squared_error: 2624.8223 - val_loss: 6.5623 - val_root_mean_squared_error: 2534.9485
# Epoch 66/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 5.7856 - root_mean_squared_error: 2622.9888 - val_loss: 6.0131 - val_root_mean_squared_error: 2529.3645
# Epoch 67/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 5.6103 - root_mean_squared_error: 2620.5059 - val_loss: 5.5086 - val_root_mean_squared_error: 2523.5400
# Epoch 68/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 5.4417 - root_mean_squared_error: 2618.4114 - val_loss: 5.2991 - val_root_mean_squared_error: 2519.9751
# Epoch 69/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 5.3022 - root_mean_squared_error: 2615.5813 - val_loss: 5.2165 - val_root_mean_squared_error: 2519.5813
# Epoch 70/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 5.1557 - root_mean_squared_error: 2613.8440 - val_loss: 5.0488 - val_root_mean_squared_error: 2516.0166
# Epoch 71/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 5.0158 - root_mean_squared_error: 2611.1147 - val_loss: 5.1131 - val_root_mean_squared_error: 2517.8308
# Epoch 72/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 4.8896 - root_mean_squared_error: 2609.1289 - val_loss: 4.9072 - val_root_mean_squared_error: 2512.9861
# Epoch 73/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 4.7637 - root_mean_squared_error: 2606.8989 - val_loss: 4.7658 - val_root_mean_squared_error: 2510.9705
# Epoch 74/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 4.6554 - root_mean_squared_error: 2604.0820 - val_loss: 4.3782 - val_root_mean_squared_error: 2503.9514
# Epoch 75/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 4.5438 - root_mean_squared_error: 2601.3518 - val_loss: 4.2981 - val_root_mean_squared_error: 2502.2190
# Epoch 76/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 4.4452 - root_mean_squared_error: 2599.8328 - val_loss: 4.2020 - val_root_mean_squared_error: 2498.8323
# Epoch 77/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 4.3508 - root_mean_squared_error: 2596.8933 - val_loss: 4.1335 - val_root_mean_squared_error: 2497.5491
# Epoch 78/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 4.2605 - root_mean_squared_error: 2594.2249 - val_loss: 4.0441 - val_root_mean_squared_error: 2493.3948
# Epoch 79/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 4.1638 - root_mean_squared_error: 2591.7578 - val_loss: 3.9860 - val_root_mean_squared_error: 2492.8938
# Epoch 80/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 4.0897 - root_mean_squared_error: 2589.5725 - val_loss: 3.9769 - val_root_mean_squared_error: 2491.6487
# Epoch 81/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 4.0004 - root_mean_squared_error: 2586.4338 - val_loss: 4.0156 - val_root_mean_squared_error: 2493.9973
# Epoch 82/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 3.9251 - root_mean_squared_error: 2584.8169 - val_loss: 3.8434 - val_root_mean_squared_error: 2488.4370
# Epoch 83/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 3.8607 - root_mean_squared_error: 2582.1074 - val_loss: 3.9178 - val_root_mean_squared_error: 2490.4153
# Epoch 84/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 3.7924 - root_mean_squared_error: 2579.8853 - val_loss: 4.0080 - val_root_mean_squared_error: 2492.7642
# Epoch 85/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 3.7273 - root_mean_squared_error: 2577.0076 - val_loss: 3.8158 - val_root_mean_squared_error: 2487.0979
# Epoch 86/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 3.6696 - root_mean_squared_error: 2574.0645 - val_loss: 3.9649 - val_root_mean_squared_error: 2492.2034
# Epoch 87/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 3.6147 - root_mean_squared_error: 2571.6089 - val_loss: 3.8296 - val_root_mean_squared_error: 2488.1855
# Epoch 88/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 3.5547 - root_mean_squared_error: 2570.1699 - val_loss: 3.6018 - val_root_mean_squared_error: 2479.5813
# Epoch 89/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 3.5000 - root_mean_squared_error: 2566.9451 - val_loss: 3.5305 - val_root_mean_squared_error: 2476.6846
# Epoch 90/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 3.4533 - root_mean_squared_error: 2565.0464 - val_loss: 3.4636 - val_root_mean_squared_error: 2472.8259
# Epoch 91/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 3.4044 - root_mean_squared_error: 2560.7432 - val_loss: 3.4670 - val_root_mean_squared_error: 2472.0298
# Epoch 92/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 3.3631 - root_mean_squared_error: 2559.3965 - val_loss: 3.4185 - val_root_mean_squared_error: 2472.2913
# Epoch 93/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 3.3177 - root_mean_squared_error: 2557.6963 - val_loss: 3.3161 - val_root_mean_squared_error: 2465.7056
# Epoch 94/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 3.2774 - root_mean_squared_error: 2554.0632 - val_loss: 3.3422 - val_root_mean_squared_error: 2467.6475
# Epoch 95/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 3.2431 - root_mean_squared_error: 2552.7175 - val_loss: 3.2548 - val_root_mean_squared_error: 2462.6646
# Epoch 96/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 3.2006 - root_mean_squared_error: 2549.8975 - val_loss: 3.1835 - val_root_mean_squared_error: 2458.3433
# Epoch 97/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 3.1695 - root_mean_squared_error: 2546.9121 - val_loss: 3.1626 - val_root_mean_squared_error: 2457.5996
# Epoch 98/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 3.1370 - root_mean_squared_error: 2546.6230 - val_loss: 3.1501 - val_root_mean_squared_error: 2455.2603
# Epoch 99/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 3.1034 - root_mean_squared_error: 2542.4546 - val_loss: 3.0786 - val_root_mean_squared_error: 2451.9639
# Epoch 100/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 3.0748 - root_mean_squared_error: 2540.5134 - val_loss: 3.1148 - val_root_mean_squared_error: 2454.1670
# Epoch 101/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 3.0446 - root_mean_squared_error: 2538.3755 - val_loss: 3.0723 - val_root_mean_squared_error: 2451.3411
# Epoch 102/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 3.0208 - root_mean_squared_error: 2535.2000 - val_loss: 3.0128 - val_root_mean_squared_error: 2446.2551
# Epoch 103/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.9925 - root_mean_squared_error: 2534.6375 - val_loss: 3.0147 - val_root_mean_squared_error: 2446.9575
# Epoch 104/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.9662 - root_mean_squared_error: 2530.6628 - val_loss: 2.9916 - val_root_mean_squared_error: 2445.2310
# Epoch 105/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.9456 - root_mean_squared_error: 2529.2568 - val_loss: 2.9238 - val_root_mean_squared_error: 2439.7998
# Epoch 106/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.9228 - root_mean_squared_error: 2526.9731 - val_loss: 2.8818 - val_root_mean_squared_error: 2435.8557
# Epoch 107/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.9019 - root_mean_squared_error: 2525.2112 - val_loss: 2.8913 - val_root_mean_squared_error: 2437.3025
# Epoch 108/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.8831 - root_mean_squared_error: 2523.2861 - val_loss: 2.8631 - val_root_mean_squared_error: 2435.0408
# Epoch 109/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.8616 - root_mean_squared_error: 2522.8572 - val_loss: 2.8424 - val_root_mean_squared_error: 2432.3987
# Epoch 110/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.8440 - root_mean_squared_error: 2518.7219 - val_loss: 2.8736 - val_root_mean_squared_error: 2435.9094
# Epoch 111/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.8290 - root_mean_squared_error: 2517.5061 - val_loss: 2.8484 - val_root_mean_squared_error: 2433.3943
# Epoch 112/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.8094 - root_mean_squared_error: 2514.3315 - val_loss: 2.8390 - val_root_mean_squared_error: 2431.9197
# Epoch 113/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.7962 - root_mean_squared_error: 2513.6252 - val_loss: 2.7834 - val_root_mean_squared_error: 2425.5391
# Epoch 114/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.7810 - root_mean_squared_error: 2512.2312 - val_loss: 2.7624 - val_root_mean_squared_error: 2424.9688
# Epoch 115/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.7673 - root_mean_squared_error: 2509.8337 - val_loss: 2.7253 - val_root_mean_squared_error: 2420.9473
# Epoch 116/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.7532 - root_mean_squared_error: 2507.9954 - val_loss: 2.7426 - val_root_mean_squared_error: 2423.0310
# Epoch 117/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.7389 - root_mean_squared_error: 2506.0737 - val_loss: 2.7230 - val_root_mean_squared_error: 2419.8704
# Epoch 118/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.7300 - root_mean_squared_error: 2505.3674 - val_loss: 2.7119 - val_root_mean_squared_error: 2422.3000
# Epoch 119/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.7170 - root_mean_squared_error: 2504.6311 - val_loss: 2.6890 - val_root_mean_squared_error: 2417.9229
# Epoch 120/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.7088 - root_mean_squared_error: 2501.2969 - val_loss: 2.7053 - val_root_mean_squared_error: 2419.0959
# Epoch 121/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.6960 - root_mean_squared_error: 2500.8857 - val_loss: 2.6766 - val_root_mean_squared_error: 2414.6392
# Epoch 122/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.6884 - root_mean_squared_error: 2499.2722 - val_loss: 2.6965 - val_root_mean_squared_error: 2419.4673
# Epoch 123/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.6804 - root_mean_squared_error: 2498.2478 - val_loss: 2.7197 - val_root_mean_squared_error: 2420.6658
# Epoch 124/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.6687 - root_mean_squared_error: 2496.8770 - val_loss: 2.6942 - val_root_mean_squared_error: 2415.1069
# Epoch 125/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.6621 - root_mean_squared_error: 2495.1074 - val_loss: 2.6576 - val_root_mean_squared_error: 2413.4011
# Epoch 126/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.6527 - root_mean_squared_error: 2494.3923 - val_loss: 2.7015 - val_root_mean_squared_error: 2419.1455
# Epoch 127/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.6447 - root_mean_squared_error: 2491.9343 - val_loss: 2.6831 - val_root_mean_squared_error: 2416.2725
# Epoch 128/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.6403 - root_mean_squared_error: 2491.9976 - val_loss: 2.6564 - val_root_mean_squared_error: 2412.3894
# Epoch 129/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.6319 - root_mean_squared_error: 2490.8030 - val_loss: 2.6624 - val_root_mean_squared_error: 2416.1814
# Epoch 130/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.6270 - root_mean_squared_error: 2489.1211 - val_loss: 2.6734 - val_root_mean_squared_error: 2418.4309
# Epoch 131/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.6243 - root_mean_squared_error: 2487.1597 - val_loss: 2.6532 - val_root_mean_squared_error: 2414.2581
# Epoch 132/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.6152 - root_mean_squared_error: 2488.0242 - val_loss: 2.6712 - val_root_mean_squared_error: 2418.2043
# Epoch 133/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.6108 - root_mean_squared_error: 2487.4128 - val_loss: 2.6478 - val_root_mean_squared_error: 2411.6604
# Epoch 134/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.6019 - root_mean_squared_error: 2484.6167 - val_loss: 2.6395 - val_root_mean_squared_error: 2410.6116
# Epoch 135/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5994 - root_mean_squared_error: 2486.4089 - val_loss: 2.6603 - val_root_mean_squared_error: 2416.5779
# Epoch 136/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5941 - root_mean_squared_error: 2484.1277 - val_loss: 2.6067 - val_root_mean_squared_error: 2408.7549
# Epoch 137/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5903 - root_mean_squared_error: 2483.0969 - val_loss: 2.6258 - val_root_mean_squared_error: 2410.2463
# Epoch 138/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5859 - root_mean_squared_error: 2481.3215 - val_loss: 2.5998 - val_root_mean_squared_error: 2405.6589
# Epoch 139/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5821 - root_mean_squared_error: 2482.2224 - val_loss: 2.6076 - val_root_mean_squared_error: 2409.0364
# Epoch 140/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5784 - root_mean_squared_error: 2481.4109 - val_loss: 2.6050 - val_root_mean_squared_error: 2412.7524
# Epoch 141/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5758 - root_mean_squared_error: 2481.0339 - val_loss: 2.5984 - val_root_mean_squared_error: 2410.1191
# Epoch 142/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5732 - root_mean_squared_error: 2478.2888 - val_loss: 2.6015 - val_root_mean_squared_error: 2406.8079
# Epoch 143/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5691 - root_mean_squared_error: 2479.6462 - val_loss: 2.6222 - val_root_mean_squared_error: 2408.8123
# Epoch 144/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5679 - root_mean_squared_error: 2481.5151 - val_loss: 2.6420 - val_root_mean_squared_error: 2415.0962
# Epoch 145/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5646 - root_mean_squared_error: 2478.0381 - val_loss: 2.5937 - val_root_mean_squared_error: 2405.2158
# Epoch 146/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5625 - root_mean_squared_error: 2480.3030 - val_loss: 2.5924 - val_root_mean_squared_error: 2408.4380
# Epoch 147/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5597 - root_mean_squared_error: 2478.6797 - val_loss: 2.5930 - val_root_mean_squared_error: 2408.8496
# Epoch 148/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5587 - root_mean_squared_error: 2477.7517 - val_loss: 2.5941 - val_root_mean_squared_error: 2411.4241
# Epoch 149/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5563 - root_mean_squared_error: 2479.6511 - val_loss: 2.5794 - val_root_mean_squared_error: 2405.6514
# Epoch 150/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5558 - root_mean_squared_error: 2479.5901 - val_loss: 2.6023 - val_root_mean_squared_error: 2413.6528
# Epoch 151/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5544 - root_mean_squared_error: 2478.6128 - val_loss: 2.5974 - val_root_mean_squared_error: 2426.7310
# Epoch 152/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5523 - root_mean_squared_error: 2477.2434 - val_loss: 2.5879 - val_root_mean_squared_error: 2414.8237
# Epoch 153/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5487 - root_mean_squared_error: 2476.1111 - val_loss: 2.5748 - val_root_mean_squared_error: 2410.1824
# Epoch 154/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5481 - root_mean_squared_error: 2477.7051 - val_loss: 2.5787 - val_root_mean_squared_error: 2412.0000
# Epoch 155/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5494 - root_mean_squared_error: 2480.5657 - val_loss: 2.5789 - val_root_mean_squared_error: 2405.8411
# Epoch 156/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5482 - root_mean_squared_error: 2476.8516 - val_loss: 2.5839 - val_root_mean_squared_error: 2408.6670
# Epoch 157/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5457 - root_mean_squared_error: 2476.2964 - val_loss: 2.5727 - val_root_mean_squared_error: 2411.8928
# Epoch 158/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5447 - root_mean_squared_error: 2476.3989 - val_loss: 2.5746 - val_root_mean_squared_error: 2406.9453
# Epoch 159/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5449 - root_mean_squared_error: 2478.5159 - val_loss: 2.5853 - val_root_mean_squared_error: 2414.5088
# Epoch 160/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5438 - root_mean_squared_error: 2477.5320 - val_loss: 2.5709 - val_root_mean_squared_error: 2415.1448
# Epoch 161/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5412 - root_mean_squared_error: 2478.6543 - val_loss: 2.5722 - val_root_mean_squared_error: 2407.3179
# Epoch 162/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5439 - root_mean_squared_error: 2474.6704 - val_loss: 2.5761 - val_root_mean_squared_error: 2407.6340
# Epoch 163/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5402 - root_mean_squared_error: 2477.9709 - val_loss: 2.5763 - val_root_mean_squared_error: 2408.4861
# Epoch 164/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5391 - root_mean_squared_error: 2479.7297 - val_loss: 2.5786 - val_root_mean_squared_error: 2419.8108
# Epoch 165/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5395 - root_mean_squared_error: 2475.8137 - val_loss: 2.5713 - val_root_mean_squared_error: 2414.5991
# Epoch 166/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5375 - root_mean_squared_error: 2477.3706 - val_loss: 2.5805 - val_root_mean_squared_error: 2414.2715
# Epoch 167/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5375 - root_mean_squared_error: 2478.0867 - val_loss: 2.5739 - val_root_mean_squared_error: 2409.1101
# Epoch 168/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5373 - root_mean_squared_error: 2477.2107 - val_loss: 2.5682 - val_root_mean_squared_error: 2414.2485
# Epoch 169/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5375 - root_mean_squared_error: 2474.8350 - val_loss: 2.5841 - val_root_mean_squared_error: 2421.4910
# Epoch 170/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5370 - root_mean_squared_error: 2479.6477 - val_loss: 2.5702 - val_root_mean_squared_error: 2414.9995
# Epoch 171/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5367 - root_mean_squared_error: 2479.2827 - val_loss: 2.5697 - val_root_mean_squared_error: 2421.3350
# Epoch 172/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5351 - root_mean_squared_error: 2476.8711 - val_loss: 2.5701 - val_root_mean_squared_error: 2422.3162
# Epoch 173/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5356 - root_mean_squared_error: 2477.7747 - val_loss: 2.5765 - val_root_mean_squared_error: 2410.8059
# Epoch 174/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5363 - root_mean_squared_error: 2476.5281 - val_loss: 2.5688 - val_root_mean_squared_error: 2421.7852
# Epoch 175/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5357 - root_mean_squared_error: 2479.0198 - val_loss: 2.5693 - val_root_mean_squared_error: 2421.2512
# Epoch 176/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5358 - root_mean_squared_error: 2478.4968 - val_loss: 2.5730 - val_root_mean_squared_error: 2429.3811
# Epoch 177/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5348 - root_mean_squared_error: 2477.4663 - val_loss: 2.5707 - val_root_mean_squared_error: 2428.7051
# Epoch 178/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5317 - root_mean_squared_error: 2477.8479 - val_loss: 2.5695 - val_root_mean_squared_error: 2418.6392
# Epoch 179/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5351 - root_mean_squared_error: 2477.7878 - val_loss: 2.5694 - val_root_mean_squared_error: 2421.9426
# Epoch 180/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5353 - root_mean_squared_error: 2481.1855 - val_loss: 2.5746 - val_root_mean_squared_error: 2445.7239
# Epoch 181/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5326 - root_mean_squared_error: 2482.2388 - val_loss: 2.5697 - val_root_mean_squared_error: 2418.2483
# Epoch 182/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5347 - root_mean_squared_error: 2476.8442 - val_loss: 2.5677 - val_root_mean_squared_error: 2417.5647
# Epoch 183/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5354 - root_mean_squared_error: 2482.7668 - val_loss: 2.5683 - val_root_mean_squared_error: 2428.8799
# Epoch 184/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5335 - root_mean_squared_error: 2478.3916 - val_loss: 2.5710 - val_root_mean_squared_error: 2434.7849
# Epoch 185/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5331 - root_mean_squared_error: 2479.8362 - val_loss: 2.5664 - val_root_mean_squared_error: 2419.2275
# Epoch 186/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5345 - root_mean_squared_error: 2479.6611 - val_loss: 2.5729 - val_root_mean_squared_error: 2428.8074
# Epoch 187/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5331 - root_mean_squared_error: 2481.0784 - val_loss: 2.5735 - val_root_mean_squared_error: 2419.2100
# Epoch 188/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5319 - root_mean_squared_error: 2481.8923 - val_loss: 2.5741 - val_root_mean_squared_error: 2416.5400
# Epoch 189/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5328 - root_mean_squared_error: 2479.1787 - val_loss: 2.5795 - val_root_mean_squared_error: 2415.1489
# Epoch 190/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5341 - root_mean_squared_error: 2480.7368 - val_loss: 2.5748 - val_root_mean_squared_error: 2425.8359
# Epoch 191/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5322 - root_mean_squared_error: 2479.3323 - val_loss: 2.5692 - val_root_mean_squared_error: 2427.9275
# Epoch 192/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5322 - root_mean_squared_error: 2483.3442 - val_loss: 2.5825 - val_root_mean_squared_error: 2420.5815
# Epoch 193/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5352 - root_mean_squared_error: 2480.3140 - val_loss: 2.5710 - val_root_mean_squared_error: 2416.1077
# Epoch 194/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5321 - root_mean_squared_error: 2480.5146 - val_loss: 2.5669 - val_root_mean_squared_error: 2416.1370
# Epoch 195/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5313 - root_mean_squared_error: 2477.5417 - val_loss: 2.5743 - val_root_mean_squared_error: 2418.9724
# Epoch 196/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5346 - root_mean_squared_error: 2487.1975 - val_loss: 2.5785 - val_root_mean_squared_error: 2422.8311
# Epoch 197/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5331 - root_mean_squared_error: 2476.8979 - val_loss: 2.5815 - val_root_mean_squared_error: 2439.3867
# Epoch 198/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5367 - root_mean_squared_error: 2486.7048 - val_loss: 2.5719 - val_root_mean_squared_error: 2421.7676
# Epoch 199/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5326 - root_mean_squared_error: 2483.0608 - val_loss: 2.5712 - val_root_mean_squared_error: 2425.9717
# Epoch 200/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5346 - root_mean_squared_error: 2481.8115 - val_loss: 2.5721 - val_root_mean_squared_error: 2440.7615
# Epoch 201/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5340 - root_mean_squared_error: 2485.1050 - val_loss: 2.5666 - val_root_mean_squared_error: 2420.5195
# Epoch 202/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.5320 - root_mean_squared_error: 2480.5681 - val_loss: 2.5687 - val_root_mean_squared_error: 2424.2056
# Epoch 203/5000
# 25/30 [========================>.....] - ETA: 0s - loss: 2.5371 - root_mean_squared_error: 2478.4358
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5343 - root_mean_squared_error: 2483.8457 - val_loss: 2.5758 - val_root_mean_squared_error: 2452.7078
# Epoch 204/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.5343 - root_mean_squared_error: 2487.1865 - val_loss: 2.5709 - val_root_mean_squared_error: 2430.4475
# Epoch 205/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5346 - root_mean_squared_error: 2483.4243 - val_loss: 2.5790 - val_root_mean_squared_error: 2441.3911
# CPU times: user 30 s, sys: 5.87 s, total: 35.8 s
# Wall time: 29.2 s

# %%
# -------------------------- get validation loss --------------------------
main_val_loss, main_rmse = model_main_effect.evaluate(X_val_split, y_val, verbose = False) # get the validation loss and RMSE
print(f"Validation loss for main effect: {main_val_loss}")
print(f"Validation RMSE for main effect: {main_rmse}")
# Out:
# Validation loss for main effect: 2.5664050579071045
# Validation RMSE for main effect: 2419.2275390625

# %%
############################   preparation for interaction selection   ############################
global_layers = ["main_subnet", "main_output", "interaction_output", "final_output"] # these layers are always trainable
imp_vars = [f"X{i}" for i in range(1,9)] # important variables
num_layers_interaction = 10 # number of layers for each interaction effect
num_neurons_interaction = 100 # number of neurons per dense layer for each interaction effect
keypoints = 20
lattice_sizes_pairwise = {}
for var in imp_vars:
    if var in cat_vars:
        lattice_sizes_pairwise[var] = X_train[var].nunique()
    else:
        lattice_sizes_pairwise[var] = 8

# %%
# -------------------------- create calibrator for lattice layer --------------------------
def add_calibrate_layer(var, data, monotonicity_list, lattice_sizes, keypoints, cat_vars, lattice_smooth_reg = [0,0]):
    if var in cat_vars:
        calibrator_layer = tfl.layers.CategoricalCalibration(
            num_buckets = data[var].nunique(),
            output_min = 0,
            output_max = lattice_sizes[var] - 1,
            name = f"{var}_calibrator_pairwise"
        )
    else:
        calibrator_layer = tfl.layers.PWLCalibration(
            input_keypoints =  np.linspace(data[var].min(), data[var].max(), num = keypoints), # keypoints
            kernel_regularizer = ('hessian', lattice_smooth_reg[0], lattice_smooth_reg[1]), # for smoothness
            monotonicity = monotonicity_list[var] if var in monotonicity_list else "none", # monotonicity constraint
            output_min = 0,
            output_max = lattice_sizes[var] - 1,
            name = f"{var}_calibrator_pairwise"
            )
    return calibrator_layer

# %%
############################ select interaction effect ############################

interactions = combinations(imp_vars, 2)
interaction_loss = {} # this stores the validation loss when fitting each pair of interaction effect
for var1, var2 in interactions:

    # -------------------------- initialize a cloned model --------------------------
    model_main_cloned = clone_model(model_main_effect) # clone the main effect model
    model_main_cloned.build(model_main_effect.input_shape)
    model_main_cloned.set_weights(model_main_effect.get_weights()) # copy the weights


    # -------------------------- build a subnet for pairwise interaction effect --------------------------
    var1_input = model_main_cloned.inputs[imp_vars.index(var1)]
    var2_input = model_main_cloned.inputs[imp_vars.index(var2)]

    # Lattice model if the pair contains a monotonic variable
    if any(var in monotonicity_list for var in [var1, var2]):
        lattice_inputs = []

        # create calibrator_layer
        calibrator_var1 = add_calibrate_layer(var1, X_train, monotonicity_list, lattice_sizes_pairwise, keypoints, cat_vars)
        calibrator_var2 = add_calibrate_layer(var2, X_train, monotonicity_list, lattice_sizes_pairwise, keypoints, cat_vars)
        calibrator_layer_var1 = calibrator_var1(var1_input)
        calibrator_layer_var2 = calibrator_var2(var2_input)
        
        # lattice
        lattice_inputs.append(calibrator_layer_var1)
        lattice_inputs.append(calibrator_layer_var2)
        lattice_layer = tfl.layers.Lattice(lattice_sizes = [lattice_sizes_pairwise[var1],lattice_sizes_pairwise[var2]], 
                            monotonicities = ["increasing" if var1 in monotonicity_list else 'none',
                                                "increasing" if var2 in monotonicity_list else 'none'],
                            name = f"{var1}_{var2}_lattice")(lattice_inputs)
        pairwise_output = BatchNormalization(scale = False, name = f"{var1}_{var2}_mean")(lattice_layer)
    else:
        # Subnetwork if the pair contains no monotonic variables
        pairwise_input_layer = Concatenate(name = f"{var1}_{var2}_concat")([var1_input, var2_input])
        pairwise_subnet = create_subnet(num_layers_interaction, 
                                        num_neurons_interaction, 
                                        activation, 
                                        f"{var1}_{var2}_subnetwork")
        pairwise_output = pairwise_subnet(pairwise_input_layer)

    # final output
    interaction_subnet_output = Activation('exponential',
                        name = "interaction_output")(pairwise_output)
    main_subnet_output = model_main_cloned.output
    final_output = Multiply(name = "final_output")([main_subnet_output, interaction_subnet_output])
    model_pairwise = Model(inputs = model_main_cloned.inputs, outputs = final_output)


    # -------------------------- switch on/off layers --------------------------
    for layer in model_pairwise.layers:
        if layer.name not in global_layers and var1 not in layer.name and var2 not in layer.name:
            layer.trainable = False

    # -------------------------- compile and train the model --------------------------
    model_pairwise.compile(optimizer = 'adam', 
                        loss = gamma_nll, 
                        metrics = [gamma_nll, RootMeanSquaredError()])
    es = EarlyStopping(patience = 25, restore_best_weights = True)
    model_pairwise.fit(X_train_split, y_train, epochs = 5_000, \
                            callbacks = [es], batch_size = 1_000, validation_data = (X_val_split, y_val))
    _, gamma_log_metric, _ = model_pairwise.evaluate(X_val_split, y_val, batch_size = X_val_split[0].shape[0])
    interaction_loss[f"{var1}_{var2}"] = gamma_log_metric # add to the val loss list
# Out:
# Epoch 1/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 2.5416 - gamma_nll: 2.5418 - root_mean_squared_error: 2492.2227 - val_loss: 2.5750 - val_gamma_nll: 2.5750 - val_root_mean_squared_error: 2429.5581
# Epoch 2/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5403 - gamma_nll: 2.5403 - root_mean_squared_error: 2489.2788 - val_loss: 2.5674 - val_gamma_nll: 2.5674 - val_root_mean_squared_error: 2428.3054
# Epoch 3/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5327 - gamma_nll: 2.5345 - root_mean_squared_error: 2481.8008 - val_loss: 2.5694 - val_gamma_nll: 2.5693 - val_root_mean_squared_error: 2421.2925
# Epoch 4/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5384 - gamma_nll: 2.5393 - root_mean_squared_error: 2492.6914 - val_loss: 2.6273 - val_gamma_nll: 2.6272 - val_root_mean_squared_error: 2510.0093
# Epoch 5/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5339 - gamma_nll: 2.5337 - root_mean_squared_error: 2480.8787 - val_loss: 2.6877 - val_gamma_nll: 2.6876 - val_root_mean_squared_error: 2759.6221
# Epoch 6/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5342 - gamma_nll: 2.5353 - root_mean_squared_error: 2486.2056 - val_loss: 2.6589 - val_gamma_nll: 2.6590 - val_root_mean_squared_error: 2643.1917
# Epoch 7/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5404 - gamma_nll: 2.5406 - root_mean_squared_error: 2488.5205 - val_loss: 2.7201 - val_gamma_nll: 2.7202 - val_root_mean_squared_error: 2843.7788
# Epoch 8/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5337 - gamma_nll: 2.5338 - root_mean_squared_error: 2486.9641 - val_loss: 2.5774 - val_gamma_nll: 2.5774 - val_root_mean_squared_error: 2441.9707
# Epoch 9/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5300 - gamma_nll: 2.5294 - root_mean_squared_error: 2482.5369 - val_loss: 2.6071 - val_gamma_nll: 2.6069 - val_root_mean_squared_error: 2414.4055
# Epoch 10/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5311 - gamma_nll: 2.5304 - root_mean_squared_error: 2482.1948 - val_loss: 2.5725 - val_gamma_nll: 2.5725 - val_root_mean_squared_error: 2421.4292
# Epoch 11/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5334 - gamma_nll: 2.5334 - root_mean_squared_error: 2491.0630 - val_loss: 2.6030 - val_gamma_nll: 2.6027 - val_root_mean_squared_error: 2440.6987
# Epoch 12/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5333 - gamma_nll: 2.5334 - root_mean_squared_error: 2483.5120 - val_loss: 2.5677 - val_gamma_nll: 2.5675 - val_root_mean_squared_error: 2415.2778
# Epoch 13/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5310 - gamma_nll: 2.5317 - root_mean_squared_error: 2483.3975 - val_loss: 2.5966 - val_gamma_nll: 2.5965 - val_root_mean_squared_error: 2463.9478
# Epoch 14/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5335 - gamma_nll: 2.5344 - root_mean_squared_error: 2486.5105 - val_loss: 2.6708 - val_gamma_nll: 2.6708 - val_root_mean_squared_error: 2598.6538
# Epoch 15/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5331 - gamma_nll: 2.5339 - root_mean_squared_error: 2486.0154 - val_loss: 2.6071 - val_gamma_nll: 2.6071 - val_root_mean_squared_error: 2510.4253
# Epoch 16/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5319 - gamma_nll: 2.5317 - root_mean_squared_error: 2487.6472 - val_loss: 2.5717 - val_gamma_nll: 2.5717 - val_root_mean_squared_error: 2425.6946
# Epoch 17/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5337 - gamma_nll: 2.5344 - root_mean_squared_error: 2484.5945 - val_loss: 2.5829 - val_gamma_nll: 2.5830 - val_root_mean_squared_error: 2457.7451
# Epoch 18/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5348 - gamma_nll: 2.5349 - root_mean_squared_error: 2486.6804 - val_loss: 2.5756 - val_gamma_nll: 2.5756 - val_root_mean_squared_error: 2410.0093
# Epoch 19/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5300 - gamma_nll: 2.5298 - root_mean_squared_error: 2485.2144 - val_loss: 2.5881 - val_gamma_nll: 2.5879 - val_root_mean_squared_error: 2412.6938
# Epoch 20/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5339 - gamma_nll: 2.5334 - root_mean_squared_error: 2485.7043 - val_loss: 2.5700 - val_gamma_nll: 2.5699 - val_root_mean_squared_error: 2424.6731
# Epoch 21/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5312 - gamma_nll: 2.5309 - root_mean_squared_error: 2485.4214 - val_loss: 2.5781 - val_gamma_nll: 2.5779 - val_root_mean_squared_error: 2442.0959
# Epoch 22/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5305 - gamma_nll: 2.5304 - root_mean_squared_error: 2488.8330 - val_loss: 2.5865 - val_gamma_nll: 2.5865 - val_root_mean_squared_error: 2466.0039
# Epoch 23/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5324 - gamma_nll: 2.5324 - root_mean_squared_error: 2485.3179 - val_loss: 2.5713 - val_gamma_nll: 2.5713 - val_root_mean_squared_error: 2440.1323
# Epoch 24/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5301 - gamma_nll: 2.5301 - root_mean_squared_error: 2484.9519 - val_loss: 2.5951 - val_gamma_nll: 2.5951 - val_root_mean_squared_error: 2478.6375
# Epoch 25/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5369 - gamma_nll: 2.5376 - root_mean_squared_error: 2495.8967 - val_loss: 2.6274 - val_gamma_nll: 2.6271 - val_root_mean_squared_error: 2477.2312
# Epoch 26/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5331 - gamma_nll: 2.5321 - root_mean_squared_error: 2492.9546 - val_loss: 2.5982 - val_gamma_nll: 2.5981 - val_root_mean_squared_error: 2404.4377
# Epoch 27/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5315 - gamma_nll: 2.5320 - root_mean_squared_error: 2483.2297 - val_loss: 2.5772 - val_gamma_nll: 2.5771 - val_root_mean_squared_error: 2458.5837
# 1/1 [==============================] - 0s 26ms/step - loss: 2.5674 - gamma_nll: 2.5674 - root_mean_squared_error: 2428.3054
# Epoch 1/5000
# 30/30 [==============================] - 1s 12ms/step - loss: 2.3785 - gamma_nll: 2.3783 - root_mean_squared_error: 2448.9807 - val_loss: 2.8400 - val_gamma_nll: 2.8400 - val_root_mean_squared_error: 2983.8652
# Epoch 2/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3638 - gamma_nll: 2.3637 - root_mean_squared_error: 2417.9009 - val_loss: 2.6846 - val_gamma_nll: 2.6846 - val_root_mean_squared_error: 2629.8755
# Epoch 3/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3607 - gamma_nll: 2.3618 - root_mean_squared_error: 2412.4067 - val_loss: 2.6440 - val_gamma_nll: 2.6440 - val_root_mean_squared_error: 2551.1614
# Epoch 4/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3620 - gamma_nll: 2.3623 - root_mean_squared_error: 2420.3604 - val_loss: 2.5828 - val_gamma_nll: 2.5828 - val_root_mean_squared_error: 2493.1709
# Epoch 5/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3565 - gamma_nll: 2.3556 - root_mean_squared_error: 2413.9900 - val_loss: 2.4858 - val_gamma_nll: 2.4859 - val_root_mean_squared_error: 2417.1912
# Epoch 6/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3592 - gamma_nll: 2.3592 - root_mean_squared_error: 2419.5488 - val_loss: 2.4577 - val_gamma_nll: 2.4578 - val_root_mean_squared_error: 2404.6582
# Epoch 7/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.3619 - gamma_nll: 2.3621 - root_mean_squared_error: 2419.7622 - val_loss: 2.5039 - val_gamma_nll: 2.5038 - val_root_mean_squared_error: 2414.1094
# Epoch 8/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3639 - gamma_nll: 2.3645 - root_mean_squared_error: 2425.5625 - val_loss: 2.4653 - val_gamma_nll: 2.4655 - val_root_mean_squared_error: 2385.2173
# Epoch 9/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3608 - gamma_nll: 2.3603 - root_mean_squared_error: 2419.3130 - val_loss: 2.4074 - val_gamma_nll: 2.4077 - val_root_mean_squared_error: 2381.8188
# Epoch 10/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3613 - gamma_nll: 2.3609 - root_mean_squared_error: 2426.8892 - val_loss: 2.4171 - val_gamma_nll: 2.4174 - val_root_mean_squared_error: 2401.1497
# Epoch 11/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3598 - gamma_nll: 2.3597 - root_mean_squared_error: 2421.8335 - val_loss: 2.4150 - val_gamma_nll: 2.4154 - val_root_mean_squared_error: 2532.7510
# Epoch 12/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3623 - gamma_nll: 2.3623 - root_mean_squared_error: 2425.7817 - val_loss: 2.5470 - val_gamma_nll: 2.5473 - val_root_mean_squared_error: 2611.5925
# Epoch 13/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3560 - gamma_nll: 2.3566 - root_mean_squared_error: 2422.0339 - val_loss: 2.5621 - val_gamma_nll: 2.5624 - val_root_mean_squared_error: 2711.2112
# Epoch 14/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.3577 - gamma_nll: 2.3577 - root_mean_squared_error: 2423.1770 - val_loss: 2.3805 - val_gamma_nll: 2.3811 - val_root_mean_squared_error: 2401.4009
# Epoch 15/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3571 - gamma_nll: 2.3579 - root_mean_squared_error: 2424.0840 - val_loss: 2.3895 - val_gamma_nll: 2.3901 - val_root_mean_squared_error: 2381.4819
# Epoch 16/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3571 - gamma_nll: 2.3567 - root_mean_squared_error: 2429.4727 - val_loss: 2.4128 - val_gamma_nll: 2.4137 - val_root_mean_squared_error: 2360.7585
# Epoch 17/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3575 - gamma_nll: 2.3586 - root_mean_squared_error: 2421.4326 - val_loss: 2.4409 - val_gamma_nll: 2.4420 - val_root_mean_squared_error: 2374.8679
# Epoch 18/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3573 - gamma_nll: 2.3571 - root_mean_squared_error: 2424.0076 - val_loss: 2.4269 - val_gamma_nll: 2.4278 - val_root_mean_squared_error: 2363.8757
# Epoch 19/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3543 - gamma_nll: 2.3542 - root_mean_squared_error: 2417.8665 - val_loss: 2.3747 - val_gamma_nll: 2.3753 - val_root_mean_squared_error: 2401.8135
# Epoch 20/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3545 - gamma_nll: 2.3539 - root_mean_squared_error: 2422.7463 - val_loss: 2.3815 - val_gamma_nll: 2.3821 - val_root_mean_squared_error: 2478.6184
# Epoch 21/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.3547 - gamma_nll: 2.3544 - root_mean_squared_error: 2426.3384 - val_loss: 2.3868 - val_gamma_nll: 2.3875 - val_root_mean_squared_error: 2396.3574
# Epoch 22/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3553 - gamma_nll: 2.3552 - root_mean_squared_error: 2431.9729 - val_loss: 2.3765 - val_gamma_nll: 2.3771 - val_root_mean_squared_error: 2365.0569
# Epoch 23/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3551 - gamma_nll: 2.3556 - root_mean_squared_error: 2419.4658 - val_loss: 2.3769 - val_gamma_nll: 2.3775 - val_root_mean_squared_error: 2440.3169
# Epoch 24/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3556 - gamma_nll: 2.3556 - root_mean_squared_error: 2427.1211 - val_loss: 2.3777 - val_gamma_nll: 2.3785 - val_root_mean_squared_error: 2416.5378
# Epoch 25/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3568 - gamma_nll: 2.3578 - root_mean_squared_error: 2426.7026 - val_loss: 2.3780 - val_gamma_nll: 2.3787 - val_root_mean_squared_error: 2496.7305
# Epoch 26/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3561 - gamma_nll: 2.3557 - root_mean_squared_error: 2427.1440 - val_loss: 2.3780 - val_gamma_nll: 2.3786 - val_root_mean_squared_error: 2411.7798
# Epoch 27/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3573 - gamma_nll: 2.3572 - root_mean_squared_error: 2420.3132 - val_loss: 2.3813 - val_gamma_nll: 2.3820 - val_root_mean_squared_error: 2505.5957
# Epoch 28/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3549 - gamma_nll: 2.3535 - root_mean_squared_error: 2429.3975 - val_loss: 2.3778 - val_gamma_nll: 2.3788 - val_root_mean_squared_error: 2410.3357
# Epoch 29/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3537 - gamma_nll: 2.3534 - root_mean_squared_error: 2430.6003 - val_loss: 2.3825 - val_gamma_nll: 2.3831 - val_root_mean_squared_error: 2481.2737
# Epoch 30/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3566 - gamma_nll: 2.3572 - root_mean_squared_error: 2429.9036 - val_loss: 2.3798 - val_gamma_nll: 2.3805 - val_root_mean_squared_error: 2395.5474
# Epoch 31/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3579 - gamma_nll: 2.3578 - root_mean_squared_error: 2430.7515 - val_loss: 2.3826 - val_gamma_nll: 2.3835 - val_root_mean_squared_error: 2391.8513
# Epoch 32/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3526 - gamma_nll: 2.3524 - root_mean_squared_error: 2427.8765 - val_loss: 2.4156 - val_gamma_nll: 2.4160 - val_root_mean_squared_error: 2505.7046
# Epoch 33/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3527 - gamma_nll: 2.3519 - root_mean_squared_error: 2425.9490 - val_loss: 2.4201 - val_gamma_nll: 2.4207 - val_root_mean_squared_error: 2605.6130
# Epoch 34/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3551 - gamma_nll: 2.3539 - root_mean_squared_error: 2431.6714 - val_loss: 2.3745 - val_gamma_nll: 2.3750 - val_root_mean_squared_error: 2400.4290
# Epoch 35/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3558 - gamma_nll: 2.3551 - root_mean_squared_error: 2429.5723 - val_loss: 2.3755 - val_gamma_nll: 2.3763 - val_root_mean_squared_error: 2382.4744
# Epoch 36/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3512 - gamma_nll: 2.3518 - root_mean_squared_error: 2430.2869 - val_loss: 2.3923 - val_gamma_nll: 2.3931 - val_root_mean_squared_error: 2366.5349
# Epoch 37/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3522 - gamma_nll: 2.3524 - root_mean_squared_error: 2429.1907 - val_loss: 2.5023 - val_gamma_nll: 2.5031 - val_root_mean_squared_error: 2378.3596
# Epoch 38/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3537 - gamma_nll: 2.3539 - root_mean_squared_error: 2427.6694 - val_loss: 2.5081 - val_gamma_nll: 2.5090 - val_root_mean_squared_error: 2376.1133
# Epoch 39/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3519 - gamma_nll: 2.3513 - root_mean_squared_error: 2431.0908 - val_loss: 2.3904 - val_gamma_nll: 2.3913 - val_root_mean_squared_error: 2380.8674
# Epoch 40/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3515 - gamma_nll: 2.3523 - root_mean_squared_error: 2431.1816 - val_loss: 2.3986 - val_gamma_nll: 2.3993 - val_root_mean_squared_error: 2377.5193
# Epoch 41/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3508 - gamma_nll: 2.3519 - root_mean_squared_error: 2428.3643 - val_loss: 2.3880 - val_gamma_nll: 2.3887 - val_root_mean_squared_error: 2373.0891
# Epoch 42/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3522 - gamma_nll: 2.3518 - root_mean_squared_error: 2432.7847 - val_loss: 2.3741 - val_gamma_nll: 2.3749 - val_root_mean_squared_error: 2407.3125
# Epoch 43/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 2.3542 - gamma_nll: 2.3549 - root_mean_squared_error: 2437.9756 - val_loss: 2.3897 - val_gamma_nll: 2.3901 - val_root_mean_squared_error: 2403.8428
# Epoch 44/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3525 - gamma_nll: 2.3529 - root_mean_squared_error: 2430.2810 - val_loss: 2.3833 - val_gamma_nll: 2.3839 - val_root_mean_squared_error: 2407.4375
# Epoch 45/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3508 - gamma_nll: 2.3507 - root_mean_squared_error: 2431.0947 - val_loss: 2.3802 - val_gamma_nll: 2.3809 - val_root_mean_squared_error: 2390.1104
# Epoch 46/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3527 - gamma_nll: 2.3527 - root_mean_squared_error: 2437.0745 - val_loss: 2.4098 - val_gamma_nll: 2.4108 - val_root_mean_squared_error: 2400.7751
# Epoch 47/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3544 - gamma_nll: 2.3552 - root_mean_squared_error: 2436.3699 - val_loss: 2.3827 - val_gamma_nll: 2.3835 - val_root_mean_squared_error: 2384.7952
# Epoch 48/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3548 - gamma_nll: 2.3551 - root_mean_squared_error: 2439.1689 - val_loss: 2.3688 - val_gamma_nll: 2.3695 - val_root_mean_squared_error: 2407.3181
# Epoch 49/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3515 - gamma_nll: 2.3524 - root_mean_squared_error: 2435.2886 - val_loss: 2.4005 - val_gamma_nll: 2.4010 - val_root_mean_squared_error: 2512.9299
# Epoch 50/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3536 - gamma_nll: 2.3536 - root_mean_squared_error: 2431.4309 - val_loss: 2.3943 - val_gamma_nll: 2.3951 - val_root_mean_squared_error: 2772.8801
# Epoch 51/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3585 - gamma_nll: 2.3577 - root_mean_squared_error: 2450.9897 - val_loss: 2.4711 - val_gamma_nll: 2.4716 - val_root_mean_squared_error: 2703.6006
# Epoch 52/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3516 - gamma_nll: 2.3513 - root_mean_squared_error: 2434.0808 - val_loss: 2.4549 - val_gamma_nll: 2.4555 - val_root_mean_squared_error: 2794.7227
# Epoch 53/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3499 - gamma_nll: 2.3497 - root_mean_squared_error: 2430.6997 - val_loss: 2.4339 - val_gamma_nll: 2.4344 - val_root_mean_squared_error: 2619.8657
# Epoch 54/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3529 - gamma_nll: 2.3521 - root_mean_squared_error: 2438.7100 - val_loss: 2.4198 - val_gamma_nll: 2.4204 - val_root_mean_squared_error: 2592.4031
# Epoch 55/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3561 - gamma_nll: 2.3569 - root_mean_squared_error: 2439.7061 - val_loss: 2.3738 - val_gamma_nll: 2.3746 - val_root_mean_squared_error: 2468.3540
# Epoch 56/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3554 - gamma_nll: 2.3563 - root_mean_squared_error: 2453.7632 - val_loss: 2.3902 - val_gamma_nll: 2.3910 - val_root_mean_squared_error: 2511.1147
# Epoch 57/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3523 - gamma_nll: 2.3521 - root_mean_squared_error: 2433.1885 - val_loss: 2.4747 - val_gamma_nll: 2.4751 - val_root_mean_squared_error: 2706.4402
# Epoch 58/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3596 - gamma_nll: 2.3596 - root_mean_squared_error: 2439.8367 - val_loss: 2.3710 - val_gamma_nll: 2.3717 - val_root_mean_squared_error: 2433.2148
# Epoch 59/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3502 - gamma_nll: 2.3500 - root_mean_squared_error: 2443.6316 - val_loss: 2.3862 - val_gamma_nll: 2.3868 - val_root_mean_squared_error: 2511.3735
# Epoch 60/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3498 - gamma_nll: 2.3496 - root_mean_squared_error: 2438.4087 - val_loss: 2.3981 - val_gamma_nll: 2.3989 - val_root_mean_squared_error: 2494.5586
# Epoch 61/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3527 - gamma_nll: 2.3540 - root_mean_squared_error: 2440.5420 - val_loss: 2.3765 - val_gamma_nll: 2.3771 - val_root_mean_squared_error: 2463.2112
# Epoch 62/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3515 - gamma_nll: 2.3502 - root_mean_squared_error: 2444.8545 - val_loss: 2.4244 - val_gamma_nll: 2.4249 - val_root_mean_squared_error: 2636.5972
# Epoch 63/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3501 - gamma_nll: 2.3502 - root_mean_squared_error: 2431.5593 - val_loss: 2.4434 - val_gamma_nll: 2.4439 - val_root_mean_squared_error: 2597.4458
# Epoch 64/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3516 - gamma_nll: 2.3513 - root_mean_squared_error: 2445.0347 - val_loss: 2.4574 - val_gamma_nll: 2.4579 - val_root_mean_squared_error: 2751.5300
# Epoch 65/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3496 - gamma_nll: 2.3498 - root_mean_squared_error: 2434.6846 - val_loss: 2.4217 - val_gamma_nll: 2.4222 - val_root_mean_squared_error: 2583.8840
# Epoch 66/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3503 - gamma_nll: 2.3513 - root_mean_squared_error: 2437.2705 - val_loss: 2.5424 - val_gamma_nll: 2.5428 - val_root_mean_squared_error: 2741.2405
# Epoch 67/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3506 - gamma_nll: 2.3508 - root_mean_squared_error: 2439.6826 - val_loss: 2.4130 - val_gamma_nll: 2.4136 - val_root_mean_squared_error: 2659.7317
# Epoch 68/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3495 - gamma_nll: 2.3491 - root_mean_squared_error: 2435.6123 - val_loss: 2.4096 - val_gamma_nll: 2.4101 - val_root_mean_squared_error: 2616.9912
# Epoch 69/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3546 - gamma_nll: 2.3546 - root_mean_squared_error: 2440.3784 - val_loss: 2.4029 - val_gamma_nll: 2.4034 - val_root_mean_squared_error: 2538.7273
# Epoch 70/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3526 - gamma_nll: 2.3527 - root_mean_squared_error: 2443.6892 - val_loss: 2.3635 - val_gamma_nll: 2.3642 - val_root_mean_squared_error: 2419.4683
# Epoch 71/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3481 - gamma_nll: 2.3481 - root_mean_squared_error: 2431.5090 - val_loss: 2.3674 - val_gamma_nll: 2.3681 - val_root_mean_squared_error: 2472.3860
# Epoch 72/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3492 - gamma_nll: 2.3502 - root_mean_squared_error: 2441.4998 - val_loss: 2.4419 - val_gamma_nll: 2.4424 - val_root_mean_squared_error: 2586.6213
# Epoch 73/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3495 - gamma_nll: 2.3490 - root_mean_squared_error: 2433.7676 - val_loss: 2.4315 - val_gamma_nll: 2.4321 - val_root_mean_squared_error: 2745.0010
# Epoch 74/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3516 - gamma_nll: 2.3509 - root_mean_squared_error: 2449.6958 - val_loss: 2.4070 - val_gamma_nll: 2.4076 - val_root_mean_squared_error: 2654.7461
# Epoch 75/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3490 - gamma_nll: 2.3490 - root_mean_squared_error: 2437.4080 - val_loss: 2.4674 - val_gamma_nll: 2.4679 - val_root_mean_squared_error: 2683.0615
# Epoch 76/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3480 - gamma_nll: 2.3470 - root_mean_squared_error: 2437.2581 - val_loss: 2.3941 - val_gamma_nll: 2.3947 - val_root_mean_squared_error: 2572.6824
# Epoch 77/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3497 - gamma_nll: 2.3503 - root_mean_squared_error: 2438.1069 - val_loss: 2.3803 - val_gamma_nll: 2.3811 - val_root_mean_squared_error: 2485.5215
# Epoch 78/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3491 - gamma_nll: 2.3487 - root_mean_squared_error: 2437.5774 - val_loss: 2.3920 - val_gamma_nll: 2.3927 - val_root_mean_squared_error: 2571.8015
# Epoch 79/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3499 - gamma_nll: 2.3495 - root_mean_squared_error: 2439.7556 - val_loss: 2.3886 - val_gamma_nll: 2.3893 - val_root_mean_squared_error: 2558.3325
# Epoch 80/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3498 - gamma_nll: 2.3499 - root_mean_squared_error: 2440.9839 - val_loss: 2.4723 - val_gamma_nll: 2.4727 - val_root_mean_squared_error: 2674.2244
# Epoch 81/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3482 - gamma_nll: 2.3485 - root_mean_squared_error: 2439.3879 - val_loss: 2.3728 - val_gamma_nll: 2.3735 - val_root_mean_squared_error: 2499.2559
# Epoch 82/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3494 - gamma_nll: 2.3486 - root_mean_squared_error: 2439.7043 - val_loss: 2.3886 - val_gamma_nll: 2.3892 - val_root_mean_squared_error: 2514.6663
# Epoch 83/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3485 - gamma_nll: 2.3487 - root_mean_squared_error: 2441.6521 - val_loss: 2.3955 - val_gamma_nll: 2.3962 - val_root_mean_squared_error: 2554.7476
# Epoch 84/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3474 - gamma_nll: 2.3485 - root_mean_squared_error: 2444.4407 - val_loss: 2.4440 - val_gamma_nll: 2.4445 - val_root_mean_squared_error: 2668.0017
# Epoch 85/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3476 - gamma_nll: 2.3474 - root_mean_squared_error: 2446.5540 - val_loss: 2.4245 - val_gamma_nll: 2.4250 - val_root_mean_squared_error: 2500.4131
# Epoch 86/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3474 - gamma_nll: 2.3477 - root_mean_squared_error: 2438.3298 - val_loss: 2.4276 - val_gamma_nll: 2.4282 - val_root_mean_squared_error: 2590.3203
# Epoch 87/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3492 - gamma_nll: 2.3503 - root_mean_squared_error: 2441.9714 - val_loss: 2.4072 - val_gamma_nll: 2.4079 - val_root_mean_squared_error: 2680.3909
# Epoch 88/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3498 - gamma_nll: 2.3495 - root_mean_squared_error: 2448.2615 - val_loss: 2.5082 - val_gamma_nll: 2.5087 - val_root_mean_squared_error: 2876.1565
# Epoch 89/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3507 - gamma_nll: 2.3511 - root_mean_squared_error: 2446.4219 - val_loss: 2.4125 - val_gamma_nll: 2.4132 - val_root_mean_squared_error: 2674.9514
# Epoch 90/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3489 - gamma_nll: 2.3487 - root_mean_squared_error: 2442.9070 - val_loss: 2.3704 - val_gamma_nll: 2.3712 - val_root_mean_squared_error: 2526.4648
# Epoch 91/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3466 - gamma_nll: 2.3463 - root_mean_squared_error: 2447.4060 - val_loss: 2.3794 - val_gamma_nll: 2.3801 - val_root_mean_squared_error: 2601.1035
# Epoch 92/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3480 - gamma_nll: 2.3480 - root_mean_squared_error: 2447.0125 - val_loss: 2.3908 - val_gamma_nll: 2.3914 - val_root_mean_squared_error: 2656.5681
# Epoch 93/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3468 - gamma_nll: 2.3459 - root_mean_squared_error: 2437.8440 - val_loss: 2.4119 - val_gamma_nll: 2.4125 - val_root_mean_squared_error: 2637.9651
# Epoch 94/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3478 - gamma_nll: 2.3474 - root_mean_squared_error: 2447.5405 - val_loss: 2.3779 - val_gamma_nll: 2.3785 - val_root_mean_squared_error: 2481.4795
# Epoch 95/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 2.3478 - gamma_nll: 2.3489 - root_mean_squared_error: 2440.9736 - val_loss: 2.3650 - val_gamma_nll: 2.3658 - val_root_mean_squared_error: 2456.9805
# 1/1 [==============================] - 0s 20ms/step - loss: 2.3635 - gamma_nll: 2.3635 - root_mean_squared_error: 2419.4683
# Epoch 1/5000
# 30/30 [==============================] - 1s 17ms/step - loss: 2.5485 - gamma_nll: 2.5486 - root_mean_squared_error: 2503.6230 - val_loss: 2.5715 - val_gamma_nll: 2.5714 - val_root_mean_squared_error: 2419.6697
# Epoch 2/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5393 - gamma_nll: 2.5393 - root_mean_squared_error: 2488.8245 - val_loss: 2.5998 - val_gamma_nll: 2.5997 - val_root_mean_squared_error: 2406.0281
# Epoch 3/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 2.5322 - gamma_nll: 2.5340 - root_mean_squared_error: 2481.7881 - val_loss: 2.5982 - val_gamma_nll: 2.5982 - val_root_mean_squared_error: 2479.2297
# Epoch 4/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5411 - gamma_nll: 2.5418 - root_mean_squared_error: 2492.6243 - val_loss: 2.5721 - val_gamma_nll: 2.5720 - val_root_mean_squared_error: 2428.2363
# Epoch 5/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5349 - gamma_nll: 2.5346 - root_mean_squared_error: 2483.4646 - val_loss: 2.6073 - val_gamma_nll: 2.6072 - val_root_mean_squared_error: 2521.9617
# Epoch 6/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5322 - gamma_nll: 2.5332 - root_mean_squared_error: 2483.5974 - val_loss: 2.5759 - val_gamma_nll: 2.5758 - val_root_mean_squared_error: 2456.4490
# Epoch 7/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5340 - gamma_nll: 2.5342 - root_mean_squared_error: 2483.9829 - val_loss: 2.6071 - val_gamma_nll: 2.6069 - val_root_mean_squared_error: 2422.4626
# Epoch 8/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5347 - gamma_nll: 2.5348 - root_mean_squared_error: 2484.3174 - val_loss: 2.5910 - val_gamma_nll: 2.5909 - val_root_mean_squared_error: 2402.7466
# Epoch 9/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5354 - gamma_nll: 2.5348 - root_mean_squared_error: 2485.3899 - val_loss: 2.5728 - val_gamma_nll: 2.5727 - val_root_mean_squared_error: 2431.1746
# Epoch 10/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5335 - gamma_nll: 2.5329 - root_mean_squared_error: 2485.0439 - val_loss: 2.5793 - val_gamma_nll: 2.5792 - val_root_mean_squared_error: 2456.5083
# Epoch 11/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5336 - gamma_nll: 2.5337 - root_mean_squared_error: 2488.4492 - val_loss: 2.6290 - val_gamma_nll: 2.6288 - val_root_mean_squared_error: 2599.5654
# Epoch 12/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5368 - gamma_nll: 2.5368 - root_mean_squared_error: 2485.8872 - val_loss: 2.7010 - val_gamma_nll: 2.7009 - val_root_mean_squared_error: 2740.3679
# Epoch 13/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5308 - gamma_nll: 2.5317 - root_mean_squared_error: 2484.3020 - val_loss: 2.6615 - val_gamma_nll: 2.6615 - val_root_mean_squared_error: 2582.8933
# Epoch 14/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5326 - gamma_nll: 2.5334 - root_mean_squared_error: 2488.0698 - val_loss: 2.6202 - val_gamma_nll: 2.6202 - val_root_mean_squared_error: 2513.3066
# Epoch 15/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5337 - gamma_nll: 2.5344 - root_mean_squared_error: 2487.0447 - val_loss: 2.5792 - val_gamma_nll: 2.5791 - val_root_mean_squared_error: 2419.1099
# Epoch 16/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5348 - gamma_nll: 2.5346 - root_mean_squared_error: 2487.0959 - val_loss: 2.5689 - val_gamma_nll: 2.5689 - val_root_mean_squared_error: 2413.1265
# Epoch 17/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5330 - gamma_nll: 2.5336 - root_mean_squared_error: 2485.4351 - val_loss: 2.5715 - val_gamma_nll: 2.5715 - val_root_mean_squared_error: 2429.1238
# Epoch 18/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5387 - gamma_nll: 2.5389 - root_mean_squared_error: 2487.1697 - val_loss: 2.5944 - val_gamma_nll: 2.5945 - val_root_mean_squared_error: 2484.2791
# Epoch 19/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5320 - gamma_nll: 2.5318 - root_mean_squared_error: 2484.9910 - val_loss: 2.5775 - val_gamma_nll: 2.5774 - val_root_mean_squared_error: 2457.1311
# Epoch 20/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5328 - gamma_nll: 2.5321 - root_mean_squared_error: 2486.5022 - val_loss: 2.5896 - val_gamma_nll: 2.5895 - val_root_mean_squared_error: 2440.8037
# Epoch 21/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5333 - gamma_nll: 2.5330 - root_mean_squared_error: 2485.6428 - val_loss: 2.5672 - val_gamma_nll: 2.5671 - val_root_mean_squared_error: 2416.5166
# Epoch 22/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5337 - gamma_nll: 2.5335 - root_mean_squared_error: 2490.7686 - val_loss: 2.5736 - val_gamma_nll: 2.5736 - val_root_mean_squared_error: 2436.8484
# Epoch 23/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5319 - gamma_nll: 2.5319 - root_mean_squared_error: 2485.0190 - val_loss: 2.6927 - val_gamma_nll: 2.6927 - val_root_mean_squared_error: 2676.3447
# Epoch 24/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5320 - gamma_nll: 2.5320 - root_mean_squared_error: 2487.6045 - val_loss: 2.6705 - val_gamma_nll: 2.6705 - val_root_mean_squared_error: 2638.4275
# Epoch 25/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5347 - gamma_nll: 2.5352 - root_mean_squared_error: 2488.4072 - val_loss: 2.6507 - val_gamma_nll: 2.6506 - val_root_mean_squared_error: 2659.6641
# Epoch 26/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5333 - gamma_nll: 2.5323 - root_mean_squared_error: 2488.5361 - val_loss: 2.6617 - val_gamma_nll: 2.6617 - val_root_mean_squared_error: 2615.9666
# Epoch 27/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5324 - gamma_nll: 2.5330 - root_mean_squared_error: 2484.4783 - val_loss: 2.5955 - val_gamma_nll: 2.5954 - val_root_mean_squared_error: 2501.2002
# Epoch 28/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5355 - gamma_nll: 2.5346 - root_mean_squared_error: 2486.4741 - val_loss: 2.6008 - val_gamma_nll: 2.6008 - val_root_mean_squared_error: 2511.0139
# Epoch 29/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5332 - gamma_nll: 2.5331 - root_mean_squared_error: 2490.2461 - val_loss: 2.5707 - val_gamma_nll: 2.5706 - val_root_mean_squared_error: 2428.7273
# Epoch 30/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5338 - gamma_nll: 2.5333 - root_mean_squared_error: 2491.1694 - val_loss: 2.5705 - val_gamma_nll: 2.5704 - val_root_mean_squared_error: 2421.7468
# Epoch 31/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5354 - gamma_nll: 2.5357 - root_mean_squared_error: 2490.8359 - val_loss: 2.5959 - val_gamma_nll: 2.5958 - val_root_mean_squared_error: 2489.9861
# Epoch 32/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5390 - gamma_nll: 2.5388 - root_mean_squared_error: 2496.6902 - val_loss: 2.6069 - val_gamma_nll: 2.6068 - val_root_mean_squared_error: 2522.1904
# Epoch 33/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5359 - gamma_nll: 2.5362 - root_mean_squared_error: 2488.7561 - val_loss: 2.6178 - val_gamma_nll: 2.6178 - val_root_mean_squared_error: 2534.1343
# Epoch 34/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5323 - gamma_nll: 2.5307 - root_mean_squared_error: 2486.1028 - val_loss: 2.6177 - val_gamma_nll: 2.6176 - val_root_mean_squared_error: 2573.5215
# Epoch 35/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5367 - gamma_nll: 2.5358 - root_mean_squared_error: 2495.3220 - val_loss: 2.6657 - val_gamma_nll: 2.6657 - val_root_mean_squared_error: 2612.9453
# Epoch 36/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5296 - gamma_nll: 2.5295 - root_mean_squared_error: 2487.0371 - val_loss: 2.5649 - val_gamma_nll: 2.5648 - val_root_mean_squared_error: 2419.1326
# Epoch 37/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5315 - gamma_nll: 2.5307 - root_mean_squared_error: 2483.4529 - val_loss: 2.5978 - val_gamma_nll: 2.5975 - val_root_mean_squared_error: 2431.9414
# Epoch 38/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5328 - gamma_nll: 2.5331 - root_mean_squared_error: 2490.9539 - val_loss: 2.5984 - val_gamma_nll: 2.5983 - val_root_mean_squared_error: 2408.0603
# Epoch 39/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5316 - gamma_nll: 2.5308 - root_mean_squared_error: 2485.5632 - val_loss: 2.6125 - val_gamma_nll: 2.6124 - val_root_mean_squared_error: 2407.5002
# Epoch 40/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5398 - gamma_nll: 2.5397 - root_mean_squared_error: 2501.5640 - val_loss: 2.6777 - val_gamma_nll: 2.6776 - val_root_mean_squared_error: 2416.8269
# Epoch 41/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5339 - gamma_nll: 2.5344 - root_mean_squared_error: 2490.1118 - val_loss: 2.6136 - val_gamma_nll: 2.6134 - val_root_mean_squared_error: 2406.4211
# Epoch 42/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5337 - gamma_nll: 2.5338 - root_mean_squared_error: 2488.7332 - val_loss: 2.5993 - val_gamma_nll: 2.5991 - val_root_mean_squared_error: 2416.2642
# Epoch 43/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5344 - gamma_nll: 2.5352 - root_mean_squared_error: 2491.5300 - val_loss: 2.7537 - val_gamma_nll: 2.7532 - val_root_mean_squared_error: 2420.9429
# Epoch 44/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5330 - gamma_nll: 2.5330 - root_mean_squared_error: 2490.0178 - val_loss: 2.6291 - val_gamma_nll: 2.6289 - val_root_mean_squared_error: 2410.4321
# Epoch 45/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5321 - gamma_nll: 2.5325 - root_mean_squared_error: 2489.1724 - val_loss: 2.5943 - val_gamma_nll: 2.5942 - val_root_mean_squared_error: 2408.8188
# Epoch 46/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5356 - gamma_nll: 2.5368 - root_mean_squared_error: 2489.6643 - val_loss: 2.6186 - val_gamma_nll: 2.6184 - val_root_mean_squared_error: 2419.8926
# Epoch 47/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5417 - gamma_nll: 2.5420 - root_mean_squared_error: 2496.4377 - val_loss: 2.6516 - val_gamma_nll: 2.6514 - val_root_mean_squared_error: 2414.3508
# Epoch 48/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5305 - gamma_nll: 2.5311 - root_mean_squared_error: 2490.9609 - val_loss: 2.7213 - val_gamma_nll: 2.7211 - val_root_mean_squared_error: 2419.8110
# Epoch 49/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5347 - gamma_nll: 2.5352 - root_mean_squared_error: 2493.4255 - val_loss: 2.6372 - val_gamma_nll: 2.6371 - val_root_mean_squared_error: 2405.8401
# Epoch 50/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5344 - gamma_nll: 2.5342 - root_mean_squared_error: 2490.5398 - val_loss: 2.5852 - val_gamma_nll: 2.5852 - val_root_mean_squared_error: 2441.9395
# Epoch 51/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5352 - gamma_nll: 2.5336 - root_mean_squared_error: 2490.5986 - val_loss: 2.5798 - val_gamma_nll: 2.5797 - val_root_mean_squared_error: 2477.7620
# Epoch 52/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5304 - gamma_nll: 2.5300 - root_mean_squared_error: 2489.2451 - val_loss: 2.5731 - val_gamma_nll: 2.5731 - val_root_mean_squared_error: 2446.2588
# Epoch 53/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5306 - gamma_nll: 2.5299 - root_mean_squared_error: 2486.0713 - val_loss: 2.5677 - val_gamma_nll: 2.5677 - val_root_mean_squared_error: 2425.6196
# Epoch 54/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5304 - gamma_nll: 2.5295 - root_mean_squared_error: 2486.9805 - val_loss: 2.5864 - val_gamma_nll: 2.5864 - val_root_mean_squared_error: 2489.9329
# Epoch 55/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5331 - gamma_nll: 2.5336 - root_mean_squared_error: 2491.6226 - val_loss: 2.6694 - val_gamma_nll: 2.6695 - val_root_mean_squared_error: 2619.1936
# Epoch 56/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5330 - gamma_nll: 2.5346 - root_mean_squared_error: 2493.6216 - val_loss: 2.6701 - val_gamma_nll: 2.6702 - val_root_mean_squared_error: 2641.4551
# Epoch 57/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5312 - gamma_nll: 2.5308 - root_mean_squared_error: 2489.6628 - val_loss: 2.5894 - val_gamma_nll: 2.5894 - val_root_mean_squared_error: 2486.5266
# Epoch 58/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5342 - gamma_nll: 2.5347 - root_mean_squared_error: 2491.9587 - val_loss: 2.5829 - val_gamma_nll: 2.5829 - val_root_mean_squared_error: 2478.3430
# Epoch 59/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5336 - gamma_nll: 2.5331 - root_mean_squared_error: 2491.7808 - val_loss: 2.5763 - val_gamma_nll: 2.5762 - val_root_mean_squared_error: 2450.9988
# Epoch 60/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5314 - gamma_nll: 2.5309 - root_mean_squared_error: 2489.0354 - val_loss: 2.5848 - val_gamma_nll: 2.5847 - val_root_mean_squared_error: 2500.2786
# Epoch 61/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5353 - gamma_nll: 2.5368 - root_mean_squared_error: 2493.6421 - val_loss: 2.5674 - val_gamma_nll: 2.5673 - val_root_mean_squared_error: 2420.1477
# 1/1 [==============================] - 0s 26ms/step - loss: 2.5649 - gamma_nll: 2.5649 - root_mean_squared_error: 2419.1326
# Epoch 1/5000
# 30/30 [==============================] - 1s 16ms/step - loss: 2.5481 - gamma_nll: 2.5483 - root_mean_squared_error: 2505.5920 - val_loss: 2.5732 - val_gamma_nll: 2.5731 - val_root_mean_squared_error: 2420.0891
# Epoch 2/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5378 - gamma_nll: 2.5379 - root_mean_squared_error: 2488.8816 - val_loss: 2.5726 - val_gamma_nll: 2.5725 - val_root_mean_squared_error: 2440.2107
# Epoch 3/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 2.5372 - gamma_nll: 2.5392 - root_mean_squared_error: 2489.7393 - val_loss: 2.5846 - val_gamma_nll: 2.5844 - val_root_mean_squared_error: 2493.6929
# Epoch 4/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5478 - gamma_nll: 2.5485 - root_mean_squared_error: 2506.4741 - val_loss: 2.5818 - val_gamma_nll: 2.5818 - val_root_mean_squared_error: 2458.2659
# Epoch 5/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5415 - gamma_nll: 2.5410 - root_mean_squared_error: 2492.3499 - val_loss: 2.5866 - val_gamma_nll: 2.5865 - val_root_mean_squared_error: 2481.6091
# Epoch 6/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5327 - gamma_nll: 2.5337 - root_mean_squared_error: 2487.1836 - val_loss: 2.5693 - val_gamma_nll: 2.5692 - val_root_mean_squared_error: 2424.8694
# Epoch 7/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5327 - gamma_nll: 2.5328 - root_mean_squared_error: 2481.8826 - val_loss: 2.5894 - val_gamma_nll: 2.5892 - val_root_mean_squared_error: 2448.1758
# Epoch 8/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5330 - gamma_nll: 2.5330 - root_mean_squared_error: 2488.5864 - val_loss: 2.5702 - val_gamma_nll: 2.5702 - val_root_mean_squared_error: 2411.7192
# Epoch 9/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5342 - gamma_nll: 2.5335 - root_mean_squared_error: 2487.4883 - val_loss: 2.5768 - val_gamma_nll: 2.5767 - val_root_mean_squared_error: 2420.7886
# Epoch 10/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5318 - gamma_nll: 2.5312 - root_mean_squared_error: 2487.1780 - val_loss: 2.5742 - val_gamma_nll: 2.5742 - val_root_mean_squared_error: 2450.6953
# Epoch 11/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5322 - gamma_nll: 2.5322 - root_mean_squared_error: 2485.1570 - val_loss: 2.5971 - val_gamma_nll: 2.5969 - val_root_mean_squared_error: 2489.4619
# Epoch 12/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5347 - gamma_nll: 2.5348 - root_mean_squared_error: 2485.9014 - val_loss: 2.6013 - val_gamma_nll: 2.6012 - val_root_mean_squared_error: 2505.6746
# Epoch 13/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5316 - gamma_nll: 2.5325 - root_mean_squared_error: 2485.4626 - val_loss: 2.5665 - val_gamma_nll: 2.5665 - val_root_mean_squared_error: 2409.4990
# Epoch 14/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5292 - gamma_nll: 2.5298 - root_mean_squared_error: 2484.0505 - val_loss: 2.5737 - val_gamma_nll: 2.5736 - val_root_mean_squared_error: 2421.6946
# Epoch 15/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5324 - gamma_nll: 2.5332 - root_mean_squared_error: 2480.1711 - val_loss: 2.5844 - val_gamma_nll: 2.5842 - val_root_mean_squared_error: 2428.0576
# Epoch 16/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5311 - gamma_nll: 2.5311 - root_mean_squared_error: 2488.9197 - val_loss: 2.7118 - val_gamma_nll: 2.7116 - val_root_mean_squared_error: 2423.9216
# Epoch 17/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5306 - gamma_nll: 2.5311 - root_mean_squared_error: 2480.5439 - val_loss: 2.6921 - val_gamma_nll: 2.6920 - val_root_mean_squared_error: 2417.1672
# Epoch 18/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5336 - gamma_nll: 2.5337 - root_mean_squared_error: 2485.3843 - val_loss: 2.5706 - val_gamma_nll: 2.5706 - val_root_mean_squared_error: 2410.0286
# Epoch 19/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5279 - gamma_nll: 2.5276 - root_mean_squared_error: 2480.8447 - val_loss: 2.5702 - val_gamma_nll: 2.5701 - val_root_mean_squared_error: 2438.2393
# Epoch 20/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5344 - gamma_nll: 2.5339 - root_mean_squared_error: 2485.3855 - val_loss: 2.5686 - val_gamma_nll: 2.5685 - val_root_mean_squared_error: 2397.3977
# Epoch 21/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5351 - gamma_nll: 2.5348 - root_mean_squared_error: 2488.5576 - val_loss: 2.5700 - val_gamma_nll: 2.5699 - val_root_mean_squared_error: 2391.8618
# Epoch 22/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.5324 - gamma_nll: 2.5321 - root_mean_squared_error: 2495.1169 - val_loss: 2.5760 - val_gamma_nll: 2.5760 - val_root_mean_squared_error: 2386.8767
# Epoch 23/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5335 - gamma_nll: 2.5335 - root_mean_squared_error: 2485.1665 - val_loss: 2.6284 - val_gamma_nll: 2.6282 - val_root_mean_squared_error: 2425.7925
# Epoch 24/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5297 - gamma_nll: 2.5297 - root_mean_squared_error: 2484.9680 - val_loss: 2.6887 - val_gamma_nll: 2.6886 - val_root_mean_squared_error: 2417.6245
# Epoch 25/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5324 - gamma_nll: 2.5330 - root_mean_squared_error: 2489.1555 - val_loss: 2.5747 - val_gamma_nll: 2.5745 - val_root_mean_squared_error: 2445.7097
# Epoch 26/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5319 - gamma_nll: 2.5309 - root_mean_squared_error: 2487.3613 - val_loss: 2.5709 - val_gamma_nll: 2.5708 - val_root_mean_squared_error: 2419.1003
# Epoch 27/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5305 - gamma_nll: 2.5309 - root_mean_squared_error: 2481.7795 - val_loss: 2.5755 - val_gamma_nll: 2.5753 - val_root_mean_squared_error: 2417.3557
# Epoch 28/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5340 - gamma_nll: 2.5330 - root_mean_squared_error: 2483.5100 - val_loss: 2.5669 - val_gamma_nll: 2.5668 - val_root_mean_squared_error: 2438.1707
# Epoch 29/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5291 - gamma_nll: 2.5290 - root_mean_squared_error: 2492.2217 - val_loss: 2.5634 - val_gamma_nll: 2.5633 - val_root_mean_squared_error: 2422.6848
# Epoch 30/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5350 - gamma_nll: 2.5345 - root_mean_squared_error: 2488.0903 - val_loss: 2.5680 - val_gamma_nll: 2.5680 - val_root_mean_squared_error: 2421.1865
# Epoch 31/5000
# ...
# Epoch 98/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2726 - gamma_nll: 2.2728 - root_mean_squared_error: 2396.9187 - val_loss: 2.3217 - val_gamma_nll: 2.3213 - val_root_mean_squared_error: 2323.8723
# Epoch 99/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2612 - gamma_nll: 2.2610 - root_mean_squared_error: 2399.6860 - val_loss: 2.3147 - val_gamma_nll: 2.3143 - val_root_mean_squared_error: 2346.9534
# Epoch 100/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2709 - gamma_nll: 2.2710 - root_mean_squared_error: 2398.5979 - val_loss: 2.3318 - val_gamma_nll: 2.3312 - val_root_mean_squared_error: 2350.6875
# Epoch 101/5000
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2762 - gamma_nll: 2.2763 - root_mean_squared_error: 2410.5991 - val_loss: 2.3144 - val_gamma_nll: 2.3140 - val_root_mean_squared_error: 2371.2966
# Epoch 102/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2541 - gamma_nll: 2.2539 - root_mean_squared_error: 2389.3577 - val_loss: 2.3172 - val_gamma_nll: 2.3168 - val_root_mean_squared_error: 2335.2554
# Epoch 103/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2652 - gamma_nll: 2.2660 - root_mean_squared_error: 2392.3457 - val_loss: 2.3838 - val_gamma_nll: 2.3837 - val_root_mean_squared_error: 2476.7656
# Epoch 104/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2921 - gamma_nll: 2.2919 - root_mean_squared_error: 2407.7383 - val_loss: 2.3250 - val_gamma_nll: 2.3249 - val_root_mean_squared_error: 2400.9231
# Epoch 105/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.2731 - gamma_nll: 2.2732 - root_mean_squared_error: 2398.1641 - val_loss: 2.3163 - val_gamma_nll: 2.3156 - val_root_mean_squared_error: 2358.2256
# Epoch 106/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2709 - gamma_nll: 2.2703 - root_mean_squared_error: 2396.0898 - val_loss: 2.3695 - val_gamma_nll: 2.3693 - val_root_mean_squared_error: 2341.0161
# Epoch 107/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2875 - gamma_nll: 2.2875 - root_mean_squared_error: 2398.6777 - val_loss: 2.3607 - val_gamma_nll: 2.3602 - val_root_mean_squared_error: 2337.7239
# Epoch 108/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2749 - gamma_nll: 2.2753 - root_mean_squared_error: 2398.1858 - val_loss: 2.3235 - val_gamma_nll: 2.3232 - val_root_mean_squared_error: 2339.5410
# Epoch 109/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2595 - gamma_nll: 2.2593 - root_mean_squared_error: 2393.3960 - val_loss: 2.3387 - val_gamma_nll: 2.3384 - val_root_mean_squared_error: 2412.7063
# Epoch 110/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2657 - gamma_nll: 2.2670 - root_mean_squared_error: 2393.2327 - val_loss: 2.3104 - val_gamma_nll: 2.3101 - val_root_mean_squared_error: 2327.7695
# Epoch 111/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2645 - gamma_nll: 2.2639 - root_mean_squared_error: 2393.5952 - val_loss: 2.3306 - val_gamma_nll: 2.3301 - val_root_mean_squared_error: 2416.0474
# Epoch 112/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2589 - gamma_nll: 2.2588 - root_mean_squared_error: 2385.1208 - val_loss: 2.3203 - val_gamma_nll: 2.3203 - val_root_mean_squared_error: 2353.2622
# Epoch 113/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2634 - gamma_nll: 2.2638 - root_mean_squared_error: 2403.6580 - val_loss: 2.3034 - val_gamma_nll: 2.3030 - val_root_mean_squared_error: 2322.3726
# Epoch 114/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2608 - gamma_nll: 2.2599 - root_mean_squared_error: 2394.2559 - val_loss: 2.4157 - val_gamma_nll: 2.4150 - val_root_mean_squared_error: 2324.4023
# Epoch 115/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2586 - gamma_nll: 2.2583 - root_mean_squared_error: 2402.5876 - val_loss: 2.3363 - val_gamma_nll: 2.3363 - val_root_mean_squared_error: 2405.5947
# Epoch 116/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2654 - gamma_nll: 2.2651 - root_mean_squared_error: 2395.8694 - val_loss: 2.3357 - val_gamma_nll: 2.3355 - val_root_mean_squared_error: 2439.9368
# Epoch 117/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2693 - gamma_nll: 2.2691 - root_mean_squared_error: 2402.3486 - val_loss: 2.3130 - val_gamma_nll: 2.3124 - val_root_mean_squared_error: 2396.9146
# Epoch 118/5000
# 30/30 [==============================] - 0s 11ms/step - loss: 2.2594 - gamma_nll: 2.2589 - root_mean_squared_error: 2393.8308 - val_loss: 2.3015 - val_gamma_nll: 2.3013 - val_root_mean_squared_error: 2337.3555
# Epoch 119/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2582 - gamma_nll: 2.2581 - root_mean_squared_error: 2388.1189 - val_loss: 2.3198 - val_gamma_nll: 2.3195 - val_root_mean_squared_error: 2373.6838
# Epoch 120/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2634 - gamma_nll: 2.2629 - root_mean_squared_error: 2395.5559 - val_loss: 2.3108 - val_gamma_nll: 2.3104 - val_root_mean_squared_error: 2342.8262
# Epoch 121/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2675 - gamma_nll: 2.2687 - root_mean_squared_error: 2402.1404 - val_loss: 2.3338 - val_gamma_nll: 2.3335 - val_root_mean_squared_error: 2345.3723
# Epoch 122/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2613 - gamma_nll: 2.2612 - root_mean_squared_error: 2403.0205 - val_loss: 2.2897 - val_gamma_nll: 2.2894 - val_root_mean_squared_error: 2340.1809
# Epoch 123/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2450 - gamma_nll: 2.2444 - root_mean_squared_error: 2395.4812 - val_loss: 2.3049 - val_gamma_nll: 2.3046 - val_root_mean_squared_error: 2374.3181
# Epoch 124/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2496 - gamma_nll: 2.2500 - root_mean_squared_error: 2382.1040 - val_loss: 2.3265 - val_gamma_nll: 2.3262 - val_root_mean_squared_error: 2345.4128
# Epoch 125/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2733 - gamma_nll: 2.2728 - root_mean_squared_error: 2392.2754 - val_loss: 2.3303 - val_gamma_nll: 2.3301 - val_root_mean_squared_error: 2412.5977
# Epoch 126/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2611 - gamma_nll: 2.2605 - root_mean_squared_error: 2394.8235 - val_loss: 2.3118 - val_gamma_nll: 2.3115 - val_root_mean_squared_error: 2315.9773
# Epoch 127/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2481 - gamma_nll: 2.2481 - root_mean_squared_error: 2386.4604 - val_loss: 2.3043 - val_gamma_nll: 2.3038 - val_root_mean_squared_error: 2323.2312
# Epoch 128/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2612 - gamma_nll: 2.2603 - root_mean_squared_error: 2390.6731 - val_loss: 2.3477 - val_gamma_nll: 2.3474 - val_root_mean_squared_error: 2339.8147
# Epoch 129/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2726 - gamma_nll: 2.2723 - root_mean_squared_error: 2400.4185 - val_loss: 2.3129 - val_gamma_nll: 2.3125 - val_root_mean_squared_error: 2347.9934
# Epoch 130/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2474 - gamma_nll: 2.2478 - root_mean_squared_error: 2383.9380 - val_loss: 2.2842 - val_gamma_nll: 2.2840 - val_root_mean_squared_error: 2356.3931
# Epoch 131/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2598 - gamma_nll: 2.2593 - root_mean_squared_error: 2390.1914 - val_loss: 2.3047 - val_gamma_nll: 2.3046 - val_root_mean_squared_error: 2381.0037
# Epoch 132/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2620 - gamma_nll: 2.2625 - root_mean_squared_error: 2392.4233 - val_loss: 2.3023 - val_gamma_nll: 2.3022 - val_root_mean_squared_error: 2374.6353
# Epoch 133/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2459 - gamma_nll: 2.2460 - root_mean_squared_error: 2391.6282 - val_loss: 2.3241 - val_gamma_nll: 2.3239 - val_root_mean_squared_error: 2380.3440
# Epoch 134/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2719 - gamma_nll: 2.2720 - root_mean_squared_error: 2401.3733 - val_loss: 2.3494 - val_gamma_nll: 2.3490 - val_root_mean_squared_error: 2450.4824
# Epoch 135/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2578 - gamma_nll: 2.2576 - root_mean_squared_error: 2396.1567 - val_loss: 2.3170 - val_gamma_nll: 2.3167 - val_root_mean_squared_error: 2344.6128
# Epoch 136/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2398 - gamma_nll: 2.2396 - root_mean_squared_error: 2387.2798 - val_loss: 2.3039 - val_gamma_nll: 2.3037 - val_root_mean_squared_error: 2308.2969
# Epoch 137/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2456 - gamma_nll: 2.2452 - root_mean_squared_error: 2388.8530 - val_loss: 2.2997 - val_gamma_nll: 2.2995 - val_root_mean_squared_error: 2329.9675
# Epoch 138/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2563 - gamma_nll: 2.2567 - root_mean_squared_error: 2393.5051 - val_loss: 2.3340 - val_gamma_nll: 2.3344 - val_root_mean_squared_error: 2367.2273
# Epoch 139/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2795 - gamma_nll: 2.2802 - root_mean_squared_error: 2396.1013 - val_loss: 2.3394 - val_gamma_nll: 2.3389 - val_root_mean_squared_error: 2401.5203
# Epoch 140/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2500 - gamma_nll: 2.2503 - root_mean_squared_error: 2397.5491 - val_loss: 2.2998 - val_gamma_nll: 2.2996 - val_root_mean_squared_error: 2352.7532
# Epoch 141/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2643 - gamma_nll: 2.2647 - root_mean_squared_error: 2393.1692 - val_loss: 2.3572 - val_gamma_nll: 2.3566 - val_root_mean_squared_error: 2451.5793
# Epoch 142/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2505 - gamma_nll: 2.2501 - root_mean_squared_error: 2390.5625 - val_loss: 2.2807 - val_gamma_nll: 2.2804 - val_root_mean_squared_error: 2333.7830
# Epoch 143/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2442 - gamma_nll: 2.2446 - root_mean_squared_error: 2388.3320 - val_loss: 2.3061 - val_gamma_nll: 2.3057 - val_root_mean_squared_error: 2343.1853
# Epoch 144/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2609 - gamma_nll: 2.2616 - root_mean_squared_error: 2412.4248 - val_loss: 2.2961 - val_gamma_nll: 2.2960 - val_root_mean_squared_error: 2349.8401
# Epoch 145/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2494 - gamma_nll: 2.2487 - root_mean_squared_error: 2385.4138 - val_loss: 2.3047 - val_gamma_nll: 2.3046 - val_root_mean_squared_error: 2335.7454
# Epoch 146/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2468 - gamma_nll: 2.2465 - root_mean_squared_error: 2392.2644 - val_loss: 2.3087 - val_gamma_nll: 2.3084 - val_root_mean_squared_error: 2346.1492
# Epoch 147/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2434 - gamma_nll: 2.2439 - root_mean_squared_error: 2387.0027 - val_loss: 2.2993 - val_gamma_nll: 2.2991 - val_root_mean_squared_error: 2335.8914
# Epoch 148/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2358 - gamma_nll: 2.2350 - root_mean_squared_error: 2384.3718 - val_loss: 2.2812 - val_gamma_nll: 2.2809 - val_root_mean_squared_error: 2336.2107
# Epoch 149/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2389 - gamma_nll: 2.2390 - root_mean_squared_error: 2388.3325 - val_loss: 2.3080 - val_gamma_nll: 2.3080 - val_root_mean_squared_error: 2335.5925
# Epoch 150/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2543 - gamma_nll: 2.2547 - root_mean_squared_error: 2392.2070 - val_loss: 2.3226 - val_gamma_nll: 2.3227 - val_root_mean_squared_error: 2399.1765
# Epoch 151/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2486 - gamma_nll: 2.2480 - root_mean_squared_error: 2398.1797 - val_loss: 2.2916 - val_gamma_nll: 2.2915 - val_root_mean_squared_error: 2381.8613
# Epoch 152/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2340 - gamma_nll: 2.2346 - root_mean_squared_error: 2383.8110 - val_loss: 2.2867 - val_gamma_nll: 2.2866 - val_root_mean_squared_error: 2339.7432
# Epoch 153/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2285 - gamma_nll: 2.2278 - root_mean_squared_error: 2373.8372 - val_loss: 2.2819 - val_gamma_nll: 2.2815 - val_root_mean_squared_error: 2386.2332
# Epoch 154/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2263 - gamma_nll: 2.2256 - root_mean_squared_error: 2380.3179 - val_loss: 2.3154 - val_gamma_nll: 2.3151 - val_root_mean_squared_error: 2371.4902
# Epoch 155/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2462 - gamma_nll: 2.2467 - root_mean_squared_error: 2383.5586 - val_loss: 2.3057 - val_gamma_nll: 2.3055 - val_root_mean_squared_error: 2379.2244
# Epoch 156/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2431 - gamma_nll: 2.2427 - root_mean_squared_error: 2397.3608 - val_loss: 2.2974 - val_gamma_nll: 2.2973 - val_root_mean_squared_error: 2399.9570
# Epoch 157/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2370 - gamma_nll: 2.2378 - root_mean_squared_error: 2382.6289 - val_loss: 2.3013 - val_gamma_nll: 2.3012 - val_root_mean_squared_error: 2346.4023
# Epoch 158/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2607 - gamma_nll: 2.2619 - root_mean_squared_error: 2400.4829 - val_loss: 2.3697 - val_gamma_nll: 2.3695 - val_root_mean_squared_error: 2515.3037
# Epoch 159/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2377 - gamma_nll: 2.2375 - root_mean_squared_error: 2387.0854 - val_loss: 2.2897 - val_gamma_nll: 2.2896 - val_root_mean_squared_error: 2364.5417
# Epoch 160/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2618 - gamma_nll: 2.2620 - root_mean_squared_error: 2390.7349 - val_loss: 2.3299 - val_gamma_nll: 2.3304 - val_root_mean_squared_error: 2414.1077
# Epoch 161/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2467 - gamma_nll: 2.2469 - root_mean_squared_error: 2388.9189 - val_loss: 2.2817 - val_gamma_nll: 2.2817 - val_root_mean_squared_error: 2371.5737
# Epoch 162/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2378 - gamma_nll: 2.2382 - root_mean_squared_error: 2381.7126 - val_loss: 2.3079 - val_gamma_nll: 2.3076 - val_root_mean_squared_error: 2321.4124
# Epoch 163/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2336 - gamma_nll: 2.2340 - root_mean_squared_error: 2390.9351 - val_loss: 2.3086 - val_gamma_nll: 2.3085 - val_root_mean_squared_error: 2335.7891
# Epoch 164/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2353 - gamma_nll: 2.2350 - root_mean_squared_error: 2381.6892 - val_loss: 2.3373 - val_gamma_nll: 2.3374 - val_root_mean_squared_error: 2329.7415
# Epoch 165/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2491 - gamma_nll: 2.2488 - root_mean_squared_error: 2393.6218 - val_loss: 2.3465 - val_gamma_nll: 2.3461 - val_root_mean_squared_error: 2467.3848
# Epoch 166/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2528 - gamma_nll: 2.2536 - root_mean_squared_error: 2389.2966 - val_loss: 2.3163 - val_gamma_nll: 2.3158 - val_root_mean_squared_error: 2334.3911
# Epoch 167/5000
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2318 - gamma_nll: 2.2316 - root_mean_squared_error: 2379.5369 - val_loss: 2.2893 - val_gamma_nll: 2.2891 - val_root_mean_squared_error: 2332.2263
# 1/1 [==============================] - 0s 30ms/step - loss: 2.2807 - gamma_nll: 2.2807 - root_mean_squared_error: 2333.7827

# %%
# -------------------------- plot the validation loss --------------------------
# Convert interaction loss dictionary to a pandas DataFrame
interaction_df = pd.DataFrame(list(interaction_loss.items()), columns = ['Interaction_Pair', 'Validation_Loss'])

# Sort the DataFrame by Validation_Loss in increasing order
interaction_df = interaction_df.sort_values(by = 'Validation_Loss', ascending = True)

# for presentation, select top k effect
interaction_df = interaction_df.head(10)

# Create the bar plot using Seaborn
# plt.figure(figsize = (12, 8))
sns.lineplot(x = 'Interaction_Pair', y = 'Validation_Loss', data = interaction_df, marker = 'o')
plt.axhline(main_val_loss, color = 'red', linestyle = '--')
plt.xlabel('')
plt.ylabel('Validation Loss')
plt.title('Validation Loss for Pairwise Effect - Top 10 - Low Noise')
# plt.legend()

plt.rcParams["figure.figsize"] = (8, 3) # (for square figures)
plt.rcParams["figure.dpi"] = 350
plt.rcParams["savefig.bbox"] = "tight"
plt.rcParams["font.family"] = "serif"
plt.rcParams["axes.spines.right"] = False
plt.rcParams["axes.spines.top"] = False

plt.ylim(2.2,2.7)

plt.show()
