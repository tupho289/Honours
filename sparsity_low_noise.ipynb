# %%
############################ 0. PREPARATION ############################

#-------------------------- import packages --------------------------
import random
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from itertools import combinations
import seaborn as sns
import copy
import itertools

import tensorflow as tf
import tensorflow_lattice as tfl
import tf_keras as keras # need keras 2 to fit Lattice model
from tf_keras.models import Sequential, Model
from tf_keras.layers import Dense, Input, Multiply, Add, Embedding, Reshape, Concatenate, Dropout, BatchNormalization, Lambda, Layer, CategoryEncoding, Activation
from tf_keras.constraints import Constraint
from tf_keras.callbacks import EarlyStopping
from tf_keras.initializers import Zeros, Constant
from tf_keras.optimizers import Adam, Nadam, RMSprop
from tf_keras.models import clone_model
import keras_tuner as kt
from tf_keras import backend as K
from tf_keras import regularizers
from tf_keras.utils import plot_model
from tf_keras.losses import Poisson, Loss
from tf_keras.metrics import MeanAbsoluteError, RootMeanSquaredError
from scipy.stats import gamma


from pygam import LinearGAM, GAM, s, f, l
from sklearn.linear_model import ElasticNet
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error as mae
from sklearn.tree import DecisionTreeRegressor
from interpret.glassbox import ExplainableBoostingClassifier

# %%
#-------------------------- for reproducibility --------------------------
seed_value = 28
keras.utils.set_random_seed(seed_value)

# %%
#-------------------------- import data --------------------------
data = pd.read_csv("synthetic_low_var.csv")

# %%
#-------------------------- remove outliers --------------------------
log_claim = np.log(data['Y'])
IQR = log_claim.quantile(0.75) - log_claim.quantile(0.25) # inter-quartile range
lower_whisker = log_claim.quantile(0.25)- 1.5*IQR
upper_whisker = log_claim.quantile(0.75) + 1.5*IQR

# remove outliers: filter rows where the log of 'Y' is within the whiskers
dt_cleaned = data[(log_claim >= lower_whisker) & (log_claim <= upper_whisker)]
dt_cleaned
# Out:
#              X1        X2        X3        X4        X5        X6        X7  \
# 0      0.097627 -0.215654 -0.261487  0.855910 -0.977807  0.070514  0.247397
# 1      0.430379 -0.917687 -0.577348  0.805874 -0.996460  0.808088 -0.727145
# 2      0.205527  0.846601 -0.046190 -0.144766 -0.689890  0.004793  0.787168
# 3      0.089766 -0.187530 -0.835531  0.021611 -0.366478 -0.798260 -0.363850
# 4     -0.152690  0.888564 -0.524681  0.166400  0.303690  0.055164  0.158018
# ...         ...       ...       ...       ...       ...       ...       ...
# 19995  0.496349  0.336766  0.766494 -0.723110  0.451842 -0.547824  0.165682
# 19996 -0.403467  0.989823 -0.239838  0.690306  0.015041  0.168038 -0.808643
# 19997 -0.107088  0.176448 -0.661992  0.568246  0.620266  0.669292 -0.267906
# 19998 -0.279747 -0.150770 -0.472139  0.238510  0.102065 -0.832383  0.539168
# 19999  0.251773  0.803265 -0.397666 -0.684942 -0.548488 -0.791774 -0.620137
#
#              X8        X9       X10            Y
# 0     -0.844805 -0.633014  0.932805   269.727579
# 1      0.592222  0.416902  0.949203   606.423722
# 2     -0.029304 -0.254262 -0.739165  6740.904922
# 3      0.669637 -0.150974  0.020263  6749.592779
# 4      0.046901 -0.468522 -0.772319    79.024055
# ...         ...       ...       ...          ...
# 19995 -0.515032  0.372611 -0.262674    30.561326
# 19996 -0.903895 -0.433667 -0.389854   105.129106
# 19997  0.006409  0.871063 -0.570751  1101.252426
# 19998  0.073274  0.110462 -0.408447   634.928937
# 19999  0.197031 -0.409905  0.685008  2295.828834
#
# [19825 rows x 11 columns]

# %%
#-------------------------- distribution of log(response) --------------------------
plt.figure(figsize = (10, 6)) # set the size of the figure
sns.set_style("darkgrid")
sns.histplot(np.log(dt_cleaned['Y']), bins = 30, kde = True) # draw the chart
plt.title('Distribution of log(Y)')
plt.xlabel('Log(Y)')
plt.ylabel('Frequency')
plt.tick_params(axis = 'x')
plt.tick_params(axis = 'y')
plt.grid(True)
plt.show()

# %%
# remove unnecessary columns
dt_cleaned = dt_cleaned.drop(columns=["X7", "X8", "X9", "X10"])

# %%
#-------------------------- column lists --------------------------
target_var = "Y" # target feature
all_vars = list(dt_cleaned.columns)
all_vars.remove(target_var) # store all input features
cat_vars = [] # categorical features

# %%
############################ 1. MODEL FITTING ############################

#-------------------------- train-test split --------------------------
X_main, X_test, y_main, y_test = train_test_split(
    dt_cleaned[all_vars], dt_cleaned[["Y"]], test_size = 0.2, random_state = 1)
X_train, X_val, y_train, y_val  = train_test_split(
    X_main, y_main, test_size = 0.25, random_state = 1)

# %%
# -------------------------- function to create a subnetwork --------------------------
# subnet for numerical variables
def create_subnet(num_layers, units_per_layer, activation, model_name, dropout_rate = 0, trainable = True, seed = 1):
    model = Sequential(name = model_name)
    for _ in range(num_layers):
        model.add(Dense(units_per_layer, activation = activation, trainable = trainable))
        model.add(Dropout(dropout_rate, seed = seed))
    model.add(Dense(1, trainable = trainable))
    model.add(BatchNormalization(scale = False)) # for identifiability
    return model

# layer to add all subnets' outputs and a bias term
@keras.saving.register_keras_serializable()
class AddSubnetOutput(Layer):
    def __init__(self, activation = None, **kwargs):
        super().__init__(**kwargs)
        self.activation = keras.activations.get(activation)
        self.bias = self.add_weight(
            shape = (1,), initializer = 'zeros', trainable = True, name = 'bias'
        )   
    def call(self, inputs):
        subnet_sum = K.sum(inputs, axis = -1, keepdims = True)
        output = subnet_sum + self.bias
        if self.activation is not None:
            output = self.activation(output)
        return output

# %%
# -------------------------- define model architecture --------------------------
inputs = []  # input layers
sub_outputs_main = []  # main effect subnet output
num_neurons_main = 10
num_layers_main = 2
activation = 'leaky_relu'
keypoints = 10
monotonicity_list = {"X3" : "decreasing"} # either "increasing", "decreasing", or "none"

# main effect
for name in all_vars:
    input_layer = Input(shape = (1,), name = name)
    inputs.append(input_layer)

    # subnetworks for main effects
    if name in cat_vars: # categorical variables
        # categorical variables will be one-hot encoded
        embed_layer = Embedding(input_dim = X_train[name].nunique(), 
                                output_dim = 1, 
                                name = f"{name}_embed")(input_layer)
        embed_layer_reshape = Reshape(target_shape = (1,), name = f"{name}_reshape")(embed_layer)
        mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(embed_layer_reshape)
        sub_outputs_main.append(mean_layer)
    elif name in monotonicity_list: # variables with monotonicity constraint
        calibrator_layer = tfl.layers.PWLCalibration(
            input_keypoints =  np.linspace(X_train[name].min(), X_train[name].max(), num = keypoints), # keypoints
            monotonicity = monotonicity_list[name], # monotonicity constraint
            name = f"{name}_pwlcalibrator"
        )(input_layer)
        mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(calibrator_layer)
        sub_outputs_main.append(mean_layer)
    else: # numeric variables
        subnet = create_subnet(num_layers_main, num_neurons_main, activation, f"{name}_subnetwork")
        sub_output = subnet(input_layer)
        sub_outputs_main.append(sub_output)

# combine subnets' outputs
main_subnets = Concatenate(name = "main_subnet")(sub_outputs_main)
final_output = AddSubnetOutput(activation = 'exponential',
                     name = "main_output")(main_subnets)

# final model
model_main_effect = Model(inputs = inputs, outputs = final_output)

# %%
plot_model(model_main_effect)

# %%
# -------------------------- define loss function --------------------------
# we will use a Gamma loss function
def gamma_nll(y_true, y_pred):
    y_pred = K.clip(y_pred, 1e-7, 1e30)
    return K.mean(y_true/y_pred - K.log(y_true/y_pred))

# create training & validation data consistent with the model architecture
X_train_split = []
X_val_split = []
X_test_split = []
for i in range(len(X_train.columns)):
    X_train_split.append(X_train.iloc[:, i])
    X_val_split.append(X_val.iloc[:, i])
    X_test_split.append(X_test.iloc[:, i])

# compile and fit
model_main_effect.compile(optimizer = "rmsprop", loss = gamma_nll, metrics = [RootMeanSquaredError()])
es = EarlyStopping(restore_best_weights = True, patience = 10)
# %time hist_main = model_main_effect.fit(X_train_split, y_train, epochs = 5_000, \
    callbacks = [es], batch_size = 1_000, validation_data = (X_val_split, y_val))
# Out:
# Epoch 1/5000
# 12/12 [==============================] - 1s 19ms/step - loss: 5629.9551 - root_mean_squared_error: 2395.5098 - val_loss: 980.3502 - val_root_mean_squared_error: 2619.5083
# Epoch 2/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 3092.4653 - root_mean_squared_error: 2395.2100 - val_loss: 911.1771 - val_root_mean_squared_error: 2619.4858
# Epoch 3/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2288.1748 - root_mean_squared_error: 2394.4880 - val_loss: 831.9930 - val_root_mean_squared_error: 2619.4546
# Epoch 4/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1710.1042 - root_mean_squared_error: 2394.3057 - val_loss: 759.2111 - val_root_mean_squared_error: 2619.4236
# Epoch 5/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1199.1104 - root_mean_squared_error: 2394.4163 - val_loss: 657.9146 - val_root_mean_squared_error: 2619.3706
# Epoch 6/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 693.7748 - root_mean_squared_error: 2395.2693 - val_loss: 602.0829 - val_root_mean_squared_error: 2619.3291
# Epoch 7/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 521.3303 - root_mean_squared_error: 2395.6699 - val_loss: 567.3983 - val_root_mean_squared_error: 2619.2981
# Epoch 8/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 415.4716 - root_mean_squared_error: 2395.9294 - val_loss: 525.9407 - val_root_mean_squared_error: 2619.2551
# Epoch 9/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 356.7054 - root_mean_squared_error: 2396.0391 - val_loss: 480.6616 - val_root_mean_squared_error: 2619.1997
# Epoch 10/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 318.8194 - root_mean_squared_error: 2396.0193 - val_loss: 435.9435 - val_root_mean_squared_error: 2619.1328
# Epoch 11/5000
# 12/12 [==============================] - 0s 20ms/step - loss: 291.9490 - root_mean_squared_error: 2395.8499 - val_loss: 422.5438 - val_root_mean_squared_error: 2619.1099
# Epoch 12/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 268.4313 - root_mean_squared_error: 2395.6758 - val_loss: 377.3536 - val_root_mean_squared_error: 2619.0210
# Epoch 13/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 245.0168 - root_mean_squared_error: 2395.4258 - val_loss: 336.6595 - val_root_mean_squared_error: 2618.9209
# Epoch 14/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 224.1485 - root_mean_squared_error: 2395.1919 - val_loss: 305.8699 - val_root_mean_squared_error: 2618.8274
# Epoch 15/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 205.8060 - root_mean_squared_error: 2394.9678 - val_loss: 271.3122 - val_root_mean_squared_error: 2618.6963
# Epoch 16/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 190.3553 - root_mean_squared_error: 2394.6250 - val_loss: 241.9803 - val_root_mean_squared_error: 2618.5586
# Epoch 17/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 175.1098 - root_mean_squared_error: 2394.4185 - val_loss: 213.2302 - val_root_mean_squared_error: 2618.3835
# Epoch 18/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 161.3362 - root_mean_squared_error: 2394.0100 - val_loss: 214.0962 - val_root_mean_squared_error: 2618.3872
# Epoch 19/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 148.6174 - root_mean_squared_error: 2393.7612 - val_loss: 200.3131 - val_root_mean_squared_error: 2618.2874
# Epoch 20/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 136.7106 - root_mean_squared_error: 2393.4248 - val_loss: 179.4663 - val_root_mean_squared_error: 2618.1062
# Epoch 21/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 125.7866 - root_mean_squared_error: 2392.9783 - val_loss: 150.7970 - val_root_mean_squared_error: 2617.7773
# Epoch 22/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 115.5256 - root_mean_squared_error: 2392.6230 - val_loss: 124.9489 - val_root_mean_squared_error: 2617.3516
# Epoch 23/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 107.5410 - root_mean_squared_error: 2392.0305 - val_loss: 114.5537 - val_root_mean_squared_error: 2617.1245
# Epoch 24/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 97.2565 - root_mean_squared_error: 2391.6765 - val_loss: 110.6620 - val_root_mean_squared_error: 2617.0188
# Epoch 25/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 90.4903 - root_mean_squared_error: 2390.9758 - val_loss: 96.6267 - val_root_mean_squared_error: 2616.6143
# Epoch 26/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 82.7981 - root_mean_squared_error: 2390.5806 - val_loss: 75.3060 - val_root_mean_squared_error: 2615.7036
# Epoch 27/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 75.6203 - root_mean_squared_error: 2389.8044 - val_loss: 69.3917 - val_root_mean_squared_error: 2615.3501
# Epoch 28/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 70.1021 - root_mean_squared_error: 2389.0713 - val_loss: 67.9719 - val_root_mean_squared_error: 2615.2607
# Epoch 29/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 64.3777 - root_mean_squared_error: 2388.3816 - val_loss: 70.8890 - val_root_mean_squared_error: 2615.4153
# Epoch 30/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 59.2953 - root_mean_squared_error: 2387.3772 - val_loss: 73.3877 - val_root_mean_squared_error: 2615.5530
# Epoch 31/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 54.4032 - root_mean_squared_error: 2386.5979 - val_loss: 71.7923 - val_root_mean_squared_error: 2615.4402
# Epoch 32/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 49.9208 - root_mean_squared_error: 2385.6917 - val_loss: 68.1687 - val_root_mean_squared_error: 2615.1914
# Epoch 33/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 46.0705 - root_mean_squared_error: 2384.6094 - val_loss: 69.7298 - val_root_mean_squared_error: 2615.2422
# Epoch 34/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 41.9875 - root_mean_squared_error: 2383.4429 - val_loss: 56.1638 - val_root_mean_squared_error: 2614.1145
# Epoch 35/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 38.6057 - root_mean_squared_error: 2381.7227 - val_loss: 64.8300 - val_root_mean_squared_error: 2614.8477
# Epoch 36/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 35.5195 - root_mean_squared_error: 2380.8904 - val_loss: 50.5995 - val_root_mean_squared_error: 2613.4155
# Epoch 37/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 32.6092 - root_mean_squared_error: 2379.4585 - val_loss: 48.5515 - val_root_mean_squared_error: 2613.1150
# Epoch 38/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 30.3796 - root_mean_squared_error: 2377.8560 - val_loss: 38.1577 - val_root_mean_squared_error: 2611.1997
# Epoch 39/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 27.6434 - root_mean_squared_error: 2375.8208 - val_loss: 33.2580 - val_root_mean_squared_error: 2609.8413
# Epoch 40/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 25.4193 - root_mean_squared_error: 2374.0332 - val_loss: 27.7925 - val_root_mean_squared_error: 2607.9824
# Epoch 41/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 23.2107 - root_mean_squared_error: 2372.2083 - val_loss: 23.5402 - val_root_mean_squared_error: 2605.8108
# Epoch 42/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 21.6960 - root_mean_squared_error: 2370.7092 - val_loss: 14.6639 - val_root_mean_squared_error: 2597.1921
# Epoch 43/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 19.7466 - root_mean_squared_error: 2367.8948 - val_loss: 16.5959 - val_root_mean_squared_error: 2599.3245
# Epoch 44/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 18.1424 - root_mean_squared_error: 2364.9194 - val_loss: 13.7909 - val_root_mean_squared_error: 2595.0295
# Epoch 45/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 16.7822 - root_mean_squared_error: 2362.3228 - val_loss: 18.2513 - val_root_mean_squared_error: 2600.6575
# Epoch 46/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 15.3686 - root_mean_squared_error: 2359.2996 - val_loss: 9.7900 - val_root_mean_squared_error: 2584.2104
# Epoch 47/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 14.2449 - root_mean_squared_error: 2356.0481 - val_loss: 7.8549 - val_root_mean_squared_error: 2575.1785
# Epoch 48/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 12.9627 - root_mean_squared_error: 2353.1902 - val_loss: 10.5243 - val_root_mean_squared_error: 2584.7046
# Epoch 49/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 11.9893 - root_mean_squared_error: 2348.4026 - val_loss: 9.1517 - val_root_mean_squared_error: 2579.7156
# Epoch 50/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 11.1100 - root_mean_squared_error: 2345.1406 - val_loss: 6.6442 - val_root_mean_squared_error: 2563.1160
# Epoch 51/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 10.2288 - root_mean_squared_error: 2340.9316 - val_loss: 7.2932 - val_root_mean_squared_error: 2565.9502
# Epoch 52/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 9.4127 - root_mean_squared_error: 2336.4631 - val_loss: 15.6828 - val_root_mean_squared_error: 2593.1060
# Epoch 53/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 8.7798 - root_mean_squared_error: 2329.8821 - val_loss: 13.9571 - val_root_mean_squared_error: 2589.8391
# Epoch 54/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 7.9941 - root_mean_squared_error: 2326.0820 - val_loss: 6.2931 - val_root_mean_squared_error: 2554.5742
# Epoch 55/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 7.4053 - root_mean_squared_error: 2319.3950 - val_loss: 10.6459 - val_root_mean_squared_error: 2580.2559
# Epoch 56/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 6.8759 - root_mean_squared_error: 2313.5654 - val_loss: 11.8604 - val_root_mean_squared_error: 2582.1670
# Epoch 57/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 6.3247 - root_mean_squared_error: 2307.9333 - val_loss: 8.1404 - val_root_mean_squared_error: 2562.0557
# Epoch 58/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 5.8865 - root_mean_squared_error: 2301.2295 - val_loss: 8.8878 - val_root_mean_squared_error: 2568.5557
# Epoch 59/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 5.4865 - root_mean_squared_error: 2291.9478 - val_loss: 5.0071 - val_root_mean_squared_error: 2523.5750
# Epoch 60/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 5.1258 - root_mean_squared_error: 2284.2561 - val_loss: 3.6972 - val_root_mean_squared_error: 2491.7354
# Epoch 61/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 4.7288 - root_mean_squared_error: 2277.6716 - val_loss: 5.4288 - val_root_mean_squared_error: 2533.5740
# Epoch 62/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 4.4350 - root_mean_squared_error: 2272.2368 - val_loss: 2.5164 - val_root_mean_squared_error: 2394.6711
# Epoch 63/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 4.1695 - root_mean_squared_error: 2263.6526 - val_loss: 2.9703 - val_root_mean_squared_error: 2431.9883
# Epoch 64/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 3.9109 - root_mean_squared_error: 2249.7124 - val_loss: 2.8620 - val_root_mean_squared_error: 2434.5288
# Epoch 65/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 3.6457 - root_mean_squared_error: 2240.9214 - val_loss: 2.3286 - val_root_mean_squared_error: 2355.1030
# Epoch 66/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 3.4610 - root_mean_squared_error: 2230.9331 - val_loss: 2.3740 - val_root_mean_squared_error: 2380.3345
# Epoch 67/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 3.2509 - root_mean_squared_error: 2221.0217 - val_loss: 2.2834 - val_root_mean_squared_error: 2356.9675
# Epoch 68/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 3.1137 - root_mean_squared_error: 2211.7666 - val_loss: 2.4045 - val_root_mean_squared_error: 2378.7952
# Epoch 69/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.9650 - root_mean_squared_error: 2201.9529 - val_loss: 2.6722 - val_root_mean_squared_error: 2408.5876
# Epoch 70/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.8211 - root_mean_squared_error: 2192.9478 - val_loss: 2.8525 - val_root_mean_squared_error: 2418.7207
# Epoch 71/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.7041 - root_mean_squared_error: 2184.4136 - val_loss: 2.2085 - val_root_mean_squared_error: 2366.2263
# Epoch 72/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.6295 - root_mean_squared_error: 2182.6179 - val_loss: 2.1926 - val_root_mean_squared_error: 2379.5718
# Epoch 73/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.5289 - root_mean_squared_error: 2163.7820 - val_loss: 2.1868 - val_root_mean_squared_error: 2359.4468
# Epoch 74/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.4530 - root_mean_squared_error: 2160.3979 - val_loss: 2.2056 - val_root_mean_squared_error: 2453.8064
# Epoch 75/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.3870 - root_mean_squared_error: 2152.1338 - val_loss: 2.5932 - val_root_mean_squared_error: 2394.9375
# Epoch 76/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.3419 - root_mean_squared_error: 2153.9316 - val_loss: 2.1881 - val_root_mean_squared_error: 2341.2666
# Epoch 77/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2931 - root_mean_squared_error: 2150.8584 - val_loss: 2.2056 - val_root_mean_squared_error: 2427.5251
# Epoch 78/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2593 - root_mean_squared_error: 2151.6189 - val_loss: 2.2030 - val_root_mean_squared_error: 2492.8132
# Epoch 79/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2314 - root_mean_squared_error: 2140.1355 - val_loss: 2.2363 - val_root_mean_squared_error: 2509.4153
# Epoch 80/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2084 - root_mean_squared_error: 2168.8821 - val_loss: 2.3284 - val_root_mean_squared_error: 2890.7847
# Epoch 81/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1970 - root_mean_squared_error: 2169.5022 - val_loss: 2.2070 - val_root_mean_squared_error: 2499.2019
# Epoch 82/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1873 - root_mean_squared_error: 2190.9607 - val_loss: 2.4236 - val_root_mean_squared_error: 3516.3269
# Epoch 83/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1836 - root_mean_squared_error: 2197.8767 - val_loss: 2.6762 - val_root_mean_squared_error: 5373.9702
# CPU times: user 5.06 s, sys: 530 ms, total: 5.59 s
# Wall time: 4.61 s

# %%
# -------------------------- get validation loss --------------------------
main_val_loss, main_rmse = model_main_effect.evaluate(X_val_split, y_val, verbose = False) # get the validation loss and RMSE
print(f"Validation loss for main effect: {main_val_loss}")
print(f"Validation RMSE for main effect: {main_rmse}")
# Out:
# Validation loss for main effect: 2.1868391036987305
# Validation RMSE for main effect: 2359.447265625

# %%
# -------------------------- quantify variable importance --------------------------
main_output_layer = model_main_effect.get_layer("main_subnet")  # Get the subnet output layer
main_model = Model(inputs = model_main_effect.inputs, outputs = main_output_layer.output)
main_output_values = main_model.predict(X_train_split)
# subnet_weights = model_main_effect.get_layer("main_output").get_weights()[0]


# Get the variance of each subnetwork across all data points
subnet_variance = []
for i in range(main_output_values.shape[1]):
    subnet_variance.append(np.var(main_output_values[:, i]))

# Define covariates
covariates = [name for name in all_vars]

# -------------------------- plot the variable importance --------------------------
# Create DataFrame for variable importance
var_importance = pd.DataFrame({"Covariates": covariates, "Subnet Variance": subnet_variance})

# Sort the DataFrame by subnet variance in decreasing order
varimp_sorted = var_importance.sort_values(by = "Subnet Variance", ascending = False)

# Create a bar plot using Seaborn
plt.figure(figsize = (10, 6))
sns.barplot(x = "Covariates", y = "Subnet Variance", data = varimp_sorted)
plt.title("Subnet Variance by Covariates")
plt.xlabel("Covariates")
plt.ylabel("Subnet Variance")
plt.show()
# Out:
# 372/372 [==============================] - 0s 560us/step

# %%
#-------------------------- view the shape function --------------------------
# create the plot
var_name = "X3"
var_index = all_vars.index(var_name)
plt.figure(figsize = (12, 6))
sns.lineplot(x = X_train_split[var_index], 
             y = main_output_values[:,var_index].flatten())
plt.xlabel(f"{var_name}")
plt.ylabel('Subnetwork Output')
plt.title(f"Shape function for {var_name}")
plt.grid(True)
plt.show()

# %%
############################   preparation for interaction selection   ############################
global_layers = ["main_subnet", "main_output", "interaction_output", "final_output"] # these layers are always trainable
imp_vars = [f"X{i}" for i in range(1,7)] # important variables
num_layers_interaction = 3 # number of layers for each interaction effect
num_neurons_interaction = 30 # number of neurons per dense layer for each interaction effect
keypoints = 20
lattice_sizes_pairwise = {}
for var in imp_vars:
    if var in cat_vars:
        lattice_sizes_pairwise[var] = X_train[var].nunique()
    else:
        lattice_sizes_pairwise[var] = 8

# %%
# -------------------------- create calibrator for lattice layer --------------------------
def add_calibrate_layer(var, data, monotonicity_list, lattice_sizes, keypoints, cat_vars, lattice_smooth_reg = [0,0]):
    if var in cat_vars:
        calibrator_layer = tfl.layers.CategoricalCalibration(
            num_buckets = data[var].nunique(),
            output_min = 0,
            output_max = lattice_sizes[var] - 1,
            name = f"{var}_calibrator_pairwise"
        )
    else:
        calibrator_layer = tfl.layers.PWLCalibration(
            input_keypoints =  np.linspace(data[var].min(), data[var].max(), num = keypoints), # keypoints
            kernel_regularizer = ('hessian', lattice_smooth_reg[0], lattice_smooth_reg[1]), # for smoothness
            monotonicity = monotonicity_list[var] if var in monotonicity_list else "none", # monotonicity constraint
            output_min = 0,
            output_max = lattice_sizes[var] - 1,
            name = f"{var}_calibrator_pairwise"
            )
    return calibrator_layer

# %%
############################   select interaction effect   ############################

lambd_val_loss = {}
# add pairwise effect and evaluate validation loss
for  lambd in [0]:

    interactions = combinations(imp_vars, 2)
    interaction_loss = {} # this stores the validation loss when fitting each pair of interaction effect
    for var1, var2 in interactions:

        # -------------------------- initialize a cloned model --------------------------
        model_main_cloned = clone_model(model_main_effect) # clone the main effect model
        model_main_cloned.build(model_main_effect.input_shape)
        model_main_cloned.set_weights(model_main_effect.get_weights()) # copy the weights


        # -------------------------- build a subnet for pairwise interaction effect --------------------------
        var1_input = model_main_cloned.inputs[all_vars.index(var1)]
        var2_input = model_main_cloned.inputs[all_vars.index(var2)]

        # Lattice model if the pair contains a monotonic variable
        if any(var in monotonicity_list for var in [var1, var2]):
            lattice_inputs = []

            # create calibrator_layer
            calibrator_var1 = add_calibrate_layer(var1, X_train, monotonicity_list, lattice_sizes_pairwise, keypoints, cat_vars)
            calibrator_var2 = add_calibrate_layer(var2, X_train, monotonicity_list, lattice_sizes_pairwise, keypoints, cat_vars)
            calibrator_layer_var1 = calibrator_var1(var1_input)
            calibrator_layer_var2 = calibrator_var2(var2_input)
            
            # lattice
            lattice_inputs.append(calibrator_layer_var1)
            lattice_inputs.append(calibrator_layer_var2)
            lattice_layer = tfl.layers.Lattice(lattice_sizes = [lattice_sizes_pairwise[var1],lattice_sizes_pairwise[var2]], 
                                monotonicities = ["increasing" if var1 in monotonicity_list else 'none',
                                                    "increasing" if var2 in monotonicity_list else 'none'],
                                name = f"{var1}_{var2}_lattice")(lattice_inputs)
            pairwise_output = BatchNormalization(scale = False, name = f"{var1}_{var2}_mean")(lattice_layer)
        else:
            # Subnetwork if the pair contains no monotonic variables
            pairwise_input_layer = Concatenate(name = f"{var1}_{var2}_concat")([var1_input, var2_input])
            pairwise_subnet = create_subnet(num_layers_interaction, 
                                            num_neurons_interaction, 
                                            activation, 
                                            f"{var1}_{var2}_subnetwork")
            pairwise_output = pairwise_subnet(pairwise_input_layer)

        # final output
        interaction_subnet_output = Activation('exponential',
                            name = "interaction_output")(pairwise_output)
        main_subnet_output = model_main_cloned.output
        final_output = Multiply(name = "final_output")([main_subnet_output, interaction_subnet_output])
        model_pairwise = Model(inputs = model_main_cloned.inputs, outputs = final_output)


        # -------------------------- switch on/off layers --------------------------
        for layer in model_pairwise.layers:
            if layer.name not in global_layers and var1 not in layer.name and var2 not in layer.name:
                layer.trainable = False


        #-------------------------- custom loss function with marginal clarity constraint --------------------------
        # add marginal clarity constraint
        main_effects_output = model_pairwise.get_layer("main_subnet").output
        main_output_var1 = main_effects_output[all_vars.index(var1)]
        main_output_var2 = main_effects_output[all_vars.index(var2)]
        interaction_output = pairwise_output
        penalty = lambd * (
            K.abs(K.mean(main_output_var1 * interaction_output)) +
            K.abs(K.mean(main_output_var2 * interaction_output))
        )

        # Add the penalty to the model's total loss
        model_pairwise.add_loss(penalty)

        # -------------------------- compile and train the model --------------------------
        model_pairwise.compile(optimizer = 'rmsprop', 
                            loss = gamma_nll, 
                            metrics = [gamma_nll, RootMeanSquaredError()])
        es = EarlyStopping(patience = 10, restore_best_weights = True)
        model_pairwise.fit(X_train_split, y_train, epochs = 5_000, \
                                callbacks = [es], batch_size = 1_000, validation_data = (X_val_split, y_val))
        _, gamma_log_metric, _ = model_pairwise.evaluate(X_val_split, y_val, batch_size = X_val_split[0].shape[0])
        interaction_loss[f"{var1}_{var2}"] = gamma_log_metric # add to the val loss list
    
    lambd_val_loss[lambd] = interaction_loss
# Out:
# Epoch 1/5000
# 12/12 [==============================] - 1s 21ms/step - loss: 2.2807 - gamma_nll: 2.2800 - root_mean_squared_error: 2269.0779 - val_loss: 2.2498 - val_gamma_nll: 2.2495 - val_root_mean_squared_error: 2383.4026
# Epoch 2/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1972 - gamma_nll: 2.1965 - root_mean_squared_error: 2214.9258 - val_loss: 2.4162 - val_gamma_nll: 2.4158 - val_root_mean_squared_error: 2433.8000
# Epoch 3/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2078 - gamma_nll: 2.2076 - root_mean_squared_error: 2202.9114 - val_loss: 2.7372 - val_gamma_nll: 2.7365 - val_root_mean_squared_error: 2577.2012
# Epoch 4/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1796 - gamma_nll: 2.1796 - root_mean_squared_error: 2182.4590 - val_loss: 2.4917 - val_gamma_nll: 2.4913 - val_root_mean_squared_error: 2534.9241
# Epoch 5/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1880 - gamma_nll: 2.1885 - root_mean_squared_error: 2178.3867 - val_loss: 2.8171 - val_gamma_nll: 2.8165 - val_root_mean_squared_error: 2674.3215
# Epoch 6/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1798 - gamma_nll: 2.1801 - root_mean_squared_error: 2191.9263 - val_loss: 2.7046 - val_gamma_nll: 2.7040 - val_root_mean_squared_error: 2736.7268
# Epoch 7/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1899 - gamma_nll: 2.1899 - root_mean_squared_error: 2178.2341 - val_loss: 2.6348 - val_gamma_nll: 2.6344 - val_root_mean_squared_error: 2631.1543
# Epoch 8/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1900 - gamma_nll: 2.1899 - root_mean_squared_error: 2176.6960 - val_loss: 2.7883 - val_gamma_nll: 2.7877 - val_root_mean_squared_error: 2630.1497
# Epoch 9/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1735 - gamma_nll: 2.1731 - root_mean_squared_error: 2161.9717 - val_loss: 2.5563 - val_gamma_nll: 2.5560 - val_root_mean_squared_error: 2657.3618
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1843 - gamma_nll: 2.1842 - root_mean_squared_error: 2170.9011 - val_loss: 2.9320 - val_gamma_nll: 2.9315 - val_root_mean_squared_error: 2697.3943
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1830 - gamma_nll: 2.1827 - root_mean_squared_error: 2187.3496 - val_loss: 2.8185 - val_gamma_nll: 2.8181 - val_root_mean_squared_error: 2685.8953
# 1/1 [==============================] - 0s 17ms/step - loss: 2.2498 - gamma_nll: 2.2498 - root_mean_squared_error: 2383.4026
# Epoch 1/5000
# 12/12 [==============================] - 1s 24ms/step - loss: 2.4188 - gamma_nll: 2.4175 - root_mean_squared_error: 2717.6362 - val_loss: 2.8833 - val_gamma_nll: 2.8837 - val_root_mean_squared_error: 4408.4170
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2420 - gamma_nll: 2.2411 - root_mean_squared_error: 2302.2048 - val_loss: 2.8664 - val_gamma_nll: 2.8668 - val_root_mean_squared_error: 4327.6558
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2301 - gamma_nll: 2.2303 - root_mean_squared_error: 2321.0266 - val_loss: 2.7857 - val_gamma_nll: 2.7860 - val_root_mean_squared_error: 4002.2822
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2245 - gamma_nll: 2.2245 - root_mean_squared_error: 2394.2610 - val_loss: 2.8138 - val_gamma_nll: 2.8141 - val_root_mean_squared_error: 4181.9956
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2195 - gamma_nll: 2.2199 - root_mean_squared_error: 2427.8989 - val_loss: 2.8351 - val_gamma_nll: 2.8355 - val_root_mean_squared_error: 4504.1230
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2148 - gamma_nll: 2.2149 - root_mean_squared_error: 2471.1614 - val_loss: 2.9554 - val_gamma_nll: 2.9558 - val_root_mean_squared_error: 5136.8555
# Epoch 7/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2171 - gamma_nll: 2.2170 - root_mean_squared_error: 2503.5732 - val_loss: 2.8360 - val_gamma_nll: 2.8363 - val_root_mean_squared_error: 4505.4702
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2163 - gamma_nll: 2.2159 - root_mean_squared_error: 2551.2498 - val_loss: 2.6755 - val_gamma_nll: 2.6758 - val_root_mean_squared_error: 3784.0696
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2124 - gamma_nll: 2.2122 - root_mean_squared_error: 2556.9683 - val_loss: 2.6069 - val_gamma_nll: 2.6072 - val_root_mean_squared_error: 3494.8037
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2103 - gamma_nll: 2.2100 - root_mean_squared_error: 2578.5276 - val_loss: 2.4119 - val_gamma_nll: 2.4121 - val_root_mean_squared_error: 2818.1531
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2134 - gamma_nll: 2.2130 - root_mean_squared_error: 2617.5518 - val_loss: 2.3106 - val_gamma_nll: 2.3108 - val_root_mean_squared_error: 2597.2332
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2118 - gamma_nll: 2.2117 - root_mean_squared_error: 2592.0940 - val_loss: 2.3701 - val_gamma_nll: 2.3703 - val_root_mean_squared_error: 2798.2910
# Epoch 13/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2120 - gamma_nll: 2.2114 - root_mean_squared_error: 2622.3748 - val_loss: 2.4574 - val_gamma_nll: 2.4577 - val_root_mean_squared_error: 3321.1350
# Epoch 14/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2119 - gamma_nll: 2.2120 - root_mean_squared_error: 2623.6804 - val_loss: 2.4668 - val_gamma_nll: 2.4671 - val_root_mean_squared_error: 3224.9338
# Epoch 15/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2078 - gamma_nll: 2.2077 - root_mean_squared_error: 2602.5200 - val_loss: 2.4163 - val_gamma_nll: 2.4166 - val_root_mean_squared_error: 3072.7507
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2113 - gamma_nll: 2.2114 - root_mean_squared_error: 2646.7400 - val_loss: 2.3966 - val_gamma_nll: 2.3969 - val_root_mean_squared_error: 3105.4109
# Epoch 17/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2111 - gamma_nll: 2.2108 - root_mean_squared_error: 2634.9502 - val_loss: 2.2871 - val_gamma_nll: 2.2873 - val_root_mean_squared_error: 2751.9470
# Epoch 18/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2071 - gamma_nll: 2.2069 - root_mean_squared_error: 2651.6086 - val_loss: 2.2764 - val_gamma_nll: 2.2766 - val_root_mean_squared_error: 2754.8987
# Epoch 19/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2124 - gamma_nll: 2.2122 - root_mean_squared_error: 2639.3723 - val_loss: 2.3406 - val_gamma_nll: 2.3408 - val_root_mean_squared_error: 3209.4773
# Epoch 20/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2110 - gamma_nll: 2.2105 - root_mean_squared_error: 2626.7476 - val_loss: 2.2999 - val_gamma_nll: 2.3001 - val_root_mean_squared_error: 2911.8098
# Epoch 21/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2101 - gamma_nll: 2.2101 - root_mean_squared_error: 2650.0610 - val_loss: 2.2546 - val_gamma_nll: 2.2547 - val_root_mean_squared_error: 2760.8367
# Epoch 22/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2112 - gamma_nll: 2.2112 - root_mean_squared_error: 2666.6636 - val_loss: 2.2450 - val_gamma_nll: 2.2451 - val_root_mean_squared_error: 2798.0933
# Epoch 23/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2058 - gamma_nll: 2.2060 - root_mean_squared_error: 2680.5972 - val_loss: 2.3105 - val_gamma_nll: 2.3108 - val_root_mean_squared_error: 3165.5103
# Epoch 24/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2067 - gamma_nll: 2.2061 - root_mean_squared_error: 2668.2620 - val_loss: 2.2636 - val_gamma_nll: 2.2638 - val_root_mean_squared_error: 3001.6736
# Epoch 25/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2092 - gamma_nll: 2.2093 - root_mean_squared_error: 2657.8184 - val_loss: 2.2306 - val_gamma_nll: 2.2307 - val_root_mean_squared_error: 2889.0720
# Epoch 26/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2087 - gamma_nll: 2.2089 - root_mean_squared_error: 2644.4629 - val_loss: 2.2392 - val_gamma_nll: 2.2393 - val_root_mean_squared_error: 2964.2061
# Epoch 27/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2069 - gamma_nll: 2.2070 - root_mean_squared_error: 2646.8530 - val_loss: 2.2042 - val_gamma_nll: 2.2042 - val_root_mean_squared_error: 2716.3062
# Epoch 28/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2069 - gamma_nll: 2.2062 - root_mean_squared_error: 2664.6211 - val_loss: 2.2102 - val_gamma_nll: 2.2103 - val_root_mean_squared_error: 2779.0186
# Epoch 29/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2050 - gamma_nll: 2.2048 - root_mean_squared_error: 2651.0906 - val_loss: 2.1959 - val_gamma_nll: 2.1958 - val_root_mean_squared_error: 2587.0461
# Epoch 30/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2091 - gamma_nll: 2.2091 - root_mean_squared_error: 2631.3076 - val_loss: 2.2217 - val_gamma_nll: 2.2218 - val_root_mean_squared_error: 2938.3777
# Epoch 31/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2057 - gamma_nll: 2.2057 - root_mean_squared_error: 2652.2278 - val_loss: 2.2205 - val_gamma_nll: 2.2206 - val_root_mean_squared_error: 2985.7629
# Epoch 32/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2070 - gamma_nll: 2.2069 - root_mean_squared_error: 2656.9897 - val_loss: 2.2309 - val_gamma_nll: 2.2310 - val_root_mean_squared_error: 3059.6279
# Epoch 33/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2054 - gamma_nll: 2.2053 - root_mean_squared_error: 2647.7673 - val_loss: 2.2109 - val_gamma_nll: 2.2109 - val_root_mean_squared_error: 2888.3464
# Epoch 34/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2075 - gamma_nll: 2.2079 - root_mean_squared_error: 2673.2512 - val_loss: 2.2085 - val_gamma_nll: 2.2085 - val_root_mean_squared_error: 2833.9067
# Epoch 35/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2037 - gamma_nll: 2.2040 - root_mean_squared_error: 2672.8840 - val_loss: 2.2157 - val_gamma_nll: 2.2157 - val_root_mean_squared_error: 2897.8005
# Epoch 36/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2049 - gamma_nll: 2.2044 - root_mean_squared_error: 2672.8789 - val_loss: 2.2258 - val_gamma_nll: 2.2258 - val_root_mean_squared_error: 3085.5925
# Epoch 37/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2052 - gamma_nll: 2.2052 - root_mean_squared_error: 2672.0510 - val_loss: 2.2102 - val_gamma_nll: 2.2102 - val_root_mean_squared_error: 2858.3394
# Epoch 38/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2058 - gamma_nll: 2.2059 - root_mean_squared_error: 2663.0999 - val_loss: 2.2228 - val_gamma_nll: 2.2227 - val_root_mean_squared_error: 3053.2769
# Epoch 39/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2050 - gamma_nll: 2.2054 - root_mean_squared_error: 2674.6130 - val_loss: 2.2159 - val_gamma_nll: 2.2157 - val_root_mean_squared_error: 2687.5935
# 1/1 [==============================] - 0s 16ms/step - loss: 2.1959 - gamma_nll: 2.1959 - root_mean_squared_error: 2587.0461
# Epoch 1/5000
# 12/12 [==============================] - 1s 21ms/step - loss: 2.6711 - gamma_nll: 2.6685 - root_mean_squared_error: 2172.4302 - val_loss: 2.3376 - val_gamma_nll: 2.3379 - val_root_mean_squared_error: 3033.5974
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3374 - gamma_nll: 2.3362 - root_mean_squared_error: 2140.7722 - val_loss: 2.3224 - val_gamma_nll: 2.3226 - val_root_mean_squared_error: 3031.3821
# Epoch 3/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2875 - gamma_nll: 2.2882 - root_mean_squared_error: 2120.8555 - val_loss: 2.3947 - val_gamma_nll: 2.3949 - val_root_mean_squared_error: 3513.9468
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2537 - gamma_nll: 2.2535 - root_mean_squared_error: 2130.5583 - val_loss: 2.4215 - val_gamma_nll: 2.4216 - val_root_mean_squared_error: 3387.0042
# Epoch 5/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2284 - gamma_nll: 2.2291 - root_mean_squared_error: 2119.2966 - val_loss: 2.5280 - val_gamma_nll: 2.5279 - val_root_mean_squared_error: 3419.1775
# Epoch 6/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2121 - gamma_nll: 2.2120 - root_mean_squared_error: 2111.2756 - val_loss: 2.7883 - val_gamma_nll: 2.7882 - val_root_mean_squared_error: 3523.3992
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2066 - gamma_nll: 2.2066 - root_mean_squared_error: 2114.4502 - val_loss: 2.9394 - val_gamma_nll: 2.9391 - val_root_mean_squared_error: 3535.0271
# Epoch 8/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2000 - gamma_nll: 2.1996 - root_mean_squared_error: 2118.7866 - val_loss: 2.8726 - val_gamma_nll: 2.8725 - val_root_mean_squared_error: 4028.6719
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1889 - gamma_nll: 2.1884 - root_mean_squared_error: 2111.8142 - val_loss: 3.0498 - val_gamma_nll: 3.0497 - val_root_mean_squared_error: 5325.1963
# Epoch 10/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1802 - gamma_nll: 2.1801 - root_mean_squared_error: 2114.6768 - val_loss: 2.9214 - val_gamma_nll: 2.9213 - val_root_mean_squared_error: 3794.8513
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1835 - gamma_nll: 2.1832 - root_mean_squared_error: 2119.6538 - val_loss: 3.1278 - val_gamma_nll: 3.1272 - val_root_mean_squared_error: 3074.4497
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1770 - gamma_nll: 2.1770 - root_mean_squared_error: 2114.4753 - val_loss: 2.9618 - val_gamma_nll: 2.9615 - val_root_mean_squared_error: 4192.9199
# 1/1 [==============================] - 0s 14ms/step - loss: 2.3224 - gamma_nll: 2.3224 - root_mean_squared_error: 3031.3823
# Epoch 1/5000
# 12/12 [==============================] - 1s 21ms/step - loss: 2.4163 - gamma_nll: 2.4149 - root_mean_squared_error: 2326.5613 - val_loss: 2.4746 - val_gamma_nll: 2.4751 - val_root_mean_squared_error: 6155.0342
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2172 - gamma_nll: 2.2163 - root_mean_squared_error: 2141.3914 - val_loss: 2.6211 - val_gamma_nll: 2.6218 - val_root_mean_squared_error: 10409.6299
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1908 - gamma_nll: 2.1909 - root_mean_squared_error: 2151.4246 - val_loss: 2.6220 - val_gamma_nll: 2.6226 - val_root_mean_squared_error: 9123.4619
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1848 - gamma_nll: 2.1849 - root_mean_squared_error: 2149.6384 - val_loss: 2.6255 - val_gamma_nll: 2.6260 - val_root_mean_squared_error: 8172.9619
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1860 - gamma_nll: 2.1864 - root_mean_squared_error: 2162.7351 - val_loss: 2.6669 - val_gamma_nll: 2.6676 - val_root_mean_squared_error: 10115.7822
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1778 - gamma_nll: 2.1777 - root_mean_squared_error: 2142.7063 - val_loss: 2.7089 - val_gamma_nll: 2.7096 - val_root_mean_squared_error: 9493.3047
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1880 - gamma_nll: 2.1881 - root_mean_squared_error: 2163.4080 - val_loss: 2.6490 - val_gamma_nll: 2.6495 - val_root_mean_squared_error: 8210.1279
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1799 - gamma_nll: 2.1798 - root_mean_squared_error: 2154.9019 - val_loss: 2.6064 - val_gamma_nll: 2.6069 - val_root_mean_squared_error: 7579.5454
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1737 - gamma_nll: 2.1733 - root_mean_squared_error: 2150.5100 - val_loss: 2.5995 - val_gamma_nll: 2.6000 - val_root_mean_squared_error: 6088.6689
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1834 - gamma_nll: 2.1833 - root_mean_squared_error: 2155.3276 - val_loss: 2.6174 - val_gamma_nll: 2.6178 - val_root_mean_squared_error: 5486.7393
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1778 - gamma_nll: 2.1778 - root_mean_squared_error: 2155.9224 - val_loss: 2.5199 - val_gamma_nll: 2.5204 - val_root_mean_squared_error: 6376.3101
# 1/1 [==============================] - 0s 16ms/step - loss: 2.4746 - gamma_nll: 2.4746 - root_mean_squared_error: 6155.0342
# Epoch 1/5000
# 12/12 [==============================] - 1s 20ms/step - loss: 2.3714 - gamma_nll: 2.3708 - root_mean_squared_error: 2195.6406 - val_loss: 3.4530 - val_gamma_nll: 3.4501 - val_root_mean_squared_error: 3039.7373
# Epoch 2/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2373 - gamma_nll: 2.2365 - root_mean_squared_error: 2133.9827 - val_loss: 3.4807 - val_gamma_nll: 3.4778 - val_root_mean_squared_error: 2968.4507
# Epoch 3/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2161 - gamma_nll: 2.2162 - root_mean_squared_error: 2126.8047 - val_loss: 4.0000 - val_gamma_nll: 3.9960 - val_root_mean_squared_error: 2839.5833
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2044 - gamma_nll: 2.2044 - root_mean_squared_error: 2133.0532 - val_loss: 3.2596 - val_gamma_nll: 3.2570 - val_root_mean_squared_error: 2820.1848
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1952 - gamma_nll: 2.1957 - root_mean_squared_error: 2131.1296 - val_loss: 2.9856 - val_gamma_nll: 2.9837 - val_root_mean_squared_error: 3447.6404
# Epoch 6/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1847 - gamma_nll: 2.1845 - root_mean_squared_error: 2137.4907 - val_loss: 3.1662 - val_gamma_nll: 3.1640 - val_root_mean_squared_error: 3422.9934
# Epoch 7/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1890 - gamma_nll: 2.1892 - root_mean_squared_error: 2136.7273 - val_loss: 3.0889 - val_gamma_nll: 3.0867 - val_root_mean_squared_error: 3024.5083
# Epoch 8/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1830 - gamma_nll: 2.1829 - root_mean_squared_error: 2138.2432 - val_loss: 3.0364 - val_gamma_nll: 3.0344 - val_root_mean_squared_error: 3385.6184
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1772 - gamma_nll: 2.1768 - root_mean_squared_error: 2144.0278 - val_loss: 2.8141 - val_gamma_nll: 2.8126 - val_root_mean_squared_error: 2928.0872
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1754 - gamma_nll: 2.1754 - root_mean_squared_error: 2140.9702 - val_loss: 2.6983 - val_gamma_nll: 2.6971 - val_root_mean_squared_error: 3021.2554
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1819 - gamma_nll: 2.1817 - root_mean_squared_error: 2166.4875 - val_loss: 2.7195 - val_gamma_nll: 2.7183 - val_root_mean_squared_error: 3347.4141
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1741 - gamma_nll: 2.1740 - root_mean_squared_error: 2145.6609 - val_loss: 2.6488 - val_gamma_nll: 2.6479 - val_root_mean_squared_error: 4031.4492
# Epoch 13/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1777 - gamma_nll: 2.1771 - root_mean_squared_error: 2166.2539 - val_loss: 2.6567 - val_gamma_nll: 2.6559 - val_root_mean_squared_error: 4255.7109
# Epoch 14/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1754 - gamma_nll: 2.1754 - root_mean_squared_error: 2156.2495 - val_loss: 2.6195 - val_gamma_nll: 2.6186 - val_root_mean_squared_error: 3386.8669
# Epoch 15/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1724 - gamma_nll: 2.1725 - root_mean_squared_error: 2151.2642 - val_loss: 2.4304 - val_gamma_nll: 2.4298 - val_root_mean_squared_error: 2922.2678
# Epoch 16/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1780 - gamma_nll: 2.1777 - root_mean_squared_error: 2155.9927 - val_loss: 2.5962 - val_gamma_nll: 2.5954 - val_root_mean_squared_error: 3750.1799
# Epoch 17/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1753 - gamma_nll: 2.1753 - root_mean_squared_error: 2156.6560 - val_loss: 2.4642 - val_gamma_nll: 2.4637 - val_root_mean_squared_error: 3243.4885
# Epoch 18/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1737 - gamma_nll: 2.1735 - root_mean_squared_error: 2160.7097 - val_loss: 2.5119 - val_gamma_nll: 2.5114 - val_root_mean_squared_error: 3532.9297
# Epoch 19/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1776 - gamma_nll: 2.1775 - root_mean_squared_error: 2158.7266 - val_loss: 2.4747 - val_gamma_nll: 2.4742 - val_root_mean_squared_error: 3542.3987
# Epoch 20/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1763 - gamma_nll: 2.1759 - root_mean_squared_error: 2159.9663 - val_loss: 2.5338 - val_gamma_nll: 2.5329 - val_root_mean_squared_error: 3031.9722
# Epoch 21/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1751 - gamma_nll: 2.1749 - root_mean_squared_error: 2155.4500 - val_loss: 2.4487 - val_gamma_nll: 2.4480 - val_root_mean_squared_error: 2846.0974
# Epoch 22/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1746 - gamma_nll: 2.1743 - root_mean_squared_error: 2163.3552 - val_loss: 2.3640 - val_gamma_nll: 2.3635 - val_root_mean_squared_error: 2713.3071
# Epoch 23/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1706 - gamma_nll: 2.1707 - root_mean_squared_error: 2156.7161 - val_loss: 2.4770 - val_gamma_nll: 2.4762 - val_root_mean_squared_error: 2761.5161
# Epoch 24/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1729 - gamma_nll: 2.1725 - root_mean_squared_error: 2158.0613 - val_loss: 2.5538 - val_gamma_nll: 2.5527 - val_root_mean_squared_error: 2629.9751
# Epoch 25/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1740 - gamma_nll: 2.1740 - root_mean_squared_error: 2156.8943 - val_loss: 2.3926 - val_gamma_nll: 2.3920 - val_root_mean_squared_error: 2797.4421
# Epoch 26/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1733 - gamma_nll: 2.1736 - root_mean_squared_error: 2149.8621 - val_loss: 2.4237 - val_gamma_nll: 2.4230 - val_root_mean_squared_error: 2782.1721
# Epoch 27/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1706 - gamma_nll: 2.1708 - root_mean_squared_error: 2151.7947 - val_loss: 2.2969 - val_gamma_nll: 2.2965 - val_root_mean_squared_error: 2537.2249
# Epoch 28/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1730 - gamma_nll: 2.1721 - root_mean_squared_error: 2155.3228 - val_loss: 2.4455 - val_gamma_nll: 2.4447 - val_root_mean_squared_error: 2629.2024
# Epoch 29/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1719 - gamma_nll: 2.1717 - root_mean_squared_error: 2154.1694 - val_loss: 2.4019 - val_gamma_nll: 2.4011 - val_root_mean_squared_error: 2461.1567
# Epoch 30/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1730 - gamma_nll: 2.1727 - root_mean_squared_error: 2148.2722 - val_loss: 2.4434 - val_gamma_nll: 2.4426 - val_root_mean_squared_error: 2690.4446
# Epoch 31/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1716 - gamma_nll: 2.1713 - root_mean_squared_error: 2155.0708 - val_loss: 2.3282 - val_gamma_nll: 2.3278 - val_root_mean_squared_error: 2800.9846
# Epoch 32/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1717 - gamma_nll: 2.1714 - root_mean_squared_error: 2157.9836 - val_loss: 2.3373 - val_gamma_nll: 2.3368 - val_root_mean_squared_error: 2547.9995
# Epoch 33/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1684 - gamma_nll: 2.1683 - root_mean_squared_error: 2145.3440 - val_loss: 2.3088 - val_gamma_nll: 2.3083 - val_root_mean_squared_error: 2571.3757
# Epoch 34/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1711 - gamma_nll: 2.1714 - root_mean_squared_error: 2162.5898 - val_loss: 2.2508 - val_gamma_nll: 2.2505 - val_root_mean_squared_error: 2511.0740
# Epoch 35/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1724 - gamma_nll: 2.1728 - root_mean_squared_error: 2145.8049 - val_loss: 2.2908 - val_gamma_nll: 2.2903 - val_root_mean_squared_error: 2445.5520
# Epoch 36/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1703 - gamma_nll: 2.1699 - root_mean_squared_error: 2155.9348 - val_loss: 2.2403 - val_gamma_nll: 2.2400 - val_root_mean_squared_error: 2448.7319
# Epoch 37/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1688 - gamma_nll: 2.1687 - root_mean_squared_error: 2159.4482 - val_loss: 2.2327 - val_gamma_nll: 2.2326 - val_root_mean_squared_error: 2559.2610
# Epoch 38/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1727 - gamma_nll: 2.1729 - root_mean_squared_error: 2164.2842 - val_loss: 2.2592 - val_gamma_nll: 2.2591 - val_root_mean_squared_error: 2775.4563
# Epoch 39/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1732 - gamma_nll: 2.1733 - root_mean_squared_error: 2153.3643 - val_loss: 2.2664 - val_gamma_nll: 2.2660 - val_root_mean_squared_error: 2439.6702
# Epoch 40/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1684 - gamma_nll: 2.1680 - root_mean_squared_error: 2152.9541 - val_loss: 2.2254 - val_gamma_nll: 2.2251 - val_root_mean_squared_error: 2471.0020
# Epoch 41/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1688 - gamma_nll: 2.1685 - root_mean_squared_error: 2157.5984 - val_loss: 2.2392 - val_gamma_nll: 2.2388 - val_root_mean_squared_error: 2364.4993
# Epoch 42/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1685 - gamma_nll: 2.1684 - root_mean_squared_error: 2150.5916 - val_loss: 2.3404 - val_gamma_nll: 2.3396 - val_root_mean_squared_error: 2433.0332
# Epoch 43/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1670 - gamma_nll: 2.1670 - root_mean_squared_error: 2151.1670 - val_loss: 2.2025 - val_gamma_nll: 2.2024 - val_root_mean_squared_error: 2463.4214
# Epoch 44/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1703 - gamma_nll: 2.1709 - root_mean_squared_error: 2145.5310 - val_loss: 2.2339 - val_gamma_nll: 2.2336 - val_root_mean_squared_error: 2426.6450
# Epoch 45/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1645 - gamma_nll: 2.1647 - root_mean_squared_error: 2178.1694 - val_loss: 2.2269 - val_gamma_nll: 2.2266 - val_root_mean_squared_error: 2435.2258
# Epoch 46/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1686 - gamma_nll: 2.1688 - root_mean_squared_error: 2152.2812 - val_loss: 2.2033 - val_gamma_nll: 2.2032 - val_root_mean_squared_error: 2431.4287
# Epoch 47/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1684 - gamma_nll: 2.1683 - root_mean_squared_error: 2155.1028 - val_loss: 2.2311 - val_gamma_nll: 2.2311 - val_root_mean_squared_error: 2588.8755
# Epoch 48/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1668 - gamma_nll: 2.1667 - root_mean_squared_error: 2148.2114 - val_loss: 2.2481 - val_gamma_nll: 2.2482 - val_root_mean_squared_error: 2682.2209
# Epoch 49/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1664 - gamma_nll: 2.1661 - root_mean_squared_error: 2158.3108 - val_loss: 2.2202 - val_gamma_nll: 2.2201 - val_root_mean_squared_error: 2521.5334
# Epoch 50/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1673 - gamma_nll: 2.1672 - root_mean_squared_error: 2157.1511 - val_loss: 2.1919 - val_gamma_nll: 2.1918 - val_root_mean_squared_error: 2402.0244
# Epoch 51/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1686 - gamma_nll: 2.1692 - root_mean_squared_error: 2159.1643 - val_loss: 2.2198 - val_gamma_nll: 2.2198 - val_root_mean_squared_error: 2532.4270
# Epoch 52/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1656 - gamma_nll: 2.1654 - root_mean_squared_error: 2161.5679 - val_loss: 2.2137 - val_gamma_nll: 2.2136 - val_root_mean_squared_error: 2485.5547
# Epoch 53/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1665 - gamma_nll: 2.1666 - root_mean_squared_error: 2153.3813 - val_loss: 2.2340 - val_gamma_nll: 2.2341 - val_root_mean_squared_error: 2619.1548
# Epoch 54/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1703 - gamma_nll: 2.1709 - root_mean_squared_error: 2165.1636 - val_loss: 2.2544 - val_gamma_nll: 2.2545 - val_root_mean_squared_error: 2598.9441
# Epoch 55/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1677 - gamma_nll: 2.1679 - root_mean_squared_error: 2155.8594 - val_loss: 2.2217 - val_gamma_nll: 2.2217 - val_root_mean_squared_error: 2485.7024
# Epoch 56/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1659 - gamma_nll: 2.1658 - root_mean_squared_error: 2150.9939 - val_loss: 2.2148 - val_gamma_nll: 2.2148 - val_root_mean_squared_error: 2482.5999
# Epoch 57/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1664 - gamma_nll: 2.1668 - root_mean_squared_error: 2157.7485 - val_loss: 2.1883 - val_gamma_nll: 2.1882 - val_root_mean_squared_error: 2366.4014
# Epoch 58/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1641 - gamma_nll: 2.1641 - root_mean_squared_error: 2146.7749 - val_loss: 2.1884 - val_gamma_nll: 2.1883 - val_root_mean_squared_error: 2417.6870
# Epoch 59/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1695 - gamma_nll: 2.1700 - root_mean_squared_error: 2165.3167 - val_loss: 2.1995 - val_gamma_nll: 2.1992 - val_root_mean_squared_error: 2396.0933
# Epoch 60/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1669 - gamma_nll: 2.1667 - root_mean_squared_error: 2162.7065 - val_loss: 2.2311 - val_gamma_nll: 2.2312 - val_root_mean_squared_error: 2620.9622
# Epoch 61/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1682 - gamma_nll: 2.1682 - root_mean_squared_error: 2164.0066 - val_loss: 2.1974 - val_gamma_nll: 2.1974 - val_root_mean_squared_error: 2448.0300
# Epoch 62/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1658 - gamma_nll: 2.1658 - root_mean_squared_error: 2160.5137 - val_loss: 2.1858 - val_gamma_nll: 2.1856 - val_root_mean_squared_error: 2356.8184
# Epoch 63/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1662 - gamma_nll: 2.1664 - root_mean_squared_error: 2156.1255 - val_loss: 2.2096 - val_gamma_nll: 2.2097 - val_root_mean_squared_error: 2500.9915
# Epoch 64/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1655 - gamma_nll: 2.1646 - root_mean_squared_error: 2153.5310 - val_loss: 2.2075 - val_gamma_nll: 2.2076 - val_root_mean_squared_error: 2449.2305
# Epoch 65/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1674 - gamma_nll: 2.1675 - root_mean_squared_error: 2153.1594 - val_loss: 2.2029 - val_gamma_nll: 2.2029 - val_root_mean_squared_error: 2431.3271
# Epoch 66/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1672 - gamma_nll: 2.1675 - root_mean_squared_error: 2154.8396 - val_loss: 2.1952 - val_gamma_nll: 2.1952 - val_root_mean_squared_error: 2446.2952
# Epoch 67/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1625 - gamma_nll: 2.1622 - root_mean_squared_error: 2156.3828 - val_loss: 2.2368 - val_gamma_nll: 2.2368 - val_root_mean_squared_error: 2490.9285
# Epoch 68/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1643 - gamma_nll: 2.1641 - root_mean_squared_error: 2147.2954 - val_loss: 2.2597 - val_gamma_nll: 2.2599 - val_root_mean_squared_error: 2700.4399
# Epoch 69/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1653 - gamma_nll: 2.1651 - root_mean_squared_error: 2162.2844 - val_loss: 2.2245 - val_gamma_nll: 2.2245 - val_root_mean_squared_error: 2665.7629
# Epoch 70/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1633 - gamma_nll: 2.1634 - root_mean_squared_error: 2158.7024 - val_loss: 2.2388 - val_gamma_nll: 2.2389 - val_root_mean_squared_error: 2559.3223
# Epoch 71/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1655 - gamma_nll: 2.1654 - root_mean_squared_error: 2155.6348 - val_loss: 2.2219 - val_gamma_nll: 2.2220 - val_root_mean_squared_error: 2598.0352
# Epoch 72/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1651 - gamma_nll: 2.1647 - root_mean_squared_error: 2153.1343 - val_loss: 2.2160 - val_gamma_nll: 2.2160 - val_root_mean_squared_error: 2494.1089
# 1/1 [==============================] - 0s 14ms/step - loss: 2.1858 - gamma_nll: 2.1858 - root_mean_squared_error: 2356.8184
# Epoch 1/5000
# 12/12 [==============================] - 1s 24ms/step - loss: 2.3706 - gamma_nll: 2.3697 - root_mean_squared_error: 3366.1667 - val_loss: 2.8647 - val_gamma_nll: 2.8650 - val_root_mean_squared_error: 4163.0210
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2314 - gamma_nll: 2.2306 - root_mean_squared_error: 2486.1528 - val_loss: 2.7107 - val_gamma_nll: 2.7110 - val_root_mean_squared_error: 3515.6904
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2336 - gamma_nll: 2.2337 - root_mean_squared_error: 2489.9292 - val_loss: 2.5860 - val_gamma_nll: 2.5862 - val_root_mean_squared_error: 3125.9058
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2196 - gamma_nll: 2.2196 - root_mean_squared_error: 2522.9290 - val_loss: 2.6174 - val_gamma_nll: 2.6176 - val_root_mean_squared_error: 3211.7139
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2238 - gamma_nll: 2.2244 - root_mean_squared_error: 2505.5532 - val_loss: 2.5708 - val_gamma_nll: 2.5711 - val_root_mean_squared_error: 3094.0347
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2219 - gamma_nll: 2.2219 - root_mean_squared_error: 2534.0376 - val_loss: 2.4675 - val_gamma_nll: 2.4678 - val_root_mean_squared_error: 2810.0393
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2162 - gamma_nll: 2.2162 - root_mean_squared_error: 2553.9580 - val_loss: 2.5054 - val_gamma_nll: 2.5057 - val_root_mean_squared_error: 2992.6711
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2254 - gamma_nll: 2.2251 - root_mean_squared_error: 2585.6267 - val_loss: 2.5329 - val_gamma_nll: 2.5332 - val_root_mean_squared_error: 3105.4868
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2153 - gamma_nll: 2.2150 - root_mean_squared_error: 2551.6582 - val_loss: 2.4522 - val_gamma_nll: 2.4524 - val_root_mean_squared_error: 2871.4294
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2150 - gamma_nll: 2.2148 - root_mean_squared_error: 2556.3552 - val_loss: 2.3678 - val_gamma_nll: 2.3680 - val_root_mean_squared_error: 2672.6509
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2138 - gamma_nll: 2.2134 - root_mean_squared_error: 2592.6760 - val_loss: 2.3427 - val_gamma_nll: 2.3429 - val_root_mean_squared_error: 2620.3787
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2140 - gamma_nll: 2.2139 - root_mean_squared_error: 2578.1331 - val_loss: 2.2421 - val_gamma_nll: 2.2421 - val_root_mean_squared_error: 2436.4941
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2209 - gamma_nll: 2.2203 - root_mean_squared_error: 2584.1907 - val_loss: 2.2258 - val_gamma_nll: 2.2259 - val_root_mean_squared_error: 2400.2646
# Epoch 14/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2098 - gamma_nll: 2.2100 - root_mean_squared_error: 2585.8955 - val_loss: 2.2839 - val_gamma_nll: 2.2841 - val_root_mean_squared_error: 2561.6750
# Epoch 15/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2145 - gamma_nll: 2.2143 - root_mean_squared_error: 2590.6040 - val_loss: 2.2793 - val_gamma_nll: 2.2795 - val_root_mean_squared_error: 2580.0916
# Epoch 16/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2171 - gamma_nll: 2.2169 - root_mean_squared_error: 2615.8926 - val_loss: 2.2629 - val_gamma_nll: 2.2630 - val_root_mean_squared_error: 2561.0325
# Epoch 17/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2132 - gamma_nll: 2.2128 - root_mean_squared_error: 2575.6697 - val_loss: 2.2429 - val_gamma_nll: 2.2431 - val_root_mean_squared_error: 2534.8608
# Epoch 18/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2080 - gamma_nll: 2.2078 - root_mean_squared_error: 2596.8098 - val_loss: 2.2392 - val_gamma_nll: 2.2393 - val_root_mean_squared_error: 2572.4036
# Epoch 19/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2105 - gamma_nll: 2.2106 - root_mean_squared_error: 2567.3115 - val_loss: 2.2311 - val_gamma_nll: 2.2312 - val_root_mean_squared_error: 2539.2922
# Epoch 20/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2102 - gamma_nll: 2.2096 - root_mean_squared_error: 2552.5676 - val_loss: 2.2085 - val_gamma_nll: 2.2085 - val_root_mean_squared_error: 2499.4690
# Epoch 21/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2117 - gamma_nll: 2.2115 - root_mean_squared_error: 2601.9468 - val_loss: 2.2885 - val_gamma_nll: 2.2887 - val_root_mean_squared_error: 2809.5564
# Epoch 22/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2070 - gamma_nll: 2.2070 - root_mean_squared_error: 2603.8779 - val_loss: 2.2147 - val_gamma_nll: 2.2148 - val_root_mean_squared_error: 2560.5535
# Epoch 23/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2131 - gamma_nll: 2.2132 - root_mean_squared_error: 2601.6660 - val_loss: 2.1907 - val_gamma_nll: 2.1906 - val_root_mean_squared_error: 2393.2405
# Epoch 24/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2096 - gamma_nll: 2.2091 - root_mean_squared_error: 2610.2915 - val_loss: 2.2160 - val_gamma_nll: 2.2161 - val_root_mean_squared_error: 2616.2473
# Epoch 25/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2052 - gamma_nll: 2.2052 - root_mean_squared_error: 2552.4824 - val_loss: 2.2173 - val_gamma_nll: 2.2174 - val_root_mean_squared_error: 2617.7104
# Epoch 26/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2118 - gamma_nll: 2.2121 - root_mean_squared_error: 2592.4990 - val_loss: 2.2192 - val_gamma_nll: 2.2193 - val_root_mean_squared_error: 2650.3950
# Epoch 27/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2044 - gamma_nll: 2.2044 - root_mean_squared_error: 2582.7329 - val_loss: 2.1972 - val_gamma_nll: 2.1972 - val_root_mean_squared_error: 2533.6418
# Epoch 28/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2031 - gamma_nll: 2.2022 - root_mean_squared_error: 2568.0920 - val_loss: 2.2044 - val_gamma_nll: 2.2045 - val_root_mean_squared_error: 2622.0923
# Epoch 29/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2110 - gamma_nll: 2.2107 - root_mean_squared_error: 2621.6392 - val_loss: 2.1973 - val_gamma_nll: 2.1973 - val_root_mean_squared_error: 2567.2051
# Epoch 30/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2092 - gamma_nll: 2.2090 - root_mean_squared_error: 2578.8950 - val_loss: 2.2082 - val_gamma_nll: 2.2082 - val_root_mean_squared_error: 2572.2983
# Epoch 31/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2015 - gamma_nll: 2.2013 - root_mean_squared_error: 2543.5698 - val_loss: 2.1985 - val_gamma_nll: 2.1984 - val_root_mean_squared_error: 2544.8240
# Epoch 32/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2048 - gamma_nll: 2.2047 - root_mean_squared_error: 2575.7571 - val_loss: 2.2024 - val_gamma_nll: 2.2023 - val_root_mean_squared_error: 2517.1360
# Epoch 33/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2061 - gamma_nll: 2.2060 - root_mean_squared_error: 2553.8438 - val_loss: 2.2152 - val_gamma_nll: 2.2150 - val_root_mean_squared_error: 2496.4114
# 1/1 [==============================] - 0s 14ms/step - loss: 2.1907 - gamma_nll: 2.1907 - root_mean_squared_error: 2393.2405
# Epoch 1/5000
# 12/12 [==============================] - 1s 21ms/step - loss: 2.4258 - gamma_nll: 2.4242 - root_mean_squared_error: 2195.9563 - val_loss: 2.4071 - val_gamma_nll: 2.4064 - val_root_mean_squared_error: 2351.0554
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2341 - gamma_nll: 2.2332 - root_mean_squared_error: 2136.6182 - val_loss: 2.3571 - val_gamma_nll: 2.3565 - val_root_mean_squared_error: 2409.4824
# Epoch 3/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2235 - gamma_nll: 2.2236 - root_mean_squared_error: 2126.2349 - val_loss: 2.5496 - val_gamma_nll: 2.5487 - val_root_mean_squared_error: 2762.3242
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1963 - gamma_nll: 2.1962 - root_mean_squared_error: 2128.8374 - val_loss: 2.3811 - val_gamma_nll: 2.3805 - val_root_mean_squared_error: 2805.9333
# Epoch 5/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1994 - gamma_nll: 2.2000 - root_mean_squared_error: 2140.9607 - val_loss: 2.5469 - val_gamma_nll: 2.5462 - val_root_mean_squared_error: 3289.0342
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1903 - gamma_nll: 2.1902 - root_mean_squared_error: 2139.5801 - val_loss: 2.6109 - val_gamma_nll: 2.6101 - val_root_mean_squared_error: 3648.5447
# Epoch 7/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1886 - gamma_nll: 2.1887 - root_mean_squared_error: 2153.8115 - val_loss: 2.5774 - val_gamma_nll: 2.5765 - val_root_mean_squared_error: 3204.7456
# Epoch 8/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1871 - gamma_nll: 2.1870 - root_mean_squared_error: 2142.3643 - val_loss: 2.7832 - val_gamma_nll: 2.7818 - val_root_mean_squared_error: 3163.4182
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1775 - gamma_nll: 2.1770 - root_mean_squared_error: 2129.4312 - val_loss: 2.6254 - val_gamma_nll: 2.6245 - val_root_mean_squared_error: 3950.8984
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1791 - gamma_nll: 2.1792 - root_mean_squared_error: 2130.9006 - val_loss: 2.6810 - val_gamma_nll: 2.6799 - val_root_mean_squared_error: 3823.9355
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1809 - gamma_nll: 2.1806 - root_mean_squared_error: 2147.6331 - val_loss: 2.8763 - val_gamma_nll: 2.8747 - val_root_mean_squared_error: 3321.5503
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1827 - gamma_nll: 2.1826 - root_mean_squared_error: 2143.6572 - val_loss: 2.9995 - val_gamma_nll: 2.9978 - val_root_mean_squared_error: 4430.8999
# 1/1 [==============================] - 0s 15ms/step - loss: 2.3571 - gamma_nll: 2.3571 - root_mean_squared_error: 2409.4824
# Epoch 1/5000
# 12/12 [==============================] - 1s 20ms/step - loss: 2.2472 - gamma_nll: 2.2471 - root_mean_squared_error: 4079.8811 - val_loss: 2.5226 - val_gamma_nll: 2.5225 - val_root_mean_squared_error: 2891.9548
# Epoch 2/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2054 - gamma_nll: 2.2046 - root_mean_squared_error: 2283.5896 - val_loss: 2.7808 - val_gamma_nll: 2.7805 - val_root_mean_squared_error: 2808.7590
# Epoch 3/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1969 - gamma_nll: 2.1969 - root_mean_squared_error: 2226.5317 - val_loss: 2.9856 - val_gamma_nll: 2.9853 - val_root_mean_squared_error: 2998.1328
# Epoch 4/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1873 - gamma_nll: 2.1872 - root_mean_squared_error: 2211.4368 - val_loss: 2.5663 - val_gamma_nll: 2.5662 - val_root_mean_squared_error: 2803.5747
# Epoch 5/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1867 - gamma_nll: 2.1873 - root_mean_squared_error: 2199.4243 - val_loss: 2.7983 - val_gamma_nll: 2.7982 - val_root_mean_squared_error: 3199.3479
# Epoch 6/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1814 - gamma_nll: 2.1814 - root_mean_squared_error: 2181.5591 - val_loss: 2.5461 - val_gamma_nll: 2.5460 - val_root_mean_squared_error: 3193.6636
# Epoch 7/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1790 - gamma_nll: 2.1791 - root_mean_squared_error: 2184.8416 - val_loss: 2.5367 - val_gamma_nll: 2.5367 - val_root_mean_squared_error: 3241.2017
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1824 - gamma_nll: 2.1826 - root_mean_squared_error: 2180.7947 - val_loss: 2.5091 - val_gamma_nll: 2.5091 - val_root_mean_squared_error: 3309.3127
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1771 - gamma_nll: 2.1765 - root_mean_squared_error: 2172.6062 - val_loss: 2.4790 - val_gamma_nll: 2.4790 - val_root_mean_squared_error: 3107.0942
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1808 - gamma_nll: 2.1808 - root_mean_squared_error: 2181.9768 - val_loss: 2.5455 - val_gamma_nll: 2.5455 - val_root_mean_squared_error: 3196.4709
# Epoch 11/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1758 - gamma_nll: 2.1754 - root_mean_squared_error: 2172.1255 - val_loss: 2.5060 - val_gamma_nll: 2.5060 - val_root_mean_squared_error: 3438.3289
# Epoch 12/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1800 - gamma_nll: 2.1800 - root_mean_squared_error: 2186.3999 - val_loss: 2.5972 - val_gamma_nll: 2.5972 - val_root_mean_squared_error: 3116.7480
# Epoch 13/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1767 - gamma_nll: 2.1761 - root_mean_squared_error: 2160.2129 - val_loss: 2.5731 - val_gamma_nll: 2.5731 - val_root_mean_squared_error: 3210.8286
# Epoch 14/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1724 - gamma_nll: 2.1724 - root_mean_squared_error: 2176.3171 - val_loss: 2.5872 - val_gamma_nll: 2.5872 - val_root_mean_squared_error: 3265.6765
# Epoch 15/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1739 - gamma_nll: 2.1740 - root_mean_squared_error: 2168.5461 - val_loss: 2.5561 - val_gamma_nll: 2.5561 - val_root_mean_squared_error: 4210.5977
# Epoch 16/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1772 - gamma_nll: 2.1770 - root_mean_squared_error: 2181.6909 - val_loss: 2.5109 - val_gamma_nll: 2.5110 - val_root_mean_squared_error: 3478.7974
# Epoch 17/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1747 - gamma_nll: 2.1746 - root_mean_squared_error: 2151.0571 - val_loss: 2.4811 - val_gamma_nll: 2.4811 - val_root_mean_squared_error: 3341.3828
# Epoch 18/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1749 - gamma_nll: 2.1748 - root_mean_squared_error: 2175.4309 - val_loss: 2.5451 - val_gamma_nll: 2.5451 - val_root_mean_squared_error: 3313.3210
# Epoch 19/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1747 - gamma_nll: 2.1748 - root_mean_squared_error: 2166.6697 - val_loss: 2.4602 - val_gamma_nll: 2.4601 - val_root_mean_squared_error: 3004.8748
# Epoch 20/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1731 - gamma_nll: 2.1725 - root_mean_squared_error: 2154.1377 - val_loss: 2.4094 - val_gamma_nll: 2.4093 - val_root_mean_squared_error: 2793.4214
# Epoch 21/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1744 - gamma_nll: 2.1740 - root_mean_squared_error: 2162.0283 - val_loss: 2.4080 - val_gamma_nll: 2.4079 - val_root_mean_squared_error: 2535.5818
# Epoch 22/5000
# ...
# Epoch 28/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8912 - gamma_nll: 1.8902 - root_mean_squared_error: 2068.8044 - val_loss: 2.0950 - val_gamma_nll: 2.0949 - val_root_mean_squared_error: 2261.7222
# Epoch 29/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8987 - gamma_nll: 1.8987 - root_mean_squared_error: 2067.6675 - val_loss: 2.1190 - val_gamma_nll: 2.1187 - val_root_mean_squared_error: 2271.9019
# Epoch 30/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9015 - gamma_nll: 1.9011 - root_mean_squared_error: 2061.8960 - val_loss: 2.0899 - val_gamma_nll: 2.0897 - val_root_mean_squared_error: 2268.7910
# Epoch 31/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9015 - gamma_nll: 1.9010 - root_mean_squared_error: 2116.0698 - val_loss: 2.0653 - val_gamma_nll: 2.0652 - val_root_mean_squared_error: 2252.8254
# Epoch 32/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8844 - gamma_nll: 1.8840 - root_mean_squared_error: 2078.7085 - val_loss: 2.0878 - val_gamma_nll: 2.0877 - val_root_mean_squared_error: 2269.3142
# Epoch 33/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9023 - gamma_nll: 1.9020 - root_mean_squared_error: 2099.1394 - val_loss: 2.0525 - val_gamma_nll: 2.0524 - val_root_mean_squared_error: 2249.3801
# Epoch 34/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8833 - gamma_nll: 1.8833 - root_mean_squared_error: 2017.8180 - val_loss: 2.0491 - val_gamma_nll: 2.0489 - val_root_mean_squared_error: 2249.3645
# Epoch 35/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8900 - gamma_nll: 1.8901 - root_mean_squared_error: 2042.1121 - val_loss: 2.0394 - val_gamma_nll: 2.0393 - val_root_mean_squared_error: 2250.4575
# Epoch 36/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8864 - gamma_nll: 1.8863 - root_mean_squared_error: 2057.1169 - val_loss: 2.0373 - val_gamma_nll: 2.0372 - val_root_mean_squared_error: 2261.9526
# Epoch 37/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8846 - gamma_nll: 1.8847 - root_mean_squared_error: 2074.7969 - val_loss: 2.1492 - val_gamma_nll: 2.1493 - val_root_mean_squared_error: 2561.5171
# Epoch 38/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8922 - gamma_nll: 1.8920 - root_mean_squared_error: 2061.6199 - val_loss: 2.1346 - val_gamma_nll: 2.1348 - val_root_mean_squared_error: 2498.3342
# Epoch 39/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8765 - gamma_nll: 1.8763 - root_mean_squared_error: 2050.8762 - val_loss: 2.1103 - val_gamma_nll: 2.1105 - val_root_mean_squared_error: 2489.2173
# Epoch 40/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8713 - gamma_nll: 1.8712 - root_mean_squared_error: 2029.9832 - val_loss: 2.0939 - val_gamma_nll: 2.0939 - val_root_mean_squared_error: 2448.4573
# Epoch 41/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8630 - gamma_nll: 1.8624 - root_mean_squared_error: 2020.6907 - val_loss: 2.1049 - val_gamma_nll: 2.1050 - val_root_mean_squared_error: 2450.3198
# Epoch 42/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8792 - gamma_nll: 1.8788 - root_mean_squared_error: 2003.1562 - val_loss: 1.9970 - val_gamma_nll: 1.9971 - val_root_mean_squared_error: 2292.5200
# Epoch 43/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8837 - gamma_nll: 1.8838 - root_mean_squared_error: 2072.8623 - val_loss: 1.9554 - val_gamma_nll: 1.9554 - val_root_mean_squared_error: 2232.7808
# Epoch 44/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8643 - gamma_nll: 1.8644 - root_mean_squared_error: 2029.9248 - val_loss: 1.9494 - val_gamma_nll: 1.9493 - val_root_mean_squared_error: 2221.5569
# Epoch 45/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8651 - gamma_nll: 1.8651 - root_mean_squared_error: 2028.9182 - val_loss: 1.9504 - val_gamma_nll: 1.9503 - val_root_mean_squared_error: 2215.5586
# Epoch 46/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8663 - gamma_nll: 1.8666 - root_mean_squared_error: 2032.2618 - val_loss: 1.9519 - val_gamma_nll: 1.9519 - val_root_mean_squared_error: 2254.1169
# Epoch 47/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8694 - gamma_nll: 1.8693 - root_mean_squared_error: 2065.2974 - val_loss: 1.9267 - val_gamma_nll: 1.9267 - val_root_mean_squared_error: 2238.2009
# Epoch 48/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8620 - gamma_nll: 1.8618 - root_mean_squared_error: 2036.3799 - val_loss: 1.9181 - val_gamma_nll: 1.9181 - val_root_mean_squared_error: 2222.1160
# Epoch 49/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8688 - gamma_nll: 1.8686 - root_mean_squared_error: 2068.0647 - val_loss: 1.9374 - val_gamma_nll: 1.9374 - val_root_mean_squared_error: 2251.5723
# Epoch 50/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8661 - gamma_nll: 1.8658 - root_mean_squared_error: 2043.3330 - val_loss: 1.9658 - val_gamma_nll: 1.9657 - val_root_mean_squared_error: 2268.6213
# Epoch 51/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8617 - gamma_nll: 1.8625 - root_mean_squared_error: 2025.5732 - val_loss: 1.9530 - val_gamma_nll: 1.9530 - val_root_mean_squared_error: 2260.9019
# Epoch 52/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8339 - gamma_nll: 1.8337 - root_mean_squared_error: 1984.5387 - val_loss: 2.0655 - val_gamma_nll: 2.0651 - val_root_mean_squared_error: 2316.1460
# Epoch 53/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8838 - gamma_nll: 1.8832 - root_mean_squared_error: 2054.1523 - val_loss: 1.9012 - val_gamma_nll: 1.9012 - val_root_mean_squared_error: 2198.7134
# Epoch 54/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8581 - gamma_nll: 1.8581 - root_mean_squared_error: 2035.6305 - val_loss: 1.8991 - val_gamma_nll: 1.8989 - val_root_mean_squared_error: 2213.0088
# Epoch 55/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8478 - gamma_nll: 1.8483 - root_mean_squared_error: 1976.4796 - val_loss: 2.0661 - val_gamma_nll: 2.0658 - val_root_mean_squared_error: 2267.7126
# Epoch 56/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8529 - gamma_nll: 1.8526 - root_mean_squared_error: 2004.3926 - val_loss: 1.9708 - val_gamma_nll: 1.9705 - val_root_mean_squared_error: 2236.2043
# Epoch 57/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8485 - gamma_nll: 1.8483 - root_mean_squared_error: 2034.7168 - val_loss: 1.9061 - val_gamma_nll: 1.9060 - val_root_mean_squared_error: 2212.0305
# Epoch 58/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8545 - gamma_nll: 1.8547 - root_mean_squared_error: 2007.0693 - val_loss: 1.8996 - val_gamma_nll: 1.8994 - val_root_mean_squared_error: 2209.8208
# Epoch 59/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8443 - gamma_nll: 1.8442 - root_mean_squared_error: 2005.6942 - val_loss: 1.8645 - val_gamma_nll: 1.8645 - val_root_mean_squared_error: 2203.5928
# Epoch 60/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8476 - gamma_nll: 1.8474 - root_mean_squared_error: 2079.9749 - val_loss: 1.8638 - val_gamma_nll: 1.8637 - val_root_mean_squared_error: 2167.2263
# Epoch 61/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8604 - gamma_nll: 1.8608 - root_mean_squared_error: 2031.3065 - val_loss: 1.8730 - val_gamma_nll: 1.8730 - val_root_mean_squared_error: 2201.1377
# Epoch 62/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8447 - gamma_nll: 1.8443 - root_mean_squared_error: 2015.0981 - val_loss: 1.9089 - val_gamma_nll: 1.9089 - val_root_mean_squared_error: 2263.1145
# Epoch 63/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8415 - gamma_nll: 1.8412 - root_mean_squared_error: 1989.8180 - val_loss: 1.9160 - val_gamma_nll: 1.9161 - val_root_mean_squared_error: 2272.3501
# Epoch 64/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8419 - gamma_nll: 1.8420 - root_mean_squared_error: 1990.2312 - val_loss: 1.9391 - val_gamma_nll: 1.9391 - val_root_mean_squared_error: 2446.9631
# Epoch 65/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8361 - gamma_nll: 1.8362 - root_mean_squared_error: 1973.0557 - val_loss: 1.9176 - val_gamma_nll: 1.9177 - val_root_mean_squared_error: 2462.4695
# Epoch 66/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8554 - gamma_nll: 1.8550 - root_mean_squared_error: 2010.3301 - val_loss: 1.8627 - val_gamma_nll: 1.8627 - val_root_mean_squared_error: 2218.5461
# Epoch 67/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8319 - gamma_nll: 1.8318 - root_mean_squared_error: 2011.2784 - val_loss: 1.9078 - val_gamma_nll: 1.9079 - val_root_mean_squared_error: 2341.8975
# Epoch 68/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8372 - gamma_nll: 1.8372 - root_mean_squared_error: 2011.8813 - val_loss: 1.9692 - val_gamma_nll: 1.9692 - val_root_mean_squared_error: 2555.7200
# Epoch 69/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8143 - gamma_nll: 1.8145 - root_mean_squared_error: 1993.1266 - val_loss: 2.0610 - val_gamma_nll: 2.0611 - val_root_mean_squared_error: 3147.4683
# Epoch 70/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8433 - gamma_nll: 1.8431 - root_mean_squared_error: 2005.0670 - val_loss: 2.0103 - val_gamma_nll: 2.0104 - val_root_mean_squared_error: 2687.1714
# Epoch 71/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8321 - gamma_nll: 1.8320 - root_mean_squared_error: 1990.3287 - val_loss: 2.0395 - val_gamma_nll: 2.0397 - val_root_mean_squared_error: 2755.0159
# Epoch 72/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8335 - gamma_nll: 1.8334 - root_mean_squared_error: 2003.0383 - val_loss: 1.8831 - val_gamma_nll: 1.8831 - val_root_mean_squared_error: 2269.5999
# Epoch 73/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8395 - gamma_nll: 1.8393 - root_mean_squared_error: 1991.0635 - val_loss: 1.8527 - val_gamma_nll: 1.8528 - val_root_mean_squared_error: 2271.0818
# Epoch 74/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8105 - gamma_nll: 1.8100 - root_mean_squared_error: 1959.5018 - val_loss: 1.8622 - val_gamma_nll: 1.8620 - val_root_mean_squared_error: 2173.1067
# Epoch 75/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8375 - gamma_nll: 1.8370 - root_mean_squared_error: 2041.2622 - val_loss: 1.8786 - val_gamma_nll: 1.8782 - val_root_mean_squared_error: 2207.2354
# Epoch 76/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8232 - gamma_nll: 1.8230 - root_mean_squared_error: 2001.2738 - val_loss: 1.8858 - val_gamma_nll: 1.8855 - val_root_mean_squared_error: 2175.4480
# Epoch 77/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8136 - gamma_nll: 1.8138 - root_mean_squared_error: 1979.2057 - val_loss: 1.8563 - val_gamma_nll: 1.8563 - val_root_mean_squared_error: 2222.5066
# Epoch 78/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8407 - gamma_nll: 1.8404 - root_mean_squared_error: 2016.5500 - val_loss: 1.8359 - val_gamma_nll: 1.8359 - val_root_mean_squared_error: 2162.3564
# Epoch 79/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8124 - gamma_nll: 1.8124 - root_mean_squared_error: 1970.4927 - val_loss: 1.8280 - val_gamma_nll: 1.8279 - val_root_mean_squared_error: 2150.4583
# Epoch 80/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8053 - gamma_nll: 1.8055 - root_mean_squared_error: 1956.1859 - val_loss: 1.8560 - val_gamma_nll: 1.8557 - val_root_mean_squared_error: 2192.5305
# Epoch 81/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8299 - gamma_nll: 1.8303 - root_mean_squared_error: 2047.1632 - val_loss: 1.8756 - val_gamma_nll: 1.8756 - val_root_mean_squared_error: 2373.0332
# Epoch 82/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.7999 - gamma_nll: 1.8001 - root_mean_squared_error: 1960.2366 - val_loss: 1.8896 - val_gamma_nll: 1.8896 - val_root_mean_squared_error: 2256.4719
# Epoch 83/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8209 - gamma_nll: 1.8207 - root_mean_squared_error: 2011.8451 - val_loss: 1.9018 - val_gamma_nll: 1.9019 - val_root_mean_squared_error: 2628.0659
# Epoch 84/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8244 - gamma_nll: 1.8244 - root_mean_squared_error: 2014.0234 - val_loss: 1.8562 - val_gamma_nll: 1.8562 - val_root_mean_squared_error: 2228.1694
# Epoch 85/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8038 - gamma_nll: 1.8038 - root_mean_squared_error: 1967.7448 - val_loss: 1.8605 - val_gamma_nll: 1.8605 - val_root_mean_squared_error: 2301.9448
# Epoch 86/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8085 - gamma_nll: 1.8091 - root_mean_squared_error: 1997.2576 - val_loss: 1.8981 - val_gamma_nll: 1.8978 - val_root_mean_squared_error: 2398.5767
# Epoch 87/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8168 - gamma_nll: 1.8159 - root_mean_squared_error: 2021.5338 - val_loss: 1.8203 - val_gamma_nll: 1.8203 - val_root_mean_squared_error: 2201.2090
# Epoch 88/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8034 - gamma_nll: 1.8032 - root_mean_squared_error: 1971.9806 - val_loss: 1.7917 - val_gamma_nll: 1.7916 - val_root_mean_squared_error: 2125.2751
# Epoch 89/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8159 - gamma_nll: 1.8158 - root_mean_squared_error: 1998.9478 - val_loss: 1.8371 - val_gamma_nll: 1.8369 - val_root_mean_squared_error: 2191.6790
# Epoch 90/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8050 - gamma_nll: 1.8054 - root_mean_squared_error: 1971.3143 - val_loss: 1.8354 - val_gamma_nll: 1.8353 - val_root_mean_squared_error: 2202.4504
# Epoch 91/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8016 - gamma_nll: 1.8016 - root_mean_squared_error: 1991.6013 - val_loss: 1.8339 - val_gamma_nll: 1.8337 - val_root_mean_squared_error: 2169.2625
# Epoch 92/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.7975 - gamma_nll: 1.7974 - root_mean_squared_error: 1983.6573 - val_loss: 1.8002 - val_gamma_nll: 1.8000 - val_root_mean_squared_error: 2146.3542
# Epoch 93/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8157 - gamma_nll: 1.8151 - root_mean_squared_error: 2032.9908 - val_loss: 1.8031 - val_gamma_nll: 1.8030 - val_root_mean_squared_error: 2173.0400
# Epoch 94/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.7917 - gamma_nll: 1.7917 - root_mean_squared_error: 1973.3749 - val_loss: 1.8521 - val_gamma_nll: 1.8521 - val_root_mean_squared_error: 2353.3909
# Epoch 95/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8128 - gamma_nll: 1.8125 - root_mean_squared_error: 2029.8234 - val_loss: 1.8089 - val_gamma_nll: 1.8087 - val_root_mean_squared_error: 2179.8965
# Epoch 96/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.7860 - gamma_nll: 1.7858 - root_mean_squared_error: 1945.3264 - val_loss: 1.9410 - val_gamma_nll: 1.9412 - val_root_mean_squared_error: 2596.2603
# Epoch 97/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8092 - gamma_nll: 1.8087 - root_mean_squared_error: 2019.7084 - val_loss: 1.9214 - val_gamma_nll: 1.9215 - val_root_mean_squared_error: 2441.8052
# Epoch 98/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.7953 - gamma_nll: 1.7957 - root_mean_squared_error: 1973.4500 - val_loss: 1.9311 - val_gamma_nll: 1.9313 - val_root_mean_squared_error: 2719.1733
# 1/1 [==============================] - 0s 15ms/step - loss: 1.7917 - gamma_nll: 1.7917 - root_mean_squared_error: 2125.2749

# %%
average_val_loss = {}

# Iterate over each lambda and its corresponding interaction losses
for lambd, loss_dict in lambd_val_loss.items():
    # Calculate the average validation loss for the current lambda
    avg_loss = sum(loss_dict.values()) / len(loss_dict)
    average_val_loss[lambd] = avg_loss

# Optionally, sort the lambdas for better readability
average_val_loss = dict(sorted(average_val_loss.items()))
average_val_loss
# Out:
# {0: 2.2377724170684816}

# %%
# -------------------------- plot the validation loss --------------------------
# Convert interaction loss dictionary to a pandas DataFrame
interaction_df = pd.DataFrame(list(lambd_val_loss[0].items()), columns = ['Interaction_Pair', 'Validation_Loss'])

# Sort the DataFrame by Validation_Loss in increasing order
interaction_df = interaction_df.sort_values(by = 'Validation_Loss', ascending = True)

# Create the bar plot using Seaborn
plt.figure(figsize = (20, 12))
sns.lineplot(x = 'Interaction_Pair', y = 'Validation_Loss', data = interaction_df, marker = 'o')
plt.axhline(main_val_loss, color = 'red', linestyle = '--', label = 'Validation Loss of Main Effect Model')
plt.xlabel('Interaction Effect Pairs')
plt.ylabel('Validation Loss')
plt.title('Validation Loss for Interaction Effect Pairs (Sorted by Increasing Loss)')
plt.legend()
plt.show()

# %%
# # -------------------------- Create the Pairwise Only Model --------------------------
# # pairwise_effect = ("X3", "X4")  # the pairwise effect we want to view
# pairwise_effect = interactions[0]
# pairwise_index = interactions.index(pairwise_effect)
# subnet_output_layer = model_pairwise.get_layer("interaction_output")
# subnet_model = Model(inputs = model_pairwise.inputs, outputs = subnet_output_layer.output)


# # -------------------------- Generate the Input Grid --------------------------
# # Create a grid of values
# grid_length = 100
# var1_values = np.linspace(X_train[interactions[pairwise_index][0]].min(), 
#                           X_train[interactions[pairwise_index][0]].max(), 
#                           grid_length)
# var2_values = np.linspace(X_train[interactions[pairwise_index][1]].min(), 
#                           X_train[interactions[pairwise_index][1]].max(), 
#                           grid_length)

# # Create a meshgrid
# grid_var1, grid_var2 = np.meshgrid(var1_values, var2_values)

# # Flatten the grid
# grid_flat_var1 = grid_var1.ravel()
# grid_flat_var2 = grid_var2.ravel()


# # -------------------------- Prepare Inputs for the Model --------------------------
# grid_inputs = []
# for var in all_vars:
#     if var == interactions[pairwise_index][0]:
#         grid_inputs.append(grid_flat_var1)
#     elif var == interactions[pairwise_index][1]:
#         grid_inputs.append(grid_flat_var2)
#     else:
#         grid_inputs.append(np.zeros_like(grid_flat_var1))


# # -------------------------- Predict Using the Pairwise-Only Model --------------------------
# # Predict the pairwise interaction effect
# pairwise_predictions = np.log(subnet_model.predict(grid_inputs))

# # Reshape the predictions to the grid format
# heatmap_values = pairwise_predictions.reshape(grid_var1.shape)


# # -------------------------- Plot the Heatmap --------------------------
# plt.figure(figsize = (10, 8))
# contour = plt.contourf(grid_var1, grid_var2, heatmap_values, levels = 10)
# plt.colorbar(contour)
# plt.title('Predicted Function by the Model')
# plt.xlabel(f"{interactions[pairwise_index][0]}")
# plt.ylabel(f"{interactions[pairwise_index][1]}")
# plt.show()

# %%
# #-------------------------- view the shape function --------------------------
# # get the prediction
# main_output_layer = model_pairwise.get_layer("main_subnet")
# subnet_model = Model(inputs = model_pairwise.inputs, outputs = main_output_layer.output)
# subnet_output = subnet_model.predict(X_train_split)

# # create the plot
# var_name = "X3"
# var_index = all_vars.index(var_name)
# plt.figure(figsize = (12, 6))
# sns.lineplot(x = X_train_split[var_index], 
#              y = subnet_output[:,var_index])
# plt.xlabel(f"{var_name}")
# plt.ylabel('Subnetwork Output')
# plt.title(f"Shape function for {var_name}")
# plt.grid(True)
# plt.show()
