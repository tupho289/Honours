# %%
############################ 0. PREPARATION ############################

#-------------------------- import packages --------------------------
import random
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from itertools import combinations
import seaborn as sns
import copy
import itertools

import tensorflow as tf
import tensorflow_lattice as tfl
import tf_keras as keras # need keras 2 to fit Lattice model
from tf_keras.models import Sequential, Model
from tf_keras.layers import Dense, Input, Multiply, Add, Embedding, Reshape, Concatenate, Dropout, BatchNormalization, Lambda, Layer, CategoryEncoding, Activation
from tf_keras.constraints import Constraint
from tf_keras.callbacks import EarlyStopping
from tf_keras.initializers import Zeros, Constant
from tf_keras.optimizers import Adam, Nadam, RMSprop
from tf_keras.models import clone_model
import keras_tuner as kt
from tf_keras import backend as K
from tf_keras import regularizers
from tf_keras.utils import plot_model
from tf_keras.losses import Poisson, Loss
from tf_keras.metrics import MeanAbsoluteError, RootMeanSquaredError
from scipy.stats import gamma


from pygam import LinearGAM, GAM, s, f, l
from sklearn.linear_model import ElasticNet
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error as mae
from sklearn.tree import DecisionTreeRegressor
from interpret.glassbox import ExplainableBoostingClassifier

# %%
#-------------------------- for reproducibility --------------------------
seed_value = 28
keras.utils.set_random_seed(seed_value)

# %%
#-------------------------- import data --------------------------
data = pd.read_csv("synthetic_low_var.csv")

# %%
#-------------------------- remove outliers --------------------------
log_claim = np.log(data['Y'])
IQR = log_claim.quantile(0.75) - log_claim.quantile(0.25) # inter-quartile range
lower_whisker = log_claim.quantile(0.25)- 1.5*IQR
upper_whisker = log_claim.quantile(0.75) + 1.5*IQR

# remove outliers: filter rows where the log of 'Y' is within the whiskers
dt_cleaned = data[(log_claim >= lower_whisker) & (log_claim <= upper_whisker)]
dt_cleaned
# Out:
#              X1        X2        X3        X4        X5        X6        X7  \
# 0      0.097627 -0.215654 -0.261487  0.855910 -0.977807  0.070514  0.247397
# 1      0.430379 -0.917687 -0.577348  0.805874 -0.996460  0.808088 -0.727145
# 2      0.205527  0.846601 -0.046190 -0.144766 -0.689890  0.004793  0.787168
# 3      0.089766 -0.187530 -0.835531  0.021611 -0.366478 -0.798260 -0.363850
# 4     -0.152690  0.888564 -0.524681  0.166400  0.303690  0.055164  0.158018
# ...         ...       ...       ...       ...       ...       ...       ...
# 19995  0.496349  0.336766  0.766494 -0.723110  0.451842 -0.547824  0.165682
# 19996 -0.403467  0.989823 -0.239838  0.690306  0.015041  0.168038 -0.808643
# 19997 -0.107088  0.176448 -0.661992  0.568246  0.620266  0.669292 -0.267906
# 19998 -0.279747 -0.150770 -0.472139  0.238510  0.102065 -0.832383  0.539168
# 19999  0.251773  0.803265 -0.397666 -0.684942 -0.548488 -0.791774 -0.620137
#
#              X8        X9       X10            Y
# 0     -0.844805 -0.633014  0.932805   269.727579
# 1      0.592222  0.416902  0.949203   606.423722
# 2     -0.029304 -0.254262 -0.739165  6740.904922
# 3      0.669637 -0.150974  0.020263  6749.592779
# 4      0.046901 -0.468522 -0.772319    79.024055
# ...         ...       ...       ...          ...
# 19995 -0.515032  0.372611 -0.262674    30.561326
# 19996 -0.903895 -0.433667 -0.389854   105.129106
# 19997  0.006409  0.871063 -0.570751  1101.252426
# 19998  0.073274  0.110462 -0.408447   634.928937
# 19999  0.197031 -0.409905  0.685008  2295.828834
#
# [19825 rows x 11 columns]

# %%
#-------------------------- distribution of log(response) --------------------------
plt.figure(figsize = (10, 6)) # set the size of the figure
sns.set_style("darkgrid")
sns.histplot(np.log(dt_cleaned['Y']), bins = 30, kde = True) # draw the chart
plt.title('Distribution of log(Y)')
plt.xlabel('Log(Y)')
plt.ylabel('Frequency')
plt.tick_params(axis = 'x')
plt.tick_params(axis = 'y')
plt.grid(True)
plt.show()

# %%
#-------------------------- column lists --------------------------
target_var = "Y" # target feature
all_vars = list(dt_cleaned.columns)
all_vars.remove(target_var) # store all input features
cat_vars = [] # categorical features

# %%
############################ 1. MODEL FITTING ############################

#-------------------------- train-test split --------------------------
X_main, X_test, y_main, y_test = train_test_split(
    dt_cleaned[all_vars], dt_cleaned[["Y"]], test_size = 0.2, random_state = 1)
X_train, X_val, y_train, y_val  = train_test_split(
    X_main, y_main, test_size = 0.25, random_state = 1)

# %%
# -------------------------- function to create a subnetwork --------------------------
# subnet for numerical variables
def create_subnet(num_layers, units_per_layer, activation, model_name, dropout_rate = 0, trainable = True, seed = 1):
    model = Sequential(name = model_name)
    for _ in range(num_layers):
        model.add(Dense(units_per_layer, activation = activation, trainable = trainable))
        model.add(Dropout(dropout_rate, seed = seed))
    model.add(Dense(1, trainable = trainable))
    model.add(BatchNormalization(scale = False)) # for identifiability
    return model

# layer to add all subnets' outputs and a bias term
@keras.saving.register_keras_serializable()
class AddSubnetOutput(Layer):
    def __init__(self, activation = None, **kwargs):
        super().__init__(**kwargs)
        self.activation = keras.activations.get(activation)
        self.bias = self.add_weight(
            shape = (1,), initializer = 'zeros', trainable = True, name = 'bias'
        )   
    def call(self, inputs):
        subnet_sum = K.sum(inputs, axis = -1, keepdims = True)
        output = subnet_sum + self.bias
        if self.activation is not None:
            output = self.activation(output)
        return output

# %%
# -------------------------- define model architecture --------------------------
inputs = []  # input layers
sub_outputs_main = []  # main effect subnet output
num_neurons_main = 10
num_layers_main = 2
activation = 'leaky_relu'
keypoints = 10
monotonicity_list = {"X3" : "decreasing"} # either "increasing", "decreasing", or "none"

# main effect
for name in all_vars:
    input_layer = Input(shape = (1,), name = name)
    inputs.append(input_layer)

    # subnetworks for main effects
    if name in cat_vars: # categorical variables
        # categorical variables will be one-hot encoded
        embed_layer = Embedding(input_dim = X_train[name].nunique(), 
                                output_dim = 1, 
                                name = f"{name}_embed")(input_layer)
        embed_layer_reshape = Reshape(target_shape = (1,), name = f"{name}_reshape")(embed_layer)
        mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(embed_layer_reshape)
        sub_outputs_main.append(mean_layer)
    elif name in monotonicity_list: # variables with monotonicity constraint
        calibrator_layer = tfl.layers.PWLCalibration(
            input_keypoints =  np.linspace(X_train[name].min(), X_train[name].max(), num = keypoints), # keypoints
            monotonicity = monotonicity_list[name], # monotonicity constraint
            name = f"{name}_pwlcalibrator"
        )(input_layer)
        mean_layer = BatchNormalization(scale = False, name = f"{name}_mean")(calibrator_layer)
        sub_outputs_main.append(mean_layer)
    else: # numeric variables
        subnet = create_subnet(num_layers_main, num_neurons_main, activation, f"{name}_subnetwork")
        sub_output = subnet(input_layer)
        sub_outputs_main.append(sub_output)

# combine subnets' outputs
main_subnets = Concatenate(name = "main_subnet")(sub_outputs_main)
final_output = AddSubnetOutput(activation = 'exponential',
                     name = "main_output")(main_subnets)

# final model
model_main_effect = Model(inputs = inputs, outputs = final_output)

# %%
plot_model(model_main_effect)

# %%
# -------------------------- define loss function --------------------------
# we will use a Gamma loss function
def gamma_log_likelihood(y_true, y_pred):
    y_pred = K.clip(y_pred, 1e-7, 1e30)
    return K.mean(y_true/y_pred - K.log(y_true/y_pred))

# create training & validation data consistent with the model architecture
X_train_split = []
X_val_split = []
X_test_split = []
for i in range(len(X_train.columns)):
    X_train_split.append(X_train.iloc[:, i])
    X_val_split.append(X_val.iloc[:, i])
    X_test_split.append(X_test.iloc[:, i])

# compile and fit
model_main_effect.compile(optimizer = "rmsprop", loss = gamma_log_likelihood, metrics = [RootMeanSquaredError()])
es = EarlyStopping(restore_best_weights = True, patience = 10)
# %time hist_main = model_main_effect.fit(X_train_split, y_train, epochs = 5_000, \
    callbacks = [es], batch_size = 1_000, validation_data = (X_val_split, y_val))
# Out:
# Epoch 1/5000
# 12/12 [==============================] - 2s 25ms/step - loss: 16906.7871 - root_mean_squared_error: 2450.9612 - val_loss: 919.2094 - val_root_mean_squared_error: 2619.4668
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 9504.6572 - root_mean_squared_error: 2415.3411 - val_loss: 817.6498 - val_root_mean_squared_error: 2619.4243
# Epoch 3/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 6746.4097 - root_mean_squared_error: 2399.9993 - val_loss: 751.2767 - val_root_mean_squared_error: 2619.3923
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4855.9927 - root_mean_squared_error: 2396.6296 - val_loss: 671.0491 - val_root_mean_squared_error: 2619.3479
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2789.1682 - root_mean_squared_error: 2394.0803 - val_loss: 613.0065 - val_root_mean_squared_error: 2619.3115
# Epoch 6/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 1556.4285 - root_mean_squared_error: 2392.6592 - val_loss: 562.2798 - val_root_mean_squared_error: 2619.2725
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 1045.0273 - root_mean_squared_error: 2392.7883 - val_loss: 513.9258 - val_root_mean_squared_error: 2619.2344
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 604.1174 - root_mean_squared_error: 2394.0742 - val_loss: 494.6069 - val_root_mean_squared_error: 2619.2129
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 461.8718 - root_mean_squared_error: 2394.4775 - val_loss: 463.6653 - val_root_mean_squared_error: 2619.1719
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 363.9429 - root_mean_squared_error: 2394.6606 - val_loss: 386.6699 - val_root_mean_squared_error: 2619.0386
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 296.8462 - root_mean_squared_error: 2394.5762 - val_loss: 336.8481 - val_root_mean_squared_error: 2618.9204
# Epoch 12/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 235.9178 - root_mean_squared_error: 2394.5903 - val_loss: 298.9395 - val_root_mean_squared_error: 2618.8042
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 191.2889 - root_mean_squared_error: 2394.4258 - val_loss: 275.3257 - val_root_mean_squared_error: 2618.7151
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 165.9142 - root_mean_squared_error: 2394.0642 - val_loss: 234.3247 - val_root_mean_squared_error: 2618.5178
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 146.9191 - root_mean_squared_error: 2393.6357 - val_loss: 216.9928 - val_root_mean_squared_error: 2618.4106
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 128.3909 - root_mean_squared_error: 2392.9204 - val_loss: 177.4170 - val_root_mean_squared_error: 2618.0942
# Epoch 17/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 113.9331 - root_mean_squared_error: 2392.4609 - val_loss: 166.6035 - val_root_mean_squared_error: 2617.9785
# Epoch 18/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 100.8314 - root_mean_squared_error: 2391.5659 - val_loss: 153.4689 - val_root_mean_squared_error: 2617.8191
# Epoch 19/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 88.6594 - root_mean_squared_error: 2390.9309 - val_loss: 150.1302 - val_root_mean_squared_error: 2617.7712
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 78.0292 - root_mean_squared_error: 2390.1001 - val_loss: 129.8900 - val_root_mean_squared_error: 2617.4519
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 69.8671 - root_mean_squared_error: 2388.9324 - val_loss: 112.7994 - val_root_mean_squared_error: 2617.0928
# Epoch 22/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 60.2019 - root_mean_squared_error: 2387.8396 - val_loss: 92.4781 - val_root_mean_squared_error: 2616.4961
# Epoch 23/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 53.8496 - root_mean_squared_error: 2386.4656 - val_loss: 81.7648 - val_root_mean_squared_error: 2616.0559
# Epoch 24/5000
# 12/12 [==============================] - 0s 6ms/step - loss: 47.1298 - root_mean_squared_error: 2385.0588 - val_loss: 64.8140 - val_root_mean_squared_error: 2615.0786
# Epoch 25/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 42.0419 - root_mean_squared_error: 2383.3464 - val_loss: 52.4842 - val_root_mean_squared_error: 2613.9873
# Epoch 26/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 37.1816 - root_mean_squared_error: 2381.5073 - val_loss: 41.0754 - val_root_mean_squared_error: 2612.3911
# Epoch 27/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 32.7992 - root_mean_squared_error: 2379.4197 - val_loss: 35.4493 - val_root_mean_squared_error: 2611.2268
# Epoch 28/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 28.8973 - root_mean_squared_error: 2377.0789 - val_loss: 31.9977 - val_root_mean_squared_error: 2610.3425
# Epoch 29/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 25.1664 - root_mean_squared_error: 2374.6143 - val_loss: 32.7042 - val_root_mean_squared_error: 2610.4790
# Epoch 30/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 22.4585 - root_mean_squared_error: 2371.3955 - val_loss: 30.8670 - val_root_mean_squared_error: 2609.9202
# Epoch 31/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 19.9103 - root_mean_squared_error: 2368.2795 - val_loss: 21.4919 - val_root_mean_squared_error: 2605.7278
# Epoch 32/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 17.5581 - root_mean_squared_error: 2364.9487 - val_loss: 18.5555 - val_root_mean_squared_error: 2603.5515
# Epoch 33/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 15.4593 - root_mean_squared_error: 2360.8013 - val_loss: 20.6184 - val_root_mean_squared_error: 2604.9512
# Epoch 34/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 13.6629 - root_mean_squared_error: 2356.3032 - val_loss: 16.8701 - val_root_mean_squared_error: 2601.6064
# Epoch 35/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 12.0616 - root_mean_squared_error: 2350.7925 - val_loss: 20.0736 - val_root_mean_squared_error: 2604.3550
# Epoch 36/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 10.5728 - root_mean_squared_error: 2345.2822 - val_loss: 12.6940 - val_root_mean_squared_error: 2595.7102
# Epoch 37/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 9.4348 - root_mean_squared_error: 2339.5002 - val_loss: 15.7904 - val_root_mean_squared_error: 2600.0613
# Epoch 38/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 8.6265 - root_mean_squared_error: 2333.2161 - val_loss: 11.9807 - val_root_mean_squared_error: 2593.7700
# Epoch 39/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 7.3759 - root_mean_squared_error: 2324.1558 - val_loss: 20.4609 - val_root_mean_squared_error: 2604.0288
# Epoch 40/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 6.7155 - root_mean_squared_error: 2316.6497 - val_loss: 17.8321 - val_root_mean_squared_error: 2601.7488
# Epoch 41/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 5.8883 - root_mean_squared_error: 2306.5679 - val_loss: 24.5739 - val_root_mean_squared_error: 2606.4937
# Epoch 42/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 5.3972 - root_mean_squared_error: 2299.0540 - val_loss: 26.7166 - val_root_mean_squared_error: 2607.1577
# Epoch 43/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.7585 - root_mean_squared_error: 2288.3967 - val_loss: 13.5078 - val_root_mean_squared_error: 2594.7026
# Epoch 44/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 4.3085 - root_mean_squared_error: 2271.8220 - val_loss: 11.7944 - val_root_mean_squared_error: 2591.1177
# Epoch 45/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 3.9159 - root_mean_squared_error: 2265.5330 - val_loss: 9.2377 - val_root_mean_squared_error: 2583.2917
# Epoch 46/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 3.6202 - root_mean_squared_error: 2250.1309 - val_loss: 7.1023 - val_root_mean_squared_error: 2571.8335
# Epoch 47/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 3.3002 - root_mean_squared_error: 2235.1145 - val_loss: 4.8109 - val_root_mean_squared_error: 2546.4448
# Epoch 48/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 3.0685 - root_mean_squared_error: 2223.0986 - val_loss: 7.1430 - val_root_mean_squared_error: 2569.2729
# Epoch 49/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.8484 - root_mean_squared_error: 2205.0959 - val_loss: 5.9972 - val_root_mean_squared_error: 2558.5786
# Epoch 50/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.7191 - root_mean_squared_error: 2199.4734 - val_loss: 2.7406 - val_root_mean_squared_error: 2456.7646
# Epoch 51/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.5723 - root_mean_squared_error: 2192.7131 - val_loss: 2.5118 - val_root_mean_squared_error: 2418.6311
# Epoch 52/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.4751 - root_mean_squared_error: 2184.1238 - val_loss: 2.3174 - val_root_mean_squared_error: 2338.2258
# Epoch 53/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.4011 - root_mean_squared_error: 2174.7180 - val_loss: 2.3948 - val_root_mean_squared_error: 2386.3330
# Epoch 54/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3321 - root_mean_squared_error: 2173.8098 - val_loss: 2.3797 - val_root_mean_squared_error: 2359.6902
# Epoch 55/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2789 - root_mean_squared_error: 2167.1262 - val_loss: 2.4467 - val_root_mean_squared_error: 2431.4524
# Epoch 56/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2544 - root_mean_squared_error: 2195.7070 - val_loss: 2.8658 - val_root_mean_squared_error: 3710.1416
# Epoch 57/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2429 - root_mean_squared_error: 2200.4775 - val_loss: 2.9882 - val_root_mean_squared_error: 4806.9341
# Epoch 58/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2357 - root_mean_squared_error: 2254.5532 - val_loss: 3.2004 - val_root_mean_squared_error: 5947.3540
# Epoch 59/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2303 - root_mean_squared_error: 2218.0005 - val_loss: 2.6472 - val_root_mean_squared_error: 3305.4585
# Epoch 60/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2404 - root_mean_squared_error: 2257.6753 - val_loss: 3.0537 - val_root_mean_squared_error: 5082.3511
# Epoch 61/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2337 - root_mean_squared_error: 2277.3535 - val_loss: 2.3868 - val_root_mean_squared_error: 2472.4202
# Epoch 62/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2361 - root_mean_squared_error: 2260.3267 - val_loss: 2.4889 - val_root_mean_squared_error: 2776.5125
# CPU times: user 6.38 s, sys: 910 ms, total: 7.29 s
# Wall time: 5.84 s

# %%
# -------------------------- get validation loss --------------------------
main_val_loss, main_rmse = model_main_effect.evaluate(X_val_split, y_val, verbose = False) # get the validation loss and RMSE
print(f"Validation loss for main effect: {main_val_loss}")
print(f"Validation RMSE for main effect: {main_rmse}")
# Out:
# Validation loss for main effect: 2.3174352645874023
# Validation RMSE for main effect: 2338.225830078125

# %%
# -------------------------- quantify variable importance --------------------------
main_output_layer = model_main_effect.get_layer("main_subnet")  # Get the subnet output layer
main_model = Model(inputs = model_main_effect.inputs, outputs = main_output_layer.output)
main_output_values = main_model.predict(X_train_split)
# subnet_weights = model_main_effect.get_layer("main_output").get_weights()[0]


# Get the variance of each subnetwork across all data points
subnet_variance = []
for i in range(main_output_values.shape[1]):
    subnet_variance.append(np.var(main_output_values[:, i]))

# Define covariates
covariates = [name for name in all_vars]

# -------------------------- plot the variable importance --------------------------
# Create DataFrame for variable importance
var_importance = pd.DataFrame({"Covariates": covariates, "Subnet Variance": subnet_variance})

# Sort the DataFrame by subnet variance in decreasing order
varimp_sorted = var_importance.sort_values(by = "Subnet Variance", ascending = False)

# Create a bar plot using Seaborn
plt.figure(figsize = (10, 6))
sns.barplot(x = "Covariates", y = "Subnet Variance", data = varimp_sorted)
plt.title("Subnet Variance by Covariates")
plt.xlabel("Covariates")
plt.ylabel("Subnet Variance")
plt.show()
# Out:
# 372/372 [==============================] - 0s 802us/step

# %%
#-------------------------- view the shape function --------------------------
# create the plot
var_name = "X3"
var_index = all_vars.index(var_name)
plt.figure(figsize = (12, 6))
sns.lineplot(x = X_train_split[var_index], 
             y = main_output_values[:,var_index].flatten())
plt.xlabel(f"{var_name}")
plt.ylabel('Subnetwork Output')
plt.title(f"Shape function for {var_name}")
plt.grid(True)
plt.show()

# %%
############################   preparation for interaction selection   ############################
global_layers = ["main_subnet", "main_output", "interaction_output", "final_output"] # these layers are always trainable
interaction_loss = {} # this stores the validation loss when fitting each pair of interaction effect
imp_vars = [f"X{i}" for i in range(1,7)] # important variables
interactions = combinations(imp_vars, 2)
# interactions = [("X3","X4")]
num_layers_interaction = 3 # number of layers for each interaction effect
num_neurons_interaction = 30 # number of neurons per dense layer for each interaction effect
keypoints = 20
lattice_sizes_pairwise = {}
for var in imp_vars:
    if var in cat_vars:
        lattice_sizes_pairwise[var] = X_train[var].nunique()
    else:
        lattice_sizes_pairwise[var] = 5

# %%
# -------------------------- create calibrator for lattice layer --------------------------
def add_calibrate_layer(var, data, monotonicity_list, lattice_sizes, keypoints, cat_vars, lattice_smooth_reg = [0,0]):
    if var in cat_vars:
        calibrator_layer = tfl.layers.CategoricalCalibration(
            num_buckets = data[var].nunique(),
            output_min = 0,
            output_max = lattice_sizes[var] - 1,
            name = f"{var}_calibrator_pairwise"
        )
    else:
        calibrator_layer = tfl.layers.PWLCalibration(
            input_keypoints =  np.linspace(data[var].min(), data[var].max(), num = keypoints), # keypoints
            kernel_regularizer = ('hessian', lattice_smooth_reg[0], lattice_smooth_reg[1]), # for smoothness
            monotonicity = monotonicity_list[var] if var in monotonicity_list else "none", # monotonicity constraint
            output_min = 0,
            output_max = lattice_sizes[var] - 1,
            name = f"{var}_calibrator_pairwise"
            )
    return calibrator_layer

# %%
############################   select interaction effect   ############################

# add pairwise effect and evaluate validation loss
for var1, var2 in interactions:

    # -------------------------- initialize a cloned model --------------------------
    model_main_cloned = clone_model(model_main_effect) # clone the main effect model
    model_main_cloned.build(model_main_effect.input_shape)
    model_main_cloned.set_weights(model_main_effect.get_weights()) # copy the weights


    # -------------------------- build a subnet for pairwise interaction effect --------------------------
    var1_input = model_main_cloned.inputs[all_vars.index(var1)]
    var2_input = model_main_cloned.inputs[all_vars.index(var2)]

    # Lattice model if the pair contains a monotonic variable
    if any(var in monotonicity_list for var in [var1, var2]):
        lattice_inputs = []

        # create calibrator_layer
        calibrator_var1 = add_calibrate_layer(var1, X_train, monotonicity_list, lattice_sizes_pairwise, keypoints, cat_vars)
        calibrator_var2 = add_calibrate_layer(var2, X_train, monotonicity_list, lattice_sizes_pairwise, keypoints, cat_vars)
        calibrator_layer_var1 = calibrator_var1(var1_input)
        calibrator_layer_var2 = calibrator_var2(var2_input)
        
        # lattice
        lattice_inputs.append(calibrator_layer_var1)
        lattice_inputs.append(calibrator_layer_var2)
        lattice_layer = tfl.layers.Lattice(lattice_sizes = [lattice_sizes_pairwise[var1],lattice_sizes_pairwise[var2]], 
                             monotonicities = ["increasing" if var1 in monotonicity_list else 'none',
                                                "increasing" if var2 in monotonicity_list else 'none'],
                             name = f"{var1}_{var2}_lattice")(lattice_inputs)
        pairwise_output = BatchNormalization(scale = False, name = f"{var1}_{var2}_mean")(lattice_layer)
    else:
        # Subnetwork if the pair contains no monotonic variables
        pairwise_input_layer = Concatenate(name = f"{var1}_{var2}_concat")([var1_input, var2_input])
        pairwise_subnet = create_subnet(num_layers_interaction, 
                                        num_neurons_interaction, 
                                        activation, 
                                        f"{var1}_{var2}_subnetwork")
        pairwise_output = pairwise_subnet(pairwise_input_layer)

    # final output
    interaction_subnet_output = Activation('exponential',
                        name = "interaction_output")(pairwise_output)
    main_subnet_output = model_main_cloned.output
    final_output = Multiply(name = "final_output")([main_subnet_output, interaction_subnet_output])
    model_pairwise = Model(inputs = model_main_cloned.inputs, outputs = final_output)


    # -------------------------- switch on/off layers --------------------------
    for layer in model_pairwise.layers:
        if layer.name not in global_layers and var1 not in layer.name and var2 not in layer.name:
            layer.trainable = False


    #-------------------------- custom loss function with marginal clarity constraint --------------------------
    # add marginal clarity constraint
    main_effects_output = model_pairwise.get_layer("main_subnet").output
    main_output_var1 = main_effects_output[all_vars.index(var1)]
    main_output_var2 = main_effects_output[all_vars.index(var2)]
    interaction_output = pairwise_output
    lambd = 5
    penalty = lambd * (
        K.abs(K.mean(main_output_var1 * interaction_output)) +
        K.abs(K.mean(main_output_var2 * interaction_output))
    )

    # Add the penalty to the model's total loss
    model_pairwise.add_loss(penalty)

    # -------------------------- compile and train the model --------------------------
    model_pairwise.compile(optimizer = 'rmsprop', 
                           loss = gamma_log_likelihood, 
                           metrics = [gamma_log_likelihood, RootMeanSquaredError()])
    es = EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)
    model_pairwise.fit(X_train_split, y_train, epochs = 5_000, \
                            callbacks = [es], batch_size = 1_000, validation_data = (X_val_split, y_val))
    _, gamma_log_metric, _ = model_pairwise.evaluate(X_val_split, y_val, batch_size = X_val_split[0].shape[0])
    interaction_loss[f"{var1}_{var2}"] = gamma_log_metric # add to the val loss list
# Out:
# Epoch 1/5000
# 12/12 [==============================] - 1s 28ms/step - loss: 2.3986 - gamma_log_likelihood: 2.3921 - root_mean_squared_error: 2214.8772 - val_loss: 2.4169 - val_gamma_log_likelihood: 2.4068 - val_root_mean_squared_error: 2404.5593
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2877 - gamma_log_likelihood: 2.2838 - root_mean_squared_error: 2108.8020 - val_loss: 2.5133 - val_gamma_log_likelihood: 2.4692 - val_root_mean_squared_error: 2390.1177
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2984 - gamma_log_likelihood: 2.2954 - root_mean_squared_error: 2119.2449 - val_loss: 2.5190 - val_gamma_log_likelihood: 2.4542 - val_root_mean_squared_error: 2400.3303
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2726 - gamma_log_likelihood: 2.2698 - root_mean_squared_error: 2100.5576 - val_loss: 2.5559 - val_gamma_log_likelihood: 2.5452 - val_root_mean_squared_error: 2496.7158
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2802 - gamma_log_likelihood: 2.2775 - root_mean_squared_error: 2106.8289 - val_loss: 2.5482 - val_gamma_log_likelihood: 2.5039 - val_root_mean_squared_error: 2663.3218
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2648 - gamma_log_likelihood: 2.2616 - root_mean_squared_error: 2098.0127 - val_loss: 2.6028 - val_gamma_log_likelihood: 2.5418 - val_root_mean_squared_error: 2594.7566
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2718 - gamma_log_likelihood: 2.2689 - root_mean_squared_error: 2105.5349 - val_loss: 2.6191 - val_gamma_log_likelihood: 2.5654 - val_root_mean_squared_error: 3021.8848
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2711 - gamma_log_likelihood: 2.2681 - root_mean_squared_error: 2103.4773 - val_loss: 2.6255 - val_gamma_log_likelihood: 2.5786 - val_root_mean_squared_error: 2985.4521
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2607 - gamma_log_likelihood: 2.2574 - root_mean_squared_error: 2098.6960 - val_loss: 2.5751 - val_gamma_log_likelihood: 2.5365 - val_root_mean_squared_error: 2796.8394
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2579 - gamma_log_likelihood: 2.2550 - root_mean_squared_error: 2094.1992 - val_loss: 2.6182 - val_gamma_log_likelihood: 2.5366 - val_root_mean_squared_error: 2688.8794
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2667 - gamma_log_likelihood: 2.2641 - root_mean_squared_error: 2104.5581 - val_loss: 2.7351 - val_gamma_log_likelihood: 2.6020 - val_root_mean_squared_error: 2636.4470
# 1/1 [==============================] - 0s 18ms/step - loss: 2.4165 - gamma_log_likelihood: 2.4066 - root_mean_squared_error: 2404.5593
# Epoch 1/5000
# 12/12 [==============================] - 2s 29ms/step - loss: 2.5334 - gamma_log_likelihood: 2.5263 - root_mean_squared_error: 2856.1096 - val_loss: 6.3249 - val_gamma_log_likelihood: 3.0642 - val_root_mean_squared_error: 3617.4888
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3431 - gamma_log_likelihood: 2.3388 - root_mean_squared_error: 2240.9609 - val_loss: 6.2788 - val_gamma_log_likelihood: 3.1827 - val_root_mean_squared_error: 4203.2974
# Epoch 3/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3392 - gamma_log_likelihood: 2.3366 - root_mean_squared_error: 2244.4009 - val_loss: 5.7395 - val_gamma_log_likelihood: 2.9834 - val_root_mean_squared_error: 3426.7075
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3319 - gamma_log_likelihood: 2.3289 - root_mean_squared_error: 2261.5320 - val_loss: 5.2159 - val_gamma_log_likelihood: 2.7609 - val_root_mean_squared_error: 2781.2686
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3265 - gamma_log_likelihood: 2.3240 - root_mean_squared_error: 2272.9185 - val_loss: 4.8962 - val_gamma_log_likelihood: 2.6534 - val_root_mean_squared_error: 2587.5713
# Epoch 6/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3181 - gamma_log_likelihood: 2.3149 - root_mean_squared_error: 2259.2378 - val_loss: 4.6374 - val_gamma_log_likelihood: 2.5814 - val_root_mean_squared_error: 2507.1821
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3201 - gamma_log_likelihood: 2.3171 - root_mean_squared_error: 2285.4319 - val_loss: 4.4059 - val_gamma_log_likelihood: 2.4974 - val_root_mean_squared_error: 2402.9868
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3132 - gamma_log_likelihood: 2.3100 - root_mean_squared_error: 2304.6160 - val_loss: 4.4648 - val_gamma_log_likelihood: 2.5847 - val_root_mean_squared_error: 2539.9351
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3134 - gamma_log_likelihood: 2.3104 - root_mean_squared_error: 2296.9980 - val_loss: 4.3301 - val_gamma_log_likelihood: 2.5517 - val_root_mean_squared_error: 2487.9683
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3046 - gamma_log_likelihood: 2.3014 - root_mean_squared_error: 2311.1143 - val_loss: 4.3364 - val_gamma_log_likelihood: 2.5818 - val_root_mean_squared_error: 2545.3540
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3121 - gamma_log_likelihood: 2.3090 - root_mean_squared_error: 2344.8672 - val_loss: 4.2839 - val_gamma_log_likelihood: 2.6087 - val_root_mean_squared_error: 2612.4424
# Epoch 12/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3064 - gamma_log_likelihood: 2.3029 - root_mean_squared_error: 2333.9021 - val_loss: 4.3240 - val_gamma_log_likelihood: 2.6799 - val_root_mean_squared_error: 2773.2908
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3027 - gamma_log_likelihood: 2.2992 - root_mean_squared_error: 2325.1885 - val_loss: 4.1859 - val_gamma_log_likelihood: 2.6316 - val_root_mean_squared_error: 2770.9771
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3011 - gamma_log_likelihood: 2.2983 - root_mean_squared_error: 2337.7383 - val_loss: 4.2030 - val_gamma_log_likelihood: 2.6331 - val_root_mean_squared_error: 2701.5083
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2910 - gamma_log_likelihood: 2.2882 - root_mean_squared_error: 2331.8606 - val_loss: 4.1977 - val_gamma_log_likelihood: 2.6512 - val_root_mean_squared_error: 2756.7715
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2910 - gamma_log_likelihood: 2.2883 - root_mean_squared_error: 2329.1326 - val_loss: 4.2146 - val_gamma_log_likelihood: 2.6954 - val_root_mean_squared_error: 2908.6350
# Epoch 17/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2888 - gamma_log_likelihood: 2.2858 - root_mean_squared_error: 2331.9968 - val_loss: 4.0800 - val_gamma_log_likelihood: 2.6055 - val_root_mean_squared_error: 2699.5630
# Epoch 18/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2854 - gamma_log_likelihood: 2.2820 - root_mean_squared_error: 2325.1990 - val_loss: 4.2500 - val_gamma_log_likelihood: 2.7012 - val_root_mean_squared_error: 2971.1199
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2867 - gamma_log_likelihood: 2.2839 - root_mean_squared_error: 2311.9065 - val_loss: 4.1873 - val_gamma_log_likelihood: 2.6325 - val_root_mean_squared_error: 2917.6074
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2816 - gamma_log_likelihood: 2.2782 - root_mean_squared_error: 2302.3628 - val_loss: 4.0710 - val_gamma_log_likelihood: 2.4980 - val_root_mean_squared_error: 2492.9893
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2792 - gamma_log_likelihood: 2.2766 - root_mean_squared_error: 2292.4875 - val_loss: 4.0186 - val_gamma_log_likelihood: 2.4160 - val_root_mean_squared_error: 2387.9670
# Epoch 22/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2753 - gamma_log_likelihood: 2.2722 - root_mean_squared_error: 2281.3396 - val_loss: 4.0105 - val_gamma_log_likelihood: 2.3553 - val_root_mean_squared_error: 2342.3811
# Epoch 23/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2673 - gamma_log_likelihood: 2.2646 - root_mean_squared_error: 2263.9045 - val_loss: 4.2502 - val_gamma_log_likelihood: 2.4961 - val_root_mean_squared_error: 2531.9268
# Epoch 24/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2689 - gamma_log_likelihood: 2.2653 - root_mean_squared_error: 2238.7068 - val_loss: 4.1105 - val_gamma_log_likelihood: 2.3717 - val_root_mean_squared_error: 2356.4038
# Epoch 25/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2607 - gamma_log_likelihood: 2.2578 - root_mean_squared_error: 2200.2605 - val_loss: 4.3400 - val_gamma_log_likelihood: 2.4768 - val_root_mean_squared_error: 2570.5085
# Epoch 26/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2589 - gamma_log_likelihood: 2.2560 - root_mean_squared_error: 2183.2771 - val_loss: 4.3578 - val_gamma_log_likelihood: 2.4297 - val_root_mean_squared_error: 2452.8540
# Epoch 27/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2581 - gamma_log_likelihood: 2.2557 - root_mean_squared_error: 2160.4836 - val_loss: 4.7092 - val_gamma_log_likelihood: 2.5441 - val_root_mean_squared_error: 2655.8965
# Epoch 28/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2471 - gamma_log_likelihood: 2.2433 - root_mean_squared_error: 2140.2896 - val_loss: 5.0018 - val_gamma_log_likelihood: 2.6624 - val_root_mean_squared_error: 2893.4312
# Epoch 29/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2429 - gamma_log_likelihood: 2.2397 - root_mean_squared_error: 2124.1462 - val_loss: 5.0617 - val_gamma_log_likelihood: 2.6684 - val_root_mean_squared_error: 2917.0332
# Epoch 30/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2433 - gamma_log_likelihood: 2.2402 - root_mean_squared_error: 2112.1074 - val_loss: 5.3563 - val_gamma_log_likelihood: 2.8154 - val_root_mean_squared_error: 3586.5967
# Epoch 31/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2420 - gamma_log_likelihood: 2.2387 - root_mean_squared_error: 2100.5981 - val_loss: 5.0427 - val_gamma_log_likelihood: 2.6511 - val_root_mean_squared_error: 2966.2385
# Epoch 32/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2438 - gamma_log_likelihood: 2.2401 - root_mean_squared_error: 2097.6260 - val_loss: 4.9836 - val_gamma_log_likelihood: 2.6480 - val_root_mean_squared_error: 2936.9116
# 1/1 [==============================] - 0s 18ms/step - loss: 3.8405 - gamma_log_likelihood: 2.3552 - root_mean_squared_error: 2342.3811
# Epoch 1/5000
# 12/12 [==============================] - 1s 27ms/step - loss: 2.4443 - gamma_log_likelihood: 2.4381 - root_mean_squared_error: 2245.8169 - val_loss: 2.5328 - val_gamma_log_likelihood: 2.4030 - val_root_mean_squared_error: 2360.8127
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3217 - gamma_log_likelihood: 2.3180 - root_mean_squared_error: 2144.1553 - val_loss: 2.6307 - val_gamma_log_likelihood: 2.4733 - val_root_mean_squared_error: 2421.6284
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3118 - gamma_log_likelihood: 2.3091 - root_mean_squared_error: 2130.5913 - val_loss: 2.6996 - val_gamma_log_likelihood: 2.4946 - val_root_mean_squared_error: 2507.6182
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2994 - gamma_log_likelihood: 2.2964 - root_mean_squared_error: 2129.1492 - val_loss: 2.8265 - val_gamma_log_likelihood: 2.5331 - val_root_mean_squared_error: 2507.5144
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2886 - gamma_log_likelihood: 2.2860 - root_mean_squared_error: 2123.4895 - val_loss: 2.5792 - val_gamma_log_likelihood: 2.4913 - val_root_mean_squared_error: 2500.6194
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2814 - gamma_log_likelihood: 2.2779 - root_mean_squared_error: 2118.2024 - val_loss: 2.5396 - val_gamma_log_likelihood: 2.4492 - val_root_mean_squared_error: 2377.7439
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2786 - gamma_log_likelihood: 2.2759 - root_mean_squared_error: 2116.0251 - val_loss: 2.5471 - val_gamma_log_likelihood: 2.4605 - val_root_mean_squared_error: 2364.2876
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2795 - gamma_log_likelihood: 2.2761 - root_mean_squared_error: 2118.0601 - val_loss: 2.6227 - val_gamma_log_likelihood: 2.4383 - val_root_mean_squared_error: 2364.8416
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2704 - gamma_log_likelihood: 2.2671 - root_mean_squared_error: 2111.4768 - val_loss: 2.5602 - val_gamma_log_likelihood: 2.4155 - val_root_mean_squared_error: 2350.5725
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2707 - gamma_log_likelihood: 2.2678 - root_mean_squared_error: 2111.7483 - val_loss: 2.5060 - val_gamma_log_likelihood: 2.4399 - val_root_mean_squared_error: 2343.6143
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2716 - gamma_log_likelihood: 2.2687 - root_mean_squared_error: 2110.3279 - val_loss: 2.6608 - val_gamma_log_likelihood: 2.4490 - val_root_mean_squared_error: 2340.8730
# Epoch 12/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2705 - gamma_log_likelihood: 2.2677 - root_mean_squared_error: 2112.9980 - val_loss: 2.5748 - val_gamma_log_likelihood: 2.4896 - val_root_mean_squared_error: 2369.8447
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2656 - gamma_log_likelihood: 2.2620 - root_mean_squared_error: 2108.0371 - val_loss: 2.5472 - val_gamma_log_likelihood: 2.4321 - val_root_mean_squared_error: 2371.1082
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2659 - gamma_log_likelihood: 2.2630 - root_mean_squared_error: 2107.3357 - val_loss: 2.6671 - val_gamma_log_likelihood: 2.5197 - val_root_mean_squared_error: 2472.3904
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2621 - gamma_log_likelihood: 2.2596 - root_mean_squared_error: 2110.7974 - val_loss: 2.6368 - val_gamma_log_likelihood: 2.4839 - val_root_mean_squared_error: 2398.6414
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2586 - gamma_log_likelihood: 2.2558 - root_mean_squared_error: 2099.9304 - val_loss: 2.5504 - val_gamma_log_likelihood: 2.4114 - val_root_mean_squared_error: 2359.2673
# Epoch 17/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2582 - gamma_log_likelihood: 2.2553 - root_mean_squared_error: 2108.9785 - val_loss: 2.5811 - val_gamma_log_likelihood: 2.4791 - val_root_mean_squared_error: 2374.2754
# Epoch 18/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2620 - gamma_log_likelihood: 2.2581 - root_mean_squared_error: 2104.2634 - val_loss: 2.5660 - val_gamma_log_likelihood: 2.4252 - val_root_mean_squared_error: 2329.5933
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2610 - gamma_log_likelihood: 2.2581 - root_mean_squared_error: 2102.4111 - val_loss: 2.5295 - val_gamma_log_likelihood: 2.4285 - val_root_mean_squared_error: 2344.3958
# Epoch 20/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2579 - gamma_log_likelihood: 2.2546 - root_mean_squared_error: 2101.2534 - val_loss: 2.5780 - val_gamma_log_likelihood: 2.4420 - val_root_mean_squared_error: 2342.6213
# 1/1 [==============================] - 0s 18ms/step - loss: 2.4487 - gamma_log_likelihood: 2.4396 - root_mean_squared_error: 2343.6143
# Epoch 1/5000
# 12/12 [==============================] - 1s 27ms/step - loss: 2.3965 - gamma_log_likelihood: 2.3901 - root_mean_squared_error: 2172.7190 - val_loss: 2.4821 - val_gamma_log_likelihood: 2.3466 - val_root_mean_squared_error: 2370.4460
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2887 - gamma_log_likelihood: 2.2850 - root_mean_squared_error: 2130.8237 - val_loss: 2.4984 - val_gamma_log_likelihood: 2.3629 - val_root_mean_squared_error: 2395.2468
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2993 - gamma_log_likelihood: 2.2965 - root_mean_squared_error: 2138.2458 - val_loss: 2.4862 - val_gamma_log_likelihood: 2.3883 - val_root_mean_squared_error: 2466.4434
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2752 - gamma_log_likelihood: 2.2722 - root_mean_squared_error: 2121.5950 - val_loss: 2.5063 - val_gamma_log_likelihood: 2.3790 - val_root_mean_squared_error: 2453.2944
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2694 - gamma_log_likelihood: 2.2668 - root_mean_squared_error: 2122.8120 - val_loss: 2.5310 - val_gamma_log_likelihood: 2.4122 - val_root_mean_squared_error: 2581.3835
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2642 - gamma_log_likelihood: 2.2608 - root_mean_squared_error: 2112.8987 - val_loss: 2.6453 - val_gamma_log_likelihood: 2.5272 - val_root_mean_squared_error: 3257.7944
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2749 - gamma_log_likelihood: 2.2722 - root_mean_squared_error: 2116.3289 - val_loss: 2.6616 - val_gamma_log_likelihood: 2.4989 - val_root_mean_squared_error: 3160.7100
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2612 - gamma_log_likelihood: 2.2580 - root_mean_squared_error: 2116.8972 - val_loss: 2.6987 - val_gamma_log_likelihood: 2.5315 - val_root_mean_squared_error: 3452.8347
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2617 - gamma_log_likelihood: 2.2585 - root_mean_squared_error: 2115.8154 - val_loss: 2.6043 - val_gamma_log_likelihood: 2.5429 - val_root_mean_squared_error: 3652.2224
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2600 - gamma_log_likelihood: 2.2572 - root_mean_squared_error: 2111.2615 - val_loss: 2.6460 - val_gamma_log_likelihood: 2.5453 - val_root_mean_squared_error: 3630.0222
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2583 - gamma_log_likelihood: 2.2553 - root_mean_squared_error: 2108.3176 - val_loss: 2.6089 - val_gamma_log_likelihood: 2.4884 - val_root_mean_squared_error: 3331.2341
# 1/1 [==============================] - 0s 18ms/step - loss: 2.4695 - gamma_log_likelihood: 2.3465 - root_mean_squared_error: 2370.4463
# Epoch 1/5000
# 12/12 [==============================] - 1s 28ms/step - loss: 2.4097 - gamma_log_likelihood: 2.4031 - root_mean_squared_error: 2372.5581 - val_loss: 2.3897 - val_gamma_log_likelihood: 2.3335 - val_root_mean_squared_error: 2310.8613
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3054 - gamma_log_likelihood: 2.3012 - root_mean_squared_error: 2144.1848 - val_loss: 2.3548 - val_gamma_log_likelihood: 2.3247 - val_root_mean_squared_error: 2345.1768
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2901 - gamma_log_likelihood: 2.2874 - root_mean_squared_error: 2128.2651 - val_loss: 2.4338 - val_gamma_log_likelihood: 2.3449 - val_root_mean_squared_error: 2356.3896
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2866 - gamma_log_likelihood: 2.2835 - root_mean_squared_error: 2132.5898 - val_loss: 2.4902 - val_gamma_log_likelihood: 2.3952 - val_root_mean_squared_error: 2376.1663
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2769 - gamma_log_likelihood: 2.2744 - root_mean_squared_error: 2106.3782 - val_loss: 2.6271 - val_gamma_log_likelihood: 2.4920 - val_root_mean_squared_error: 2404.6729
# Epoch 6/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2603 - gamma_log_likelihood: 2.2575 - root_mean_squared_error: 2094.2168 - val_loss: 2.7660 - val_gamma_log_likelihood: 2.6565 - val_root_mean_squared_error: 2431.4382
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2701 - gamma_log_likelihood: 2.2679 - root_mean_squared_error: 2100.6055 - val_loss: 2.7370 - val_gamma_log_likelihood: 2.6094 - val_root_mean_squared_error: 2421.7759
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2644 - gamma_log_likelihood: 2.2613 - root_mean_squared_error: 2100.1592 - val_loss: 2.9701 - val_gamma_log_likelihood: 2.7721 - val_root_mean_squared_error: 2430.3145
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2618 - gamma_log_likelihood: 2.2586 - root_mean_squared_error: 2098.6121 - val_loss: 3.1208 - val_gamma_log_likelihood: 2.9052 - val_root_mean_squared_error: 2448.2454
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2532 - gamma_log_likelihood: 2.2504 - root_mean_squared_error: 2091.5283 - val_loss: 2.9672 - val_gamma_log_likelihood: 2.6920 - val_root_mean_squared_error: 2431.8396
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2638 - gamma_log_likelihood: 2.2612 - root_mean_squared_error: 2102.4707 - val_loss: 3.0098 - val_gamma_log_likelihood: 2.8635 - val_root_mean_squared_error: 2467.8850
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2559 - gamma_log_likelihood: 2.2526 - root_mean_squared_error: 2094.8479 - val_loss: 3.6067 - val_gamma_log_likelihood: 3.3942 - val_root_mean_squared_error: 2469.3196
# 1/1 [==============================] - 0s 18ms/step - loss: 2.3555 - gamma_log_likelihood: 2.3248 - root_mean_squared_error: 2345.1770
# Epoch 1/5000
# 12/12 [==============================] - 1s 29ms/step - loss: 2.5372 - gamma_log_likelihood: 2.5304 - root_mean_squared_error: 2818.4089 - val_loss: 5.9835 - val_gamma_log_likelihood: 2.8662 - val_root_mean_squared_error: 2954.8376
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3394 - gamma_log_likelihood: 2.3356 - root_mean_squared_error: 2227.4150 - val_loss: 5.6150 - val_gamma_log_likelihood: 2.7663 - val_root_mean_squared_error: 2736.8506
# Epoch 3/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3442 - gamma_log_likelihood: 2.3415 - root_mean_squared_error: 2238.9441 - val_loss: 5.2904 - val_gamma_log_likelihood: 2.6959 - val_root_mean_squared_error: 2637.1052
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3304 - gamma_log_likelihood: 2.3272 - root_mean_squared_error: 2252.2410 - val_loss: 5.3172 - val_gamma_log_likelihood: 2.8511 - val_root_mean_squared_error: 2987.9302
# Epoch 5/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3357 - gamma_log_likelihood: 2.3336 - root_mean_squared_error: 2257.0464 - val_loss: 5.0732 - val_gamma_log_likelihood: 2.8045 - val_root_mean_squared_error: 2900.1836
# Epoch 6/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3308 - gamma_log_likelihood: 2.3276 - root_mean_squared_error: 2275.2195 - val_loss: 4.7250 - val_gamma_log_likelihood: 2.6710 - val_root_mean_squared_error: 2629.6750
# Epoch 7/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3262 - gamma_log_likelihood: 2.3230 - root_mean_squared_error: 2296.9158 - val_loss: 4.4575 - val_gamma_log_likelihood: 2.5892 - val_root_mean_squared_error: 2511.0955
# Epoch 8/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3311 - gamma_log_likelihood: 2.3278 - root_mean_squared_error: 2319.6462 - val_loss: 4.2738 - val_gamma_log_likelihood: 2.5556 - val_root_mean_squared_error: 2479.6201
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3285 - gamma_log_likelihood: 2.3252 - root_mean_squared_error: 2307.9438 - val_loss: 4.1052 - val_gamma_log_likelihood: 2.5233 - val_root_mean_squared_error: 2450.9617
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3233 - gamma_log_likelihood: 2.3202 - root_mean_squared_error: 2323.9397 - val_loss: 3.9207 - val_gamma_log_likelihood: 2.4671 - val_root_mean_squared_error: 2406.5713
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3244 - gamma_log_likelihood: 2.3215 - root_mean_squared_error: 2332.0906 - val_loss: 3.7459 - val_gamma_log_likelihood: 2.4148 - val_root_mean_squared_error: 2361.4988
# Epoch 12/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3259 - gamma_log_likelihood: 2.3227 - root_mean_squared_error: 2326.0166 - val_loss: 3.7066 - val_gamma_log_likelihood: 2.4341 - val_root_mean_squared_error: 2392.7090
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3280 - gamma_log_likelihood: 2.3246 - root_mean_squared_error: 2334.1653 - val_loss: 3.5998 - val_gamma_log_likelihood: 2.4307 - val_root_mean_squared_error: 2394.9814
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3224 - gamma_log_likelihood: 2.3195 - root_mean_squared_error: 2334.9722 - val_loss: 3.5681 - val_gamma_log_likelihood: 2.4722 - val_root_mean_squared_error: 2461.9419
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3219 - gamma_log_likelihood: 2.3188 - root_mean_squared_error: 2337.7773 - val_loss: 3.5086 - val_gamma_log_likelihood: 2.4822 - val_root_mean_squared_error: 2501.1011
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3268 - gamma_log_likelihood: 2.3235 - root_mean_squared_error: 2347.1143 - val_loss: 3.3149 - val_gamma_log_likelihood: 2.3999 - val_root_mean_squared_error: 2399.2698
# Epoch 17/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3208 - gamma_log_likelihood: 2.3176 - root_mean_squared_error: 2327.9863 - val_loss: 3.2197 - val_gamma_log_likelihood: 2.3807 - val_root_mean_squared_error: 2393.4414
# Epoch 18/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3176 - gamma_log_likelihood: 2.3144 - root_mean_squared_error: 2348.4805 - val_loss: 3.1854 - val_gamma_log_likelihood: 2.3945 - val_root_mean_squared_error: 2458.8867
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3210 - gamma_log_likelihood: 2.3180 - root_mean_squared_error: 2328.9902 - val_loss: 3.0970 - val_gamma_log_likelihood: 2.3701 - val_root_mean_squared_error: 2406.8950
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3208 - gamma_log_likelihood: 2.3170 - root_mean_squared_error: 2330.0505 - val_loss: 3.0361 - val_gamma_log_likelihood: 2.3576 - val_root_mean_squared_error: 2404.3135
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3227 - gamma_log_likelihood: 2.3200 - root_mean_squared_error: 2345.2727 - val_loss: 3.0651 - val_gamma_log_likelihood: 2.4207 - val_root_mean_squared_error: 2524.2917
# Epoch 22/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3178 - gamma_log_likelihood: 2.3152 - root_mean_squared_error: 2360.1072 - val_loss: 2.9762 - val_gamma_log_likelihood: 2.3982 - val_root_mean_squared_error: 2510.7490
# Epoch 23/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3230 - gamma_log_likelihood: 2.3203 - root_mean_squared_error: 2342.0808 - val_loss: 3.0683 - val_gamma_log_likelihood: 2.5041 - val_root_mean_squared_error: 2790.5752
# Epoch 24/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3175 - gamma_log_likelihood: 2.3141 - root_mean_squared_error: 2347.7668 - val_loss: 2.8939 - val_gamma_log_likelihood: 2.3911 - val_root_mean_squared_error: 2542.8342
# Epoch 25/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3158 - gamma_log_likelihood: 2.3128 - root_mean_squared_error: 2328.1440 - val_loss: 2.9158 - val_gamma_log_likelihood: 2.4243 - val_root_mean_squared_error: 2679.9636
# Epoch 26/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3205 - gamma_log_likelihood: 2.3181 - root_mean_squared_error: 2341.5308 - val_loss: 2.9313 - val_gamma_log_likelihood: 2.4859 - val_root_mean_squared_error: 2880.5500
# Epoch 27/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3152 - gamma_log_likelihood: 2.3126 - root_mean_squared_error: 2339.2063 - val_loss: 2.7855 - val_gamma_log_likelihood: 2.3545 - val_root_mean_squared_error: 2492.0789
# Epoch 28/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3161 - gamma_log_likelihood: 2.3119 - root_mean_squared_error: 2336.8167 - val_loss: 2.7486 - val_gamma_log_likelihood: 2.3282 - val_root_mean_squared_error: 2444.4761
# Epoch 29/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3159 - gamma_log_likelihood: 2.3125 - root_mean_squared_error: 2342.7896 - val_loss: 2.8082 - val_gamma_log_likelihood: 2.3450 - val_root_mean_squared_error: 2489.5720
# Epoch 30/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3144 - gamma_log_likelihood: 2.3111 - root_mean_squared_error: 2326.3562 - val_loss: 2.7798 - val_gamma_log_likelihood: 2.3173 - val_root_mean_squared_error: 2416.6021
# Epoch 31/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3082 - gamma_log_likelihood: 2.3051 - root_mean_squared_error: 2302.5198 - val_loss: 2.8513 - val_gamma_log_likelihood: 2.3214 - val_root_mean_squared_error: 2433.9575
# Epoch 32/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3097 - gamma_log_likelihood: 2.3067 - root_mean_squared_error: 2316.0938 - val_loss: 2.8979 - val_gamma_log_likelihood: 2.3076 - val_root_mean_squared_error: 2388.4128
# Epoch 33/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3137 - gamma_log_likelihood: 2.3108 - root_mean_squared_error: 2304.3384 - val_loss: 2.9198 - val_gamma_log_likelihood: 2.3140 - val_root_mean_squared_error: 2383.5745
# Epoch 34/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3065 - gamma_log_likelihood: 2.3042 - root_mean_squared_error: 2313.9377 - val_loss: 2.9260 - val_gamma_log_likelihood: 2.3284 - val_root_mean_squared_error: 2356.3027
# Epoch 35/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3060 - gamma_log_likelihood: 2.3034 - root_mean_squared_error: 2300.5222 - val_loss: 3.0098 - val_gamma_log_likelihood: 2.3075 - val_root_mean_squared_error: 2396.1558
# Epoch 36/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3056 - gamma_log_likelihood: 2.3029 - root_mean_squared_error: 2304.9641 - val_loss: 3.0904 - val_gamma_log_likelihood: 2.3477 - val_root_mean_squared_error: 2497.8721
# Epoch 37/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2999 - gamma_log_likelihood: 2.2970 - root_mean_squared_error: 2271.4473 - val_loss: 3.1427 - val_gamma_log_likelihood: 2.3498 - val_root_mean_squared_error: 2540.8203
# Epoch 38/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3023 - gamma_log_likelihood: 2.2997 - root_mean_squared_error: 2266.3271 - val_loss: 3.2370 - val_gamma_log_likelihood: 2.3630 - val_root_mean_squared_error: 2558.2039
# 1/1 [==============================] - 0s 19ms/step - loss: 2.7146 - gamma_log_likelihood: 2.3282 - root_mean_squared_error: 2444.4761
# Epoch 1/5000
# 12/12 [==============================] - 1s 28ms/step - loss: 2.5898 - gamma_log_likelihood: 2.5824 - root_mean_squared_error: 2230.9277 - val_loss: 2.4557 - val_gamma_log_likelihood: 2.3126 - val_root_mean_squared_error: 2324.1821
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3275 - gamma_log_likelihood: 2.3236 - root_mean_squared_error: 2146.8013 - val_loss: 2.4462 - val_gamma_log_likelihood: 2.3411 - val_root_mean_squared_error: 2351.0935
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3182 - gamma_log_likelihood: 2.3150 - root_mean_squared_error: 2146.1458 - val_loss: 2.4531 - val_gamma_log_likelihood: 2.3953 - val_root_mean_squared_error: 2471.1619
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2942 - gamma_log_likelihood: 2.2912 - root_mean_squared_error: 2134.6819 - val_loss: 2.3952 - val_gamma_log_likelihood: 2.3742 - val_root_mean_squared_error: 2462.0469
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2900 - gamma_log_likelihood: 2.2874 - root_mean_squared_error: 2123.8979 - val_loss: 2.5130 - val_gamma_log_likelihood: 2.4912 - val_root_mean_squared_error: 2570.0625
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2856 - gamma_log_likelihood: 2.2826 - root_mean_squared_error: 2123.6182 - val_loss: 2.6339 - val_gamma_log_likelihood: 2.6198 - val_root_mean_squared_error: 2621.2673
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2902 - gamma_log_likelihood: 2.2873 - root_mean_squared_error: 2133.1880 - val_loss: 2.5955 - val_gamma_log_likelihood: 2.5707 - val_root_mean_squared_error: 2660.3464
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2871 - gamma_log_likelihood: 2.2836 - root_mean_squared_error: 2124.4495 - val_loss: 2.6993 - val_gamma_log_likelihood: 2.6701 - val_root_mean_squared_error: 2741.2000
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2785 - gamma_log_likelihood: 2.2753 - root_mean_squared_error: 2117.7500 - val_loss: 2.7244 - val_gamma_log_likelihood: 2.6787 - val_root_mean_squared_error: 2786.2175
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2755 - gamma_log_likelihood: 2.2728 - root_mean_squared_error: 2115.2856 - val_loss: 2.7598 - val_gamma_log_likelihood: 2.7316 - val_root_mean_squared_error: 2762.1414
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2791 - gamma_log_likelihood: 2.2762 - root_mean_squared_error: 2114.1309 - val_loss: 2.7860 - val_gamma_log_likelihood: 2.7540 - val_root_mean_squared_error: 2823.6267
# Epoch 12/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2818 - gamma_log_likelihood: 2.2786 - root_mean_squared_error: 2119.9993 - val_loss: 2.9404 - val_gamma_log_likelihood: 2.8922 - val_root_mean_squared_error: 2805.7249
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2833 - gamma_log_likelihood: 2.2802 - root_mean_squared_error: 2122.6501 - val_loss: 2.9554 - val_gamma_log_likelihood: 2.9006 - val_root_mean_squared_error: 3068.3188
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2754 - gamma_log_likelihood: 2.2727 - root_mean_squared_error: 2116.2461 - val_loss: 2.9713 - val_gamma_log_likelihood: 2.9261 - val_root_mean_squared_error: 3002.8096
# 1/1 [==============================] - 0s 19ms/step - loss: 2.3944 - gamma_log_likelihood: 2.3745 - root_mean_squared_error: 2462.0471
# Epoch 1/5000
# 12/12 [==============================] - 1s 28ms/step - loss: 2.5571 - gamma_log_likelihood: 2.5504 - root_mean_squared_error: 3314.7466 - val_loss: 2.5208 - val_gamma_log_likelihood: 2.3751 - val_root_mean_squared_error: 2364.1038
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3000 - gamma_log_likelihood: 2.2964 - root_mean_squared_error: 2205.4792 - val_loss: 2.4813 - val_gamma_log_likelihood: 2.4465 - val_root_mean_squared_error: 2473.2004
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2744 - gamma_log_likelihood: 2.2717 - root_mean_squared_error: 2135.9954 - val_loss: 2.5332 - val_gamma_log_likelihood: 2.4919 - val_root_mean_squared_error: 2498.1580
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2677 - gamma_log_likelihood: 2.2645 - root_mean_squared_error: 2124.3909 - val_loss: 2.6173 - val_gamma_log_likelihood: 2.5598 - val_root_mean_squared_error: 2762.4568
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2708 - gamma_log_likelihood: 2.2682 - root_mean_squared_error: 2124.2859 - val_loss: 2.6740 - val_gamma_log_likelihood: 2.5642 - val_root_mean_squared_error: 2750.2996
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2659 - gamma_log_likelihood: 2.2624 - root_mean_squared_error: 2126.9912 - val_loss: 2.6654 - val_gamma_log_likelihood: 2.5063 - val_root_mean_squared_error: 2516.4233
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2637 - gamma_log_likelihood: 2.2608 - root_mean_squared_error: 2131.3313 - val_loss: 2.7110 - val_gamma_log_likelihood: 2.5518 - val_root_mean_squared_error: 2706.4763
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2693 - gamma_log_likelihood: 2.2664 - root_mean_squared_error: 2125.6997 - val_loss: 2.8062 - val_gamma_log_likelihood: 2.5054 - val_root_mean_squared_error: 2650.8494
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2649 - gamma_log_likelihood: 2.2610 - root_mean_squared_error: 2123.8813 - val_loss: 2.7992 - val_gamma_log_likelihood: 2.5069 - val_root_mean_squared_error: 2561.1729
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2620 - gamma_log_likelihood: 2.2596 - root_mean_squared_error: 2125.2622 - val_loss: 2.9258 - val_gamma_log_likelihood: 2.6209 - val_root_mean_squared_error: 2517.9810
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2595 - gamma_log_likelihood: 2.2567 - root_mean_squared_error: 2124.3611 - val_loss: 2.7342 - val_gamma_log_likelihood: 2.5129 - val_root_mean_squared_error: 2393.0300
# Epoch 12/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2600 - gamma_log_likelihood: 2.2568 - root_mean_squared_error: 2125.7974 - val_loss: 2.8075 - val_gamma_log_likelihood: 2.5438 - val_root_mean_squared_error: 2374.8091
# 1/1 [==============================] - 0s 18ms/step - loss: 2.4540 - gamma_log_likelihood: 2.4466 - root_mean_squared_error: 2473.2002
# Epoch 1/5000
# 12/12 [==============================] - 2s 27ms/step - loss: 2.3150 - gamma_log_likelihood: 2.3093 - root_mean_squared_error: 2234.8674 - val_loss: 3.2935 - val_gamma_log_likelihood: 2.9161 - val_root_mean_squared_error: 2434.7537
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2736 - gamma_log_likelihood: 2.2699 - root_mean_squared_error: 2111.1516 - val_loss: 3.2913 - val_gamma_log_likelihood: 2.9149 - val_root_mean_squared_error: 2428.2612
# Epoch 3/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2726 - gamma_log_likelihood: 2.2703 - root_mean_squared_error: 2110.5959 - val_loss: 3.2655 - val_gamma_log_likelihood: 2.9302 - val_root_mean_squared_error: 2459.9316
# Epoch 4/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2675 - gamma_log_likelihood: 2.2644 - root_mean_squared_error: 2109.2654 - val_loss: 2.8886 - val_gamma_log_likelihood: 2.5501 - val_root_mean_squared_error: 2403.4673
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2706 - gamma_log_likelihood: 2.2682 - root_mean_squared_error: 2104.4307 - val_loss: 3.1157 - val_gamma_log_likelihood: 2.7978 - val_root_mean_squared_error: 2448.5310
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2671 - gamma_log_likelihood: 2.2640 - root_mean_squared_error: 2108.0833 - val_loss: 3.3039 - val_gamma_log_likelihood: 3.0463 - val_root_mean_squared_error: 2440.8042
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2648 - gamma_log_likelihood: 2.2621 - root_mean_squared_error: 2109.4373 - val_loss: 2.9898 - val_gamma_log_likelihood: 2.6954 - val_root_mean_squared_error: 2423.9502
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2672 - gamma_log_likelihood: 2.2640 - root_mean_squared_error: 2105.3684 - val_loss: 2.9284 - val_gamma_log_likelihood: 2.6927 - val_root_mean_squared_error: 2432.2349
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2653 - gamma_log_likelihood: 2.2618 - root_mean_squared_error: 2104.0928 - val_loss: 2.8959 - val_gamma_log_likelihood: 2.6160 - val_root_mean_squared_error: 2425.0627
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2594 - gamma_log_likelihood: 2.2569 - root_mean_squared_error: 2103.0715 - val_loss: 2.8401 - val_gamma_log_likelihood: 2.4662 - val_root_mean_squared_error: 2411.0911
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2615 - gamma_log_likelihood: 2.2588 - root_mean_squared_error: 2105.2290 - val_loss: 2.8942 - val_gamma_log_likelihood: 2.5637 - val_root_mean_squared_error: 2461.5737
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2633 - gamma_log_likelihood: 2.2602 - root_mean_squared_error: 2106.4514 - val_loss: 3.1523 - val_gamma_log_likelihood: 2.8891 - val_root_mean_squared_error: 2461.0208
# Epoch 13/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2634 - gamma_log_likelihood: 2.2600 - root_mean_squared_error: 2106.7729 - val_loss: 3.1205 - val_gamma_log_likelihood: 2.8496 - val_root_mean_squared_error: 2430.2561
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2596 - gamma_log_likelihood: 2.2567 - root_mean_squared_error: 2103.2563 - val_loss: 3.2636 - val_gamma_log_likelihood: 2.9861 - val_root_mean_squared_error: 2444.3645
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2570 - gamma_log_likelihood: 2.2542 - root_mean_squared_error: 2101.0012 - val_loss: 2.6650 - val_gamma_log_likelihood: 2.5087 - val_root_mean_squared_error: 2397.1016
# Epoch 16/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2623 - gamma_log_likelihood: 2.2593 - root_mean_squared_error: 2100.4431 - val_loss: 2.8080 - val_gamma_log_likelihood: 2.7351 - val_root_mean_squared_error: 2440.1682
# Epoch 17/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2589 - gamma_log_likelihood: 2.2560 - root_mean_squared_error: 2102.8125 - val_loss: 2.5838 - val_gamma_log_likelihood: 2.5089 - val_root_mean_squared_error: 2489.0574
# Epoch 18/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2597 - gamma_log_likelihood: 2.2565 - root_mean_squared_error: 2104.1221 - val_loss: 2.6627 - val_gamma_log_likelihood: 2.5677 - val_root_mean_squared_error: 2571.0488
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2605 - gamma_log_likelihood: 2.2577 - root_mean_squared_error: 2101.9712 - val_loss: 2.6558 - val_gamma_log_likelihood: 2.4878 - val_root_mean_squared_error: 2439.8118
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2548 - gamma_log_likelihood: 2.2513 - root_mean_squared_error: 2099.0195 - val_loss: 2.6352 - val_gamma_log_likelihood: 2.5272 - val_root_mean_squared_error: 2446.7705
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2567 - gamma_log_likelihood: 2.2539 - root_mean_squared_error: 2101.2034 - val_loss: 2.5640 - val_gamma_log_likelihood: 2.4950 - val_root_mean_squared_error: 2438.1636
# Epoch 22/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2562 - gamma_log_likelihood: 2.2529 - root_mean_squared_error: 2102.6699 - val_loss: 2.6711 - val_gamma_log_likelihood: 2.3918 - val_root_mean_squared_error: 2414.3892
# Epoch 23/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2584 - gamma_log_likelihood: 2.2561 - root_mean_squared_error: 2101.5625 - val_loss: 2.5468 - val_gamma_log_likelihood: 2.4563 - val_root_mean_squared_error: 2458.2727
# Epoch 24/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2553 - gamma_log_likelihood: 2.2523 - root_mean_squared_error: 2100.9617 - val_loss: 2.5730 - val_gamma_log_likelihood: 2.4841 - val_root_mean_squared_error: 2556.6389
# Epoch 25/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2565 - gamma_log_likelihood: 2.2535 - root_mean_squared_error: 2098.2131 - val_loss: 2.5741 - val_gamma_log_likelihood: 2.4592 - val_root_mean_squared_error: 2541.5139
# Epoch 26/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2571 - gamma_log_likelihood: 2.2544 - root_mean_squared_error: 2098.8271 - val_loss: 2.5784 - val_gamma_log_likelihood: 2.3945 - val_root_mean_squared_error: 2420.9116
# Epoch 27/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2553 - gamma_log_likelihood: 2.2524 - root_mean_squared_error: 2101.3450 - val_loss: 2.5485 - val_gamma_log_likelihood: 2.4124 - val_root_mean_squared_error: 2436.0781
# Epoch 28/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2531 - gamma_log_likelihood: 2.2488 - root_mean_squared_error: 2098.5645 - val_loss: 2.6119 - val_gamma_log_likelihood: 2.3886 - val_root_mean_squared_error: 2399.0605
# Epoch 29/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2563 - gamma_log_likelihood: 2.2528 - root_mean_squared_error: 2101.4954 - val_loss: 2.6499 - val_gamma_log_likelihood: 2.4452 - val_root_mean_squared_error: 2377.5627
# Epoch 30/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2567 - gamma_log_likelihood: 2.2534 - root_mean_squared_error: 2100.7847 - val_loss: 2.6517 - val_gamma_log_likelihood: 2.3513 - val_root_mean_squared_error: 2365.6819
# Epoch 31/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2536 - gamma_log_likelihood: 2.2507 - root_mean_squared_error: 2094.4934 - val_loss: 2.5162 - val_gamma_log_likelihood: 2.4168 - val_root_mean_squared_error: 2377.5408
# Epoch 32/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2532 - gamma_log_likelihood: 2.2495 - root_mean_squared_error: 2098.6770 - val_loss: 2.5932 - val_gamma_log_likelihood: 2.4915 - val_root_mean_squared_error: 2386.4592
# Epoch 33/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2511 - gamma_log_likelihood: 2.2480 - root_mean_squared_error: 2095.4890 - val_loss: 2.8590 - val_gamma_log_likelihood: 2.7620 - val_root_mean_squared_error: 2412.2603
# Epoch 34/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2497 - gamma_log_likelihood: 2.2478 - root_mean_squared_error: 2094.4451 - val_loss: 2.7507 - val_gamma_log_likelihood: 2.6593 - val_root_mean_squared_error: 2404.4307
# Epoch 35/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2538 - gamma_log_likelihood: 2.2509 - root_mean_squared_error: 2095.2134 - val_loss: 2.6057 - val_gamma_log_likelihood: 2.4404 - val_root_mean_squared_error: 2388.0000
# Epoch 36/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2520 - gamma_log_likelihood: 2.2496 - root_mean_squared_error: 2095.8638 - val_loss: 2.5409 - val_gamma_log_likelihood: 2.4230 - val_root_mean_squared_error: 2383.1995
# Epoch 37/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2516 - gamma_log_likelihood: 2.2485 - root_mean_squared_error: 2096.3384 - val_loss: 2.6292 - val_gamma_log_likelihood: 2.5065 - val_root_mean_squared_error: 2389.7761
# Epoch 38/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2544 - gamma_log_likelihood: 2.2516 - root_mean_squared_error: 2096.4387 - val_loss: 2.7777 - val_gamma_log_likelihood: 2.3547 - val_root_mean_squared_error: 2357.4316
# Epoch 39/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2572 - gamma_log_likelihood: 2.2541 - root_mean_squared_error: 2099.8145 - val_loss: 2.7348 - val_gamma_log_likelihood: 2.3447 - val_root_mean_squared_error: 2360.9402
# Epoch 40/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2535 - gamma_log_likelihood: 2.2507 - root_mean_squared_error: 2100.5171 - val_loss: 2.7473 - val_gamma_log_likelihood: 2.2954 - val_root_mean_squared_error: 2338.0020
# Epoch 41/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2513 - gamma_log_likelihood: 2.2477 - root_mean_squared_error: 2097.9795 - val_loss: 2.8333 - val_gamma_log_likelihood: 2.2715 - val_root_mean_squared_error: 2320.8110
# 1/1 [==============================] - 0s 19ms/step - loss: 2.5084 - gamma_log_likelihood: 2.4170 - root_mean_squared_error: 2377.5405
# Epoch 1/5000
# ...
# Epoch 13/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3238 - gamma_log_likelihood: 2.3205 - root_mean_squared_error: 2388.1934 - val_loss: 3.4633 - val_gamma_log_likelihood: 2.3873 - val_root_mean_squared_error: 2372.7825
# Epoch 14/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3266 - gamma_log_likelihood: 2.3237 - root_mean_squared_error: 2373.9011 - val_loss: 3.3553 - val_gamma_log_likelihood: 2.3530 - val_root_mean_squared_error: 2345.7188
# Epoch 15/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3217 - gamma_log_likelihood: 2.3187 - root_mean_squared_error: 2379.2754 - val_loss: 3.2966 - val_gamma_log_likelihood: 2.3575 - val_root_mean_squared_error: 2357.9224
# Epoch 16/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3281 - gamma_log_likelihood: 2.3250 - root_mean_squared_error: 2393.2981 - val_loss: 3.1698 - val_gamma_log_likelihood: 2.3270 - val_root_mean_squared_error: 2350.2458
# Epoch 17/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3226 - gamma_log_likelihood: 2.3194 - root_mean_squared_error: 2384.7307 - val_loss: 3.0840 - val_gamma_log_likelihood: 2.3010 - val_root_mean_squared_error: 2330.6023
# Epoch 18/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3208 - gamma_log_likelihood: 2.3176 - root_mean_squared_error: 2390.3403 - val_loss: 3.0608 - val_gamma_log_likelihood: 2.3179 - val_root_mean_squared_error: 2348.5425
# Epoch 19/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3285 - gamma_log_likelihood: 2.3259 - root_mean_squared_error: 2393.5981 - val_loss: 3.0385 - val_gamma_log_likelihood: 2.3386 - val_root_mean_squared_error: 2389.7236
# Epoch 20/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3205 - gamma_log_likelihood: 2.3167 - root_mean_squared_error: 2387.8374 - val_loss: 3.0141 - val_gamma_log_likelihood: 2.3410 - val_root_mean_squared_error: 2409.6709
# Epoch 21/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3232 - gamma_log_likelihood: 2.3207 - root_mean_squared_error: 2391.4490 - val_loss: 3.0059 - val_gamma_log_likelihood: 2.3562 - val_root_mean_squared_error: 2449.4707
# Epoch 22/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3195 - gamma_log_likelihood: 2.3166 - root_mean_squared_error: 2403.9658 - val_loss: 3.1609 - val_gamma_log_likelihood: 2.4776 - val_root_mean_squared_error: 2748.6814
# Epoch 23/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3228 - gamma_log_likelihood: 2.3203 - root_mean_squared_error: 2413.7644 - val_loss: 3.0495 - val_gamma_log_likelihood: 2.3845 - val_root_mean_squared_error: 2524.2234
# Epoch 24/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3183 - gamma_log_likelihood: 2.3148 - root_mean_squared_error: 2398.7756 - val_loss: 3.0183 - val_gamma_log_likelihood: 2.3748 - val_root_mean_squared_error: 2527.8911
# Epoch 25/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3240 - gamma_log_likelihood: 2.3208 - root_mean_squared_error: 2415.3777 - val_loss: 2.9580 - val_gamma_log_likelihood: 2.3600 - val_root_mean_squared_error: 2523.3445
# Epoch 26/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3190 - gamma_log_likelihood: 2.3163 - root_mean_squared_error: 2396.3281 - val_loss: 3.0647 - val_gamma_log_likelihood: 2.4795 - val_root_mean_squared_error: 2873.1719
# Epoch 27/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3181 - gamma_log_likelihood: 2.3153 - root_mean_squared_error: 2376.0181 - val_loss: 3.3194 - val_gamma_log_likelihood: 2.6923 - val_root_mean_squared_error: 3842.4841
# Epoch 28/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3216 - gamma_log_likelihood: 2.3175 - root_mean_squared_error: 2394.2507 - val_loss: 3.1951 - val_gamma_log_likelihood: 2.6008 - val_root_mean_squared_error: 3467.5898
# Epoch 29/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3180 - gamma_log_likelihood: 2.3150 - root_mean_squared_error: 2379.3022 - val_loss: 2.9439 - val_gamma_log_likelihood: 2.4290 - val_root_mean_squared_error: 2803.7090
# Epoch 30/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3205 - gamma_log_likelihood: 2.3176 - root_mean_squared_error: 2388.5969 - val_loss: 2.7948 - val_gamma_log_likelihood: 2.3334 - val_root_mean_squared_error: 2524.6306
# Epoch 31/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.3195 - gamma_log_likelihood: 2.3168 - root_mean_squared_error: 2396.5505 - val_loss: 2.7646 - val_gamma_log_likelihood: 2.3115 - val_root_mean_squared_error: 2428.3853
# Epoch 32/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3199 - gamma_log_likelihood: 2.3165 - root_mean_squared_error: 2408.1138 - val_loss: 2.8156 - val_gamma_log_likelihood: 2.3136 - val_root_mean_squared_error: 2473.7412
# Epoch 33/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3190 - gamma_log_likelihood: 2.3159 - root_mean_squared_error: 2382.3298 - val_loss: 2.7871 - val_gamma_log_likelihood: 2.3128 - val_root_mean_squared_error: 2435.9705
# Epoch 34/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3154 - gamma_log_likelihood: 2.3132 - root_mean_squared_error: 2379.9353 - val_loss: 2.9021 - val_gamma_log_likelihood: 2.3647 - val_root_mean_squared_error: 2670.2834
# Epoch 35/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3167 - gamma_log_likelihood: 2.3141 - root_mean_squared_error: 2381.1367 - val_loss: 2.8391 - val_gamma_log_likelihood: 2.3448 - val_root_mean_squared_error: 2626.4709
# Epoch 36/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3143 - gamma_log_likelihood: 2.3115 - root_mean_squared_error: 2377.7124 - val_loss: 2.7931 - val_gamma_log_likelihood: 2.3169 - val_root_mean_squared_error: 2405.1628
# Epoch 37/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3136 - gamma_log_likelihood: 2.3105 - root_mean_squared_error: 2390.0498 - val_loss: 2.7883 - val_gamma_log_likelihood: 2.3294 - val_root_mean_squared_error: 2389.2456
# Epoch 38/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3172 - gamma_log_likelihood: 2.3141 - root_mean_squared_error: 2378.2532 - val_loss: 2.8018 - val_gamma_log_likelihood: 2.3075 - val_root_mean_squared_error: 2501.6030
# Epoch 39/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3093 - gamma_log_likelihood: 2.3068 - root_mean_squared_error: 2367.8284 - val_loss: 2.7831 - val_gamma_log_likelihood: 2.3043 - val_root_mean_squared_error: 2417.1243
# Epoch 40/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3141 - gamma_log_likelihood: 2.3117 - root_mean_squared_error: 2376.6028 - val_loss: 2.8100 - val_gamma_log_likelihood: 2.3103 - val_root_mean_squared_error: 2450.3108
# Epoch 41/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3075 - gamma_log_likelihood: 2.3043 - root_mean_squared_error: 2361.5403 - val_loss: 2.9177 - val_gamma_log_likelihood: 2.3571 - val_root_mean_squared_error: 2695.9148
# 1/1 [==============================] - 0s 18ms/step - loss: 2.7307 - gamma_log_likelihood: 2.3114 - root_mean_squared_error: 2428.3853
# Epoch 1/5000
# 12/12 [==============================] - 1s 27ms/step - loss: 2.5049 - gamma_log_likelihood: 2.4985 - root_mean_squared_error: 2143.6831 - val_loss: 2.9099 - val_gamma_log_likelihood: 2.4287 - val_root_mean_squared_error: 2545.1875
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3319 - gamma_log_likelihood: 2.3284 - root_mean_squared_error: 2115.7285 - val_loss: 3.0246 - val_gamma_log_likelihood: 2.5966 - val_root_mean_squared_error: 3265.3101
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3048 - gamma_log_likelihood: 2.3020 - root_mean_squared_error: 2119.9150 - val_loss: 3.1391 - val_gamma_log_likelihood: 2.7415 - val_root_mean_squared_error: 4375.2578
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2870 - gamma_log_likelihood: 2.2842 - root_mean_squared_error: 2124.6230 - val_loss: 3.1018 - val_gamma_log_likelihood: 2.8160 - val_root_mean_squared_error: 4878.2827
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2790 - gamma_log_likelihood: 2.2762 - root_mean_squared_error: 2130.3215 - val_loss: 3.0959 - val_gamma_log_likelihood: 2.8391 - val_root_mean_squared_error: 5331.4375
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2811 - gamma_log_likelihood: 2.2775 - root_mean_squared_error: 2132.4343 - val_loss: 3.0363 - val_gamma_log_likelihood: 2.8173 - val_root_mean_squared_error: 4374.7891
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2754 - gamma_log_likelihood: 2.2723 - root_mean_squared_error: 2132.7031 - val_loss: 2.9697 - val_gamma_log_likelihood: 2.8049 - val_root_mean_squared_error: 4176.2871
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2744 - gamma_log_likelihood: 2.2716 - root_mean_squared_error: 2133.0601 - val_loss: 2.9467 - val_gamma_log_likelihood: 2.7790 - val_root_mean_squared_error: 3570.0215
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2742 - gamma_log_likelihood: 2.2706 - root_mean_squared_error: 2135.2168 - val_loss: 3.0099 - val_gamma_log_likelihood: 2.7980 - val_root_mean_squared_error: 3243.5330
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2747 - gamma_log_likelihood: 2.2722 - root_mean_squared_error: 2133.5164 - val_loss: 2.9900 - val_gamma_log_likelihood: 2.8018 - val_root_mean_squared_error: 3080.2017
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2703 - gamma_log_likelihood: 2.2672 - root_mean_squared_error: 2130.6582 - val_loss: 3.0087 - val_gamma_log_likelihood: 2.6975 - val_root_mean_squared_error: 2834.4583
# 1/1 [==============================] - 0s 17ms/step - loss: 2.8848 - gamma_log_likelihood: 2.4292 - root_mean_squared_error: 2545.1877
# Epoch 1/5000
# 12/12 [==============================] - 1s 28ms/step - loss: 2.4535 - gamma_log_likelihood: 2.4466 - root_mean_squared_error: 2186.5549 - val_loss: 2.3751 - val_gamma_log_likelihood: 2.3390 - val_root_mean_squared_error: 2328.7363
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2873 - gamma_log_likelihood: 2.2836 - root_mean_squared_error: 2122.5115 - val_loss: 2.3964 - val_gamma_log_likelihood: 2.3503 - val_root_mean_squared_error: 2368.7830
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2961 - gamma_log_likelihood: 2.2941 - root_mean_squared_error: 2133.7588 - val_loss: 2.4257 - val_gamma_log_likelihood: 2.3661 - val_root_mean_squared_error: 2430.2852
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2831 - gamma_log_likelihood: 2.2800 - root_mean_squared_error: 2124.7610 - val_loss: 2.5135 - val_gamma_log_likelihood: 2.4152 - val_root_mean_squared_error: 2551.6968
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2821 - gamma_log_likelihood: 2.2790 - root_mean_squared_error: 2121.4675 - val_loss: 2.4440 - val_gamma_log_likelihood: 2.4247 - val_root_mean_squared_error: 2653.7788
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2833 - gamma_log_likelihood: 2.2800 - root_mean_squared_error: 2118.5637 - val_loss: 2.5400 - val_gamma_log_likelihood: 2.4519 - val_root_mean_squared_error: 2635.5522
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2802 - gamma_log_likelihood: 2.2778 - root_mean_squared_error: 2119.4321 - val_loss: 2.5586 - val_gamma_log_likelihood: 2.4431 - val_root_mean_squared_error: 2584.7593
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2815 - gamma_log_likelihood: 2.2782 - root_mean_squared_error: 2116.8445 - val_loss: 2.7073 - val_gamma_log_likelihood: 2.5562 - val_root_mean_squared_error: 2571.2734
# Epoch 9/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2750 - gamma_log_likelihood: 2.2719 - root_mean_squared_error: 2114.6575 - val_loss: 2.7102 - val_gamma_log_likelihood: 2.5936 - val_root_mean_squared_error: 2807.5889
# Epoch 10/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.2761 - gamma_log_likelihood: 2.2738 - root_mean_squared_error: 2115.1970 - val_loss: 2.7702 - val_gamma_log_likelihood: 2.6656 - val_root_mean_squared_error: 2933.2910
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2730 - gamma_log_likelihood: 2.2704 - root_mean_squared_error: 2111.1047 - val_loss: 2.8091 - val_gamma_log_likelihood: 2.6705 - val_root_mean_squared_error: 2775.5408
# 1/1 [==============================] - 0s 18ms/step - loss: 2.3782 - gamma_log_likelihood: 2.3390 - root_mean_squared_error: 2328.7363
# Epoch 1/5000
# 12/12 [==============================] - 1s 28ms/step - loss: 2.4080 - gamma_log_likelihood: 2.4012 - root_mean_squared_error: 2139.5459 - val_loss: 2.4441 - val_gamma_log_likelihood: 2.3395 - val_root_mean_squared_error: 2398.3943
# Epoch 2/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.1755 - gamma_log_likelihood: 2.1718 - root_mean_squared_error: 2077.7307 - val_loss: 2.4226 - val_gamma_log_likelihood: 2.3231 - val_root_mean_squared_error: 2384.9768
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1479 - gamma_log_likelihood: 2.1452 - root_mean_squared_error: 2121.7832 - val_loss: 2.5100 - val_gamma_log_likelihood: 2.3334 - val_root_mean_squared_error: 2419.4109
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1205 - gamma_log_likelihood: 2.1176 - root_mean_squared_error: 2153.1736 - val_loss: 2.5155 - val_gamma_log_likelihood: 2.2949 - val_root_mean_squared_error: 2361.4878
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0896 - gamma_log_likelihood: 2.0868 - root_mean_squared_error: 2104.7227 - val_loss: 2.5387 - val_gamma_log_likelihood: 2.3101 - val_root_mean_squared_error: 2364.4153
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0878 - gamma_log_likelihood: 2.0844 - root_mean_squared_error: 2133.0234 - val_loss: 2.5016 - val_gamma_log_likelihood: 2.2956 - val_root_mean_squared_error: 2367.3835
# Epoch 7/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0789 - gamma_log_likelihood: 2.0765 - root_mean_squared_error: 2120.1626 - val_loss: 2.4997 - val_gamma_log_likelihood: 2.2970 - val_root_mean_squared_error: 2359.6167
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0712 - gamma_log_likelihood: 2.0682 - root_mean_squared_error: 2091.6931 - val_loss: 2.4997 - val_gamma_log_likelihood: 2.2840 - val_root_mean_squared_error: 2356.9880
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0678 - gamma_log_likelihood: 2.0640 - root_mean_squared_error: 2103.9814 - val_loss: 2.4585 - val_gamma_log_likelihood: 2.2804 - val_root_mean_squared_error: 2350.8333
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0500 - gamma_log_likelihood: 2.0482 - root_mean_squared_error: 2105.8447 - val_loss: 2.4661 - val_gamma_log_likelihood: 2.2563 - val_root_mean_squared_error: 2336.4875
# Epoch 11/5000
# 12/12 [==============================] - 0s 5ms/step - loss: 2.0346 - gamma_log_likelihood: 2.0320 - root_mean_squared_error: 2091.1152 - val_loss: 2.4876 - val_gamma_log_likelihood: 2.2899 - val_root_mean_squared_error: 2344.3875
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0463 - gamma_log_likelihood: 2.0428 - root_mean_squared_error: 2076.8066 - val_loss: 2.5713 - val_gamma_log_likelihood: 2.4200 - val_root_mean_squared_error: 2395.0415
# 1/1 [==============================] - 0s 19ms/step - loss: 2.4270 - gamma_log_likelihood: 2.3231 - root_mean_squared_error: 2384.9768

# %%
# -------------------------- plot the validation loss --------------------------
# Convert interaction loss dictionary to a pandas DataFrame
interaction_df = pd.DataFrame(list(interaction_loss.items()), columns = ['Interaction_Pair', 'Validation_Loss'])

# Sort the DataFrame by Validation_Loss in increasing order
interaction_df = interaction_df.sort_values(by = 'Validation_Loss', ascending = True)

# Create the bar plot using Seaborn
plt.figure(figsize = (20, 12))
sns.lineplot(x = 'Interaction_Pair', y = 'Validation_Loss', data = interaction_df, marker = 'o')
plt.axhline(main_val_loss, color = 'red', linestyle = '--', label = 'Validation Loss of Main Effect Model')
plt.xlabel('Interaction Effect Pairs')
plt.ylabel('Validation Loss')
plt.title('Validation Loss for Interaction Effect Pairs (Sorted by Increasing Loss)')
plt.legend()
plt.show()

# %%
# -------------------------- Create the Pairwise Only Model --------------------------
# pairwise_effect = ("X3", "X4")  # the pairwise effect we want to view
pairwise_effect = interactions[0]
pairwise_index = interactions.index(pairwise_effect)
subnet_output_layer = model_pairwise.get_layer("interaction_output")
subnet_model = Model(inputs = model_pairwise.inputs, outputs = subnet_output_layer.output)


# -------------------------- Generate the Input Grid --------------------------
# Create a grid of values
grid_length = 100
var1_values = np.linspace(X_train[interactions[pairwise_index][0]].min(), 
                          X_train[interactions[pairwise_index][0]].max(), 
                          grid_length)
var2_values = np.linspace(X_train[interactions[pairwise_index][1]].min(), 
                          X_train[interactions[pairwise_index][1]].max(), 
                          grid_length)

# Create a meshgrid
grid_var1, grid_var2 = np.meshgrid(var1_values, var2_values)

# Flatten the grid
grid_flat_var1 = grid_var1.ravel()
grid_flat_var2 = grid_var2.ravel()


# -------------------------- Prepare Inputs for the Model --------------------------
grid_inputs = []
for var in all_vars:
    if var == interactions[pairwise_index][0]:
        grid_inputs.append(grid_flat_var1)
    elif var == interactions[pairwise_index][1]:
        grid_inputs.append(grid_flat_var2)
    else:
        grid_inputs.append(np.zeros_like(grid_flat_var1))


# -------------------------- Predict Using the Pairwise-Only Model --------------------------
# Predict the pairwise interaction effect
pairwise_predictions = np.log(subnet_model.predict(grid_inputs))

# Reshape the predictions to the grid format
heatmap_values = pairwise_predictions.reshape(grid_var1.shape)


# -------------------------- Plot the Heatmap --------------------------
plt.figure(figsize = (10, 8))
contour = plt.contourf(grid_var1, grid_var2, heatmap_values, levels = 10)
plt.colorbar(contour)
plt.title('Predicted Function by the Model')
plt.xlabel(f"{interactions[pairwise_index][0]}")
plt.ylabel(f"{interactions[pairwise_index][1]}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[110], line 3
#       1 # -------------------------- Create the Pairwise Only Model --------------------------
#       2 # pairwise_effect = ("X3", "X4")  # the pairwise effect we want to view
# ----> 3 pairwise_effect = interactions[0]
#       4 pairwise_index = interactions.index(pairwise_effect)
#       5 subnet_output_layer = model_pairwise.get_layer("interaction_output")
#
# TypeError: 'itertools.combinations' object is not subscriptable

# %%
#-------------------------- view the shape function --------------------------
# get the prediction
main_output_layer = model_pairwise.get_layer("main_subnet")
subnet_model = Model(inputs = model_pairwise.inputs, outputs = main_output_layer.output)
subnet_output = subnet_model.predict(X_train_split)

# create the plot
var_name = "X3"
var_index = all_vars.index(var_name)
plt.figure(figsize = (12, 6))
sns.lineplot(x = X_train_split[var_index], 
             y = subnet_output[:,var_index])
plt.xlabel(f"{var_name}")
plt.ylabel('Subnetwork Output')
plt.title(f"Shape function for {var_name}")
plt.grid(True)
plt.show()
# Out:
# 372/372 [==============================] - 0s 795us/step
